# %%
# !pip install mlxtend
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn import svm
from mlxtend.plotting import plot_decision_regions
import numpy as np
# %matplotlib inline
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 32.2 MB/s
# Requirement already satisfied: setuptools in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (56.0.0)
# Requirement already satisfied: joblib>=0.13.2 in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: pandas>=0.24.2 in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (1.3.5)
# Requirement already satisfied: scipy>=1.2.1 in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: numpy>=1.16.2 in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in /opt/python/envs/default/lib/python3.8/site-packages (from mlxtend) (1.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (9.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (4.31.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/python/envs/default/lib/python3.8/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/python/envs/default/lib/python3.8/site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/python/envs/default/lib/python3.8/site-packages (from scikit-learn>=0.20.3->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/python/envs/default/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.19.0
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
eq = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/Sample%20Earthquake%20Data/oneyear.csv")

# %%
eq.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>latitude</th>
#       <th>longitude</th>
#       <th>depth</th>
#       <th>mag</th>
#       <th>nst</th>
#       <th>gap</th>
#       <th>dmin</th>
#       <th>rms</th>
#       <th>horizontalError</th>
#       <th>depthError</th>
#       <th>magError</th>
#       <th>magNst</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>0.0</td>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>1369.000000</td>
#       <td>1368.000000</td>
#       <td>1368.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>-1.117302</td>
#       <td>119.207969</td>
#       <td>102.069072</td>
#       <td>4.496275</td>
#       <td>NaN</td>
#       <td>100.971512</td>
#       <td>2.326909</td>
#       <td>0.852768</td>
#       <td>8.227684</td>
#       <td>6.678305</td>
#       <td>0.121450</td>
#       <td>30.986111</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>5.605702</td>
#       <td>10.028394</td>
#       <td>129.415379</td>
#       <td>0.377192</td>
#       <td>NaN</td>
#       <td>44.781584</td>
#       <td>2.286374</td>
#       <td>0.260124</td>
#       <td>2.622920</td>
#       <td>3.829167</td>
#       <td>0.050303</td>
#       <td>30.446167</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-11.762200</td>
#       <td>95.113500</td>
#       <td>4.000000</td>
#       <td>3.900000</td>
#       <td>NaN</td>
#       <td>13.000000</td>
#       <td>0.008000</td>
#       <td>0.130000</td>
#       <td>2.400000</td>
#       <td>0.600000</td>
#       <td>0.034000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>-7.026200</td>
#       <td>112.938000</td>
#       <td>24.610000</td>
#       <td>4.200000</td>
#       <td>NaN</td>
#       <td>71.000000</td>
#       <td>1.310000</td>
#       <td>0.670000</td>
#       <td>6.500000</td>
#       <td>3.600000</td>
#       <td>0.085000</td>
#       <td>13.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.268400</td>
#       <td>123.957300</td>
#       <td>53.860000</td>
#       <td>4.400000</td>
#       <td>NaN</td>
#       <td>95.000000</td>
#       <td>2.063000</td>
#       <td>0.830000</td>
#       <td>7.900000</td>
#       <td>7.000000</td>
#       <td>0.116000</td>
#       <td>20.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>3.541300</td>
#       <td>126.788100</td>
#       <td>121.110000</td>
#       <td>4.600000</td>
#       <td>NaN</td>
#       <td>128.000000</td>
#       <td>2.928000</td>
#       <td>1.030000</td>
#       <td>9.500000</td>
#       <td>8.900000</td>
#       <td>0.148000</td>
#       <td>37.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>9.268100</td>
#       <td>128.317100</td>
#       <td>621.700000</td>
#       <td>6.900000</td>
#       <td>NaN</td>
#       <td>324.000000</td>
#       <td>56.265000</td>
#       <td>1.640000</td>
#       <td>29.300000</td>
#       <td>33.700000</td>
#       <td>0.532000</td>
#       <td>269.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
eq.dropna(how='all',axis=1,inplace=True)

# %%
f= plt.subplots(figsize=(21,21))
sn.heatmap(eq.corr(),annot=True,fmt='.1f',color='green')
# Out:
# <AxesSubplot:>

# %%
X = eq[['latitude','longitude']]
Y = [0 if elem<4.5 else 1 for elem in eq.mag]

# %%
X = eq[['latitude','longitude']]
Y = [0 if elem<4.5 else 1 for elem in eq.mag]

# %%
clf = svm.SVC()

# %%
clf.fit(X,Y)
# Out:
# SVC()

# %%
plot_decision_regions(X=np.array(X), 
                      y=np.array(Y),
                      clf=clf, 
                      legend=2)

plt.xlabel(X.columns[0], size=14)
plt.ylabel(X.columns[1], size=14)
plt.title('SVM Decision Region Boundary', size=16)
# Out:
# /opt/python/envs/default/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /opt/python/envs/default/lib/python3.8/site-packages/mlxtend/plotting/decision_regions.py:243: UserWarning: No contour levels were found within the data range.
#   ax.contour(xx, yy, Z, cset.levels,
# Text(0.5, 1.0, 'SVM Decision Region Boundary')

# %%
clf.predict([[69,70]])
# Out:
# /opt/python/envs/default/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
