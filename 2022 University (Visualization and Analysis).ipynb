# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
univ = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/QS%20World%20University%20Rankings%202017-2022/QS%20World%20University%20Rankings%202022.csv")

# %%
univ.head()
# Out:
#    year rank_display                                    university  score  \
# 0  2022            1  Massachusetts Institute of Technology (MIT)   100.0
# 1  2022            2                          University of Oxford   99.5
# 2  2022           =3                           Stanford University   98.7
# 3  2022           =3                       University of Cambridge   98.7
# 4  2022            5                            Harvard University   98.0
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/u...  United Kingdom
# 2  https://www.topuniversities.com/universities/s...   United States
# 3  https://www.topuniversities.com/universities/u...  United Kingdom
# 4  https://www.topuniversities.com/universities/h...   United States
#
#         city         region                                               logo
# ...

# %%
univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          1300 non-null   int64
#  1   rank_display  1300 non-null   object
#  2   university    1300 non-null   object
#  3   score         501 non-null    float64
#  4   link          1300 non-null   object
#  5   country       1300 non-null   object
#  6   city          1251 non-null   object
#  7   region        1300 non-null   object
#  8   logo          1300 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 91.5+ KB

# %%
univ.head()
# Out:
#    year rank_display                                    university  score  \
# 0  2022            1  Massachusetts Institute of Technology (MIT)   100.0
# 1  2022            2                          University of Oxford   99.5
# 2  2022           =3                           Stanford University   98.7
# 3  2022           =3                       University of Cambridge   98.7
# 4  2022            5                            Harvard University   98.0
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/u...  United Kingdom
# 2  https://www.topuniversities.com/universities/s...   United States
# 3  https://www.topuniversities.com/universities/u...  United Kingdom
# 4  https://www.topuniversities.com/universities/h...   United States
#
#         city         region                                               logo
# ...

# %%
univ.head()
# Out:
#    year rank_display                                    university  score  \
# 0  2022            1  Massachusetts Institute of Technology (MIT)   100.0
# 1  2022            2                          University of Oxford   99.5
# 2  2022           =3                           Stanford University   98.7
# 3  2022           =3                       University of Cambridge   98.7
# 4  2022            5                            Harvard University   98.0
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/u...  United Kingdom
# 2  https://www.topuniversities.com/universities/s...   United States
# 3  https://www.topuniversities.com/universities/u...  United Kingdom
# 4  https://www.topuniversities.com/universities/h...   United States
#
#         city         region                                               logo
# ...

# %%
univ.describe().transpose()
# Out:
#         count         mean        std     min     25%     50%     75%     max
# year   1300.0  2022.000000   0.000000  2022.0  2022.0  2022.0  2022.0  2022.0
# score   501.0    44.767066  18.961269    24.1    29.6    38.6    55.4   100.0

# %%
sns.heatmap(univ.isna(),cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
univ[univ["city"].isna()]
# Out:
#       year rank_display                                         university  \
# 43    2022           44                                     Université PSL
# 71    2022           72                                Sorbonne University
# 86    2022          =86                            Université Paris-Saclay
# 212   2022          212  Ulsan National Institute of Science and Techno...
# 217   2022         =216                         Queen's University Belfast
# 264   2022         =264                               Kyung Hee University
# 268   2022         =268           National Yang Ming Chiao Tung University
# 276   2022         =275      Southern University of Science and Technology
# 325   2022         =322                                University of Macau
# 351   2022         =351                           Brunel University London
# 396   2022         =395     National Research Tomsk Polytechnic University
# ...

# %%
sns.barplot(x = 'rank_display', y = 'score',data = univ ,palette = "plasma")
# Out:
# <AxesSubplot:xlabel='rank_display', ylabel='score'>

# %%
sns.countplot(x='region', hue='region', data=univ, dodge=False )
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
plt.plot(univ['score'],univ['region'],'r.')
plt.xlabel('score')
plt.ylabel('region')
plt.title('University score per region')
plt.show()

# %%
univ[univ['region'] == 'North America'].score.max()
# Out:
# 100.0

# %%
univ[univ['region'] == 'North America'].head(1)
# Out:
#    year rank_display                                    university  score  \
# 0  2022            1  Massachusetts Institute of Technology (MIT)   100.0
#
#                                                 link        country  \
# 0  https://www.topuniversities.com/universities/m...  United States
#
#         city         region                                               logo
# 0  Cambridge  North America  https://www.topuniversities.com/sites/default/...

# %%
univ[univ['region'] == 'Europe'].score.max()
# Out:
# 99.5

# %%
univ[univ['region'] == 'Europe'].head(1)
# Out:
#    year rank_display            university  score  \
# 1  2022            2  University of Oxford   99.5
#
#                                                 link         country    city  \
# 1  https://www.topuniversities.com/universities/u...  United Kingdom  Oxford
#
#    region                                               logo
# 1  Europe  https://www.topuniversities.com/sites/default/...

# %%
univ[univ['region'] == 'Asia'].score.max()
# Out:
# 93.9
