# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-panda/blob/master/WhatsApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
WhatsApp = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/WhatsApp.csv")
 
WhatsApp
# Out:
#                            Category: All categories
# Region                WhatsApp: (8/16/19 - 8/16/20)
# New Jersey                                      100
# Florida                                          90
# District of Columbia                             89
# New York                                         79
# Texas                                            72
# Massachusetts                                    65
# California                                       65
# Maryland                                         61
# Virginia                                         57
# Connecticut                                      51
# Georgia                                          50
# Rhode Island                                     48
# Arizona                                          48
# Nevada                                           45
# Washington                                       45
# Illinois                                         45
# ...

# %%
WhatsApp.head()
# Out:
#                            Category: All categories
# Region                WhatsApp: (8/16/19 - 8/16/20)
# New Jersey                                      100
# Florida                                          90
# District of Columbia                             89
# New York                                         79

# %%
WhatsApp.tail()
# Out:
#               Category: All categories
# Maine                               24
# Montana                             24
# South Dakota                        21
# West Virginia                       21
# North Dakota                        19

# %%
WhatsApp.describe
# Out:
# <bound method NDFrame.describe of                            Category: All categories
# Region                WhatsApp: (8/16/19 - 8/16/20)
# New Jersey                                      100
# Florida                                          90
# District of Columbia                             89
# New York                                         79
# Texas                                            72
# Massachusetts                                    65
# California                                       65
# Maryland                                         61
# Virginia                                         57
# Connecticut                                      51
# Georgia                                          50
# Rhode Island                                     48
# Arizona                                          48
# Nevada                                           45
# Washington                                       45
# ...

# %%
WhatsApp.describe()
# Out:
#        Category: All categories
# count                        52
# unique                       31
# top                          26
# freq                          6

# %%
import sqlite3

# %%
conn = sqlite3.connect("WhatsApp.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("WhatsApp.db")
c = conn.cursor()

# %%
WhatsApp.to_sql("WhatsApp", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM WhatsApp""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'WhatsApp: (8/16/19 - 8/16/20)'),
#  ('New Jersey', '100'),
#  ('Florida', '90'),
#  ('District of Columbia', '89'),
#  ('New York', '79'),
#  ('Texas', '72'),
#  ('Massachusetts', '65'),
#  ('California', '65'),
#  ('Maryland', '61'),
#  ('Virginia', '57'),
#  ('Connecticut', '51'),
#  ('Georgia', '50'),
#  ('Rhode Island', '48'),
#  ('Arizona', '48'),
#  ('Nevada', '45'),
#  ('Washington', '45'),
#  ('Illinois', '45'),
#  ('Delaware', '43'),
#  ('North Carolina', '40'),
#  ('Michigan', '39'),
#  ('Colorado', '39'),
#  ('Oregon', '38'),
#  ('Pennsylvania', '37'),
#  ('Kansas', '34'),
#  ('New Mexico', '34'),
#  ('Minnesota', '33'),
#  ('Utah', '32'),
#  ('South Carolina', '32'),
#  ('Hawaii', '32'),
#  ('Louisiana', '31'),
#  ('New Hampshire', '30'),
#  ('Tennessee', '30'),
#  ('Indiana', '30'),
#  ('Ohio', '29'),
#  ('Arkansas', '29'),
#  ('Oklahoma', '28'),
#  ('Iowa', '28'),
#  ('Missouri', '27'),
#  ('Kentucky', '27'),
#  ('Wisconsin', '27'),
#  ('Nebraska', '26'),
# ...

# %%
WhatsApp.to_excel("WhatsApp.xls")

pd.read_excel("WhatsApp.xls")
# Out:
#               Unnamed: 0       Category: All categories
# 0                 Region  WhatsApp: (8/16/19 - 8/16/20)
# 1             New Jersey                            100
# 2                Florida                             90
# 3   District of Columbia                             89
# 4               New York                             79
# 5                  Texas                             72
# 6          Massachusetts                             65
# 7             California                             65
# 8               Maryland                             61
# 9               Virginia                             57
# 10           Connecticut                             51
# 11               Georgia                             50
# 12          Rhode Island                             48
# 13               Arizona                             48
# 14                Nevada                             45
# 15            Washington                             45
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('WhatsApp', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('WhatsApp')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
