# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
PARTY = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/PartyStandings.csv")
PARTY
# Out:
#          Province / Territory Political Affiliation  Seats
# 0                     Alberta          Conservative     33
# 1                     Alberta                   NDP      1
# 2            British Columbia               Liberal     11
# 3            British Columbia          Conservative     17
# 4            British Columbia                   NDP     11
# 5            British Columbia           Green Party      2
# 6            British Columbia           Independent      1
# 7                    Manitoba               Liberal      4
# 8                    Manitoba          Conservative      7
# 9                    Manitoba                   NDP      3
# 10              New Brunswick               Liberal      6
# 11              New Brunswick          Conservative      3
# 12              New Brunswick           Green Party      1
# 13  Newfoundland and Labrador               Liberal      6
# 14  Newfoundland and Labrador                   NDP      1
# ...

# %%
PARTY.head()
# Out:
#   Province / Territory Political Affiliation  Seats
# 0              Alberta          Conservative     33
# 1              Alberta                   NDP      1
# 2     British Columbia               Liberal     11
# 3     British Columbia          Conservative     17
# 4     British Columbia                   NDP     11

# %%
PARTY.tail()
# Out:
#    Province / Territory Political Affiliation  Seats
# 26               Quebec        Bloc Québécois     32
# 27               Quebec                   NDP      1
# 28         Saskatchewan          Conservative     14
# 29                Yukon               Liberal      1
# 30              Ontario                Vacant      2

# %%
PARTY.describe()
# Out:
#            Seats
# count  31.000000
# mean   10.903226
# std    16.203610
# min     1.000000
# 25%     1.000000
# 50%     4.000000
# 75%    11.000000
# max    76.000000

# %%
import sqlite3

# %%
conn = sqlite3.connect("PARTY.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("PARTY.db")
c = conn.cursor()

# %%
PARTY.to_sql("PARTY", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM PARTY""")
rows = c.fetchall()
rows
# Out:
# [(0, 'Alberta', 'Conservative', 33),
#  (1, 'Alberta', 'NDP', 1),
#  (2, 'British Columbia', 'Liberal', 11),
#  (3, 'British Columbia', 'Conservative', 17),
#  (4, 'British Columbia', 'NDP', 11),
#  (5, 'British Columbia', 'Green Party', 2),
#  (6, 'British Columbia', 'Independent', 1),
#  (7, 'Manitoba', 'Liberal', 4),
#  (8, 'Manitoba', 'Conservative', 7),
#  (9, 'Manitoba', 'NDP', 3),
#  (10, 'New Brunswick', 'Liberal', 6),
#  (11, 'New Brunswick', 'Conservative', 3),
#  (12, 'New Brunswick', 'Green Party', 1),
#  (13, 'Newfoundland and Labrador', 'Liberal', 6),
#  (14, 'Newfoundland and Labrador', 'NDP', 1),
#  (15, 'Northwest Territories', 'Liberal', 1),
#  (16, 'Nova Scotia', 'Liberal', 10),
#  (17, 'Nova Scotia', 'Conservative', 1),
#  (18, 'Nunavut', 'NDP', 1),
#  (19, 'Ontario', 'Liberal', 76),
#  (20, 'Ontario', 'Conservative', 36),
#  (21, 'Ontario', 'NDP', 6),
#  (22, 'Ontario', 'Independent', 1),
#  (23, 'Prince Edward Island', 'Liberal', 4),
# ...

# %%
PARTY.to_excel("PARTY.xls")

pd.read_excel("PARTY.xls")
# Out:
#     Unnamed: 0       Province / Territory Political Affiliation  Seats
# 0            0                    Alberta          Conservative     33
# 1            1                    Alberta                   NDP      1
# 2            2           British Columbia               Liberal     11
# 3            3           British Columbia          Conservative     17
# 4            4           British Columbia                   NDP     11
# 5            5           British Columbia           Green Party      2
# 6            6           British Columbia           Independent      1
# 7            7                   Manitoba               Liberal      4
# 8            8                   Manitoba          Conservative      7
# 9            9                   Manitoba                   NDP      3
# 10          10              New Brunswick               Liberal      6
# 11          11              New Brunswick          Conservative      3
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('PARTY STANDINGS IN THE HOUSE OF COMMONS', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('PARTY STANDINGS IN THE HOUSE OF COMMONS')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
