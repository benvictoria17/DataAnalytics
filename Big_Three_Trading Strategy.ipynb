# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")


import yfinance as yf

# %%
# input
symbol = 'AAPL'
start = '2014-01-01'
end = '2018-12-31'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-01-02  79.382858  79.575714  78.860001  79.018570  70.620010   58671200
# 2014-01-03  78.980003  79.099998  77.204285  77.282860  69.068787   98116900
# 2014-01-06  76.778572  78.114288  76.228569  77.704285  69.445427  103152700
# 2014-01-07  77.760002  77.994286  76.845711  77.148575  68.948753   79302300
# 2014-01-08  76.972855  77.937141  76.955711  77.637146  69.385429   64632400

# %%
df['SMA_20'] = df['Adj Close'].rolling(20).mean()
df['SMA_40'] = df['Adj Close'].rolling(40).mean()
df['SMA_80'] = df['Adj Close'].rolling(80).mean()

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-21  156.860001  158.160004  149.630005  150.729996  147.481339
# 2018-12-24  148.149994  151.550003  146.589996  146.830002  143.665421
# 2018-12-26  148.300003  157.229996  146.720001  157.169998  153.782547
# 2018-12-27  155.839996  156.770004  150.070007  156.149994  152.784531
# 2018-12-28  157.500000  158.520004  154.550003  156.229996  152.862808
#
#               Volume      SMA_20      SMA_40      SMA_80
# Date
# 2018-12-21  95744600  166.686310  181.893323  199.347182
# 2018-12-24  37169200  165.440748  180.127085  198.425305
# 2018-12-26  58582500  164.587053  178.699092  197.604906
# 2018-12-27  53117100  163.702047  177.345116  196.740344
# 2018-12-28  42291400  162.493175  175.967258  195.867863

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(df.index, df['Adj Close'], label='Price')
ax.plot(df.index, df['SMA_20'], label = '20-days SMA')
ax.plot(df.index, df['SMA_40'], label = '40-days SMA')
ax.plot(df.index, df['SMA_80'], label = '80-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price')
ax.set_title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
new_dates = df['2017-01-01':'2018-12-31']
new_dates.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  115.800003  116.330002  114.760002  116.150002  110.193657
# 2017-01-04  115.849998  116.510002  115.750000  116.019997  110.070328
# 2017-01-05  115.919998  116.860001  115.809998  116.610001  110.630081
# 2017-01-06  116.779999  118.160004  116.470001  117.910004  111.863426
# 2017-01-09  117.949997  119.430000  117.940002  118.989998  112.888023
#
#               Volume      SMA_20      SMA_40      SMA_80
# Date
# 2017-01-03  28781900  108.998753  106.672256  107.081219
# 2017-01-04  21118100  109.326535  106.842551  107.240328
# 2017-01-05  22193600  109.642459  106.989603  107.379180
# 2017-01-06  31751900  109.968819  107.152072  107.503835
# 2017-01-09  33561900  110.294704  107.344424  107.596227

# %%
plt.figure(figsize=(16,10))
plt.plot(new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], fmt='r-', label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA', color='b')
plt.plot(new_dates['SMA_40'], label = '40-days SMA', color='y')
plt.plot(new_dates['SMA_80'], label = '80-days SMA', color='green')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Date')
plt.title('Big Three Trading Strategy')
# Out:
# Text(0.5, 1.0, 'Big Three Trading Strategy')
