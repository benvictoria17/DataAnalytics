# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import sqlite3

# %%
data = pd.read_csv('https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/Google%20Play%20Store%20Apps/googleplaystore_user_reviews.csv')
data
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]

# %%
data.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
data.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
data.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
conn = sqlite3.connect("data.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("data.db")
c = conn.cursor()

# %%
data.to_sql("data", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM data""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   '10 Best Foods for You',
#   'I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#   'Positive',
#   1.0,
#   0.5333333333333333),
#  (1,
#   '10 Best Foods for You',
#   'This help eating healthy exercise regular basis',
#   'Positive',
#   0.25,
#   0.28846153846153844),
#  (2, '10 Best Foods for You', None, None, None, None),
#  (3,
#   '10 Best Foods for You',
#   'Works great especially going grocery store',
#   'Positive',
#   0.4,
#   0.875),
#  (4, '10 Best Foods for You', 'Best idea us', 'Positive', 1.0, 0.3),
#  (5, '10 Best Foods for You', 'Best way', 'Positive', 1.0, 0.3),
#  (6, '10 Best Foods for You', 'Amazing', 'Positive', 0.6000000000000001, 0.9),
#  (7, '10 Best Foods for You', None, None, None, None),
#  (8, '10 Best Foods for You', 'Looking forward app,', 'Neutral', 0.0, 0.0),
#  (9,
#   '10 Best Foods for You',
#   'It helpful site ! It help foods get !',
#   'Neutral',
#   0.0,
#   0.0),
#  (10,
#   '10 Best Foods for You',
#   'good you.',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (11,
#   '10 Best Foods for You',
#   'Useful information The amount spelling errors questions validity information shared. Once fixed, 5 stars given.',
#   'Positive',
#   0.2,
#   0.1),
#  (12,
#   '10 Best Foods for You',
#   'Thank you! Great app!! Add arthritis, eyes, immunity, kidney/liver detox foods please. :)',
#   'Positive',
#   0.75,
#   0.875),
#  (13,
#   '10 Best Foods for You',
#   'Greatest ever Completely awesome maintain health.... This must ppl there... Love it!!!',
#   'Positive',
#   0.9921875,
#   0.8666666666666667),
#  (14,
#   '10 Best Foods for You',
#   'Good health...... Good health first priority.......',
#   'Positive',
#   0.5499999999999999,
#   0.5111111111111112),
#  (15, '10 Best Foods for You', None, None, None, None),
#  (16,
#   '10 Best Foods for You',
#   "Health It's important world either life . think? :)",
#   'Positive',
#   0.45,
#   1.0),
#  (17,
#   '10 Best Foods for You',
#   'Mrs sunita bhati I thankful developers,to make kind app, really good healthy food body',
#   'Positive',
#   0.6,
#   0.6666666666666666),
#  (18,
#   '10 Best Foods for You',
#   'Very Useful in diabetes age 30. I need control sugar. thanks',
#   'Positive',
#   0.29500000000000004,
#   0.1),
#  (19, '10 Best Foods for You', 'One greatest apps.', 'Positive', 1.0, 1.0),
#  (20,
#   '10 Best Foods for You',
#   'good nice',
#   'Positive',
#   0.6499999999999999,
#   0.8),
#  (21,
#   '10 Best Foods for You',
#   'Healthy Really helped',
#   'Positive',
#   0.35,
#   0.35),
#  (22, '10 Best Foods for You', 'God health', 'Neutral', 0.0, 0.0),
#  (23,
#   '10 Best Foods for You',
#   'HEALTH SHOULD ALWAYS BE TOP PRIORITY. !!. ON MYSG5.',
#   'Positive',
#   0.78125,
#   0.5),
#  (24, '10 Best Foods for You', 'An excellent A useful', 'Positive', 0.65, 0.5),
#  (25,
#   '10 Best Foods for You',
#   'I found lot wealth form health...',
#   'Neutral',
#   0.0,
#   0.0),
#  (26,
#   '10 Best Foods for You',
#   'Because I found important.',
#   'Positive',
#   0.4,
#   1.0),
#  (27, '10 Best Foods for You', 'Healthy Eating', 'Positive', 0.5, 0.5),
#  (28,
#   '10 Best Foods for You',
#   'Very good Simply good',
#   'Positive',
#   0.8049999999999999,
#   0.6900000000000002),
#  (29, '10 Best Foods for You', 'On test....', 'Neutral', 0.0, 0.0),
#  (30, '10 Best Foods for You', 'Good.!!', 'Positive', 1.0, 0.6000000000000001),
#  (31,
#   '10 Best Foods for You',
#   "Thanks advice. Downloaded Adobe reader still can't get recipe book?..",
#   'Positive',
#   0.2,
#   0.2),
#  (32,
#   '10 Best Foods for You',
#   'No recipe book Unable recipe book.',
#   'Negative',
#   -0.5,
#   0.5),
#  (33,
#   '10 Best Foods for You',
#   'Absolutely Fabulous Phenomenal',
#   'Positive',
#   0.45,
#   0.75),
#  (34, '10 Best Foods for You', 'Great Love food', 'Positive', 0.65, 0.675),
#  (35,
#   '10 Best Foods for You',
#   'Excellent It really works',
#   'Positive',
#   0.6,
#   0.6),
#  (36, '10 Best Foods for You', 'Best', 'Positive', 1.0, 0.3),
#  (37,
#   '10 Best Foods for You',
#   'WEALTH OF INFORMATION Very informative ... easy understand. (The ads middle page interupted read). Update: My "ad comment" NOT objection ads, literally position ads. Smack dab MIDDLE. I new spartphones & apps. Didnt know NOT Click eveything I saw... But, ... Full Review',
#   'Positive',
#   0.1866161616161616,
#   0.3563131313131313),
#  (38,
#   '10 Best Foods for You',
#   'Not description good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (39, '10 Best Foods for You', 'Great app. Love', 'Positive', 0.65, 0.675),
#  (40, '10 Best Foods for You', 'Good', 'Positive', 0.7, 0.6000000000000001),
#  (41, '10 Best Foods for You', 'Loved Very helpful', 'Positive', 0.45, 0.55),
#  (42, '10 Best Foods for You', 'Good healthy foods.', 'Positive', 0.6, 0.55),
#  (43,
#   '10 Best Foods for You',
#   'Waste time It needs internet time n ask calls information',
#   'Negative',
#   -0.2,
#   0.0),
#  (44,
#   '10 Best Foods for You',
#   'Best thing I lost ten lbs. two months help tips',
#   'Positive',
#   0.5,
#   0.15),
#  (45,
#   '10 Best Foods for You',
#   'Ten best food promote good health Good health essential long healthy lifestyle make habit eat foods promote good health. Eat fruits veggies every day.',
#   'Positive',
#   0.44375,
#   0.4125),
#  (46,
#   '10 Best Foods for You',
#   'Healthy Food Really good information eat healthy',
#   'Positive',
#   0.5666666666666667,
#   0.5333333333333333),
#  (47,
#   '10 Best Foods for You',
#   'My mom dad important thing This good share',
#   'Positive',
#   0.55,
#   0.8),
#  (48,
#   '10 Best Foods for You',
#   'A big thanks ds I got bst gd health',
#   'Positive',
#   0.1,
#   0.15000000000000002),
#  (49,
#   '10 Best Foods for You',
#   'Lovely Best everyone needs',
#   'Positive',
#   0.75,
#   0.525),
#  (50,
#   '10 Best Foods for You',
#   'Love It I lost 6Pounds far 215 209',
#   'Positive',
#   0.3,
#   0.8),
#  (51, '10 Best Foods for You', 'I like', 'Neutral', 0.0, 0.0),
#  (52, '10 Best Foods for You', 'Thanks helpful app.', 'Positive', 0.2, 0.2),
#  (53,
#   '10 Best Foods for You',
#   'good food really good eat',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (54, '10 Best Foods for You', 'Thanks Thank u much', 'Positive', 0.2, 0.2),
#  (55,
#   '10 Best Foods for You',
#   'Love This really good',
#   'Positive',
#   0.6,
#   0.6000000000000001),
#  (56, '10 Best Foods for You', 'This helpful', 'Neutral', 0.0, 0.0),
#  (57, '10 Best Foods for You', 'I love', 'Positive', 0.5, 0.6),
#  (58, '10 Best Foods for You', 'Very useful', 'Positive', 0.39, 0.0),
#  (59, '10 Best Foods for You', 'Great Love', 'Positive', 0.65, 0.675),
#  (60, '10 Best Foods for You', 'Very informative', 'Positive', 0.2, 0.3),
#  (61, '10 Best Foods for You', 'Luv', 'Neutral', 0.0, 0.0),
#  (62, '10 Best Foods for You', 'great', 'Positive', 0.8, 0.75),
#  (63, '10 Best Foods for You', 'Wonderful', 'Positive', 1.0, 1.0),
#  (64, '10 Best Foods for You', "Doesn't work... Zero", 'Neutral', 0.0, 0.0),
#  (65,
#   '10 Best Foods for You',
#   'Weight loss Not bad',
#   'Positive',
#   0.3499999999999999,
#   0.6666666666666666),
#  (66,
#   '10 Best Foods for You',
#   '10 best foods 4u Excellent chose foods',
#   'Positive',
#   1.0,
#   0.65),
#  (67, '10 Best Foods for You', 'This needed most.', 'Positive', 0.5, 0.5),
#  (68,
#   '10 Best Foods for You',
#   'Faltu plz waste ur time',
#   'Negative',
#   -0.2,
#   0.0),
#  (69,
#   '10 Best Foods for You',
#   'Best food Thank you recipe book',
#   'Positive',
#   1.0,
#   0.3),
#  (70,
#   '10 Best Foods for You',
#   'I Love Good',
#   'Positive',
#   0.6,
#   0.6000000000000001),
#  (71, '10 Best Foods for You', 'I like Superb', 'Positive', 1.0, 1.0),
#  (72,
#   '10 Best Foods for You',
#   'Good V good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (73, '10 Best Foods for You', 'Healthy', 'Positive', 0.5, 0.5),
#  (74,
#   '10 Best Foods for You',
#   'Quick Read.',
#   'Positive',
#   0.3333333333333333,
#   0.5),
#  (75, '10 Best Foods for You', 'Great ideas', 'Positive', 0.8, 0.75),
#  (76,
#   '10 Best Foods for You',
#   'Too good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (77, '10 Best Foods for You', 'Cool.', 'Positive', 0.35, 0.65),
#  (78, '10 Best Foods for You', 'Good', 'Positive', 0.7, 0.6000000000000001),
#  (79, '10 Best Foods for You', 'Good', 'Positive', 0.7, 0.6000000000000001),
#  (80, '10 Best Foods for You', 'Best Best', 'Positive', 1.0, 0.3),
#  (81, '10 Best Foods for You', 'Great Great', 'Positive', 0.8, 0.75),
#  (82,
#   '10 Best Foods for You',
#   'Food list easy I predibetic, I scared. All Dr. said potatoes, rice, bread. He never told I could eat. I supplied paperwork stating things could happen me. This tells get works. Thank calming down.AWESOME APP. GET IT!!!!',
#   'Positive',
#   1.0,
#   0.8333333333333334),
#  (83,
#   '10 Best Foods for You',
#   "Great wife. My wife enjoy much. She's kinda person like follow health diet... She's spending much time front PC find appropriate diet food her. Now found magnificent app! Thank you! Thumbs up.",
#   'Positive',
#   0.5166666666666667,
#   0.525),
#  (84,
#   '10 Best Foods for You',
#   'Great! Very interesting useful application. I like it!',
#   'Positive',
#   0.6749999999999999,
#   0.4666666666666666),
#  (85, '10 Best Foods for You', "Crap Doesn't work", 'Negative', -0.8, 0.8),
#  (86, '10 Best Foods for You', 'This 5 starr Download', 'Neutral', 0.0, 0.0),
#  (87, '10 Best Foods for You', 'I like Was helpful', 'Neutral', 0.0, 0.0),
#  (88,
#   '10 Best Foods for You',
#   'nice super get',
#   'Positive',
#   0.4666666666666667,
#   0.8333333333333333),
#  (89, '10 Best Foods for You', 'Nice Nice collection', 'Positive', 0.6, 1.0),
#  (90, '10 Best Foods for You', 'Wow', 'Positive', 0.1, 1.0),
#  (91,
#   '10 Best Foods for You',
#   "Interesting. It interesting info, I think worth storage space phone. I'd rather research computer print list. Neat idea, make life easier, provide entertainment, I expect app.",
#   'Positive',
#   0.43333333333333335,
#   0.3666666666666667),
#  (92,
#   '10 Best Foods for You',
#   'Luv it! Simple, easy understand, well thought I follow step step problems see results. I also luv apps, gives food choices. But looks like foundation. Keep good work!',
#   'Positive',
#   0.4361111111111111,
#   0.5968253968253968),
#  (93,
#   '10 Best Foods for You',
#   "Not good Its good u net connection u can't play app.so much good.",
#   'Positive',
#   0.2625,
#   0.4500000000000001),
#  (94,
#   '10 Best Foods for You',
#   "Awesome resources I begin new journey. I can't see great results!",
#   'Positive',
#   0.712121212121212,
#   0.7348484848484849),
#  (95,
#   '10 Best Foods for You',
#   "Boring. I thought actually just texts that's it. Too poor old texts....",
#   'Negative',
#   -0.325,
#   0.475),
#  (96,
#   '10 Best Foods for You',
#   'Love app. It gives way good idea I buying store eating daily basis',
#   'Positive',
#   0.4,
#   0.4000000000000001),
#  (97,
#   '10 Best Foods for You',
#   'Great Its really best unique provides detailed information food nutritious staying healthy hats developer giving free.',
#   'Positive',
#   0.5791666666666666,
#   0.6833333333333332),
#  (98,
#   '10 Best Foods for You',
#   'Nothing special! Could find anything useful!',
#   'Positive',
#   0.4107142857142857,
#   0.2857142857142857),
#  (99,
#   '10 Best Foods for You',
#   'Its ok I love ok.',
#   'Positive',
#   0.5,
#   0.5333333333333333),
#  (100,
#   '10 Best Foods for You',
#   'I like eat delicious food. That\'s I\'m cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"',
#   'Positive',
#   1.0,
#   0.5333333333333333),
#  (101,
#   '10 Best Foods for You',
#   'This help eating healthy exercise regular basis',
#   'Positive',
#   0.25,
#   0.28846153846153844),
#  (102, '10 Best Foods for You', None, None, None, None),
#  (103,
#   '10 Best Foods for You',
#   'Works great especially going grocery store',
#   'Positive',
#   0.4,
#   0.875),
#  (104, '10 Best Foods for You', 'Best idea us', 'Positive', 1.0, 0.3),
#  (105, '10 Best Foods for You', 'Best way', 'Positive', 1.0, 0.3),
#  (106,
#   '10 Best Foods for You',
#   'Amazing',
#   'Positive',
#   0.6000000000000001,
#   0.9),
#  (107, '10 Best Foods for You', None, None, None, None),
#  (108, '10 Best Foods for You', 'Looking forward app,', 'Neutral', 0.0, 0.0),
#  (109,
#   '10 Best Foods for You',
#   'It helpful site ! It help foods get !',
#   'Neutral',
#   0.0,
#   0.0),
#  (110,
#   '10 Best Foods for You',
#   'good you.',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (111,
#   '10 Best Foods for You',
#   'Useful information The amount spelling errors questions validity information shared. Once fixed, 5 stars given.',
#   'Positive',
#   0.2,
#   0.1),
#  (112,
#   '10 Best Foods for You',
#   'Thank you! Great app!! Add arthritis, eyes, immunity, kidney/liver detox foods please. :)',
#   'Positive',
#   0.75,
#   0.875),
#  (113,
#   '10 Best Foods for You',
#   'Greatest ever Completely awesome maintain health.... This must ppl there... Love it!!!',
#   'Positive',
#   0.9921875,
#   0.8666666666666667),
#  (114,
#   '10 Best Foods for You',
#   'Good health...... Good health first priority.......',
#   'Positive',
#   0.5499999999999999,
#   0.5111111111111112),
#  (115, '10 Best Foods for You', None, None, None, None),
#  (116,
#   '10 Best Foods for You',
#   "Health It's important world either life . think? :)",
#   'Positive',
#   0.45,
#   1.0),
#  (117,
#   '10 Best Foods for You',
#   'Mrs sunita bhati I thankful developers,to make kind app, really good healthy food body',
#   'Positive',
#   0.6,
#   0.6666666666666666),
#  (118,
#   '10 Best Foods for You',
#   'Very Useful in diabetes age 30. I need control sugar. thanks',
#   'Positive',
#   0.29500000000000004,
#   0.1),
#  (119, '10 Best Foods for You', 'One greatest apps.', 'Positive', 1.0, 1.0),
#  (120,
#   '10 Best Foods for You',
#   'good nice',
#   'Positive',
#   0.6499999999999999,
#   0.8),
#  (121,
#   '10 Best Foods for You',
#   'Healthy Really helped',
#   'Positive',
#   0.35,
#   0.35),
#  (122, '10 Best Foods for You', 'God health', 'Neutral', 0.0, 0.0),
#  (123,
#   '10 Best Foods for You',
#   'HEALTH SHOULD ALWAYS BE TOP PRIORITY. !!. ON MYSG5.',
#   'Positive',
#   0.78125,
#   0.5),
#  (124,
#   '10 Best Foods for You',
#   'An excellent A useful',
#   'Positive',
#   0.65,
#   0.5),
#  (125,
#   '10 Best Foods for You',
#   'I found lot wealth form health...',
#   'Neutral',
#   0.0,
#   0.0),
#  (126,
#   '10 Best Foods for You',
#   'Because I found important.',
#   'Positive',
#   0.4,
#   1.0),
#  (127, '10 Best Foods for You', 'Healthy Eating', 'Positive', 0.5, 0.5),
#  (128,
#   '10 Best Foods for You',
#   'Very good Simply good',
#   'Positive',
#   0.8049999999999999,
#   0.6900000000000002),
#  (129, '10 Best Foods for You', 'On test....', 'Neutral', 0.0, 0.0),
#  (130,
#   '10 Best Foods for You',
#   'Good.!!',
#   'Positive',
#   1.0,
#   0.6000000000000001),
#  (131,
#   '10 Best Foods for You',
#   "Thanks advice. Downloaded Adobe reader still can't get recipe book?..",
#   'Positive',
#   0.2,
#   0.2),
#  (132,
#   '10 Best Foods for You',
#   'No recipe book Unable recipe book.',
#   'Negative',
#   -0.5,
#   0.5),
#  (133,
#   '10 Best Foods for You',
#   'Absolutely Fabulous Phenomenal',
#   'Positive',
#   0.45,
#   0.75),
#  (134, '10 Best Foods for You', 'Great Love food', 'Positive', 0.65, 0.675),
#  (135,
#   '10 Best Foods for You',
#   'Excellent It really works',
#   'Positive',
#   0.6,
#   0.6),
#  (136, '10 Best Foods for You', 'Best', 'Positive', 1.0, 0.3),
#  (137,
#   '10 Best Foods for You',
#   'WEALTH OF INFORMATION Very informative ... easy understand. (The ads middle page interupted read). Update: My "ad comment" NOT objection ads, literally position ads. Smack dab MIDDLE. I new spartphones & apps. Didnt know NOT Click eveything I saw... But, ... Full Review',
#   'Positive',
#   0.1866161616161616,
#   0.3563131313131313),
#  (138,
#   '10 Best Foods for You',
#   'Not description good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (139, '10 Best Foods for You', 'Great app. Love', 'Positive', 0.65, 0.675),
#  (140, '10 Best Foods for You', 'Good', 'Positive', 0.7, 0.6000000000000001),
#  (141, '10 Best Foods for You', 'Loved Very helpful', 'Positive', 0.45, 0.55),
#  (142, '10 Best Foods for You', 'Good healthy foods.', 'Positive', 0.6, 0.55),
#  (143,
#   '10 Best Foods for You',
#   'Waste time It needs internet time n ask calls information',
#   'Negative',
#   -0.2,
#   0.0),
#  (144,
#   '10 Best Foods for You',
#   'Best thing I lost ten lbs. two months help tips',
#   'Positive',
#   0.5,
#   0.15),
#  (145,
#   '10 Best Foods for You',
#   'Ten best food promote good health Good health essential long healthy lifestyle make habit eat foods promote good health. Eat fruits veggies every day.',
#   'Positive',
#   0.44375,
#   0.4125),
#  (146,
#   '10 Best Foods for You',
#   'Healthy Food Really good information eat healthy',
#   'Positive',
#   0.5666666666666667,
#   0.5333333333333333),
#  (147,
#   '10 Best Foods for You',
#   'My mom dad important thing This good share',
#   'Positive',
#   0.55,
#   0.8),
#  (148,
#   '10 Best Foods for You',
#   'A big thanks ds I got bst gd health',
#   'Positive',
#   0.1,
#   0.15000000000000002),
#  (149,
#   '10 Best Foods for You',
#   'Lovely Best everyone needs',
#   'Positive',
#   0.75,
#   0.525),
#  (150,
#   '10 Best Foods for You',
#   'Love It I lost 6Pounds far 215 209',
#   'Positive',
#   0.3,
#   0.8),
#  (151, '10 Best Foods for You', 'I like', 'Neutral', 0.0, 0.0),
#  (152, '10 Best Foods for You', 'Thanks helpful app.', 'Positive', 0.2, 0.2),
#  (153,
#   '10 Best Foods for You',
#   'good food really good eat',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (154, '10 Best Foods for You', 'Thanks Thank u much', 'Positive', 0.2, 0.2),
#  (155,
#   '10 Best Foods for You',
#   'Love This really good',
#   'Positive',
#   0.6,
#   0.6000000000000001),
#  (156, '10 Best Foods for You', 'This helpful', 'Neutral', 0.0, 0.0),
#  (157, '10 Best Foods for You', 'I love', 'Positive', 0.5, 0.6),
#  (158, '10 Best Foods for You', 'Very useful', 'Positive', 0.39, 0.0),
#  (159, '10 Best Foods for You', 'Great Love', 'Positive', 0.65, 0.675),
#  (160, '10 Best Foods for You', 'Very informative', 'Positive', 0.2, 0.3),
#  (161, '10 Best Foods for You', 'Luv', 'Neutral', 0.0, 0.0),
#  (162, '10 Best Foods for You', 'great', 'Positive', 0.8, 0.75),
#  (163, '10 Best Foods for You', 'Wonderful', 'Positive', 1.0, 1.0),
#  (164, '10 Best Foods for You', "Doesn't work... Zero", 'Neutral', 0.0, 0.0),
#  (165,
#   '10 Best Foods for You',
#   'Weight loss Not bad',
#   'Positive',
#   0.3499999999999999,
#   0.6666666666666666),
#  (166,
#   '10 Best Foods for You',
#   '10 best foods 4u Excellent chose foods',
#   'Positive',
#   1.0,
#   0.65),
#  (167, '10 Best Foods for You', 'This needed most.', 'Positive', 0.5, 0.5),
#  (168,
#   '10 Best Foods for You',
#   'Faltu plz waste ur time',
#   'Negative',
#   -0.2,
#   0.0),
#  (169,
#   '10 Best Foods for You',
#   'Best food Thank you recipe book',
#   'Positive',
#   1.0,
#   0.3),
#  (170,
#   '10 Best Foods for You',
#   'I Love Good',
#   'Positive',
#   0.6,
#   0.6000000000000001),
#  (171, '10 Best Foods for You', 'I like Superb', 'Positive', 1.0, 1.0),
#  (172,
#   '10 Best Foods for You',
#   'Good V good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (173, '10 Best Foods for You', 'Healthy', 'Positive', 0.5, 0.5),
#  (174,
#   '10 Best Foods for You',
#   'Quick Read.',
#   'Positive',
#   0.3333333333333333,
#   0.5),
#  (175, '10 Best Foods for You', 'Great ideas', 'Positive', 0.8, 0.75),
#  (176,
#   '10 Best Foods for You',
#   'Too good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (177, '10 Best Foods for You', 'Cool.', 'Positive', 0.35, 0.65),
#  (178, '10 Best Foods for You', 'Good', 'Positive', 0.7, 0.6000000000000001),
#  (179, '10 Best Foods for You', 'Good', 'Positive', 0.7, 0.6000000000000001),
#  (180, '10 Best Foods for You', 'Best Best', 'Positive', 1.0, 0.3),
#  (181, '10 Best Foods for You', 'Great Great', 'Positive', 0.8, 0.75),
#  (182,
#   '10 Best Foods for You',
#   'Food list easy I predibetic, I scared. All Dr. said potatoes, rice, bread. He never told I could eat. I supplied paperwork stating things could happen me. This tells get works. Thank calming down.AWESOME APP. GET IT!!!!',
#   'Positive',
#   1.0,
#   0.8333333333333334),
#  (183,
#   '10 Best Foods for You',
#   "Great wife. My wife enjoy much. She's kinda person like follow health diet... She's spending much time front PC find appropriate diet food her. Now found magnificent app! Thank you! Thumbs up.",
#   'Positive',
#   0.5166666666666667,
#   0.525),
#  (184,
#   '10 Best Foods for You',
#   'Great! Very interesting useful application. I like it!',
#   'Positive',
#   0.6749999999999999,
#   0.4666666666666666),
#  (185, '10 Best Foods for You', "Crap Doesn't work", 'Negative', -0.8, 0.8),
#  (186, '10 Best Foods for You', 'This 5 starr Download', 'Neutral', 0.0, 0.0),
#  (187, '10 Best Foods for You', 'I like Was helpful', 'Neutral', 0.0, 0.0),
#  (188,
#   '10 Best Foods for You',
#   'nice super get',
#   'Positive',
#   0.4666666666666667,
#   0.8333333333333333),
#  (189, '10 Best Foods for You', 'Nice Nice collection', 'Positive', 0.6, 1.0),
#  (190, '10 Best Foods for You', 'Wow', 'Positive', 0.1, 1.0),
#  (191,
#   '10 Best Foods for You',
#   "Interesting. It interesting info, I think worth storage space phone. I'd rather research computer print list. Neat idea, make life easier, provide entertainment, I expect app.",
#   'Positive',
#   0.43333333333333335,
#   0.3666666666666667),
#  (192,
#   '10 Best Foods for You',
#   'Luv it! Simple, easy understand, well thought I follow step step problems see results. I also luv apps, gives food choices. But looks like foundation. Keep good work!',
#   'Positive',
#   0.4361111111111111,
#   0.5968253968253968),
#  (193,
#   '10 Best Foods for You',
#   "Not good Its good u net connection u can't play app.so much good.",
#   'Positive',
#   0.2625,
#   0.4500000000000001),
#  (194,
#   '10 Best Foods for You',
#   "Awesome resources I begin new journey. I can't see great results!",
#   'Positive',
#   0.712121212121212,
#   0.7348484848484849),
#  (195,
#   '10 Best Foods for You',
#   "Boring. I thought actually just texts that's it. Too poor old texts....",
#   'Negative',
#   -0.325,
#   0.475),
#  (196,
#   '10 Best Foods for You',
#   'Love app. It gives way good idea I buying store eating daily basis',
#   'Positive',
#   0.4,
#   0.4000000000000001),
#  (197,
#   '10 Best Foods for You',
#   'Great Its really best unique provides detailed information food nutritious staying healthy hats developer giving free.',
#   'Positive',
#   0.5791666666666666,
#   0.6833333333333332),
#  (198,
#   '10 Best Foods for You',
#   'Nothing special! Could find anything useful!',
#   'Positive',
#   0.4107142857142857,
#   0.2857142857142857),
#  (199,
#   '10 Best Foods for You',
#   'Its ok I love ok.',
#   'Positive',
#   0.5,
#   0.5333333333333333),
#  (200, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Great', 'Positive', 0.8, 0.75),
#  (201, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'nice', 'Positive', 0.6, 1.0),
#  (202,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Almost mobile phone',
#   'Neutral',
#   0.0,
#   0.0),
#  (203,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Very effective, efficient convenient find available jobs. Keep good work power 104 Job Search.',
#   'Positive',
#   0.6266666666666667,
#   0.6666666666666666),
#  (204,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Easy intuitive',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (205,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'good searching job internship',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (206,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Not bad, price little bit expensive',
#   'Negative',
#   -0.11250000000000004,
#   0.6222222222222221),
#  (207,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'easy use!',
#   'Positive',
#   0.5416666666666667,
#   0.8333333333333334),
#  (208,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'job search results iOS e.g. security',
#   'Neutral',
#   0.0,
#   0.0),
#  (209,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'easy',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (210,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Well, it is also the largest human bank in Taiwan. Can you please app ui?',
#   'Neutral',
#   0.0,
#   0.1),
#  (211, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Great', 'Positive', 0.8, 0.75),
#  (212, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'So', 'Neutral', 0.0, 0.0),
#  (213,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Very useful',
#   'Positive',
#   0.39,
#   0.0),
#  (214, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Helpful', 'Neutral', 0.0, 0.0),
#  (215,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Very good job hunt',
#   'Positive',
#   0.91,
#   0.7800000000000001),
#  (216,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Easy to use.',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (217, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'nice', 'Positive', 0.6, 1.0),
#  (218,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Good find job easily',
#   'Positive',
#   0.5666666666666667,
#   0.7166666666666668),
#  (219,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Good meet good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (220, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Awesomeee', 'Neutral', 0.0, 0.0),
#  (221,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Why English version???',
#   'Neutral',
#   0.0,
#   0.0),
#  (222,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'The operation interface & information content is richer than 1111, and it is also better to use/utility without flashing back.',
#   'Positive',
#   0.25,
#   0.25),
#  (223, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Nice', 'Positive', 0.6, 1.0),
#  (224,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Is the development method completed in the early days, the computer web version and the mobile app, the function seems to be short or not the same in the same function page. For example, the similar work function of similar companies is not in the app version.',
#   'Positive',
#   0.016666666666666666,
#   0.275),
#  (225,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'This better suited possibly somebody understands pitfalls modern technology',
#   'Positive',
#   0.2333333333333333,
#   0.6),
#  (226,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Useful handy terminal mobile devices, UI/UX improved :)',
#   'Positive',
#   0.4666666666666666,
#   0.6333333333333333),
#  (227,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   '104 job hunt So amazing.. easy use.. thanx guys',
#   'Positive',
#   0.5166666666666667,
#   0.8666666666666667),
#  (228,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Convenient, easy using many large corporation it.',
#   'Positive',
#   0.3825396825396825,
#   0.5873015873015873),
#  (229,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Easy to use interface',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (230,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'easy simple easy use.',
#   'Positive',
#   0.2888888888888889,
#   0.6746031746031745),
#  (231,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'easy found job',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (232, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Great', 'Positive', 0.8, 0.75),
#  (233,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   "Useful This useful Chinese difficult people's read Chinese. If add English language useful.",
#   'Positive',
#   0.057142857142857134,
#   0.14285714285714285),
#  (234,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Selling a phone number? After completing the resume for 20 minutes, I was hit by my 4 mobile phones, including Nanshan Life Insurance.',
#   'Neutral',
#   0.0,
#   0.0),
#  (235,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Very helpful Very easy user-friendly. Brilliant app.',
#   'Positive',
#   0.5544444444444445,
#   0.7666666666666666),
#  (236,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Good Very helpful',
#   'Positive',
#   0.45,
#   0.4500000000000001),
#  (237,
#   '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#   'Very good, very convenient, easy to use, very beautiful, very good',
#   'Positive',
#   0.6906666666666667,
#   0.7386666666666668),
#  (238, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Ok', 'Positive', 0.5, 0.5),
#  (239, '104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室', 'Nice', 'Positive', 0.6, 1.0),
#  (240, '11st', 'Horrible ID verification', 'Negative', -1.0, 1.0),
#  (241,
#   '11st',
#   'Easy even basic Korean. Searching English usually bring results products shipped overseas, best search Korean.',
#   'Positive',
#   0.23666666666666664,
#   0.3016666666666667),
#  (242, '11st', 'Cool', 'Positive', 0.35, 0.65),
#  (243,
#   '11st',
#   'I do not collect it for a month, but I will not refund it. He said he would only call me all month.',
#   'Neutral',
#   0.0,
#   1.0),
#  (244,
#   '11st',
#   "Top bar missing newest update. Hard shop can't search...",
#   'Positive',
#   0.002777777777777768,
#   0.3638888888888889),
#  (245, '11st', 'There is nothing missing ~ !!!', 'Negative', -0.390625, 0.05),
#  (246,
#   '11st',
#   'Refund takes long.. 3 days still received money.. crazy',
#   'Negative',
#   -0.325,
#   0.65),
#  (247,
#   '11st',
#   'I enjoying online shopping via 11st app. Perfect!',
#   'Positive',
#   0.75,
#   0.8),
#  (248, '11st', 'good enough', 'Positive', 0.35, 0.55),
#  (249,
#   '11st',
#   "I switching gMarket Twice 11st's new face!",
#   'Positive',
#   0.17045454545454544,
#   0.4545454545454545),
#  (250,
#   '11st',
#   'forced full screen popups',
#   'Positive',
#   0.02499999999999997,
#   0.375),
#  (251,
#   '11st',
#   "Is it sound like you want to clear Chrome and pay for it again because Android users can not pay for Chrome error? I have to fix the app. Is it really true? It's makgeolli.",
#   'Positive',
#   0.2833333333333333,
#   0.4777777777777778),
#  (252, '11st', 'Ok', 'Positive', 0.5, 0.5),
#  (253,
#   '11st',
#   "I am trying to update every time but I do not stall. It's still difficult to search, and I'm tired of seeing categories by category. The benefits are getting less and less.",
#   'Negative',
#   -0.3083333333333333,
#   0.4583333333333333),
#  (254, '11st', 'Just try.. So far good', 'Positive', 0.4, 0.8),
#  (255, '11st', 'Icon name is strange after updating', 'Negative', -0.05, 0.15),
#  (256, '11st', 'com.skplanet.syruppay.cardrecognizedlib', 'Neutral', 0.0, 0.0),
#  (257, '11st', 'Nice', 'Positive', 0.6, 1.0),
#  (258, '11st', 'best shop', 'Positive', 1.0, 0.3),
#  (259,
#   '11st',
#   "I forgot password can't get new",
#   'Positive',
#   0.13636363636363635,
#   0.4545454545454545),
#  (260, '11st', 'best', 'Positive', 1.0, 0.3),
#  (261, '11st', 'I love', 'Positive', 0.5, 0.6),
#  (262, '11st', 'Force update', 'Neutral', 0.0, 0.0),
#  (263, '11st', 'She', 'Neutral', 0.0, 0.0),
#  (264, '11st', 'Love Nature', 'Positive', 0.5, 0.6),
#  (265,
#   '11st',
#   'Language barrier. I understand Korea. I want English.',
#   'Neutral',
#   0.0,
#   0.0),
#  (266,
#   '11st',
#   'Shipping View Flexible View Make it right? Why do not you come out ???',
#   'Positive',
#   0.2857142857142857,
#   0.5357142857142857),
#  (267,
#   '11st',
#   '0 points I want to give No -10000000000000 points shortage I clicked on the Internet address I could not find the product I popped up and the 11th Avenue app was automatically turned on and it was automatically abducted so I can not use the internet app.',
#   'Neutral',
#   0.0,
#   0.0),
#  (268, '11st', None, 'Neutral', 0.0, 0.0),
#  (269, '11st', 'Five star Its nice', 'Positive', 0.6, 1.0),
#  (270,
#   '11st',
#   'Forced termination is too severe. If you try to view detailed information, it will be forcibly terminated.',
#   'Positive',
#   0.2,
#   0.65),
#  (271,
#   '11st',
#   'Open Market Revolution A section of the Helo-Ship open market mobile service. There are still many page areas that can not be served by mobile service, and the interface is also an urgent level for page loading. If you understand that there is a limit to the source control of the product information provided by the sellers, it is a chronic problem that problems arise in the loading of coupons or on the benefit management page.',
#   'Positive',
#   0.16666666666666666,
#   0.5),
#  (272,
#   '11st',
#   'English version Hi possible English version. Thank you.',
#   'Neutral',
#   0.0,
#   0.3333333333333333),
#  (273,
#   '11st',
#   'If you have a phone that is authenticated by OTP and you call the agent, you will be able to find it .... There is a letter authentication and there is also an e-mail .. If you do not do such a thing and call a counselor,',
#   'Positive',
#   0.25,
#   0.5625),
#  (274,
#   '11st',
#   "It has been slowed down since the last update. It's hard for me to pay for the product ... I'll give up when I'm alive.",
#   'Negative',
#   -0.08680555555555558,
#   0.3243055555555555),
#  (275, '11st', 'good good', 'Positive', 0.7, 0.6000000000000001),
#  (276,
#   '11st',
#   "If a network error occurs, the app should save the state and try again, or try to re-point the next time, but that's it and it's gone. It's totally tough.",
#   'Negative',
#   -0.19444444444444445,
#   0.4166666666666667),
#  (277,
#   '11st',
#   'Problem language I dont understand language used app. I advise keep option user choose language may prefer',
#   'Neutral',
#   0.0,
#   0.0),
#  (278, '11st', 'Nice So nice Apps.', 'Positive', 0.6, 1.0),
#  (279, '11st', "Don't English language like", 'Neutral', 0.0, 0.0),
#  (280,
#   '1800 Contacts - Lens Store',
#   'Great hassle free way order contacts. Got call reminding prescription expires tomorrow.',
#   'Positive',
#   0.6000000000000001,
#   0.775),
#  (281,
#   '1800 Contacts - Lens Store',
#   "It's expensive I expected (I thought I'd saving money, cutting middle man), waaaaay convenient doctor's office.",
#   'Negative',
#   -0.3,
#   0.5),
#  (282,
#   '1800 Contacts - Lens Store',
#   'Super fast navigation brand fast/easy checkout additional ads BS',
#   'Positive',
#   0.26666666666666666,
#   0.6333333333333333),
#  (283,
#   '1800 Contacts - Lens Store',
#   'Easy step step process correct information took 5 minutes place order.',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (284,
#   '1800 Contacts - Lens Store',
#   "Placing order easy especially paper copy Rx. I'll update review I receive order rebate.",
#   'Positive',
#   0.21666666666666667,
#   0.9166666666666669),
#  (285,
#   '1800 Contacts - Lens Store',
#   'Super fast ordering reordering easy interface. Love convenience app!',
#   'Positive',
#   0.3979166666666667,
#   0.675),
#  (286,
#   '1800 Contacts - Lens Store',
#   'I love makes getting contacts easy!♥️',
#   'Positive',
#   0.5,
#   0.6),
#  (287,
#   '1800 Contacts - Lens Store',
#   'Easy use. Will def recommend',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (288,
#   '1800 Contacts - Lens Store',
#   'Love app. Super easy use. Ordered contacts less minute.',
#   'Positive',
#   0.275,
#   0.5416666666666667),
#  (289,
#   '1800 Contacts - Lens Store',
#   'This easy use, ordering process fast efficient.',
#   'Positive',
#   0.31666666666666665,
#   0.7166666666666667),
#  (290,
#   '1800 Contacts - Lens Store',
#   'So simple cave man it!!',
#   'Neutral',
#   0.0,
#   0.35714285714285715),
#  (291,
#   '1800 Contacts - Lens Store',
#   'Simple, fast easy use. No eye appointments',
#   'Positive',
#   0.2111111111111111,
#   0.5968253968253968),
#  (292,
#   '1800 Contacts - Lens Store',
#   'Very user friendly.',
#   'Positive',
#   0.2875,
#   0.4),
#  (293,
#   '1800 Contacts - Lens Store',
#   'Very easy use. Love free shipping',
#   'Positive',
#   0.4877777777777778,
#   0.8000000000000002),
#  (294,
#   '1800 Contacts - Lens Store',
#   'Very easy use.',
#   'Positive',
#   0.5633333333333334,
#   1.0),
#  (295, '1800 Contacts - Lens Store', 'Dope', 'Neutral', 0.0, 0.0),
#  (296,
#   '1800 Contacts - Lens Store',
#   'Easy affordable.',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (297,
#   '1800 Contacts - Lens Store',
#   'Easy',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (298, '1800 Contacts - Lens Store', 'great', 'Positive', 0.8, 0.75),
#  (299,
#   '1800 Contacts - Lens Store',
#   'So easy app! Made ordering contacts breeze! Great prices too!',
#   'Positive',
#   0.8385416666666667,
#   0.7916666666666667),
#  (300,
#   '1800 Contacts - Lens Store',
#   'Does need do. No sense giving anything less 5 stars.',
#   'Negative',
#   -0.16666666666666666,
#   0.06666666666666668),
#  (301,
#   '1800 Contacts - Lens Store',
#   'Worked well glad I',
#   'Positive',
#   0.5,
#   1.0),
#  (302,
#   '1800 Contacts - Lens Store',
#   "It's hell lot easier I thought it would be!",
#   'Neutral',
#   0.0,
#   0.0),
#  (303,
#   '1800 Contacts - Lens Store',
#   'It made getting new contacts easy!',
#   'Positive',
#   0.33901515151515155,
#   0.6439393939393939),
#  (304,
#   '1800 Contacts - Lens Store',
#   'I love app! SO easy super convenient!!',
#   'Positive',
#   0.5263888888888889,
#   0.7000000000000001),
#  (305,
#   '1800 Contacts - Lens Store',
#   'Hopefully work well. First time user.',
#   'Positive',
#   0.25,
#   0.3333333333333333),
#  (306,
#   '1800 Contacts - Lens Store',
#   'Contacts shipped time efficient.',
#   'Neutral',
#   0.0,
#   0.0),
#  (307,
#   '1800 Contacts - Lens Store',
#   'Very easy',
#   'Positive',
#   0.5633333333333334,
#   1.0),
#  (308,
#   '1800 Contacts - Lens Store',
#   'Easy access',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (309,
#   '1800 Contacts - Lens Store',
#   'First time app, always used doctors office stand behind tore contacts. Hoping solve problem 1800contacts!',
#   'Negative',
#   -0.125,
#   0.5166666666666666),
#  (310,
#   '1800 Contacts - Lens Store',
#   'Months later, GS9+, still notify expired lenses. Useless. ---- Lens notifications work, successfully pushes alerts discounts. The fundamental reason keep running lens expiration notification, work. (My notification settings fine.)',
#   'Positive',
#   0.16666666666666669,
#   0.4125),
#  (311,
#   '1800 Contacts - Lens Store',
#   'Good prices exceptional customer service. Order sent particular fault begin thoroughly checking information completing order. When I emailed I got response rather quickly (2 hours) correction made I receiving free overnight shipping ensure getting lenses promptly. Wonderful.',
#   'Positive',
#   0.5444444444444444,
#   0.7055555555555556),
#  (312,
#   '1800 Contacts - Lens Store',
#   "It's quick easy order contacts app, I love it! And really saves time money, makes extremely happy! Got love free market capitalism!",
#   'Positive',
#   0.5130952380952382,
#   0.6476190476190478),
#  (313,
#   '1800 Contacts - Lens Store',
#   'Ordered Sunday. Got call verifying last name (recently married). Scheduled shipped Monday :) Happy customer',
#   'Positive',
#   0.3875,
#   0.5791666666666666),
#  (314,
#   '1800 Contacts - Lens Store',
#   'Took 5 seconds find rx get contacts ordered, convenient.',
#   'Neutral',
#   0.0,
#   0.0),
#  (315,
#   '1800 Contacts - Lens Store',
#   'Short, simple sweet. Super easy took less 5 mins order contacts. Plus savings!',
#   'Positive',
#   0.1513888888888889,
#   0.4789682539682541),
#  (316,
#   '1800 Contacts - Lens Store',
#   'Super easy. Not super cheap, cheaper actually going optometrist, good deals shipping.',
#   'Positive',
#   0.2833333333333333,
#   0.5944444444444444),
#  (317,
#   '1800 Contacts - Lens Store',
#   'Very useful streamlines eye care needs. Recommend contact wearers. 5/5. Very reliable shipping. easy well.',
#   'Positive',
#   0.34111111111111114,
#   0.37777777777777777),
#  (318,
#   '1800 Contacts - Lens Store',
#   'Very easy use. They remembered last order I figure out!',
#   'Positive',
#   0.2816666666666667,
#   0.5333333333333333),
#  (319,
#   '1800 Contacts - Lens Store',
#   'This well designed, easy & convenient!',
#   'Positive',
#   0.5416666666666667,
#   0.8333333333333334),
#  (320,
#   '1800 Contacts - Lens Store',
#   'Great hassle free way order contacts. Got call reminding prescription expires tomorrow.',
#   'Positive',
#   0.6000000000000001,
#   0.775),
#  (321,
#   '1800 Contacts - Lens Store',
#   "It's expensive I expected (I thought I'd saving money, cutting middle man), waaaaay convenient doctor's office.",
#   'Negative',
#   -0.3,
#   0.5),
#  (322,
#   '1800 Contacts - Lens Store',
#   'Super fast navigation brand fast/easy checkout additional ads BS',
#   'Positive',
#   0.26666666666666666,
#   0.6333333333333333),
#  (323,
#   '1800 Contacts - Lens Store',
#   'Easy step step process correct information took 5 minutes place order.',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (324,
#   '1800 Contacts - Lens Store',
#   "Placing order easy especially paper copy Rx. I'll update review I receive order rebate.",
#   'Positive',
#   0.21666666666666667,
#   0.9166666666666669),
#  (325,
#   '1800 Contacts - Lens Store',
#   'Super fast ordering reordering easy interface. Love convenience app!',
#   'Positive',
#   0.3979166666666667,
#   0.675),
#  (326,
#   '1800 Contacts - Lens Store',
#   'I love makes getting contacts easy!♥️',
#   'Positive',
#   0.5,
#   0.6),
#  (327,
#   '1800 Contacts - Lens Store',
#   'Easy use. Will def recommend',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (328,
#   '1800 Contacts - Lens Store',
#   'Love app. Super easy use. Ordered contacts less minute.',
#   'Positive',
#   0.275,
#   0.5416666666666667),
#  (329,
#   '1800 Contacts - Lens Store',
#   'This easy use, ordering process fast efficient.',
#   'Positive',
#   0.31666666666666665,
#   0.7166666666666667),
#  (330,
#   '1800 Contacts - Lens Store',
#   'So simple cave man it!!',
#   'Neutral',
#   0.0,
#   0.35714285714285715),
#  (331,
#   '1800 Contacts - Lens Store',
#   'Simple, fast easy use. No eye appointments',
#   'Positive',
#   0.2111111111111111,
#   0.5968253968253968),
#  (332,
#   '1800 Contacts - Lens Store',
#   'Very user friendly.',
#   'Positive',
#   0.2875,
#   0.4),
#  (333,
#   '1800 Contacts - Lens Store',
#   'Very easy use. Love free shipping',
#   'Positive',
#   0.4877777777777778,
#   0.8000000000000002),
#  (334,
#   '1800 Contacts - Lens Store',
#   'Very easy use.',
#   'Positive',
#   0.5633333333333334,
#   1.0),
#  (335, '1800 Contacts - Lens Store', 'Dope', 'Neutral', 0.0, 0.0),
#  (336,
#   '1800 Contacts - Lens Store',
#   'Easy affordable.',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (337,
#   '1800 Contacts - Lens Store',
#   'Easy',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (338, '1800 Contacts - Lens Store', 'great', 'Positive', 0.8, 0.75),
#  (339,
#   '1800 Contacts - Lens Store',
#   'So easy app! Made ordering contacts breeze! Great prices too!',
#   'Positive',
#   0.8385416666666667,
#   0.7916666666666667),
#  (340,
#   '1800 Contacts - Lens Store',
#   'Does need do. No sense giving anything less 5 stars.',
#   'Negative',
#   -0.16666666666666666,
#   0.06666666666666668),
#  (341,
#   '1800 Contacts - Lens Store',
#   'Worked well glad I',
#   'Positive',
#   0.5,
#   1.0),
#  (342,
#   '1800 Contacts - Lens Store',
#   "It's hell lot easier I thought it would be!",
#   'Neutral',
#   0.0,
#   0.0),
#  (343,
#   '1800 Contacts - Lens Store',
#   'It made getting new contacts easy!',
#   'Positive',
#   0.33901515151515155,
#   0.6439393939393939),
#  (344,
#   '1800 Contacts - Lens Store',
#   'I love app! SO easy super convenient!!',
#   'Positive',
#   0.5263888888888889,
#   0.7000000000000001),
#  (345,
#   '1800 Contacts - Lens Store',
#   'Hopefully work well. First time user.',
#   'Positive',
#   0.25,
#   0.3333333333333333),
#  (346,
#   '1800 Contacts - Lens Store',
#   'Contacts shipped time efficient.',
#   'Neutral',
#   0.0,
#   0.0),
#  (347,
#   '1800 Contacts - Lens Store',
#   'Very easy',
#   'Positive',
#   0.5633333333333334,
#   1.0),
#  (348,
#   '1800 Contacts - Lens Store',
#   'Easy access',
#   'Positive',
#   0.43333333333333335,
#   0.8333333333333334),
#  (349,
#   '1800 Contacts - Lens Store',
#   'First time app, always used doctors office stand behind tore contacts. Hoping solve problem 1800contacts!',
#   'Negative',
#   -0.125,
#   0.5166666666666666),
#  (350,
#   '1800 Contacts - Lens Store',
#   'Months later, GS9+, still notify expired lenses. Useless. ---- Lens notifications work, successfully pushes alerts discounts. The fundamental reason keep running lens expiration notification, work. (My notification settings fine.)',
#   'Positive',
#   0.16666666666666669,
#   0.4125),
#  (351,
#   '1800 Contacts - Lens Store',
#   'Good prices exceptional customer service. Order sent particular fault begin thoroughly checking information completing order. When I emailed I got response rather quickly (2 hours) correction made I receiving free overnight shipping ensure getting lenses promptly. Wonderful.',
#   'Positive',
#   0.5444444444444444,
#   0.7055555555555556),
#  (352,
#   '1800 Contacts - Lens Store',
#   "It's quick easy order contacts app, I love it! And really saves time money, makes extremely happy! Got love free market capitalism!",
#   'Positive',
#   0.5130952380952382,
#   0.6476190476190478),
#  (353,
#   '1800 Contacts - Lens Store',
#   'Ordered Sunday. Got call verifying last name (recently married). Scheduled shipped Monday :) Happy customer',
#   'Positive',
#   0.3875,
#   0.5791666666666666),
#  (354,
#   '1800 Contacts - Lens Store',
#   'Took 5 seconds find rx get contacts ordered, convenient.',
#   'Neutral',
#   0.0,
#   0.0),
#  (355,
#   '1800 Contacts - Lens Store',
#   'Short, simple sweet. Super easy took less 5 mins order contacts. Plus savings!',
#   'Positive',
#   0.1513888888888889,
#   0.4789682539682541),
#  (356,
#   '1800 Contacts - Lens Store',
#   'Super easy. Not super cheap, cheaper actually going optometrist, good deals shipping.',
#   'Positive',
#   0.2833333333333333,
#   0.5944444444444444),
#  (357,
#   '1800 Contacts - Lens Store',
#   'Very useful streamlines eye care needs. Recommend contact wearers. 5/5. Very reliable shipping. easy well.',
#   'Positive',
#   0.34111111111111114,
#   0.37777777777777777),
#  (358,
#   '1800 Contacts - Lens Store',
#   'Very easy use. They remembered last order I figure out!',
#   'Positive',
#   0.2816666666666667,
#   0.5333333333333333),
#  (359,
#   '1800 Contacts - Lens Store',
#   'This well designed, easy & convenient!',
#   'Positive',
#   0.5416666666666667,
#   0.8333333333333334),
#  (360,
#   '1LINE – One Line with One Touch',
#   "gets 1* there's ad every single level restart, frustrating, potential",
#   'Negative',
#   -0.15714285714285714,
#   0.7047619047619048),
#  (361,
#   '1LINE – One Line with One Touch',
#   'The game interesting challenging. However, often buffers gets stuck.',
#   'Positive',
#   0.2,
#   0.6333333333333333),
#  (362, '1LINE – One Line with One Touch', None, None, None, None),
#  (363,
#   '1LINE – One Line with One Touch',
#   'Wow ,i play 15 puzzle 1st round I remember puzzle solve childhood.. Lovely',
#   'Positive',
#   0.13333333333333333,
#   0.7166666666666667),
#  (364,
#   '1LINE – One Line with One Touch',
#   "Love game deleting I've waiting 3 months levels play. I several updates none updates added new levels",
#   'Positive',
#   0.059090909090909076,
#   0.3636363636363637),
#  (365,
#   '1LINE – One Line with One Touch',
#   'Way many aggressive ads',
#   'Positive',
#   0.5,
#   0.5),
#  (366,
#   '1LINE – One Line with One Touch',
#   "amaze i'm addicted",
#   'Negative',
#   -0.4,
#   0.6),
#  (367,
#   '1LINE – One Line with One Touch',
#   'I like game',
#   'Negative',
#   -0.4,
#   0.4),
#  (368, '1LINE – One Line with One Touch', None, None, None, None),
#  (369,
#   '1LINE – One Line with One Touch',
#   'I play game',
#   'Negative',
#   -0.4,
#   0.4),
#  (370,
#   '1LINE – One Line with One Touch',
#   "It's toooo gud game",
#   'Negative',
#   -0.4,
#   0.4),
#  (371,
#   '1LINE – One Line with One Touch',
#   'Too many unskippable ads. Other than, great game.',
#   'Positive',
#   0.19375,
#   0.50625),
#  (372,
#   '1LINE – One Line with One Touch',
#   'Mind uses game',
#   'Negative',
#   -0.4,
#   0.4),
#  (373, '1LINE – One Line with One Touch', 'Too much ad', 'Positive', 0.2, 0.2),
#  (374,
#   '1LINE – One Line with One Touch',
#   'It great experience knowledge help game',
#   'Positive',
#   0.2,
#   0.575),
#  (375,
#   '1LINE – One Line with One Touch',
#   'Nice game',
#   'Positive',
#   0.09999999999999998,
#   0.7),
#  (376,
#   '1LINE – One Line with One Touch',
#   'I really good game',
#   'Positive',
#   0.14999999999999994,
#   0.5),
#  (377,
#   '1LINE – One Line with One Touch',
#   'I love game nice',
#   'Positive',
#   0.2333333333333333,
#   0.6666666666666666),
#  (378, '1LINE – One Line with One Touch', 'It granite', 'Neutral', 0.0, 0.0),
#  (379,
#   '1LINE – One Line with One Touch',
#   'It confusing',
#   'Negative',
#   -0.3,
#   0.4),
#  (380,
#   '1LINE – One Line with One Touch',
#   'Its really fun',
#   'Positive',
#   0.3,
#   0.2),
#  (381,
#   '1LINE – One Line with One Touch',
#   'Is game beautiful',
#   'Positive',
#   0.225,
#   0.7),
#  (382, '1LINE – One Line with One Touch', 'Guide', 'Neutral', 0.0, 0.0),
#  (383,
#   '1LINE – One Line with One Touch',
#   'SUPER',
#   'Positive',
#   0.3333333333333333,
#   0.6666666666666666),
#  (384, '1LINE – One Line with One Touch', 'yoko', 'Neutral', 0.0, 0.0),
#  (385, '1LINE – One Line with One Touch', "It's great", 'Positive', 0.8, 0.75),
#  (386, '1LINE – One Line with One Touch', 'Very nice', 'Positive', 0.78, 1.0),
#  (387,
#   '1LINE – One Line with One Touch',
#   'Good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (388, '1LINE – One Line with One Touch', 'Its cool', 'Positive', 0.35, 0.65),
#  (389, '1LINE – One Line with One Touch', 'Cool', 'Positive', 0.35, 0.65),
#  (390, '1LINE – One Line with One Touch', 'Fantastic', 'Positive', 0.4, 0.9),
#  (391, '1LINE – One Line with One Touch', 'Superb', 'Positive', 1.0, 1.0),
#  (392, '1LINE – One Line with One Touch', 'Excellent', 'Positive', 1.0, 1.0),
#  (393, '1LINE – One Line with One Touch', 'Nice', 'Positive', 0.6, 1.0),
#  (394, '1LINE – One Line with One Touch', 'Love', 'Positive', 0.5, 0.6),
# ...
#  (779, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (780, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (781, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (782, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (783, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (784, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (785, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (786, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (787, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (788, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (789, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (790, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (791, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (792, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (793, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (794, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (795, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (796, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (797, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (798, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (799, '3D Blue Glass Water Keyboard Theme', None, None, None, None),
#  (800,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (801,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (802,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (803,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (804,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (805,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (806,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (807,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (808,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (809,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (810,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (811,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (812,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (813,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (814,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (815,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (816,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (817,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (818,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (819,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (820,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (821,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (822,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (823,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (824,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (825,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (826,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (827,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (828,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (829,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (830,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (831,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (832,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (833,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (834,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (835,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (836,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (837,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (838,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (839,
#   '3D Color Pixel by Number - Sandbox Art Coloring',
#   None,
#   None,
#   None,
#   None),
#  (840, '3D Live Neon Weed Launcher', None, None, None, None),
#  (841, '3D Live Neon Weed Launcher', None, None, None, None),
#  (842, '3D Live Neon Weed Launcher', None, None, None, None),
#  (843, '3D Live Neon Weed Launcher', None, None, None, None),
#  (844, '3D Live Neon Weed Launcher', None, None, None, None),
#  (845, '3D Live Neon Weed Launcher', None, None, None, None),
#  (846, '3D Live Neon Weed Launcher', None, None, None, None),
#  (847, '3D Live Neon Weed Launcher', None, None, None, None),
#  (848, '3D Live Neon Weed Launcher', None, None, None, None),
#  (849, '3D Live Neon Weed Launcher', None, None, None, None),
#  (850, '3D Live Neon Weed Launcher', None, None, None, None),
#  (851, '3D Live Neon Weed Launcher', None, None, None, None),
#  (852, '3D Live Neon Weed Launcher', None, None, None, None),
#  (853, '3D Live Neon Weed Launcher', None, None, None, None),
#  (854, '3D Live Neon Weed Launcher', None, None, None, None),
#  (855, '3D Live Neon Weed Launcher', None, None, None, None),
#  (856, '3D Live Neon Weed Launcher', None, None, None, None),
#  (857, '3D Live Neon Weed Launcher', None, None, None, None),
#  (858, '3D Live Neon Weed Launcher', None, None, None, None),
#  (859, '3D Live Neon Weed Launcher', None, None, None, None),
#  (860, '3D Live Neon Weed Launcher', None, None, None, None),
#  (861, '3D Live Neon Weed Launcher', None, None, None, None),
#  (862, '3D Live Neon Weed Launcher', None, None, None, None),
#  (863, '3D Live Neon Weed Launcher', None, None, None, None),
#  (864, '3D Live Neon Weed Launcher', None, None, None, None),
#  (865, '3D Live Neon Weed Launcher', None, None, None, None),
#  (866, '3D Live Neon Weed Launcher', None, None, None, None),
#  (867, '3D Live Neon Weed Launcher', None, None, None, None),
#  (868, '3D Live Neon Weed Launcher', None, None, None, None),
#  (869, '3D Live Neon Weed Launcher', None, None, None, None),
#  (870, '3D Live Neon Weed Launcher', None, None, None, None),
#  (871, '3D Live Neon Weed Launcher', None, None, None, None),
#  (872,
#   '3D Live Neon Weed Launcher',
#   "It's best working I've used",
#   'Positive',
#   1.0,
#   0.3),
#  (873, '3D Live Neon Weed Launcher', None, None, None, None),
#  (874, '3D Live Neon Weed Launcher', None, None, None, None),
#  (875, '3D Live Neon Weed Launcher', None, None, None, None),
#  (876, '3D Live Neon Weed Launcher', None, None, None, None),
#  (877,
#   '3D Live Neon Weed Launcher',
#   'I live Colorado Springs Colorado. Need I say',
#   'Positive',
#   0.13636363636363635,
#   0.5),
#  (878, '3D Live Neon Weed Launcher', None, None, None, None),
#  (879, '3D Live Neon Weed Launcher', None, None, None, None),
#  (880, '4 in a Row', None, None, None, None),
#  (881, '4 in a Row', None, None, None, None),
#  (882, '4 in a Row', 'Excellent', 'Positive', 1.0, 1.0),
#  (883, '4 in a Row', None, None, None, None),
#  (884, '4 in a Row', None, None, None, None),
#  (885, '4 in a Row', None, None, None, None),
#  (886, '4 in a Row', None, None, None, None),
#  (887, '4 in a Row', None, None, None, None),
#  (888,
#   '4 in a Row',
#   'Better brainless runners, actually makes think',
#   'Positive',
#   0.25,
#   0.3),
#  (889, '4 in a Row', None, None, None, None),
#  (890,
#   '4 in a Row',
#   'It cool game I liked much helps developing concentration',
#   'Positive',
#   0.1875,
#   0.5125000000000001),
#  (891, '4 in a Row', None, None, None, None),
#  (892, '4 in a Row', None, None, None, None),
#  (893, '4 in a Row', None, None, None, None),
#  (894,
#   '4 in a Row',
#   'Excellent really tough higher CPU levels',
#   'Positive',
#   0.28703703703703703,
#   0.7777777777777778),
#  (895, '4 in a Row', None, None, None, None),
#  (896,
#   '4 in a Row',
#   "It's great game keep u busy hours..... Obviously.. u know play...",
#   'Positive',
#   0.125,
#   0.4875),
#  (897, '4 in a Row', None, None, None, None),
#  (898, '4 in a Row', None, None, None, None),
#  (899,
#   '4 in a Row',
#   'Simple game pass time away. My grandson like it.',
#   'Negative',
#   -0.2,
#   0.37857142857142856),
#  (900, '4 in a Row', None, None, None, None),
#  (901, '4 in a Row', None, None, None, None),
#  (902, '4 in a Row', None, None, None, None),
#  (903, '4 in a Row', None, None, None, None),
#  (904, '4 in a Row', None, None, None, None),
#  (905, '4 in a Row', 'Great way waist time.', 'Positive', 0.8, 0.75),
#  (906, '4 in a Row', None, None, None, None),
#  (907, '4 in a Row', None, None, None, None),
#  (908, '4 in a Row', None, None, None, None),
#  (909, '4 in a Row', 'Great', 'Positive', 0.8, 0.75),
#  (910, '4 in a Row', None, None, None, None),
#  (911, '4 in a Row', None, None, None, None),
#  (912, '4 in a Row', None, None, None, None),
#  (913, '4 in a Row', None, None, None, None),
#  (914, '4 in a Row', None, None, None, None),
#  (915, '4 in a Row', None, None, None, None),
#  (916, '4 in a Row', None, None, None, None),
#  (917, '4 in a Row', None, None, None, None),
#  (918, '4 in a Row', None, None, None, None),
#  (919, '4 in a Row', None, None, None, None),
#  (920, '4 in a Row', None, None, None, None),
#  (921, '4 in a Row', None, None, None, None),
#  (922, '4 in a Row', None, None, None, None),
#  (923,
#   '4 in a Row',
#   'Connect four V good',
#   'Positive',
#   0.7,
#   0.6000000000000001),
#  (924, '4 in a Row', None, None, None, None),
#  (925, '4 in a Row', None, None, None, None),
#  (926, '4 in a Row', None, None, None, None),
#  (927, '4 in a Row', None, None, None, None),
#  (928,
#   '4 in a Row',
#   "Boring All put chip hole let's win",
#   'Negative',
#   -0.09999999999999998,
#   0.7),
#  (929, '4 in a Row', None, None, None, None),
#  (930, '4 in a Row', None, None, None, None),
#  (931,
#   '4 in a Row',
#   'Super fun game Really good brain game',
#   'Positive',
#   0.10666666666666663,
#   0.4533333333333333),
#  (932, '4 in a Row', None, None, None, None),
#  (933, '4 in a Row', None, None, None, None),
#  (934, '4 in a Row', None, None, None, None),
#  (935, '4 in a Row', None, None, None, None),
#  (936, '4 in a Row', None, None, None, None),
#  (937, '4 in a Row', None, None, None, None),
#  (938, '4 in a Row', None, None, None, None),
#  (939, '4 in a Row', None, None, None, None),
#  (940, '4 in a Row', None, None, None, None),
#  (941, '4 in a Row', None, None, None, None),
#  (942,
#   '4 in a Row',
#   "It's boring This game sooooo boring.. -_-",
#   'Negative',
#   -0.7999999999999999,
#   0.7999999999999999),
#  (943, '4 in a Row', None, None, None, None),
#  (944, '4 in a Row', None, None, None, None),
#  (945, '4 in a Row', None, None, None, None),
#  (946,
#   '4 in a Row',
#   'Could made better improving manoeuvre',
#   'Positive',
#   0.5,
#   0.5),
#  (947, '4 in a Row', None, None, None, None),
#  (948,
#   '4 in a Row',
#   "Addictive! I've playing almost every day years. A GREAT version :)",
#   'Positive',
#   0.43333333333333335,
#   0.8833333333333333),
#  (949, '4 in a Row', None, None, None, None),
#  (950, '4 in a Row', None, None, None, None),
#  (951, '4 in a Row', '4 row Who knew 4 row could fun', 'Positive', 0.3, 0.2),
#  (952, '4 in a Row', None, None, None, None),
#  (953, '4 in a Row', None, None, None, None),
#  (954, '4 in a Row', 'Keeps busy', 'Positive', 0.1, 0.3),
#  (955, '4 in a Row', None, None, None, None),
#  (956, '4 in a Row', None, None, None, None),
#  (957, '4 in a Row', None, None, None, None),
#  (958, '4 in a Row', None, None, None, None),
#  (959, '4 in a Row', None, None, None, None),
#  (960, '4 in a Row', None, None, None, None),
#  (961, '4 in a Row', None, None, None, None),
#  (962, '4 in a Row', None, None, None, None),
#  (963, '4 in a Row', None, None, None, None),
#  (964, '4 in a Row', None, None, None, None),
#  (965, '4 in a Row', None, None, None, None),
#  (966, '4 in a Row', None, None, None, None),
#  (967, '4 in a Row', None, None, None, None),
#  (968, '4 in a Row', None, None, None, None),
#  (969, '4 in a Row', None, None, None, None),
#  (970,
#   '4 in a Row',
#   'Love ♥this game rocks ♥',
#   'Positive',
#   0.3666666666666667,
#   0.6666666666666666),
#  (971, '4 in a Row', None, None, None, None),
#  (972,
#   '4 in a Row',
#   'Nice simple game',
#   'Positive',
#   0.06666666666666665,
#   0.5857142857142857),
#  (973, '4 in a Row', None, None, None, None),
#  (974, '4 in a Row', None, None, None, None),
#  (975, '4 in a Row', None, None, None, None),
#  (976, '4 in a Row', None, None, None, None),
#  (977, '4 in a Row', None, None, None, None),
#  (978, '4 in a Row', 'love', 'Positive', 0.5, 0.6),
#  (979,
#   '4 in a Row',
#   'Ive played level 10 three times them. Then I programmed AI C I let go second level 10 fifteen times all. I could make suggestion improving evaluation function like. It uses concept zugzwang accurate.',
#   'Positive',
#   0.20000000000000004,
#   0.3166666666666667),
#  (980,
#   '4K Wallpapers and Ultra HD Backgrounds',
#   "Nice wallpapers they're NOT 4k even 2k, they're presented. They're hardly fullHD that's perhaps scaled 4k, making look grainy blurry. Would recommend phone screen resolution higher full HD. Nice collection, great quality, unfortunately.",
#   'Positive',
#   0.25833333333333336,
#   0.7630952380952382),
#  (981,
#   '4K Wallpapers and Ultra HD Backgrounds',
#   'The refresh function scrambles excisting wallpapers... Who fooling? Lot wallpapers bad quality. Don‘t waste time.',
#   'Negative',
#   -0.45,
#   0.3333333333333333),
#  (982,
#   '4K Wallpapers and Ultra HD Backgrounds',
#   'Awesome app. Wallpapers vibrant exclusive mostly. But excessive ads make miserable wallpapers. Please least reduce them.',
#   'Positive',
#   0.01944444444444446,
#   0.7055555555555556),
#  (983, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (984, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (985, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (986, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (987, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (988,
#   '4K Wallpapers and Ultra HD Backgrounds',
#   'Would better add animated wallpapers. Overall, good daily updated wallpapers',
#   'Positive',
#   0.3,
#   0.275),
#  (989, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (990, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (991, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (992, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (993,
#   '4K Wallpapers and Ultra HD Backgrounds',
#   'This true 4k wallpapers great variety, new wallpapers must added frequently!',
#   'Positive',
#   0.35284090909090904,
#   0.5386363636363636),
#  (994, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (995,
#   '4K Wallpapers and Ultra HD Backgrounds',
#   "It's good better 4k pictures",
#   'Positive',
#   0.6,
#   0.55),
#  (996, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (997, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (998, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  (999, '4K Wallpapers and Ultra HD Backgrounds', None, None, None, None),
#  ...]

# %%
data.to_excel("data.xls")

pd.read_excel("data.xls")
# Out:
#        Unnamed: 0                          App  \
# 0               0        10 Best Foods for You
# 1               1        10 Best Foods for You
# 2               2        10 Best Foods for You
# 3               3        10 Best Foods for You
# 4               4        10 Best Foods for You
# ...           ...                          ...
# 64290       64290  Houzz Interior Design Ideas
# 64291       64291  Houzz Interior Design Ideas
# 64292       64292  Houzz Interior Design Ideas
# 64293       64293  Houzz Interior Design Ideas
# 64294       64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 6 columns]

# %%
data[0:5]
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
data[0:101]
# Out:
#                        App                                  Translated_Review  \
# 0    10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1    10 Best Foods for You    This help eating healthy exercise regular basis
# 2    10 Best Foods for You                                                NaN
# 3    10 Best Foods for You         Works great especially going grocery store
# 4    10 Best Foods for You                                       Best idea us
# ..                     ...                                                ...
# 96   10 Best Foods for You  Love app. It gives way good idea I buying stor...
# 97   10 Best Foods for You  Great Its really best unique provides detailed...
# 98   10 Best Foods for You       Nothing special! Could find anything useful!
# 99   10 Best Foods for You                                  Its ok I love ok.
# 100  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
#
#     Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0    Positive            1.000000                0.533333
# 1    Positive            0.250000                0.288462
# 2         NaN                 NaN                     NaN
# 3    Positive            0.400000                0.875000
# 4    Positive            1.000000                0.300000
# ..        ...                 ...                     ...
# 96   Positive            0.400000                0.400000
# 97   Positive            0.579167                0.683333
# 98   Positive            0.410714                0.285714
# 99   Positive            0.500000                0.533333
# 100  Positive            1.000000                0.533333
#
# [101 rows x 5 columns]

# %%
data[4:101]
# Out:
#                        App                                  Translated_Review  \
# 4    10 Best Foods for You                                       Best idea us
# 5    10 Best Foods for You                                           Best way
# 6    10 Best Foods for You                                            Amazing
# 7    10 Best Foods for You                                                NaN
# 8    10 Best Foods for You                               Looking forward app,
# ..                     ...                                                ...
# 96   10 Best Foods for You  Love app. It gives way good idea I buying stor...
# 97   10 Best Foods for You  Great Its really best unique provides detailed...
# 98   10 Best Foods for You       Nothing special! Could find anything useful!
# 99   10 Best Foods for You                                  Its ok I love ok.
# 100  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
#
#     Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 4    Positive            1.000000                0.300000
# 5    Positive            1.000000                0.300000
# 6    Positive            0.600000                0.900000
# 7         NaN                 NaN                     NaN
# 8     Neutral            0.000000                0.000000
# ..        ...                 ...                     ...
# 96   Positive            0.400000                0.400000
# 97   Positive            0.579167                0.683333
# 98   Positive            0.410714                0.285714
# 99   Positive            0.500000                0.533333
# 100  Positive            1.000000                0.533333
#
# [97 rows x 5 columns]

# %%
data[95:101]
# Out:
#                        App                                  Translated_Review  \
# 95   10 Best Foods for You  Boring. I thought actually just texts that's i...
# 96   10 Best Foods for You  Love app. It gives way good idea I buying stor...
# 97   10 Best Foods for You  Great Its really best unique provides detailed...
# 98   10 Best Foods for You       Nothing special! Could find anything useful!
# 99   10 Best Foods for You                                  Its ok I love ok.
# 100  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
#
#     Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 95   Negative           -0.325000                0.475000
# 96   Positive            0.400000                0.400000
# 97   Positive            0.579167                0.683333
# 98   Positive            0.410714                0.285714
# 99   Positive            0.500000                0.533333
# 100  Positive            1.000000                0.533333

# %%
data.dtypes
# Out:
# App                        object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
data.add
# Out:
# <bound method _arith_method_FRAME.<locals>.f of                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]>

# %%
data.abs
# Out:
# <bound method NDFrame.abs of                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]>

# %%
data.shape
# Out:
# (64295, 5)
