# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-panda/blob/master/US_Police_Shootings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
USPolice = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/datasets_806447_1382162_shootings.csv")

USPolice
# Out:
#         id                name  ... body_camera          arms_category
# 0        3          Tim Elliot  ...       False                   Guns
# 1        4    Lewis Lee Lembke  ...       False                   Guns
# 2        5  John Paul Quintero  ...       False                Unarmed
# 3        8     Matthew Hoffman  ...       False  Other unusual objects
# 4        9   Michael Rodriguez  ...       False       Piercing objects
# ...    ...                 ...  ...         ...                    ...
# 4890  5916     Rayshard Brooks  ...        True     Electrical devices
# 4891  5925      Caine Van Pelt  ...       False                   Guns
# 4892  5918        Hannah Fizer  ...       False                Unarmed
# 4893  5921      William Slyter  ...       False                   Guns
# 4894  5924      Nicholas Hirsh  ...       False                   Guns
#
# [4895 rows x 15 columns]

# %%
USPolice.head()
# Out:
#    id                name  ... body_camera          arms_category
# 0   3          Tim Elliot  ...       False                   Guns
# 1   4    Lewis Lee Lembke  ...       False                   Guns
# 2   5  John Paul Quintero  ...       False                Unarmed
# 3   8     Matthew Hoffman  ...       False  Other unusual objects
# 4   9   Michael Rodriguez  ...       False       Piercing objects
#
# [5 rows x 15 columns]

# %%
USPolice.tail()
# Out:
#         id             name  ... body_camera       arms_category
# 4890  5916  Rayshard Brooks  ...        True  Electrical devices
# 4891  5925   Caine Van Pelt  ...       False                Guns
# 4892  5918     Hannah Fizer  ...       False             Unarmed
# 4893  5921   William Slyter  ...       False                Guns
# 4894  5924   Nicholas Hirsh  ...       False                Guns
#
# [5 rows x 15 columns]

# %%
USPolice.describe()
# Out:
#                 id          age
# count  4895.000000  4895.000000
# mean   2902.148519    36.549750
# std    1683.467910    12.694348
# min       3.000000     6.000000
# 25%    1441.500000    27.000000
# 50%    2847.000000    35.000000
# 75%    4352.500000    45.000000
# max    5925.000000    91.000000

# %%
USPolice.info
# Out:
# <bound method DataFrame.info of         id                name  ... body_camera          arms_category
# 0        3          Tim Elliot  ...       False                   Guns
# 1        4    Lewis Lee Lembke  ...       False                   Guns
# 2        5  John Paul Quintero  ...       False                Unarmed
# 3        8     Matthew Hoffman  ...       False  Other unusual objects
# 4        9   Michael Rodriguez  ...       False       Piercing objects
# ...    ...                 ...  ...         ...                    ...
# 4890  5916     Rayshard Brooks  ...        True     Electrical devices
# 4891  5925      Caine Van Pelt  ...       False                   Guns
# 4892  5918        Hannah Fizer  ...       False                Unarmed
# 4893  5921      William Slyter  ...       False                   Guns
# 4894  5924      Nicholas Hirsh  ...       False                   Guns
#
# [4895 rows x 15 columns]>

# %%
USPolice.insert
# Out:
# <bound method DataFrame.insert of         id                name  ... body_camera          arms_category
# 0        3          Tim Elliot  ...       False                   Guns
# 1        4    Lewis Lee Lembke  ...       False                   Guns
# 2        5  John Paul Quintero  ...       False                Unarmed
# 3        8     Matthew Hoffman  ...       False  Other unusual objects
# 4        9   Michael Rodriguez  ...       False       Piercing objects
# ...    ...                 ...  ...         ...                    ...
# 4890  5916     Rayshard Brooks  ...        True     Electrical devices
# 4891  5925      Caine Van Pelt  ...       False                   Guns
# 4892  5918        Hannah Fizer  ...       False                Unarmed
# 4893  5921      William Slyter  ...       False                   Guns
# 4894  5924      Nicholas Hirsh  ...       False                   Guns
#
# [4895 rows x 15 columns]>

# %%
USPolice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   object
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("USPolice.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("USPolice.db")
c = conn.cursor()

# %%
USPolice.to_sql("USPolice", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM USPolice""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   3,
#   'Tim Elliot',
#   '2015-01-02',
#   'shot',
#   'gun',
#   53.0,
#   'M',
#   'Asian',
#   'Shelton',
#   'WA',
#   1,
#   'attack',
#   'Not fleeing',
#   0,
#   'Guns'),
#  (1,
#   4,
#   'Lewis Lee Lembke',
#   '2015-01-02',
#   'shot',
#   'gun',
#   47.0,
#   'M',
#   'White',
#   'Aloha',
#   'OR',
#   0,
#   'attack',
#   'Not fleeing',
#   0,
#   'Guns'),
#  (2,
#   5,
#   'John Paul Quintero',
#   '2015-01-03',
#   'shot and Tasered',
#   'unarmed',
#   23.0,
#   'M',
#   'Hispanic',
#   'Wichita',
#   'KS',
#   0,
#   'other',
#   'Not fleeing',
#   0,
#   'Unarmed'),
#  (3,
#   8,
#   'Matthew Hoffman',
#   '2015-01-04',
#   'shot',
#   'toy weapon',
#   32.0,
#   'M',
#   'White',
#   'San Francisco',
#   'CA',
#   1,
#   'attack',
#   'Not fleeing',
#   0,
#   'Other unusual objects'),
#  (4,
#   9,
#   'Michael Rodriguez',
#   '2015-01-04',
#   'shot',
#   'nail gun',
#   39.0,
#   'M',
#   'Hispanic',
#   'Evans',
#   'CO',
#   0,
#   'attack',
# ...

# %%
USPolice.to_excel("USPolice.xls")

pd.read_excel("USPolice.xls")
# Out:
#       Unnamed: 0    id  ... body_camera          arms_category
# 0              0     3  ...       False                   Guns
# 1              1     4  ...       False                   Guns
# 2              2     5  ...       False                Unarmed
# 3              3     8  ...       False  Other unusual objects
# 4              4     9  ...       False       Piercing objects
# ...          ...   ...  ...         ...                    ...
# 4890        4890  5916  ...        True     Electrical devices
# 4891        4891  5925  ...       False                   Guns
# 4892        4892  5918  ...       False                Unarmed
# 4893        4893  5921  ...       False                   Guns
# 4894        4894  5924  ...       False                   Guns
#
# [4895 rows x 16 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('US Police Shootings', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('US Police Shootings')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
