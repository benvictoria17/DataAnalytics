# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/pandas/blob/master/Game_of_Thrones_battles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
battle = pd.read_csv("/content/drive/My Drive/developerProjects/pandas/dataset/Game of Thrones/battles.csv")
deaths = pd.read_csv("/content/drive/My Drive/developerProjects/pandas/dataset/Game of Thrones/character_deaths.csv")
pose = pd.read_csv("/content/drive/My Drive/developerProjects/pandas/dataset/Game of Thrones/character_predictions_pose.csv")
battle.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
battle.head(25)
# Out:
#                              name  ...                                               note
# 0      Battle of the Golden Tooth  ...                                                NaN
# 1     Battle at the Mummer's Ford  ...                                                NaN
# 2              Battle of Riverrun  ...                                                NaN
# 3        Battle of the Green Fork  ...                                                NaN
# 4   Battle of the Whispering Wood  ...                                                NaN
# 5             Battle of the Camps  ...                                                NaN
# 6                   Sack of Darry  ...                                                NaN
# 7           Battle of Moat Cailin  ...                                                NaN
# 8        Battle of Deepwood Motte  ...                                                NaN
# ...

# %%
attac  = battle.attacker_king.value_counts()
attac
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
defs = battle.defender_king.value_counts()
defs
# Out:
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Renly Baratheon              1
# Mance Rayder                 1
# Name: defender_king, dtype: int64

# %%
new_battle = battle.loc[:,['name',"year", "attacker_size", "defender_size"]]
new_battle['sum'] = new_battle.loc[:, 'attacker_size':'defender_size'].sum(axis=1)
new_battle.groupby('sum')['name', 'year'].max().sort_index(ascending=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                    name  year
# sum
# 101240.0         Battle of Castle Black   300
# 38000.0        Battle of the Green Fork   298
# 30000.0             Battle of the Fords   299
# 28250.0        Battle of the Blackwater   299
# 25000.0            Siege of Storm's End   299
# 19000.0      Battle of the Golden Tooth   298
# 18625.0             Battle of the Camps   298
# 16000.0               Battle of Oxcross   299
# 13000.0             Siege of Winterfell   300
# 7875.0    Battle of the Whispering Wood   298
# 7000.0                  The Red Wedding   299
# 6000.0          Battle of the Ruby Ford   299
# 4700.0       Retaking of Deepwood Motte   300
# ...

# %%
pose.head(3)
# Out:
#    s_no   plod                  name  ... ispopular  popularity isalive
# 0     1  0.946  Viserys II Targaryen  ...      True    0.605351   False
# 1     2  0.613           Walder Frey  ...      True    0.896321    True
# 2     3  0.507          Addison Hill  ...     False    0.267559    True
#
# [3 rows x 30 columns]

# %%
pose.columns
# Out:
# Index(['s_no', 'plod', 'name', 'title', 'male', 'culture', 'dateofbirth',
#        'dateofdeath', 'mother', 'father', 'heir', 'house', 'spouse', 'book1',
#        'book2', 'book3', 'book4', 'book5', 'isalivemother', 'isalivefather',
#        'isaliveheir', 'isalivespouse', 'ismarried', 'isnoble', 'age',
#        'numdeadrelations', 'booldeadrelations', 'ispopular', 'popularity',
#        'isalive'],
#       dtype='object')

# %%
pose.isalive.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       False
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1941    False
# 1942    False
# 1943     True
# 1944     True
# 1945    False
# Name: isalive, Length: 1946, dtype: bool>
