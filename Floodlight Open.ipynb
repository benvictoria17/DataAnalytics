# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Floodlight = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/main/dataset/Floodlight%20MS%20Dataset/complete_dataset.csv")
Floodlight
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       floodlightOpenId          participantCreatedOn  participantIsControl  \
# 0           FL10038084  4/23/2018 12:12:03 AM +00:00                  True
# 1           FL33016915   4/23/2018 6:11:44 AM +00:00                  True
# 2           FL26992374  4/23/2018 11:43:21 AM +00:00                  True
# 3           FL26992374  4/23/2018 11:43:21 AM +00:00                  True
# 4           FL26992374  4/23/2018 11:43:21 AM +00:00                  True
# ...                ...                           ...                   ...
# 81114       FL82638826   5/28/2019 6:13:37 PM +00:00                  True
# 81115       FL15803968  7/19/2019 10:14:04 AM +00:00                 False
# ...

# %%
Floodlight.head()
# Out:
#   floodlightOpenId          participantCreatedOn  participantIsControl  \
# 0       FL10038084  4/23/2018 12:12:03 AM +00:00                  True
# 1       FL33016915   4/23/2018 6:11:44 AM +00:00                  True
# 2       FL26992374  4/23/2018 11:43:21 AM +00:00                  True
# 3       FL26992374  4/23/2018 11:43:21 AM +00:00                  True
# 4       FL26992374  4/23/2018 11:43:21 AM +00:00                  True
#
#   participantCountryOfResidence participantSex  participantBirthYear  \
# 0                            US           male                  1966
# 1                            US           male                  1963
# 2                            US           male                  1997
# 3                            US           male                  1997
# 4                            US           male                  1997
#
#    participantWeightLbs  participantHeightCms  \
# 0                 159.0                 178.0
# ...

# %%
Floodlight.tail()
# Out:
#       floodlightOpenId          participantCreatedOn  participantIsControl  \
# 81114       FL82638826   5/28/2019 6:13:37 PM +00:00                  True
# 81115       FL15803968  7/19/2019 10:14:04 AM +00:00                 False
# 81116       FL64900646   6/19/2019 5:48:00 PM +00:00                  True
# 81117       FL64900646   6/19/2019 5:48:00 PM +00:00                  True
# 81118       FL64900646   6/19/2019 5:48:00 PM +00:00                  True
#
#       participantCountryOfResidence participantSex  participantBirthYear  \
# 81114                            CH           male                  1976
# 81115                            IT           male                  1983
# 81116                            IT         female                  1998
# 81117                            IT         female                  1998
# 81118                            IT         female                  1998
#
#        participantWeightLbs  participantHeightCms         testName  \
# ...

# %%
Floodlight.describe()
# Out:
#        participantBirthYear  participantWeightLbs  participantHeightCms  \
# count          81119.000000          81119.000000          81119.000000
# mean            1973.159285            179.265450            171.288428
# std               13.699130             65.639896             12.729977
# min             1900.000000             88.000000            100.000000
# 25%             1964.000000            135.000000            163.000000
# 50%             1972.000000            163.000000            171.000000
# 75%             1983.000000            195.000000            178.000000
# max             2019.000000            525.000000            250.000000
#
#        testResultMetricId  testResultMetricValue  Unnamed: 19
# count        81119.000000           81119.000000          0.0
# mean        136141.678509              38.984743          NaN
# std          52486.890695            3539.694992          NaN
# min              1.000000               0.000000          NaN
# ...

# %%
Floodlight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81119 entries, 0 to 81118
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   floodlightOpenId               81119 non-null  object
#  1   participantCreatedOn           81119 non-null  object
#  2   participantIsControl           81119 non-null  bool
#  3   participantCountryOfResidence  81119 non-null  object
#  4   participantSex                 81119 non-null  object
#  5   participantBirthYear           81119 non-null  int64
#  6   participantWeightLbs           81119 non-null  float64
#  7   participantHeightCms           81119 non-null  float64
#  8   testName                       81119 non-null  object
#  9   testCode                       81119 non-null  object
#  10  testMetricName                 81119 non-null  object
#  11  testMetricCode                 81119 non-null  object
# ...

# %%
Floodlight["floodlightOpenId"].head()

# %%
Floodlight["participantCreatedOn"].head()
# Out:
# 0    4/23/2018 12:12:03 AM +00:00
# 1     4/23/2018 6:11:44 AM +00:00
# 2    4/23/2018 11:43:21 AM +00:00
# 3    4/23/2018 11:43:21 AM +00:00
# 4    4/23/2018 11:43:21 AM +00:00
# Name: participantCreatedOn, dtype: object

# %%
Floodlight["participantCountryOfResidence"].head()
# Out:
# 0    US
# 1    US
# 2    US
# 3    US
# 4    US
# Name: participantCountryOfResidence, dtype: object

# %%
Floodlight["participantSex"].head()
# Out:
# 0    male
# 1    male
# 2    male
# 3    male
# 4    male
# Name: participantSex, dtype: object

# %%
Floodlight["participantBirthYear"].head()
# Out:
# 0    1966
# 1    1963
# 2    1997
# 3    1997
# 4    1997
# Name: participantBirthYear, dtype: int64

# %%
Floodlight["participantWeightLbs"].head()
# Out:
# 0    159.0
# 1    190.0
# 2    195.0
# 3    195.0
# 4    195.0
# Name: participantWeightLbs, dtype: float64

# %%
Floodlight["participantHeightCms"].head()
# Out:
# 0    178.0
# 1    178.0
# 2    188.0
# 3    188.0
# 4    188.0
# Name: participantHeightCms, dtype: float64

# %%
Floodlight["participantHeightCms"].head()
# Out:
# 0    178.0
# 1    178.0
# 2    188.0
# 3    188.0
# 4    188.0
# Name: participantHeightCms, dtype: float64

# %%
testResultMetricCreatedOn	testResultMetricTimestamp1	testResultMetricTimestamp2	testResultMetricValue
Floodlight["testName"].head()
# Out:
# 0                               Daily Questions
# 1                               Daily Questions
# 2                               Daily Questions
# 3    Information Processing Speed Baseline Test
# 4    Information Processing Speed Baseline Test
# Name: testName, dtype: object

# %%
Floodlight["testCode"].head()
# Out:
# 0    daily_questions
# 1    daily_questions
# 2    daily_questions
# 3       ips_baseline
# 4       ips_baseline
# Name: testCode, dtype: object

# %%
Floodlight['testCode'].head()
# Out:
# 0    daily_questions
# 1    daily_questions
# 2    daily_questions
# 3       ips_baseline
# 4       ips_baseline
# Name: testCode, dtype: object

# %%
Floodlight["testMetricName"]
# Out:
# 0                Mood Response
# 1                Mood Response
# 2                Mood Response
# 3            Correct Responses
# 4        Response Time Average
#                  ...
# 81114                Sway Path
# 81115            Mood Response
# 81116         Life Space Daily
# 81117       Successful Pinches
# 81118                Hand Used
# Name: testMetricName, Length: 81119, dtype: object

# %%
Floodlight["testMetricCode"].head()
# Out:
# 0        mood_response
# 1        mood_response
# 2        mood_response
# 3    correct_responses
# 4    response_time_avg
# Name: testMetricCode, dtype: object

# %%
Floodlight['testStartedAt'].head()
# Out:
# 0    4/23/2018 12:22:55 AM +00:00
# 1     4/23/2018 6:21:45 AM +00:00
# 2    4/23/2018 11:47:08 AM +00:00
# 3    4/23/2018 11:49:10 AM +00:00
# 4    4/23/2018 11:49:10 AM +00:00
# Name: testStartedAt, dtype: object

# %%
Floodlight['testEndedAt'].head()
# Out:
# 0    4/23/2018 12:22:55 AM +00:00
# 1     4/23/2018 6:21:45 AM +00:00
# 2    4/23/2018 11:47:08 AM +00:00
# 3    4/23/2018 11:49:26 AM +00:00
# 4    4/23/2018 11:49:26 AM +00:00
# Name: testEndedAt, dtype: object

# %%
Floodlight["testResultMetricId"].head()
# Out:
# 0    115524
# 1    115544
# 2    115666
# 3    115667
# 4    115668
# Name: testResultMetricId, dtype: int64

# %%
Floodlight['testEndedAt'].head()
# Out:
# 0    4/23/2018 12:22:55 AM +00:00
# 1     4/23/2018 6:21:45 AM +00:00
# 2    4/23/2018 11:47:08 AM +00:00
# 3    4/23/2018 11:49:26 AM +00:00
# 4    4/23/2018 11:49:26 AM +00:00
# Name: testEndedAt, dtype: object

# %%
Floodlight['testEndedAt'].head()
# Out:
# 0    4/23/2018 12:22:55 AM +00:00
# 1     4/23/2018 6:21:45 AM +00:00
# 2    4/23/2018 11:47:08 AM +00:00
# 3    4/23/2018 11:49:26 AM +00:00
# 4    4/23/2018 11:49:26 AM +00:00
# Name: testEndedAt, dtype: object

# %%
Floodlight['testEndedAt'].head()
# Out:
# 0    4/23/2018 12:22:55 AM +00:00
# 1     4/23/2018 6:21:45 AM +00:00
# 2    4/23/2018 11:47:08 AM +00:00
# 3    4/23/2018 11:49:26 AM +00:00
# 4    4/23/2018 11:49:26 AM +00:00
# Name: testEndedAt, dtype: object

# %%
import seaborn as sns 
data = sns.load_dataset("iris") 
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.title('Title using Matplotlib Function')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


data = sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.xlim(5)

plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
data = sns.load_dataset("iris") 
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
sns.set_style("dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
sns.despine()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

def plot():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

sns.set_palette('vlag')
plt.subplot(211)

plot()

sns.set_palette('Accent')
plt.subplot(212)
plot()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)


fig = plt.figure(figsize =(5, 4))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

graph()

ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])

graph()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("flights")

plot = sns.PairGrid(data)
plot.map(plt.plot)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.subplot(121)
graph()


plt.subplot(122)
graph()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)


plt.subplot(121)
graph()


plt.subplot(122)
graph()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.subplot(121)
graph()


plt.subplot(122)
graph()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.subplot(121)
graph()


plt.subplot(122)
graph()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("iris")

def graph():
	sns.lineplot(x="sepal_length", y="sepal_width", data=data)

plt.subplot(121)
graph()

plt.subplot(122)
graph()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.relplot(x='sepal_width', y='species', data=data)
  
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.boxplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.violinplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.stripplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.swarmplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.factorplot(x='species', y='sepal_width', data=data)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.histplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.distplot(data['sepal_width'])
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.jointplot(x='species', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.pairplot(data=data, hue='species')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.rugplot(data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("iris")
  
sns.kdeplot(x='sepal_length', y='sepal_width', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("tips")
  
sns.lmplot(x='total_bill', y='tip', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
  
data = sns.load_dataset("tips")
  
sns.regplot(x='total_bill', y='tip', data=data)
plt.show()
