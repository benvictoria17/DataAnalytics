# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/pandas/blob/master/TMDB_Movies_Dataset_(2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
TMDB = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/moviesTMDB2020.csv")

TMDB
# Out:
#              id  ...                                      genre
# 0      211672.0  ...         Family Animation Adventure Comedy
# 1      297762.0  ...                  Action Adventure Fantasy
# 2      321612.0  ...                    Family Fantasy Romance
# 3      339403.0  ...                              Action Crime
# 4      177572.0  ...  Adventure Family Animation Action Comedy
# ...         ...  ...                                        ...
# 58056  656584.0  ...                                        NaN
# 58057  705392.0  ...                                        NaN
# 58058  705161.0  ...                                        NaN
# 58059  705365.0  ...                                        NaN
# 58060  705388.0  ...                                        NaN
#
# [58061 rows x 5 columns]

# %%
TMDB.id
# Out:
# 0        211672.0
# 1        297762.0
# 2        321612.0
# 3        339403.0
# 4        177572.0
#            ...
# 58056    656584.0
# 58057    705392.0
# 58058    705161.0
# 58059    705365.0
# 58060    705388.0
# Name: id, Length: 58061, dtype: float64

# %%
TMDB.original_title
# Out:
# 0                      Minions
# 1                 Wonder Woman
# 2         Beauty and the Beast
# 3                  Baby Driver
# 4                   Big Hero 6
#                  ...
# 58056          An Unquiet Life
# 58057       The Deacon of Doom
# 58058                  Drought
# 58059                 Bad Guys
# 58060    Xane: The Vampire God
# Name: original_title, Length: 58061, dtype: object

# %%
TMDB.overview
# Out:
# 0        Minions Stuart, Kevin and Bob are recruited by...
# 1        An Amazon princess comes to the world of Man t...
# 2        A live-action adaptation of Disney's version o...
# 3        After being coerced into working for a crime b...
# 4        The special bond that develops between plus-si...
#                                ...
# 58056    The story of tumultuous marriage between actre...
# 58057    In the Middle Ages, the sole survivor of an at...
# 58058    It's 1993 and North Carolina is experiencing a...
# 58059    Two young criminals are forced to venture deep...
# 58060    Xane, an immortal vampire, returns to the past...
# Name: overview, Length: 58061, dtype: object

# %%
TMDB.genre
# Out:
# 0               Family Animation Adventure Comedy
# 1                        Action Adventure Fantasy
# 2                          Family Fantasy Romance
# 3                                    Action Crime
# 4        Adventure Family Animation Action Comedy
#                            ...
# 58056                                          NaN
# 58057                                          NaN
# 58058                                          NaN
# 58059                                          NaN
# 58060                                          NaN
# Name: genre, Length: 58061, dtype: object

# %%
TMDB.head()
# Out:
#          id  ...                                      genre
# 0  211672.0  ...         Family Animation Adventure Comedy
# 1  297762.0  ...                  Action Adventure Fantasy
# 2  321612.0  ...                    Family Fantasy Romance
# 3  339403.0  ...                              Action Crime
# 4  177572.0  ...  Adventure Family Animation Action Comedy
#
# [5 rows x 5 columns]

# %%
TMDB.tail()
# Out:
#              id  ... genre
# 58056  656584.0  ...   NaN
# 58057  705392.0  ...   NaN
# 58058  705161.0  ...   NaN
# 58059  705365.0  ...   NaN
# 58060  705388.0  ...   NaN
#
# [5 rows x 5 columns]

# %%
TMDB.describe()
# Out:
#                   id
# count   58060.000000
# mean   204305.612763
# std    211384.628324
# min         2.000000
# 25%     35072.750000
# 50%     96768.500000
# 75%    361270.250000
# max    705472.000000

# %%
TMDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58061 entries, 0 to 58060
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              58060 non-null  float64
#  1   original_title  58060 non-null  object
#  2   poster_path     56164 non-null  object
#  3   overview        57000 non-null  object
#  4   genre           27609 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.2+ MB

# %%
TMDB.info
# Out:
# <bound method DataFrame.info of              id  ...                                      genre
# 0      211672.0  ...         Family Animation Adventure Comedy
# 1      297762.0  ...                  Action Adventure Fantasy
# 2      321612.0  ...                    Family Fantasy Romance
# 3      339403.0  ...                              Action Crime
# 4      177572.0  ...  Adventure Family Animation Action Comedy
# ...         ...  ...                                        ...
# 58056  656584.0  ...                                        NaN
# 58057  705392.0  ...                                        NaN
# 58058  705161.0  ...                                        NaN
# 58059  705365.0  ...                                        NaN
# 58060  705388.0  ...                                        NaN
#
# [58061 rows x 5 columns]>

# %%
conn = sqlite3.connect("TMDB.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("TMDB.db")
c = conn.cursor()

# %%
TMDB.to_sql("TMDB", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM TMDB""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   211672.0,
#   'Minions',
#   '/q0R4crx2SehcEEQEkYObktdeFy.jpg',
#   'Minions Stuart, Kevin and Bob are recruited by Scarlet Overkill, a super-villain who, alongside her inventor husband Herb, hatches a plot to take over the world.',
#   'Family Animation Adventure Comedy '),
#  (1,
#   297762.0,
#   'Wonder Woman',
#   '/imekS7f1OuHyUP2LAiTEM0zBzUz.jpg',
#   'An Amazon princess comes to the world of Man to become the greatest of the female superheroes.',
#   'Action Adventure Fantasy '),
#  (2,
#   321612.0,
#   'Beauty and the Beast',
#   '/tWqifoYuwLETmmasnGHO7xBjEtt.jpg',
#   "A live-action adaptation of Disney's version of the classic 'Beauty and the Beast' tale of a cursed prince and a beautiful young woman who helps him break the spell.",
#   'Family Fantasy Romance '),
#  (3,
#   339403.0,
#   'Baby Driver',
#   '/dN9LbVNNZFITwfaRjl4tmwGWkRg.jpg',
# ...

# %%
TMDB.to_excel("TMDB.xls")

pd.read_excel("TMDB.xls")
# Out:
#        Unnamed: 0  ...                                      genre
# 0               0  ...         Family Animation Adventure Comedy
# 1               1  ...                  Action Adventure Fantasy
# 2               2  ...                    Family Fantasy Romance
# 3               3  ...                              Action Crime
# 4               4  ...  Adventure Family Animation Action Comedy
# ...           ...  ...                                        ...
# 58056       58056  ...                                        NaN
# 58057       58057  ...                                        NaN
# 58058       58058  ...                                        NaN
# 58059       58059  ...                                        NaN
# 58060       58060  ...                                        NaN
#
# [58061 rows x 6 columns]
