# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn

# %%
games = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/My%20Settlers%20of%20Catan%20Games/catanstats.csv")

# %%
games.groupby('player').agg({'me':'count'})
# Out:
#         me
# player
# 1       11
# 2       17
# 3       14
# 4        8

# %%
seaborn.boxplot(games['player'], 
                games['points'], 
                palette=seaborn.light_palette("purple")).set(xlabel='Placement Order', 
                                                             ylabel='Points', 
                                                             title='Settlers of Catan Placement Order vs Points', 
                                                             ylim=(0,14))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 0, 'Placement Order'),
#  Text(0, 0.5, 'Points'),
#  Text(0.5, 1.0, 'Settlers of Catan Placement Order vs Points'),
#  (0.0, 14.0)]

# %%
seaborn.regplot(games['robberCardsGain'], 
                games['points'], 
                color='purple').set(xlabel='Robber Card Gain', 
                                    ylabel='Points', 
                                    title='Robber Card Gain vs Points', 
                                    ylim=(1,13))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 0, 'Robber Card Gain'),
#  Text(0, 0.5, 'Points'),
#  Text(0.5, 1.0, 'Robber Card Gain vs Points'),
#  (1.0, 13.0)]

# %%
seaborn.regplot(games['tradeGain'], 
                games['points'], 
                color='purple').set(xlabel='Trade Gain', 
                                    ylabel='Points', 
                                    title='Trade Gain vs Points', 
                                    ylim=(1,13))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 0, 'Trade Gain'),
#  Text(0, 0.5, 'Points'),
#  Text(0.5, 1.0, 'Trade Gain vs Points'),
#  (1.0, 13.0)]

# %%
seaborn.regplot(games['production'], 
                games['points'], 
                color='purple').set(xlabel='Production', 
                                    ylabel='Points', 
                                    title='Production vs Points', 
                                    ylim=(1,13))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 0, 'Production'),
#  Text(0, 0.5, 'Points'),
#  Text(0.5, 1.0, 'Production vs Points'),
#  (1.0, 13.0)]

# %%
games_trib = games[np.abs(games['tribute'] - np.mean(games['tribute'])) <= 3*games['tribute'].std()]
seaborn.regplot(games_trib['tribute'], 
                games_trib['points'], 
                color='purple').set(xlabel='Cards lost to Tribute', 
                                    ylabel='Points', 
                                    title='Tribute Loss vs Points', 
                                    ylim=(1,13))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 0, 'Cards lost to Tribute'),
#  Text(0, 0.5, 'Points'),
#  Text(0.5, 1.0, 'Tribute Loss vs Points'),
#  (1.0, 13.0)]

# %%
seaborn.regplot(games_trib['totalGain'], 
                games_trib['points'], 
                color='purple').set(xlabel='Total Gain', 
                                    ylabel='Points', 
                                    title='Total Gain vs Points', 
                                    ylim=(1,13))
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 0, 'Total Gain'),
#  Text(0, 0.5, 'Points'),
#  Text(0.5, 1.0, 'Total Gain vs Points'),
#  (1.0, 13.0)]
