# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
Windows10 = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/Windows%2010%20laptop.csv")

Windows10
# Out:
#                                     Category: All categories
# Region                Windows 10 laptop: (8/14/19 - 8/14/20)
# Maine                                                    100
# West Virginia                                             97
# New Hampshire                                             90
# Maryland                                                  89
# Virginia                                                  88
# Delaware                                                  84
# Nebraska                                                  83
# Iowa                                                      82
# Kansas                                                    82
# Missouri                                                  82
# New Mexico                                                82
# Oregon                                                    82
# Oklahoma                                                  82
# ...

# %%
Windows10.head()
# Out:
#                              Category: All categories
# Region         Windows 10 laptop: (8/14/19 - 8/14/20)
# Maine                                             100
# West Virginia                                      97
# New Hampshire                                      90
# Maryland                                           89

# %%
Windows10.tail()
# Out:
#              Category: All categories
# Rhode Island                       71
# Vermont                            67
# Alaska                             64
# South Dakota                       57
# Wyoming                            50

# %%
Windows10.describe()
# Out:
#        Category: All categories
# count                        52
# unique                       24
# top                          82
# freq                          6

# %%
import sqlite3

# %%
conn = sqlite3.connect("Windows10.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Windows10.db")
c = conn.cursor()

# %%
Windows10.to_sql("Windows10", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2612: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM Windows10""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'Windows 10 laptop: (8/14/19 - 8/14/20)'),
#  ('Maine', '100'),
#  ('West Virginia', '97'),
#  ('New Hampshire', '90'),
#  ('Maryland', '89'),
#  ('Virginia', '88'),
#  ('Delaware', '84'),
#  ('Nebraska', '83'),
#  ('Iowa', '82'),
#  ('Kansas', '82'),
#  ('Missouri', '82'),
#  ('New Mexico', '82'),
#  ('Oregon', '82'),
#  ('Oklahoma', '82'),
#  ('Arizona', '81'),
#  ('Tennessee', '81'),
#  ('New Jersey', '81'),
#  ('Utah', '81'),
#  ('Nevada', '80'),
#  ('Arkansas', '80'),
#  ('Connecticut', '80'),
#  ('Kentucky', '80'),
#  ('Texas', '79'),
#  ('Wisconsin', '79'),
#  ('North Carolina', '78'),
#  ('Mississippi', '78'),
#  ('Ohio', '77'),
#  ('Washington', '77'),
#  ('Pennsylvania', '77'),
#  ('Idaho', '77'),
#  ('Indiana', '77'),
#  ('Montana', '76'),
#  ('Florida', '76'),
#  ('Massachusetts', '76'),
#  ('South Carolina', '75'),
#  ('Illinois', '75'),
#  ('District of Columbia', '75'),
#  ('Georgia', '75'),
#  ('Minnesota', '75'),
#  ('Colorado', '74'),
# ...

# %%
Windows10.to_excel("Windows10.xls")

pd.read_excel("Windows10.xls")
# Out:
#               Unnamed: 0                Category: All categories
# 0                 Region  Windows 10 laptop: (8/14/19 - 8/14/20)
# 1                  Maine                                     100
# 2          West Virginia                                      97
# 3          New Hampshire                                      90
# 4               Maryland                                      89
# 5               Virginia                                      88
# 6               Delaware                                      84
# 7               Nebraska                                      83
# 8                   Iowa                                      82
# 9                 Kansas                                      82
# 10              Missouri                                      82
# 11            New Mexico                                      82
# 12                Oregon                                      82
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Windows 10 laptop', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Windows 10 laptop')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
