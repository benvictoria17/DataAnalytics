# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
Softwaredeveloperjob = pd.read_csv("https://query.data.world/s/2cqpevyey6xxmihtjfwfbdyyxk62hm")

Softwaredeveloperjob
# Out:
#                 crawl_timestamp  \
# 0     2019-02-06 05:35:27 +0000
# 1     2019-02-06 05:38:58 +0000
# 2     2019-02-06 05:31:44 +0000
# 3     2019-02-06 05:27:30 +0000
# 4     2019-02-06 05:37:30 +0000
# ...                         ...
# 9995  2019-08-01 11:07:04 +0000
# 9996  2019-08-01 10:55:33 +0000
# 9997  2019-08-01 11:02:12 +0000
# 9998  2019-08-01 11:03:45 +0000
# 9999  2019-08-01 10:56:58 +0000
#
#                                                     url  \
# 0     https://www.careerbuilder.com/job/J3W7NK6NM05P...
# 1     https://www.dice.com/jobs/detail/C%2523-Lead-S...
# 2     https://www.dice.com/jobs/detail/Senior-Softwa...
# 3     https://www.dice.com/jobs/detail/Senior-Softwa...
# 4     https://www.dice.com/jobs/detail/C%2523-Lead-S...
# ...                                                 ...
# 9995  https://www.indeed.com/viewjob?jk=5edeeb79eb9d...
# 9996  https://www.indeed.com/viewjob?jk=2fab75084b6b...
# 9997  https://www.indeed.com/viewjob?jk=f4d38af861af...
# ...

# %%
Softwaredeveloperjob.head()
# Out:
#              crawl_timestamp  \
# 0  2019-02-06 05:35:27 +0000
# 1  2019-02-06 05:38:58 +0000
# 2  2019-02-06 05:31:44 +0000
# 3  2019-02-06 05:27:30 +0000
# 4  2019-02-06 05:37:30 +0000
#
#                                                  url  \
# 0  https://www.careerbuilder.com/job/J3W7NK6NM05P...
# 1  https://www.dice.com/jobs/detail/C%2523-Lead-S...
# 2  https://www.dice.com/jobs/detail/Senior-Softwa...
# 3  https://www.dice.com/jobs/detail/Senior-Softwa...
# 4  https://www.dice.com/jobs/detail/C%2523-Lead-S...
#
#                     job_title                      category  \
# 0      Sr. Software Developer  architecture and engineering
# 1  C# Lead Software Developer                           NaN
# 2   Senior Software Developer                           NaN
# 3   Senior Software Developer                           NaN
# 4  C# Lead Software Developer                           NaN
#
#             company_name          city state country inferred_city  \
# ...

# %%
Softwaredeveloperjob.tail()
# Out:
#                 crawl_timestamp  \
# 9995  2019-08-01 11:07:04 +0000
# 9996  2019-08-01 10:55:33 +0000
# 9997  2019-08-01 11:02:12 +0000
# 9998  2019-08-01 11:03:45 +0000
# 9999  2019-08-01 10:56:58 +0000
#
#                                                     url  \
# 9995  https://www.indeed.com/viewjob?jk=5edeeb79eb9d...
# 9996  https://www.indeed.com/viewjob?jk=2fab75084b6b...
# 9997  https://www.indeed.com/viewjob?jk=f4d38af861af...
# 9998  https://www.indeed.com/viewjob?jk=c1cdf7b9755c...
# 9999  https://www.indeed.com/viewjob?jk=17d7de7a0bb5...
#
#                                               job_title              category  \
# 9995                                 Software Developer  Computer-or-internet
# 9996            Software Developer Technical Specialist  Computer-or-internet
# 9997                                 Software Developer  Computer-or-internet
# 9998  Early Career - Information Technology - Softwa...  Computer-or-internet
# ...

# %%
Softwaredeveloperjob.describe()
# Out:
#        salary_offered        cursor  contact_email
# count             0.0  1.000000e+04            0.0
# mean              NaN  1.558675e+15            NaN
# std               NaN  4.828223e+12            NaN
# min               NaN  1.549433e+15            NaN
# 25%               NaN  1.554620e+15            NaN
# 50%               NaN  1.561036e+15            NaN
# 75%               NaN  1.562897e+15            NaN
# max               NaN  1.564664e+15            NaN

# %%
Softwaredeveloperjob.info
# Out:
# <bound method DataFrame.info of                 crawl_timestamp  \
# 0     2019-02-06 05:35:27 +0000
# 1     2019-02-06 05:38:58 +0000
# 2     2019-02-06 05:31:44 +0000
# 3     2019-02-06 05:27:30 +0000
# 4     2019-02-06 05:37:30 +0000
# ...                         ...
# 9995  2019-08-01 11:07:04 +0000
# 9996  2019-08-01 10:55:33 +0000
# 9997  2019-08-01 11:02:12 +0000
# 9998  2019-08-01 11:03:45 +0000
# 9999  2019-08-01 10:56:58 +0000
#
#                                                     url  \
# 0     https://www.careerbuilder.com/job/J3W7NK6NM05P...
# 1     https://www.dice.com/jobs/detail/C%2523-Lead-S...
# 2     https://www.dice.com/jobs/detail/Senior-Softwa...
# 3     https://www.dice.com/jobs/detail/Senior-Softwa...
# 4     https://www.dice.com/jobs/detail/C%2523-Lead-S...
# ...                                                 ...
# 9995  https://www.indeed.com/viewjob?jk=5edeeb79eb9d...
# 9996  https://www.indeed.com/viewjob?jk=2fab75084b6b...
# ...

# %%
Softwaredeveloperjob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   crawl_timestamp       10000 non-null  object
#  1   url                   10000 non-null  object
#  2   job_title             10000 non-null  object
#  3   category              9161 non-null   object
#  4   company_name          10000 non-null  object
#  5   city                  9869 non-null   object
#  6   state                 8754 non-null   object
#  7   country               10000 non-null  object
#  8   inferred_city         7829 non-null   object
#  9   inferred_state        9207 non-null   object
#  10  inferred_country      9229 non-null   object
#  11  post_date             10000 non-null  object
#  12  job_description       10000 non-null  object
#  13  job_type              10000 non-null  object
#  14  salary_offered        0 non-null      float64
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("Softwaredeveloperjob.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Softwaredeveloperjob.db")
c = conn.cursor()

# %%
Softwaredeveloperjob.to_sql("Softwaredeveloperjob", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM Softwaredeveloperjob""")
rows = c.fetchall()
rows[0:1]
# Out:
# [(0,
#   '2019-02-06 05:35:27 +0000',
#   'https://www.careerbuilder.com/job/J3W7NK6NM05PGMKPC9W',
#   'Sr. Software Developer',
#   'architecture and engineering',
#   'Aerotek',
#   'Raleigh',
#   'NC',
#   'Usa',
#   'Raleigh',
#   'North carolina',
#   'Usa',
#   '2019-02-05',
# ...

# %%
Softwaredeveloperjob.to_excel("Softwaredeveloperjob.xls")

pd.read_excel("Softwaredeveloperjob.xls")
# Out:
#       Unnamed: 0            crawl_timestamp  \
# 0              0  2019-02-06 05:35:27 +0000
# 1              1  2019-02-06 05:38:58 +0000
# 2              2  2019-02-06 05:31:44 +0000
# 3              3  2019-02-06 05:27:30 +0000
# 4              4  2019-02-06 05:37:30 +0000
# ...          ...                        ...
# 9995        9995  2019-08-01 11:07:04 +0000
# 9996        9996  2019-08-01 10:55:33 +0000
# 9997        9997  2019-08-01 11:02:12 +0000
# 9998        9998  2019-08-01 11:03:45 +0000
# 9999        9999  2019-08-01 10:56:58 +0000
#
#                                                     url  \
# 0     https://www.careerbuilder.com/job/J3W7NK6NM05P...
# 1     https://www.dice.com/jobs/detail/C%2523-Lead-S...
# 2     https://www.dice.com/jobs/detail/Senior-Softwa...
# 3     https://www.dice.com/jobs/detail/Senior-Softwa...
# 4     https://www.dice.com/jobs/detail/C%2523-Lead-S...
# ...                                                 ...
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Software developer job listings from USA', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Software developer job listings from USA')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
