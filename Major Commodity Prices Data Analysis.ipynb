# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
plt.style.use("seaborn-notebook")

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/Major%20commodity%20prices%20from%202000-2022/commodity%202000-2022.csv")

# %%
df.value_counts()
# Out:
# Symbol     Date        Open     High      Low       Close     Volume
# Brent Oil  2000-01-04  23.9     24.70     23.89     24.39     32509     1
# Nickel     2020-02-20  12805.0  12800.00  12675.00  12670.00  60448     1
#            2020-03-09  12500.0  12645.00  12465.00  12650.00  111185    1
#            2020-03-06  12810.0  12840.00  12725.00  12840.00  104369    1
#            2020-03-05  12850.0  12890.00  12815.00  12890.00  118853    1
#                                                                        ..
# Gold       2016-10-27  1330.0   1330.00   1330.00   1330.00   3         1
#            2016-10-26  1324.6   1324.60   1324.60   1324.60   279       1
#            2016-10-25  1331.6   1331.60   1331.60   1331.60   61        1
#            2016-10-24  1317.2   1317.20   1317.20   1317.20   42        1
# US Wheat   2022-04-08  1020.0   1054.25   1017.00   1051.50   0         1
# Length: 29935, dtype: int64

# %%
major_list = df["Symbol"].value_counts().reset_index()["index"].tolist()
major_list
# Out:
# ['US Wheat', 'Brent Oil', 'Gold', 'Natural Gas', 'Palladium', 'Nickel']

# %%
df.head()
# Out:
#   Symbol        Date   Open   High    Low  Close  Volume
# 0   Gold  2000-01-04  281.0  281.0  281.0  282.7       4
# 1   Gold  2000-01-05  283.2  283.2  283.2  281.1      16
# 2   Gold  2000-01-06  281.4  281.4  281.4  281.4       0
# 3   Gold  2000-01-07  281.9  281.9  281.9  281.9       0
# 4   Gold  2000-01-10  281.7  281.7  281.7  281.7       0

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  29935.000000  29935.000000  29935.000000  29935.000000  2.993500e+04
# mean    2199.912965   2217.497624   2183.193574   2200.980681  5.272722e+04
# std     5054.172000   5088.374345   5024.451547   5054.979572  8.280148e+04
# min        0.000000      0.000000      0.000000      1.482000  0.000000e+00
# 25%       48.075000     48.975000     47.265000     48.140000  1.000000e+00
# 50%      431.300000    435.500000    428.000000    431.400000  1.157100e+04
# 75%     1165.300000   1173.050000   1158.050000   1168.600000  7.218800e+04
# max    81066.500000  86791.500000  81031.500000  81051.500000  1.083978e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29935 entries, 0 to 29934
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Symbol  29935 non-null  object
#  1   Date    29935 non-null  object
#  2   Open    29935 non-null  float64
#  3   High    29935 non-null  float64
#  4   Low     29935 non-null  float64
#  5   Close   29935 non-null  float64
#  6   Volume  29935 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.6+ MB

# %%
Gold = df[df.Symbol=='Gold'].reset_index(drop=True) 
Gold
# Out:
#      Symbol        Date    Open    High     Low   Close  Volume
# 0      Gold  2000-01-04   281.0   281.0   281.0   282.7       4
# 1      Gold  2000-01-05   283.2   283.2   283.2   281.1      16
# 2      Gold  2000-01-06   281.4   281.4   281.4   281.4       0
# 3      Gold  2000-01-07   281.9   281.9   281.9   281.9       0
# 4      Gold  2000-01-10   281.7   281.7   281.7   281.7       0
# ...     ...         ...     ...     ...     ...     ...     ...
# 5694   Gold  2022-04-04  1921.2  1936.1  1915.6  1929.2     371
# 5695   Gold  2022-04-05  1927.1  1943.5  1918.4  1922.9     412
# 5696   Gold  2022-04-06  1916.7  1931.8  1916.7  1918.4     138
# 5697   Gold  2022-04-07  1919.5  1934.8  1919.5  1933.8     311
# 5698   Gold  2022-04-08  1928.8  1947.7  1928.8  1941.6       0
#
# [5699 rows x 7 columns]

# %%
Palladium = df[df.Symbol=='Palladium'].reset_index(drop=True) 
Palladium
# Out:
#          Symbol        Date     Open     High      Low    Close  Volume
# 0     Palladium  2007-02-28   346.60   353.00   345.00   351.10     132
# 1     Palladium  2007-03-01   351.10   353.10   347.00   348.80     457
# 2     Palladium  2007-03-02   345.75   348.00   345.75   346.10      45
# 3     Palladium  2007-03-05   340.50   345.00   340.50   342.50       3
# 4     Palladium  2007-03-06   342.85   342.85   340.00   347.10      44
# ...         ...         ...      ...      ...      ...      ...     ...
# 3616  Palladium  2022-04-04  2290.02  2339.50  2271.00  2295.00       0
# 3617  Palladium  2022-04-05  2295.02  2318.00  2206.50  2230.02       0
# 3618  Palladium  2022-04-06  2230.52  2273.02  2166.00  2191.50       0
# 3619  Palladium  2022-04-07  2201.27  2276.02  2191.50  2250.00       0
# 3620  Palladium  2022-04-08  2243.77  2465.00  2232.00  2423.00       0
#
# [3621 rows x 7 columns]

# %%
Nickel = df[df.Symbol=='Nickel'].reset_index(drop=True) 
Nickel
# Out:
#       Symbol        Date     Open     High      Low    Close  Volume
# 0     Nickel  2008-07-07  20785.0  20785.0  20785.0  20785.0       0
# 1     Nickel  2008-07-08  20460.0  20460.0  20460.0  20460.0       0
# 2     Nickel  2008-07-09  21309.0  21309.0  21309.0  21309.0       0
# 3     Nickel  2008-07-10  21760.0  21760.0  21760.0  21760.0       0
# 4     Nickel  2008-07-11  21455.0  21455.0  21455.0  21455.0       0
# ...      ...         ...      ...      ...      ...      ...     ...
# 3376  Nickel  2022-04-04  33700.0  33550.0  33600.0  33245.0    3850
# 3377  Nickel  2022-04-05  33900.0  33725.0  33775.0  33312.0    4235
# 3378  Nickel  2022-04-06  33540.0  33470.0  33520.0  33467.0    5897
# 3379  Nickel  2022-04-07  33475.0  33425.0  33475.0  33698.0    4832
# 3380  Nickel  2022-04-08  34100.0  33950.0  34000.0  33855.0       0
#
# [3381 rows x 7 columns]

# %%
Brent_Oil = df[df.Symbol=='Nickel'].reset_index(drop=True)
Brent_Oil
# Out:
#       Symbol        Date     Open     High      Low    Close  Volume
# 0     Nickel  2008-07-07  20785.0  20785.0  20785.0  20785.0       0
# 1     Nickel  2008-07-08  20460.0  20460.0  20460.0  20460.0       0
# 2     Nickel  2008-07-09  21309.0  21309.0  21309.0  21309.0       0
# 3     Nickel  2008-07-10  21760.0  21760.0  21760.0  21760.0       0
# 4     Nickel  2008-07-11  21455.0  21455.0  21455.0  21455.0       0
# ...      ...         ...      ...      ...      ...      ...     ...
# 3376  Nickel  2022-04-04  33700.0  33550.0  33600.0  33245.0    3850
# 3377  Nickel  2022-04-05  33900.0  33725.0  33775.0  33312.0    4235
# 3378  Nickel  2022-04-06  33540.0  33470.0  33520.0  33467.0    5897
# 3379  Nickel  2022-04-07  33475.0  33425.0  33475.0  33698.0    4832
# 3380  Nickel  2022-04-08  34100.0  33950.0  34000.0  33855.0       0
#
# [3381 rows x 7 columns]

# %%
Natural_Gas = df[df.Symbol=='Natural Gas'].reset_index(drop=True)
Natural_Gas
# Out:
#            Symbol        Date   Open   High    Low  Close  Volume
# 0     Natural Gas  2000-01-04  2.130  2.200  2.130  2.176   30152
# 1     Natural Gas  2000-01-05  2.180  2.200  2.125  2.168   27946
# 2     Natural Gas  2000-01-06  2.165  2.220  2.135  2.196   29071
# 3     Natural Gas  2000-01-07  2.195  2.230  2.155  2.173   28455
# 4     Natural Gas  2000-01-10  2.180  2.255  2.165  2.216   28916
# ...           ...         ...    ...    ...    ...    ...     ...
# 5687  Natural Gas  2022-04-04  5.745  5.857  5.650  5.712  137180
# 5688  Natural Gas  2022-04-05  5.782  6.201  5.771  6.032  158216
# 5689  Natural Gas  2022-04-06  6.078  6.394  6.000  6.029  166720
# 5690  Natural Gas  2022-04-07  6.116  6.440  6.000  6.359  199510
# 5691  Natural Gas  2022-04-08  6.411  6.538  6.257  6.278       0
#
# [5692 rows x 7 columns]

# %%
Wheat = df[df.Symbol=='Wheat'].reset_index(drop=True)
Wheat
# Out:
# Empty DataFrame
# Columns: [Symbol, Date, Open, High, Low, Close, Volume]
# Index: []

# %%
def close_price():
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=Gold['Date']
                             , y=Gold['Close']
                             , name='Brent Oil - Close Pricing'
                            ))

    fig.add_trace(go.Scatter(x=Palladium['Date']
                             , y=Palladium['Close']
                             , name='Palladium - Close Pricing'
                            ))

    fig.add_trace(go.Scatter(x=Nickel['Date']
                             , y=Nickel['Close']
                             , name='Nickel - Close Pricing'
                            ))

    fig.add_trace(go.Scatter(x=Brent_Oil['Date']
                             , y=Brent_Oil['Close']
                             , name='Brent Oil - Close Pricing'
                            ))

    fig.add_trace(go.Scatter(x=Natural_Gas['Date']
                             , y=Natural_Gas['Close']
                             , name='Natural Gas - Close Pricing'
                            ))

    fig.add_trace(go.Scatter(x=Wheat['Date']
                             , y=Wheat['Close']
                             , name='Wheat - Close Pricing'
                            ))
    fig.update_layout(
        updatemenus=[
            dict(
                active=0,
                buttons=list([ 

                    dict(label='Gold',
                         method='update',
                         args=[{'visible': [True, True, False, False, False, False, False, False]},
                               {'title': 'Close Pricing (Gold)'}]),

                    dict(label='Palladium',
                         method='update',
                         args=[{'visible': [False, False, True, True, False, False, False, False]},
                               {'title': 'Close Pricing  (Palladium)'}]),


                    dict(label='Nickel',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Nickel)'}]),

                    dict(label='Brent Oil',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Brent Oil)'}]),

                    dict(label='Natural Gas',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Natural Gas)'}]),

                    dict(label='Wheat',
                         method='update',
                        args=[{'visible': [False,  False, False, False, True, True, False, False]},
                               {'title': 'Close Pricing  (Wheat)'}])
                ])
               )
        ])

    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=1, label='6m', step='month', stepmode='backward'),
                dict(count=6, label='1y', step='year', stepmode='backward'),
                dict(count=2, label='2y', step='year',  stepmode='backward'),
                dict(count=5, label='5y', step='year',  stepmode='backward'),
                dict(count=10, label='10y', step='year',  stepmode='backward'),
                dict(count=1, label='YTD',step='year', stepmode='todate')
            ])
        )
    )

    fig.update_layout(title_text='Close Pricing Average')

    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Price ($)')

    fig.show()  
    
close_price()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6f96a27e-0687-40ea-a820-c599613ee026" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f96a27e-0687-40ea-a820-c599613ee026")) {                    Plotly.newPlot(                        "6f96a27e-0687-40ea-a820-c599613ee026",                        [{"name":"Brent Oil - Close Pricing","x":["2000-01-04","2000-01-05","2000-01-06","2000-01-07","2000-01-10","2000-01-11","2000-01-12","2000-01-13","2000-01-14","2000-01-18","2000-01-19","2000-01-20","2000-01-21","2000-01-24","2000-01-25","2000-01-26","2000-01-27","2000-01-28","2000-01-31","2000