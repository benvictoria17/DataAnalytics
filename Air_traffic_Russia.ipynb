# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/pandas/blob/master/Air_traffic_Russia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/datasets_577170_1055509_russian_air_service_CARGO_AND_PARCELS.csv")

# %%
df.head(10)
# Out:
#              Airport name  ...                            Airport coordinates
# 0                  Abakan  ...   (Decimal('91.399735'), Decimal('53.751351'))
# 1                  Aikhal  ...  (Decimal('111.543324'), Decimal('65.957161'))
# 2                    Loss  ...  (Decimal('125.398355'), Decimal('58.602489'))
# 3                 Amderma  ...   (Decimal('61.577429'), Decimal('69.759076'))
# 4         Anadyr (Carbon)  ...  (Decimal('177.738273'), Decimal('64.713433'))
# 5       Anapa (Vitjazevo)  ...   (Decimal('37.341511'), Decimal('45.003748'))
# 6       Apatite (Khibiny)  ...   (Decimal('33.581999'), Decimal('67.459641'))
# 7   Arkhangelsk (Vaskovo)  ...   (Decimal('40.706789'), Decimal('64.592645'))
# 8    Arkhangelsk (Talagy)  ...   (Decimal('40.714892'), Decimal('64.596138'))
# 9  Astrakhan (Narimanovo)  ...   (Decimal('47.999896'), Decimal('46.287344'))
#
# [10 rows x 16 columns]

# %%
df.rename(columns={'Airport name': 'airport', 'Year': 'year', "Whole year" : "whole_year"}, inplace=True)

df
# Out:
#                    airport  ...                            Airport coordinates
# 0                   Abakan  ...   (Decimal('91.399735'), Decimal('53.751351'))
# 1                   Aikhal  ...  (Decimal('111.543324'), Decimal('65.957161'))
# 2                     Loss  ...  (Decimal('125.398355'), Decimal('58.602489'))
# 3                  Amderma  ...   (Decimal('61.577429'), Decimal('69.759076'))
# 4          Anadyr (Carbon)  ...  (Decimal('177.738273'), Decimal('64.713433'))
# ...                    ...  ...                                            ...
# 3956               Yakutsk  ...  (Decimal('129.750225'), Decimal('62.086594'))
# 3957       Yakutsk (Magan)  ...    (Decimal('-6.226888'), Decimal('8.607871'))
# 3958               Yamburg  ...   (Decimal('75.097783'), Decimal('67.980026'))
# 3959  Yaroslavl (Tunoshna)  ...    (Decimal('40.170054'), Decimal('57.56231'))
# 3960              Yartsevo  ...   (Decimal('90.203907'), Decimal('60.252931'))
#
# [3961 rows x 16 columns]

# %%
df.airport.value_counts()
# Out:
# Nyagan                28
# Usinsk                28
# Ust-Tsilma            28
# Vorkuta               28
# Apatite (Khibiny)     14
#                       ..
# Kirov (Pobedilovo)     2
# Nazran (Magas)         2
# Anadyr (Carbon)        2
# Kaluga (Grabtsevo)     2
# Beringovskiy           1
# Name: airport, Length: 298, dtype: int64

# %%
years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
def by_years(year):
    year_of_traffic = df[df["year"] == year]
    mean_traffic = year_of_traffic["whole_year"].mean()
    return mean_traffic

# %%
data = []
for i in years:
    traf_by_years = by_years(i)
    data.append(traf_by_years)

# %%
plt.plot(years,data)

# %%
most_traffic_airport = df[df["whole_year"] == df["whole_year"].max()]
most_traffic_airport
# Out:
#                    airport  ...                           Airport coordinates
# 353  Moscow (Sheremetyevo)  ...  (Decimal('37.405974'), Decimal('55.962962'))
#
# [1 rows x 16 columns]
