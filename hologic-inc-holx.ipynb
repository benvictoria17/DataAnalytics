info
# Out:
# <bound method DataFrame.info of                  Open       High        Low      Close  Adj Close    Volume
# Date
# 1990-03-01   1.968750   2.437500   1.968750   2.390625   2.390625  17829600
# 1990-03-02   2.390625   2.437500   2.250000   2.250000   2.250000   2263200
# 1990-03-05   2.250000   2.312500   2.218750   2.281250   2.281250    741600
# 1990-03-06   2.281250   2.343750   2.187500   2.234375   2.234375    779200
# 1990-03-07   2.234375   2.250000   2.156250   2.156250   2.156250    293600
# ...               ...        ...        ...        ...        ...       ...
# 2020-08-24  66.940002  67.239998  65.110001  65.330002  65.330002   1426900
# 2020-08-25  65.650002  66.199997  64.989998  66.110001  66.110001   1109400
# 2020-08-26  66.059998  66.419998  65.300003  65.910004  65.910004   1044300
# 2020-08-27  60.029999  62.450001  57.939999  61.540001  61.540001   8004300
# 2020-08-28  61.970001  61.970001  59.500000  60.369999  60.369999   4093500
#
# ...

# %%
HOLX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7685 entries, 1990-03-01 to 2020-08-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       7685 non-null   float64
#  1   High       7685 non-null   float64
#  2   Low        7685 non-null   float64
#  3   Close      7685 non-null   float64
#  4   Adj Close  7685 non-null   float64
#  5   Volume     7685 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 420.3 KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("HOLX.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("HOLX.db")
c = conn.cursor()

# %%
HOLX.to_sql("HOLX", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2612: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM HOLXR""")
rows = c.fetchall()
rows
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-14-658fea717159> in <module>
#       1 #See data
# ----> 2 c.execute("""SELECT * FROM HOLXR""")
#       3 rows = c.fetchall()
#       4 rows
#
# OperationalError: no such table: HOLXR

# %%
HOLX.to_excel("HOLX.xls")

pd.read_excel("HOLX.xls")

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Hologic, Inc. (HOLX)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Hologic, Inc. (HOLX)')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
import urllib.request
x = urllib.request.urlopen("https://query1.finance.yahoo.com/v7/finance/download/HOLX?period1=1567110977&period2=1598733377&interval=1d&events=history")

print(x.read())
# Out:
# b'Date,Open,High,Low,Close,Adj Close,Volume\n2019-08-29,48.720001,49.240002,48.490002,49.150002,49.150002,1064100\n2019-08-30,49.270000,49.619999,49.009998,49.369999,49.369999,1515300\n2019-09-03,49.139999,49.139999,47.790001,48.459999,48.459999,1403400\n2019-09-04,48.950001,48.950001,48.099998,48.650002,48.650002,865000\n2019-09-05,49.020000,49.820000,48.790001,49.689999,49.689999,1443400\n2019-09-06,49.910000,50.230000,49.660000,49.709999,49.709999,868600\n2019-09-09,49.790001,49.930000,48.849998,48.980000,48.980000,1039000\n2019-09-10,48.860001,49.090000,47.820000,49.070000,49.070000,1216700\n2019-09-11,49.070000,49.709999,48.910000,49.549999,49.549999,1460300\n2019-09-12,49.820000,50.230000,49.680000,49.820000,49.820000,1373700\n2019-09-13,49.840000,50.040001,49.529999,49.720001,49.720001,1137000\n2019-09-16,49.500000,49.810001,49.189999,49.450001,49.450001,935900\n2019-09-17,49.419998,50.209999,49.419998,50.000000,50.000000,2158400\n2019-09-18,50.139999,50.290001,49.560001,49.99
# ...
