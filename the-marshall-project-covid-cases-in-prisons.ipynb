# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# covid_prison_cases.csv
Marshall = pd.read_csv("https://query.data.world/s/44hjnnjatmebl3wvwsakr4ajd2mdi5")

Marshall
# Out:
#                name abbreviation  staff_tests  staff_tests_with_multiples  \
# 0           Alabama           AL          NaN                         NaN
# 1            Alaska           AK          NaN                         NaN
# 2           Arizona           AZ          NaN                         NaN
# 3          Arkansas           AR       5114.0                         NaN
# 4        California           CA          NaN                         NaN
# ...             ...          ...          ...                         ...
# 1219     Washington           WA          NaN                         NaN
# 1220  West Virginia           WV          NaN                         NaN
# 1221      Wisconsin           WI          NaN                         NaN
# 1222        Wyoming           WY          0.0                         NaN
# 1223        Federal           US          NaN                         NaN
#
#       prisoner_tests  prisoner_tests_with_multiples  total_staff_cases  \
# ...

# %%
# prison_populations.csv
Marshall = pd.read_csv("https://query.data.world/s/l34u3wzyadtw5g4nc6pqsfbhjtcylu")

Marshall
# Out:
#               name abbreviation  march_pop  april_pop  june_pop  \
# 0          Alabama           AL      21114      20655     19752
# 1           Alaska           AK       4776       4277      4216
# 2          Arizona           AZ      42360      41777     40529
# 3         Arkansas           AR      17501      17502     16473
# 4       California           CA     117639     113632    109800
# 5         Colorado           CO      17585      16382     15807
# 6      Connecticut           CT      12290      11454     10206
# 7         Delaware           DE       5042       4624      4233
# 8          Florida           FL      93794      91828     88305
# 9          Georgia           GA      55019      53642     51213
# 10          Hawaii           HI       4836       4260      4404
# 11           Idaho           ID       7816       7641      7798
# 12        Illinois           IL      36931      34668     31945
# 13         Indiana           IN      26936      26418     25385
# ...

# %%
## staff_populations.csv
Marshall = pd.read_csv("https://query.data.world/s/cpr3pfqlhasktwmapypq5tblzajz4f")
Marshall
# Out:
#               name abbreviation  april_pop  as_of_date  \
# 0          Alabama           AL     6259.0   9/30/2019
# 1           Alaska           AK        NaN         NaN
# 2          Arizona           AZ     8700.0   5/11/2020
# 3         Arkansas           AR     4045.0   2/29/2020
# 4       California           CA    46000.0   4/15/2020
# 5         Colorado           CO     6267.0   12/2/2019
# 6      Connecticut           CT     6170.0    3/1/2020
# 7         Delaware           DE     2530.0    5/8/2020
# 8          Florida           FL    22218.0   4/15/2020
# 9          Georgia           GA     8399.0   6/30/2019
# 10          Hawaii           HI        NaN         NaN
# 11           Idaho           ID     1999.0   4/15/2020
# 12        Illinois           IL    11781.0   3/31/2020
# 13         Indiana           IN     6000.0   4/15/2020
# 14            Iowa           IA     2470.0   4/15/2020
# 15          Kansas           KS     3228.0    4/1/2020
# ...

# %%
#### updated_prison_populations.csv
Marshall = pd.read_csv("https://query.data.world/s/5ugjzq4pjk67brqszkca2mj4c2fe5a")

Marshall
# Out:
#               name  march_population as_of_date_march_population  \
# 0          Alabama             20948                     3/31/20
# 1          Arizona             41984                     3/31/20
# 2         Arkansas             17501                     3/15/20
# 3       California            117639                     3/11/20
# 4         Colorado             17412                     3/31/20
# 5      Connecticut              9041                     3/15/20
# 6         Delaware              4030                     3/31/20
# 7          Florida             93794                     3/15/20
# 8          Georgia             54921                      3/1/20
# 9           Hawaii              1623                     3/31/20
# 10           Idaho              7816                     3/16/20
# 11        Illinois             36931                     3/31/20
# 12         Indiana             26891                      3/1/20
# ...

# %%
Marshall.head()
# Out:
#          name  march_population as_of_date_march_population  june_population  \
# 0     Alabama             20948                     3/31/20            19562
# 1     Arizona             41984                     3/31/20            40547
# 2    Arkansas             17501                     3/15/20            16473
# 3  California            117639                     3/11/20           109800
# 4    Colorado             17412                     3/31/20            15251
#
#   as_of_date_june_population  total_change_population  \
# 0                    6/30/20                    -1386
# 1                    6/16/20                    -1437
# 2                    6/16/20                    -1028
# 3                    6/17/20                    -7839
# 4                    6/16/20                    -2161
#
#    total_change_population_percentage  \
# 0                                -6.6
# 1                                -3.4
# 2                                -5.9
# ...

# %%
Marshall.tail()
# Out:
#              name  march_population as_of_date_march_population  \
# 44     Washington             17263                     3/31/20
# 45  West Virginia              5952                     3/15/20
# 46      Wisconsin             23196                     3/13/20
# 47        Wyoming              2156                     3/15/20
# 48        Federal            172088                     3/12/20
#
#     june_population as_of_date_june_population  total_change_population  \
# 44            16084                    5/31/20                    -1179
# 45             4898                    6/15/20                    -1054
# 46            21603                    6/12/20                    -1593
# 47             2001                    6/16/20                     -155
# 48           154707                    6/18/20                   -17381
#
#     total_change_population_percentage  \
# 44                                -6.8
# 45                               -17.7
# ...

# %%
Marshall.describe()
# Out:
#        march_population  june_population  total_change_population  \
# count         49.000000        49.000000                49.000000
# mean       26582.551020     24511.775510             -2070.775510
# std        35339.637225     32334.236555              3173.173111
# min         1268.000000      1068.000000            -17381.000000
# 25%         6558.000000      5813.000000             -2111.000000
# 50%        17263.000000     15251.000000             -1028.000000
# 75%        29161.000000     28595.000000              -481.000000
# max       172088.000000    154707.000000               -70.000000
#
#        total_change_population_percentage
# count                           49.000000
# mean                            -8.736735
# std                              4.430514
# min                            -21.700000
# 25%                            -10.900000
# 50%                             -7.300000
# 75%                             -5.900000
# ...

# %%
Marshall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   name                                49 non-null     object
#  1   march_population                    49 non-null     int64
#  2   as_of_date_march_population         49 non-null     object
#  3   june_population                     49 non-null     int64
#  4   as_of_date_june_population          49 non-null     object
#  5   total_change_population             49 non-null     int64
#  6   total_change_population_percentage  49 non-null     float64
#  7   explanation                         49 non-null     object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 3.2+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("Marshall.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Marshall.db")
c = conn.cursor()

# %%
Marshall.to_sql("Marshall", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM Marshall""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   'Alabama',
#   20948,
#   '3/31/20',
#   19562,
#   '6/30/20',
#   -1386,
#   -6.6,
#   'Numbers reflect Alabama DOC\'s "in house population", which includes those in ADOC major institutions, ADOC Community Work Centers, and ADOC Work Releases. March number obtained from ADOC\'s monthly statistical report, June number reported directly by DOC upon request'),
#  (1,
#   'Arizona',
#   41984,
#   '3/31/20',
#   40547,
#   '6/16/20',
#   -1437,
#   -3.4,
#   "Numbers reflect total inmate population which includes those in Arizona's state prisons, contracted in-state private prisons, and those out to court/out to hospitals. March number obtained from state's monthly report, June number obtain directly from Department of Correction upon request"),
#  (2,
#   'Arkansas',
#   17501,
#   '3/15/20',
#   16473,
#   '6/16/20',
#   -1028,
#   -5.9,
# ...

# %%
Marshall.to_excel("Marshall.xls")

pd.read_excel("Marshall.xls")
# Out:
#     Unnamed: 0            name  march_population as_of_date_march_population  \
# 0            0         Alabama             20948                     3/31/20
# 1            1         Arizona             41984                     3/31/20
# 2            2        Arkansas             17501                     3/15/20
# 3            3      California            117639                     3/11/20
# 4            4        Colorado             17412                     3/31/20
# 5            5     Connecticut              9041                     3/15/20
# 6            6        Delaware              4030                     3/31/20
# 7            7         Florida             93794                     3/15/20
# 8            8         Georgia             54921                      3/1/20
# 9            9          Hawaii              1623                     3/31/20
# 10          10           Idaho              7816                     3/16/20
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('The Marshall Project: COVID Cases in Prisons', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('The Marshall Project: COVID Cases in Prisons')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
