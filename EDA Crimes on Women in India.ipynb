# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria17/DataAnalytics/blob/main/EDA%20Crimes%20on%20Women%20in%20India.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
crime_data_1 = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/main/dataset/Indian%20Women%20Rape%20%26%20Molestation%20Dataset/RS_Session_246_AS11.csv")
crime_data_2 = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/main/dataset/Indian%20Women%20Rape%20%26%20Molestation%20Dataset/RS_Session_246_AU_98_1.1.csv")

# %%
crime_data_1.head()
# Out:
#           States/UTs  Rape - 2015  Rape - 2016  Assaults (molestation) - 2015  \
# 0     Andhra Pradesh         1027          994                           4616
# 1  Arunachal Pradesh           71           92                            101
# 2              Assam         1733         1779                           4293
# 3              Bihar         1041         1008                            198
# 4       Chhattisgarh         1560         1626                           1868
#
#    Assaults (molestation) - 2016  Murder (women) - 2015  Murder (women) - 2016
# 0                           4829                    428                    411
# 1                            109                      9                     11
# 2                           3378                    185                    220
# 3                            324                    340                    318
# 4                           1770                    338                    347

# %%
crime_data_1.tail(10)
# Out:
#            States/UTs  Rape - 2015  Rape - 2016  \
# 29     Total (States)        32328        36657
# 30      A & N Islands           36           30
# 31         Chandigarh           72           68
# 32         D&N Haveli            8           14
# 33        Daman & Diu            5           12
# 34           Delhi UT         2199         2155
# 35        Lakshadweep            0            5
# 36         Puducherry            3            6
# 37        Total (UTs)         2323         2290
# 38  Total (All-India)        34651        38947
#
#     Assaults (molestation) - 2015  Assaults (molestation) - 2016  \
# 29                          76871                          80410
# 30                             57                             46
# 31                             76                             76
# 32                              5                              1
# 33                              7                              4
# 34                           5367                           4165
# 35                              6                              1
# 36                             33                             43
# 37                           5551                           4336
# 38                          82422                          84746
#
#     Murder (women) - 2015  Murder (women) - 2016
# 29                   8142                   8288
# 30                      8                      6
# 31                      3                      3
# 32                      3                      1
# 33                      1                      0
# 34                    124                    123
# 35                      0                      0
# 36                     10                      8
# 37                    149                    141
# 38                   8291                   8429

# %%
crime_data_1.drop([29,37,38],axis=0,inplace=True)
crime_data_1.shape
# Out:
# (36, 7)

# %%
crime_data_2.head()
# Out:
#             State/UT  2014 - Cases registered  2014 - Total rape Cases  \
# 0     Andhra Pradesh                    16526                      961
# 1  Arunachal Pradesh                      351                       83
# 2              Assam                    19169                     1980
# 3              Bihar                    15393                     1127
# 4       Chhattisgarh                     6301                     1436
#
#    2015 - Cases registered  2015 - Total rape Cases  2016 - Cases registered  \
# 0                    15967                     1027                    16362
# 1                      384                       71                      367
# 2                    23365                     1733                    20869
# 3                    13904                     1041                    13400
# 4                     5783                     1560                     5947
#
#    2016 - Total rape Cases
# 0                      994
# 1                       92
# 2                     1779
# 3                     1008
# 4                     1626

# %%
crime_data_2.tail()
# Out:
#              State/UT  2014 - Cases registered  2014 - Total rape Cases  \
# 32        Daman & Diu                       16                        2
# 33              Delhi                    15319                     2096
# 34        Lakshadweep                        4                        1
# 35         Puducherry                       77                       10
# 36  Total (All India)                   339457                    36735
#
#     2015 - Cases registered  2015 - Total rape Cases  2016 - Cases registered  \
# 32                       29                        5                       41
# 33                    17222                     2199                    15310
# 34                        9                        0                        9
# 35                       82                        3                       95
# 36                   329243                    34651                   338954
#
#     2016 - Total rape Cases
# 32                       12
# 33                     2155
# 34                        5
# 35                        6
# 36                    38947

# %%
crime_data_2.drop([36],axis=0,inplace=True)
crime_data_2.shape
# Out:
# (36, 7)

# %%
crime_data_1.rename(columns={"States/UTs":"State/UT"},inplace=True)
crime_data_1.set_index(crime_data_1["State/UT"],inplace=True)
crime_data_1.head()
# Out:
#                             State/UT  Rape - 2015  Rape - 2016  \
# State/UT
# Andhra Pradesh        Andhra Pradesh         1027          994
# Arunachal Pradesh  Arunachal Pradesh           71           92
# Assam                          Assam         1733         1779
# Bihar                          Bihar         1041         1008
# Chhattisgarh            Chhattisgarh         1560         1626
#
#                    Assaults (molestation) - 2015  \
# State/UT
# Andhra Pradesh                              4616
# Arunachal Pradesh                            101
# Assam                                       4293
# Bihar                                        198
# Chhattisgarh                                1868
#
#                    Assaults (molestation) - 2016  Murder (women) - 2015  \
# State/UT
# Andhra Pradesh                              4829                    428
# Arunachal Pradesh                            109                      9
# Assam                                       3378                    185
# Bihar                                        324                    340
# Chhattisgarh                                1770                    338
#
#                    Murder (women) - 2016
# State/UT
# Andhra Pradesh                       411
# Arunachal Pradesh                     11
# Assam                                220
# Bihar                                318
# Chhattisgarh                         347

# %%
crime_data_1.drop(["State/UT"],axis=1,inplace=True)
crime_data_2.set_index(crime_data_2["State/UT"],inplace=True)
crime_data_2.drop(["State/UT"],axis=1,inplace=True)
crime_data_2.head()
# Out:
#                    2014 - Cases registered  2014 - Total rape Cases  \
# State/UT
# Andhra Pradesh                       16526                      961
# Arunachal Pradesh                      351                       83
# Assam                                19169                     1980
# Bihar                                15393                     1127
# Chhattisgarh                          6301                     1436
#
#                    2015 - Cases registered  2015 - Total rape Cases  \
# State/UT
# Andhra Pradesh                       15967                     1027
# Arunachal Pradesh                      384                       71
# Assam                                23365                     1733
# Bihar                                13904                     1041
# Chhattisgarh                          5783                     1560
#
#                    2016 - Cases registered  2016 - Total rape Cases
# State/UT
# Andhra Pradesh                       16362                      994
# Arunachal Pradesh                      367                       92
# Assam                                20869                     1779
# Bihar                                13400                     1008
# Chhattisgarh                          5947                     1626

# %%
crime_data_2.index
# Out:
# Index(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'A & N Island',
#        'Chandigarh', 'D & N Haveli', 'Daman & Diu', 'Delhi', 'Lakshadweep',
#        'Puducherry'],
#       dtype='object', name='State/UT')

# %%
crime_data_2.index
# Out:
# Index(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
#        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'A & N Island',
#        'Chandigarh', 'D & N Haveli', 'Daman & Diu', 'Delhi', 'Lakshadweep',
#        'Puducherry'],
#       dtype='object', name='State/UT')

# %%
crime_data_1.rename(index={"A & N Islands":"A & N Island","D&N Haveli":"D & N Haveli","Delhi UT" : "Delhi"},inplace=True)
data = pd.concat([crime_data_1,crime_data_2],axis=1)
data.head()
# Out:
#                    Rape - 2015  Rape - 2016  Assaults (molestation) - 2015  \
# State/UT
# Andhra Pradesh            1027          994                           4616
# Arunachal Pradesh           71           92                            101
# Assam                     1733         1779                           4293
# Bihar                     1041         1008                            198
# Chhattisgarh              1560         1626                           1868
#
#                    Assaults (molestation) - 2016  Murder (women) - 2015  \
# State/UT
# Andhra Pradesh                              4829                    428
# Arunachal Pradesh                            109                      9
# Assam                                       3378                    185
# Bihar                                        324                    340
# Chhattisgarh                                1770                    338
#
#                    Murder (women) - 2016  2014 - Cases registered  \
# State/UT
# Andhra Pradesh                       411                    16526
# Arunachal Pradesh                     11                      351
# Assam                                220                    19169
# Bihar                                318                    15393
# Chhattisgarh                         347                     6301
#
#                    2014 - Total rape Cases  2015 - Cases registered  \
# State/UT
# Andhra Pradesh                         961                    15967
# Arunachal Pradesh                       83                      384
# Assam                                 1980                    23365
# Bihar                                 1127                    13904
# Chhattisgarh                          1436                     5783
#
#                    2015 - Total rape Cases  2016 - Cases registered  \
# State/UT
# Andhra Pradesh                        1027                    16362
# Arunachal Pradesh                       71                      367
# Assam                                 1733                    20869
# Bihar                                 1041                    13400
# Chhattisgarh                          1560                     5947
#
#                    2016 - Total rape Cases
# State/UT
# Andhra Pradesh                         994
# Arunachal Pradesh                       92
# Assam                                 1779
# Bihar                                 1008
# Chhattisgarh                          1626

# %%
data.shape
# Out:
# (36, 12)

# %%
data.drop(["2015 - Total rape Cases","2016 - Total rape Cases"],axis=1,inplace=True)
data.head()
# Out:
#                    Rape - 2015  Rape - 2016  Assaults (molestation) - 2015  \
# State/UT
# Andhra Pradesh            1027          994                           4616
# Arunachal Pradesh           71           92                            101
# Assam                     1733         1779                           4293
# Bihar                     1041         1008                            198
# Chhattisgarh              1560         1626                           1868
#
#                    Assaults (molestation) - 2016  Murder (women) - 2015  \
# State/UT
# Andhra Pradesh                              4829                    428
# Arunachal Pradesh                            109                      9
# Assam                                       3378                    185
# Bihar                                        324                    340
# Chhattisgarh                                1770                    338
#
#                    Murder (women) - 2016  2014 - Cases registered  \
# State/UT
# Andhra Pradesh                       411                    16526
# Arunachal Pradesh                     11                      351
# Assam                                220                    19169
# Bihar                                318                    15393
# Chhattisgarh                         347                     6301
#
#                    2014 - Total rape Cases  2015 - Cases registered  \
# State/UT
# Andhra Pradesh                         961                    15967
# Arunachal Pradesh                       83                      384
# Assam                                 1980                    23365
# Bihar                                 1127                    13904
# Chhattisgarh                          1436                     5783
#
#                    2016 - Cases registered
# State/UT
# Andhra Pradesh                       16362
# Arunachal Pradesh                      367
# Assam                                20869
# Bihar                                13400
# Chhattisgarh                          5947

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, Andhra Pradesh to Puducherry
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rape - 2015                    36 non-null     int64
#  1   Rape - 2016                    36 non-null     int64
#  2   Assaults (molestation) - 2015  36 non-null     int64
#  3   Assaults (molestation) - 2016  36 non-null     int64
#  4   Murder (women) - 2015          36 non-null     int64
#  5   Murder (women) - 2016          36 non-null     int64
#  6   2014 - Cases registered        36 non-null     int64
#  7   2014 - Total rape Cases        36 non-null     int64
#  8   2015 - Cases registered        36 non-null     int64
#  9   2016 - Cases registered        36 non-null     int64
# dtypes: int64(10)
# memory usage: 3.1+ KB

# %%
plt.figure(figsize=(20,20))

sns.lineplot(x=data.index,y=data["2014 - Cases registered"],ci=None,label="2014")
sns.lineplot(x=data.index,y=data["2015 - Cases registered"],ci=None,label="2015")
sns.lineplot(x=data.index,y=data["2016 - Cases registered"],ci=None,label="2016")

plt.xlabel("States/UTs")
plt.xticks(rotation=90)
plt.title("2014-2015-2016 Total Cases Registered")
plt.ylabel("Total Cases registered")
plt.legend()

# %%
plt.figure(figsize=(20,20))

sns.lineplot(x=data.index,y=data["2014 - Total rape Cases"],ci=None,label="2014")
sns.lineplot(x=data.index,y=data["Rape - 2015"],ci=None,label="2015")
sns.lineplot(x=data.index,y=data["Rape - 2016"],ci=None,label="2016")

plt.xlabel("States/UTs")
plt.xticks(rotation=90)
plt.title("2014-2015-2016 Total Rape Cases")
plt.ylabel("Total Rape Cases")
plt.legend()

# %%
plt.figure(figsize=(20,20))
sns.lineplot(x=data.index,y=(data["2014 - Total rape Cases"]/data["2014 - Cases registered"])*100,ci=None,label="2014")
sns.lineplot(x=data.index,y=(data["Rape - 2015"]/data["2015 - Cases registered"])*100,ci=None,label="2015")
sns.lineplot(x=data.index,y=(data["Rape - 2016"]/data["2016 - Cases registered"])*100,ci=None,label="2016")
plt.xlabel("States/UTs")
plt.xticks(rotation=90)
plt.title("% of Rape Cases during 2014-2016")
plt.ylabel("% of Rape Cases")
plt.legend()

# %%
plt.figure(figsize=(20,20))
sns.lineplot(x=data.index,y=(data["Assaults (molestation) - 2015"]/data["2015 - Cases registered"])*100,ci=None,label="2015")
sns.lineplot(x=data.index,y=(data["Assaults (molestation) - 2016"]/data["2016 - Cases registered"])*100,ci=None,label="2016")

plt.xlabel("States/UTs")
plt.xticks(rotation=90)
plt.title("2015-2016 % of Assaults (Molestation) Cases")
plt.ylabel("% of Assaults( Molestation) Cases")
plt.legend()

# %%
plt.figure(figsize=(20,20))

sns.lineplot(x=data.index,y=(data["Murder (women) - 2015"]/data["2015 - Cases registered"])*100,ci=None,label="2015")
sns.lineplot(x=data.index,y=(data["Murder (women) - 2016"]/data["2016 - Cases registered"])*100,ci=None,label="2016")

plt.xlabel("States/UTs")
plt.xticks(rotation=90)
plt.title("2015-2016 % of Murder Cases")
plt.ylabel("% of Murder Cases")
plt.legend()

# %%
State_UT = []
UTs = ["A & N Island","D & N Haveli","Delhi","Puducherry","Chandigarh","Daman & Diu","Lakshadweep"]
for st in data.index:
    if st not in UTs:
        State_UT.append("State")
    else:
        State_UT.append("UT")
temp = pd.concat([data,pd.DataFrame(data={"State_UT":pd.Series(State_UT,index=data.index)})],axis=1)
temp.head()
# Out:
#                    Rape - 2015  Rape - 2016  Assaults (molestation) - 2015  \
# State/UT
# Andhra Pradesh            1027          994                           4616
# Arunachal Pradesh           71           92                            101
# Assam                     1733         1779                           4293
# Bihar                     1041         1008                            198
# Chhattisgarh              1560         1626                           1868
#
#                    Assaults (molestation) - 2016  Murder (women) - 2015  \
# State/UT
# Andhra Pradesh                              4829                    428
# Arunachal Pradesh                            109                      9
# Assam                                       3378                    185
# Bihar                                        324                    340
# Chhattisgarh                                1770                    338
#
#                    Murder (women) - 2016  2014 - Cases registered  \
# State/UT
# Andhra Pradesh                       411                    16526
# Arunachal Pradesh                     11                      351
# Assam                                220                    19169
# Bihar                                318                    15393
# Chhattisgarh                         347                     6301
#
#                    2014 - Total rape Cases  2015 - Cases registered  \
# State/UT
# Andhra Pradesh                         961                    15967
# Arunachal Pradesh                       83                      384
# Assam                                 1980                    23365
# Bihar                                 1127                    13904
# Chhattisgarh                          1436                     5783
#
#                    2016 - Cases registered State_UT
# State/UT
# Andhra Pradesh                       16362    State
# Arunachal Pradesh                      367    State
# Assam                                20869    State
# Bihar                                13400    State
# Chhattisgarh                          5947    State

# %%
North_India = ["Delhi","Haryana","Jammu & Kashmir","Himachal Pradesh","Uttar Pradesh","Punjab","Uttarakhand"]
West_India = ["D & N Haveli","Daman & Diu","Goa","Gujarat","Maharashtra","Rajasthan"]
South_India = ["Kerala", "Tamil Nadu", "Karnataka", "Andhra Pradesh","Telangana","Puducherry"]
Middle_India = ["Madhya Pradesh","Chhattisgarh"]
East_India = ["Odisha","West Bengal","Bihar","Jharkhand"]
North_East_India = ["Sikkim","Meghalaya","Assam","Arunachal Pradesh","Nagaland","Manipur","Tripura","Mizoram"]
Island_India = ["A & N Island","Lakshadweep"]

# %%
def directionwise(li,col):
    r = []
    for i in li:
        r.append(temp.loc[i,col])
    return pd.Series(r)
def PlotDirectionWise(List,col1,col2,title,ylabel):
    
    plt.figure(figsize=(5,5))

    sns.barplot(x=pd.Series(List),y=(directionwise(List,col1)/directionwise(List,col2))*100,hue=directionwise(List,"State_UT"))

    plt.xlabel("States/UTs")
    plt.xticks(rotation=90)
    plt.title(title)
    plt.ylabel(ylabel)
    plt.legend()
PlotDirectionWise(North_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(North_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(North_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
PlotDirectionWise(West_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(West_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(West_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
PlotDirectionWise(South_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(South_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(South_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
PlotDirectionWise(Middle_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(Middle_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(Middle_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
PlotDirectionWise(East_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(East_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(East_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
PlotDirectionWise(North_East_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(North_East_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(North_East_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
PlotDirectionWise(Island_India,"Rape - 2016","2016 - Cases registered","% of Rape Cases - 2016","% of Rape Cases")

# %%
PlotDirectionWise(Island_India,"Assaults (molestation) - 2016","2016 - Cases registered","% of Assault Cases - 2016","% of Assault")

# %%
PlotDirectionWise(Island_India,"Murder (women) - 2016","2016 - Cases registered","% of Murder Cases - 2016","% of Murders")

# %%
def RankCalculator(data):
    RapePr14 = (data["2014 - Total rape Cases"]/data["2014 - Cases registered"])*100
    RapePr15 = (data["Rape - 2015"]/data["2015 - Cases registered"])*100
    RapePr16 = (data["Rape - 2016"]/data["2016 - Cases registered"])*100
    
    AssaultPr15 = (data["Assaults (molestation) - 2015"]/data["2015 - Cases registered"])*100
    AssaultPr16 = (data["Assaults (molestation) - 2016"]/data["2016 - Cases registered"])*100
    
    MurderPr15 = (data["Murder (women) - 2015"]/data["2015 - Cases registered"])*100
    MurderPr16 = (data["Murder (women) - 2016"]/data["2016 - Cases registered"])*100
    
    
    IncDec = []
    AvgPr = []
    for (r14,r15,r16,a15,a16,m15,m16) in zip(RapePr14,RapePr15,RapePr16,AssaultPr15,AssaultPr16,MurderPr15,MurderPr16):
        
        lr = 0
        if r15>r14:
            lr = 1
        elif r15<r14:
            lr = -1
    
        if r16>r15:
            lr = lr + 1
        elif r16<r15:
            lr = lr - 1
        
        la = 0
        if a16>a15:
            la = 1
        elif a16<a15:
            la = -1
        
        lm = 0
        if m16>m15:
            lm = 1
        elif m16<m15:
            lm = -1
        
        IncDec.append([lr,la,lm])
        AvgPr.append([(r14+r15+r16)/3 , (a15+a16)/2 , (m15+m16)/2])
        
    FinalScore = []
    for ([r,a,m],[ri,ai,mi]) in zip(AvgPr,IncDec):
        cnt = 0
        total = 0
        if ri==-2:
            cnt = 30
            total = 30*r
        elif ri==-1:
            cnt = 40
            total = 40*r
        elif ri==0:
            cnt = 50
            total = 50*r
        elif ri==1:
            cnt = 60
            total = 60*r
        else:
            cnt = 70
            total = 70*r
            
        if ai==-1:
            cnt = cnt+25
            total = total + 25*a
        elif ai==0:
            cnt = cnt+30
            total = total + 30*a
        else:
            cnt = cnt+35
            total = total + 35*a
            
        if mi==-1:
            cnt = cnt+15
            total = total + 15*m
        elif mi==0:
            cnt = cnt+20
            total = total + 20*m
        else:
            cnt = cnt+25
            total = total + 25*m
            
        FinalScore.append(total/cnt)
        
    return pd.DataFrame({"Scores" : pd.Series(FinalScore,index=data.index)})
        
finalScore = RankCalculator(data)
Ranks = finalScore.sort_values("Scores")
Ranks
# Out:
#                       Scores
# State/UT
# Bihar               5.203570
# West Bengal         6.556092
# Assam               8.929264
# Gujarat             9.404833
# Tamil Nadu         10.852439
# Haryana            11.445176
# Telangana          11.635095
# Rajasthan          11.702536
# Jharkhand          12.731914
# Uttar Pradesh      12.810019
# Chandigarh         12.938049
# Andhra Pradesh     13.667173
# Punjab             13.969184
# Delhi              14.240880
# Karnataka          16.198105
# Tripura            16.294590
# Daman & Diu        16.603907
# Maharashtra        17.090522
# Jammu & Kashmir    17.602129
# Uttarakhand        18.015862
# Kerala             18.060487
# Manipur            19.014631
# Madhya Pradesh     19.328868
# Arunachal Pradesh  19.698889
# Himachal Pradesh   19.839248
# Nagaland           20.297215
# Puducherry         20.336838
# Goa                21.677420
# Odisha             23.772360
# Chhattisgarh       24.205184
# Lakshadweep        24.366472
# D & N Haveli       26.184704
# Meghalaya          27.441128
# A & N Island       29.245905
# Sikkim             30.323282
# Mizoram            34.582516

# %%
Ranks.index
# Out:
# Index(['Bihar', 'West Bengal', 'Assam', 'Gujarat', 'Tamil Nadu', 'Haryana',
#        'Telangana', 'Rajasthan', 'Jharkhand', 'Uttar Pradesh', 'Chandigarh',
#        'Andhra Pradesh', 'Punjab', 'Delhi', 'Karnataka', 'Tripura',
#        'Daman & Diu', 'Maharashtra', 'Jammu & Kashmir', 'Uttarakhand',
#        'Kerala', 'Manipur', 'Madhya Pradesh', 'Arunachal Pradesh',
#        'Himachal Pradesh', 'Nagaland', 'Puducherry', 'Goa', 'Odisha',
#        'Chhattisgarh', 'Lakshadweep', 'D & N Haveli', 'Meghalaya',
#        'A & N Island', 'Sikkim', 'Mizoram'],
#       dtype='object', name='State/UT')
