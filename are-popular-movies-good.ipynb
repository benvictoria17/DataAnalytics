# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
popularmovies = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/RProgramming/master/dataset/movies.csv")

popularmovies
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
popularmovies.head()
# Out:
#    Rank                     Title  Year  Score  Metascore  \
# 0     1  The Shawshank Redemption  1994    9.3       80.0
# 1     2           The Dark Knight  2008    9.0       84.0
# 2     3                 Inception  2010    8.8       74.0
# 3     4                Fight Club  1999    8.8       66.0
# 4     5              Pulp Fiction  1994    8.9       94.0
#
#                        Genre     Vote           Director  Runtime  Revenue  \
# 0                      Drama  2011509     Frank Darabont      142    28.34
# 1       Action, Crime, Drama  1980200  Christopher Nolan      152   534.86
# 2  Action, Adventure, Sci-Fi  1760209  Christopher Nolan      148   292.58
# 3                      Drama  1609459      David Fincher      139    37.03
# 4               Crime, Drama  1570194  Quentin Tarantino      154   107.93
#
#                                          Description
# 0  Two imprisoned men bond over a number of years...
# 1  When the menace known as the Joker emerges fro...
# ...

# %%
popularmovies.tail()
# Out:
#        Rank                  Title  Year  Score  Metascore  \
# 9995   9996  When Night Is Falling  1995    6.6        NaN
# 9996   9997                Stachka  1925    7.6        NaN
# 9997   9998     November Criminals  2017    5.3       31.0
# 9998   9999                    120  2008    7.3        NaN
# 9999  10000             The Terror  1963    5.0        NaN
#
#                       Genre  Vote              Director  Runtime  Revenue  \
# 9995         Drama, Romance  6022       Patricia Rozema       94     1.19
# 9996                  Drama  6021  Sergei M. Eisenstein       95      NaN
# 9997  Crime, Drama, Mystery  6020         Sacha Gervasi       85      NaN
# 9998    Drama, History, War  6018            Özhan Eren      114      NaN
# 9999       Horror, Thriller  6015          Roger Corman       81      NaN
#
#                                             Description
# 9995  An uptight and conservative woman, working on ...
# ...

# %%
popularmovies.describe()
# Out:
#               Rank          Year         Score    Metascore          Vote  \
# count  10000.00000  10000.000000  10000.000000  6781.000000  1.000000e+04
# mean    5000.50000   1998.116200      6.627530    56.534140  6.448852e+04
# std     2886.89568     18.249608      1.041204    17.965689  1.249423e+05
# min        1.00000   1915.000000      1.300000    10.000000  6.015000e+03
# 25%     2500.75000   1991.000000      6.000000    44.000000  1.014725e+04
# 50%     5000.50000   2004.000000      6.700000    57.000000  2.117250e+04
# 75%     7500.25000   2011.000000      7.400000    70.000000  6.205200e+04
# max    10000.00000   2018.000000      9.600000    99.000000  2.011509e+06
#
#             Runtime      Revenue
# count  10000.000000  7473.000000
# mean     108.696900    36.263402
# std       21.659929    60.882025
# min       45.000000     0.000000
# 25%       94.000000     1.890000
# 50%      105.000000    15.090000
# 75%      118.000000    43.860000
# ...

# %%
popularmovies.info
# Out:
# <bound method DataFrame.info of        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# ...

# %%
popularmovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         10000 non-null  int64
#  1   Title        10000 non-null  object
#  2   Year         10000 non-null  int64
#  3   Score        10000 non-null  float64
#  4   Metascore    6781 non-null   float64
#  5   Genre        10000 non-null  object
#  6   Vote         10000 non-null  int64
#  7   Director     9999 non-null   object
#  8   Runtime      10000 non-null  int64
#  9   Revenue      7473 non-null   float64
#  10  Description  10000 non-null  object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 859.5+ KB

# %%
conn = sqlite3.connect("popularmovies.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("popularmovies.db")
c = conn.cursor()

# %%
popularmovies.to_sql("popularmovies", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM popularmovies""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   1,
#   'The Shawshank Redemption',
#   1994,
#   9.3,
#   80.0,
#   'Drama',
#   2011509,
#   'Frank Darabont',
#   142,
#   28.34,
#   'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'),
#  (1,
#   2,
#   'The Dark Knight',
#   2008,
#   9.0,
#   84.0,
#   'Action, Crime, Drama',
#   1980200,
#   'Christopher Nolan',
#   152,
#   534.86,
#   'When the menace known as the Joker emerges from his mysterious past, he wreaks havoc and chaos on the people of Gotham. The Dark Knight must accept one of the greatest psychological and physical tests of his ability to fight injustice.'),
#  (2,
#   3,
#   'Inception',
#   2010,
#   8.8,
#   74.0,
#   'Action, Adventure, Sci-Fi',
#   1760209,
#   'Christopher Nolan',
#   148,
#   292.58,
#   'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a CEO.'),
#  (3,
#   4,
# ...

# %%
popularmovies.to_excel("popularmovies.xls")

pd.read_excel("popularmovies.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-eeca003ff73d> in <module>
#       1 popularmovies.to_excel("popularmovies.xls")
#       2
# ----> 3 pd.read_excel("SHOP.xls")
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...
