# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-panda/blob/master/PredictTheWorldCup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
matches = pd.read_csv("https://raw.githubusercontent.com/neaorin/PredictTheWorldCup/master/input/matches.csv")

matches
# Out:
#            date team1   team1Text  ... resText team1PenScore team2PenScore
# 0      19500308   WAL       Wales  ...     0-0           NaN           NaN
# 1      19500402   ESP       Spain  ...     5-1           NaN           NaN
# 2      19500409   POR    Portugal  ...     2-2           NaN           NaN
# 3      19500415   SCO    Scotland  ...     0-1           NaN           NaN
# 4      19500624   BRA      Brazil  ...     4-0           NaN           NaN
# ...         ...   ...         ...  ...     ...           ...           ...
# 31828  20170720   MEX      Mexico  ...     1-0           NaN           NaN
# 31829  20170721   JAM     Jamaica  ...     2-1           NaN           NaN
# 31830  20170723   CRC  Costa Rica  ...     0-2           NaN           NaN
# 31831  20170724   MEX      Mexico  ...     0-1           NaN           NaN
# 31832  20170727   USA         USA  ...     2-1           NaN           NaN
#
# [31833 rows x 14 columns]

# %%
matches.head()
# Out:
#        date team1 team1Text  ... resText team1PenScore team2PenScore
# 0  19500308   WAL     Wales  ...     0-0           NaN           NaN
# 1  19500402   ESP     Spain  ...     5-1           NaN           NaN
# 2  19500409   POR  Portugal  ...     2-2           NaN           NaN
# 3  19500415   SCO  Scotland  ...     0-1           NaN           NaN
# 4  19500624   BRA    Brazil  ...     4-0           NaN           NaN
#
# [5 rows x 14 columns]

# %%
matches.tail()
# Out:
#            date team1   team1Text  ... resText team1PenScore team2PenScore
# 31828  20170720   MEX      Mexico  ...     1-0           NaN           NaN
# 31829  20170721   JAM     Jamaica  ...     2-1           NaN           NaN
# 31830  20170723   CRC  Costa Rica  ...     0-2           NaN           NaN
# 31831  20170724   MEX      Mexico  ...     0-1           NaN           NaN
# 31832  20170727   USA         USA  ...     2-1           NaN           NaN
#
# [5 rows x 14 columns]

# %%
matches.describe()
# Out:
#                date   IdCupSeason  ...  team1PenScore  team2PenScore
# count  3.183300e+04  3.183300e+04  ...     484.000000     484.000000
# mean   1.993968e+07  1.163112e+09  ...       4.010331       3.803719
# std    1.669679e+05  9.865917e+08  ...       1.681065       1.837246
# min    1.950022e+07  6.000000e+00  ...       0.000000       0.000000
# 25%    1.983081e+07  7.761000e+03  ...       3.000000       3.000000
# 50%    1.998021e+07  2.000010e+09  ...       4.000000       4.000000
# 75%    2.007102e+07  2.000010e+09  ...       5.000000       5.000000
# max    2.017123e+07  2.000010e+09  ...      13.000000      12.000000
#
# [8 rows x 6 columns]

# %%
matches.info
# Out:
# <bound method DataFrame.info of            date team1   team1Text  ... resText team1PenScore team2PenScore
# 0      19500308   WAL       Wales  ...     0-0           NaN           NaN
# 1      19500402   ESP       Spain  ...     5-1           NaN           NaN
# 2      19500409   POR    Portugal  ...     2-2           NaN           NaN
# 3      19500415   SCO    Scotland  ...     0-1           NaN           NaN
# 4      19500624   BRA      Brazil  ...     4-0           NaN           NaN
# ...         ...   ...         ...  ...     ...           ...           ...
# 31828  20170720   MEX      Mexico  ...     1-0           NaN           NaN
# 31829  20170721   JAM     Jamaica  ...     2-1           NaN           NaN
# 31830  20170723   CRC  Costa Rica  ...     0-2           NaN           NaN
# 31831  20170724   MEX      Mexico  ...     0-1           NaN           NaN
# 31832  20170727   USA         USA  ...     2-1           NaN           NaN
#
# [31833 rows x 14 columns]>

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31833 entries, 0 to 31832
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           31833 non-null  int64
#  1   team1          31833 non-null  object
#  2   team1Text      31833 non-null  object
#  3   team2          31833 non-null  object
#  4   team2Text      31833 non-null  object
#  5   venue          31770 non-null  object
#  6   IdCupSeason    31833 non-null  int64
#  7   CupName        31833 non-null  object
#  8   team1Score     31820 non-null  float64
#  9   team2Score     31820 non-null  float64
#  10  statText       484 non-null    object
#  11  resText        31460 non-null  object
#  12  team1PenScore  484 non-null    float64
#  13  team2PenScore  484 non-null    float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 3.4+ MB

# %%
import sqlite3

# %%
conn = sqlite3.connect("matches.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("matches.db")
c = conn.cursor()

# %%
matches.to_sql("matches", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM matches""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   19500308,
#   'WAL',
#   'Wales',
#   'NIR',
#   'Northern Ireland',
#   'Cardiff, Wales',
#   6,
#   'FIFA competition team qualification',
#   0.0,
#   0.0,
#   None,
#   '0-0',
#   None,
#   None),
#  (1,
#   19500402,
#   'ESP',
#   'Spain',
#   'POR',
#   'Portugal',
#   'Madrid, Spain',
#   6,
#   'FIFA competition team qualification',
#   5.0,
#   1.0,
#   None,
#   '5-1',
#   None,
#   None),
#  (2,
#   19500409,
#   'POR',
#   'Portugal',
#   'ESP',
#   'Spain',
#   'Lisbon, Portugal',
#   6,
#   'FIFA competition team qualification',
#   2.0,
#   2.0,
#   None,
#   '2-2',
#   None,
#   None),
#  (3,
#   19500415,
#   'SCO',
#   'Scotland',
#   'ENG',
#   'England',
#   'Glasgow, Scotland',
#   6,
#   'FIFA competition team qualification',
#   0.0,
#   1.0,
#   None,
#   '0-1',
#   None,
#   None),
#  (4,
#   19500624,
#   'BRA',
#   'Brazil',
#   'MEX',
#   'Mexico',
#   'Rio De Janeiro, Brazil',
#   7,
#   'FIFA competition team final',
#   4.0,
#   0.0,
# ...

# %%
matches.to_excel("matches.xls")

pd.read_excel("matches.xls")
# Out:
#        Unnamed: 0      date team1  ... resText team1PenScore team2PenScore
# 0               0  19500308   WAL  ...     0-0           NaN           NaN
# 1               1  19500402   ESP  ...     5-1           NaN           NaN
# 2               2  19500409   POR  ...     2-2           NaN           NaN
# 3               3  19500415   SCO  ...     0-1           NaN           NaN
# 4               4  19500624   BRA  ...     4-0           NaN           NaN
# ...           ...       ...   ...  ...     ...           ...           ...
# 31828       31828  20170720   MEX  ...     1-0           NaN           NaN
# 31829       31829  20170721   JAM  ...     2-1           NaN           NaN
# 31830       31830  20170723   CRC  ...     0-2           NaN           NaN
# 31831       31831  20170724   MEX  ...     0-1           NaN           NaN
# 31832       31832  20170727   USA  ...     2-1           NaN           NaN
#
# [31833 rows x 15 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('PredictTheWorldCup', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('PredictTheWorldCup')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.
