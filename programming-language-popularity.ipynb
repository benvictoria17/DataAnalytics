# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
programming = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/programminglanguage.csv")
programming
# Out:
#                                                                                                                                                      Category: All categories
# City          Python: (3/23/20 - 3/23/21) JavaScript: (3/23/20 - 3/23/21) The C++ Programming Language: (3/23/20 - 3/23/21) C: (3/23/20 - 3/23/21)  Java: (3/23/20 - 3/23/21)
# Stanford      NaN                         NaN                             NaN                                               NaN                                           NaN
# Mountain View 39%                         20%                             NaN                                               3%                                            38%
# Sunnyvale     51%                         16%                             NaN                                               4%                                            29%
# Cupertino     48%                         16%                             NaN                                               7%                                            29%
# ...                                                                                                                                                                       ...
# Santa Clarita NaN                         NaN                             NaN                                               NaN                                           NaN
# Santa Ana     NaN                         NaN                             NaN                                               NaN                                           NaN
# Sacramento    34%                         28%                             NaN                                               14%                                           24%
# Fresno        NaN                         NaN                             NaN                                               NaN                                           NaN
# Bakersfield   NaN                         NaN                             NaN                                               NaN                                           NaN
#
# [82 rows x 1 columns]

# %%
programming.head(30)
# Out:
#                                                                                                                                                       Category: All categories
# City           Python: (3/23/20 - 3/23/21) JavaScript: (3/23/20 - 3/23/21) The C++ Programming Language: (3/23/20 - 3/23/21) C: (3/23/20 - 3/23/21)  Java: (3/23/20 - 3/23/21)
# Stanford       NaN                         NaN                             NaN                                               NaN                                           NaN
# Mountain View  39%                         20%                             NaN                                               3%                                            38%
# Sunnyvale      51%                         16%                             NaN                                               4%                                            29%
# Cupertino      48%                         16%                             NaN                                               7%                                            29%
# Palo Alto      62%                         16%                             NaN                                               4%                                            18%
# Albany         66%                         12%                             NaN                                               9%                                            13%
# Newark         50%                         15%                             NaN                                               3%                                            32%
# Berkeley       68%                         14%                             NaN                                               8%                                            10%
# Fremont        51%                         16%                             NaN                                               5%                                            28%
# Foster City    NaN                         NaN                             NaN                                               NaN                                           NaN
# Saratoga       NaN                         NaN                             NaN                                               NaN                                           NaN
# Los Altos      NaN                         NaN                             NaN                                               NaN                                           NaN
# Menlo Park     65%                         15%                             NaN                                               5%                                            15%
# Emeryville     NaN                         NaN                             NaN                                               NaN                                           NaN
# San Mateo      55%                         22%                             NaN                                               4%                                            19%
# San Ramon      51%                         15%                             NaN                                               6%                                            28%
# Coto de Caza   NaN                         NaN                             NaN                                               NaN                                           NaN
# East Palo Alto NaN                         NaN                             NaN                                               NaN                                           NaN
# Davis          62%                         15%                             NaN                                               12%                                           11%
# Cambrian Park  NaN                         NaN                             NaN                                               NaN                                           NaN
# Redwood City   55%                         21%                             NaN                                               6%                                            18%
# Pleasanton     47%                         20%                             NaN                                               6%                                            27%
# Santa Clara    54%                         16%                             NaN                                               7%                                            23%
# Campbell       58%                         20%                             NaN                                               4%                                            18%
# San Jose       NaN                         NaN                             NaN                                               NaN                                           NaN
# Felton         56%                         19%                             NaN                                               16%                                            9%
# Livermore      53%                         15%                             NaN                                               4%                                            28%
# Union City     NaN                         NaN                             NaN                                               NaN                                           NaN
# San Carlos     50%                         21%                             NaN                                               4%                                            25%

# %%
programming.tail(30)
# Out:
#                                  Category: All categories
# Daly City        NaN NaN NaN NaN                      NaN
# Santa Monica     NaN NaN NaN NaN                      NaN
# Los Angeles      46% 25% NaN 8%                       21%
# Lake Forest      NaN NaN NaN NaN                      NaN
# Redondo Beach    NaN NaN NaN NaN                      NaN
# Mountain House   NaN NaN NaN NaN                      NaN
# Torrance         NaN NaN NaN NaN                      NaN
# Encinitas        NaN NaN NaN NaN                      NaN
# Carlsbad         NaN NaN NaN NaN                      NaN
# Richmond         NaN NaN NaN NaN                      NaN
# Newport Beach    NaN NaN NaN NaN                      NaN
# Gilroy           NaN NaN NaN NaN                      NaN
# Glendale         NaN NaN NaN NaN                      NaN
# Burbank          NaN NaN NaN NaN                      NaN
# Mission Viejo    NaN NaN NaN NaN                      NaN
# Fullerton        NaN NaN NaN NaN                      NaN
# Tustin           NaN NaN NaN NaN                      NaN
# Concord          NaN NaN NaN NaN                      NaN
# Huntington Beach NaN NaN NaN NaN                      NaN
# Anaheim          NaN NaN NaN NaN                      NaN
# Camarillo        NaN NaN NaN NaN                      NaN
# Santa Rosa       NaN NaN NaN NaN                      NaN
# Oceanside        NaN NaN NaN NaN                      NaN
# Riverside        49% 19% NaN 11%                      21%
# Long Beach       41% 27% NaN 11%                      21%
# Santa Clarita    NaN NaN NaN NaN                      NaN
# Santa Ana        NaN NaN NaN NaN                      NaN
# Sacramento       34% 28% NaN 14%                      24%
# Fresno           NaN NaN NaN NaN                      NaN
# Bakersfield      NaN NaN NaN NaN                      NaN

# %%
programming.describe()
# Out:
#        Category: All categories
# count                        35
# unique                       22
# top                         21%
# freq                          4

# %%
programming.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 82 entries, ('City', 'Python: (3/23/20 - 3/23/21)', 'JavaScript: (3/23/20 - 3/23/21)', 'The C++ Programming Language: (3/23/20 - 3/23/21)', 'C: (3/23/20 - 3/23/21)') to ('Bakersfield', nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Category: All categories  35 non-null     object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %%
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
sns.displot(data=tips, kind="ecdf", x="total_bill", col="time", hue="smoker", rug=True)

# %%
sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)

# %%
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker")

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.pairplot(data=penguins, hue="species")

# %%
sns.pairplot(data=penguins, hue="species")

# %%
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g"
)

# %%
sns.set_theme(style="ticks", font_scale=1.25)
g = sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g",
    palette="crest", marker="x", s=100,
)
g.set_axis_labels("Bill length (mm)", "Bill depth (mm)", labelpad=10)
g.legend.set_title("Body mass (g)")
g.fig.set_size_inches(6.5, 4.5)
g.ax.margins(.15)
g.despine(trim=True)
