# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns 
# %matplotlib inline

# %%
data_nba = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/main/dataset/NBA%20Player%20Salary%20Dataset%20(2017%20-%202018)/NBA_season1718_salary.csv", index_col=0)

# %%
data_nba.head()
# Out:
#            Player   Tm  season17_18
# 1   Stephen Curry  GSW   34682550.0
# 2    LeBron James  CLE   33285709.0
# 3    Paul Millsap  DEN   31269231.0
# 4  Gordon Hayward  BOS   29727900.0
# 5   Blake Griffin  DET   29512900.0

# %%
data_nba.isnull().sum()
# Out:
# Player         0
# Tm             0
# season17_18    0
# dtype: int64

# %%
data_nba[data_nba['season17_18']==data_nba['season17_18'].max()]
# Out:
#           Player   Tm  season17_18
# 1  Stephen Curry  GSW   34682550.0

# %%
data_nba[data_nba['season17_18']==data_nba['season17_18'].min()]
# Out:
#            Player   Tm  season17_18
# 573  Jarell Eddie  CHI      17224.0

# %%
gkk = data_nba.groupby(['Tm','Player'])
gkk.first()
# Out:
#                         season17_18
# Tm  Player
# ATL Antonius Cleveland      92160.0
#     DeAndre Liggins         26773.0
#     DeAndre' Bembry       1567200.0
#     Dennis Schroder      15500000.0
#     Dewayne Dedmon        6000000.0
# ...                             ...
# WAS Mike Scott            1709538.0
#     Otto Porter          24773250.0
#     Ramon Sessions         263124.0
#     Tim Frazier           2000000.0
#     Tomas Satoransky      3000000.0
#
# [568 rows x 1 columns]

# %%
gk = data_nba.groupby('Tm')
gk.first()
# Out:
#                     Player  season17_18
# Tm
# ATL          Kent Bazemore   16910113.0
# BOS         Gordon Hayward   29727900.0
# BRK           Allen Crabbe   19332500.0
# CHI            Dwyane Wade   15550000.0
# CHO          Dwight Howard   23500000.0
# CLE           LeBron James   33285709.0
# DAL        Harrison Barnes   23112004.0
# DEN           Paul Millsap   31269231.0
# DET          Blake Griffin   29512900.0
# GSW          Stephen Curry   34682550.0
# HOU           James Harden   28299399.0
# IND         Victor Oladipo   21000000.0
# LAC         DeAndre Jordan   22642350.0
# LAL            Brook Lopez   22642350.0
# MEM            Mike Conley   28530608.0
# MIA             Chris Bosh   25289390.0
# MIL  Giannis Antetokounmpo   22471910.0
# MIN           Jimmy Butler   19301070.0
# NOP           Jrue Holiday   25686667.0
# NYK            Enes Kanter   20566802.0
# OKC      Russell Westbrook   28530608.0
# ORL          Evan Fournier   17000000.0
# PHI            J.J. Redick   23000000.0
# PHO            Greg Monroe   17884176.0
# POR         Damian Lillard   26153057.0
# SAC          Zach Randolph   12307692.0
# SAS      LaMarcus Aldridge   21461010.0
# TOR             Kyle Lowry   28703704.0
# UTA            Rudy Gobert   21974719.0
# WAS            Otto Porter   24773250.0

# %%
gk.get_group('GSW')
# Out:
#                Player   Tm  season17_18
# 1       Stephen Curry  GSW   34682550.0
# 16       Kevin Durant  GSW   25000000.0
# 53      Klay Thompson  GSW   17826150.0
# 65     Draymond Green  GSW   16400000.0
# 75     Andre Iguodala  GSW   14814815.0
# 146  Shaun Livingston  GSW    7692308.0
# 197        Nick Young  GSW    5192000.0
# 239     Zaza Pachulia  GSW    3477600.0
# 299        David West  GSW    2328652.0
# 321      JaVale McGee  GSW    2116955.0
# 325       Omri Casspi  GSW    2106470.0
# 395      Kevon Looney  GSW    1471382.0
# 414      Damian Jones  GSW    1312611.0
# 427     Patrick McCaw  GSW    1312611.0
# 458    Jason Thompson  GSW     945126.0
# 461       Jordan Bell  GSW     815615.0

# %%
data_nba['Tm'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>
