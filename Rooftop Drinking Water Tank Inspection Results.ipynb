# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
Water = pd.read_csv("https://query.data.world/s/uwhmraje3jp6gihpcuuq3vqztie56z")

Water
# Out:
#            BIN    BOROUGH    ZIP HOUSE_NUM       STREET_NAME  BLOCK   LOT  \
# 0      1034025  MANHATTAN  10024       320    WEST 89 STREET   1250    47
# 1      1087485  MANHATTAN  10038         8        Spruce St.    100  7502
# 2      1082711  MANHATTAN  10011       455    WEST 23 STREET    721     7
# 3      1038647  MANHATTAN  10017         5  Tudor City Place   1333    23
# 4      1088817  MANHATTAN  10022       432          Park Ave   1292  7502
# ...        ...        ...    ...       ...               ...    ...   ...
# 13479  1080603  MANHATTAN  10001       115      West 31st St    807    50
# 13480  2092723      BRONX  10473       820    Boynton Avenue   3627    40
# 13481  1088764  MANHATTAN  10018       455  WEST   37 STREET    735     6
# 13482  3259642   BROOKLYN  11224      2828      west 28th st   7011    11
# 13483  1038044  MANHATTAN  10017       249      East 48th St   1322  7501
#
#       CONFIRMATION_NUM  REPORTING_YEAR  TANK_NUM  ... ECOLI MEET_STANDARDS  \
# ...

# %%
Water.head()
# Out:
#        BIN    BOROUGH    ZIP HOUSE_NUM       STREET_NAME  BLOCK   LOT  \
# 0  1034025  MANHATTAN  10024       320    WEST 89 STREET   1250    47
# 1  1087485  MANHATTAN  10038         8        Spruce St.    100  7502
# 2  1082711  MANHATTAN  10011       455    WEST 23 STREET    721     7
# 3  1038647  MANHATTAN  10017         5  Tudor City Place   1333    23
# 4  1088817  MANHATTAN  10022       432          Park Ave   1292  7502
#
#   CONFIRMATION_NUM  REPORTING_YEAR  TANK_NUM  ... ECOLI MEET_STANDARDS  \
# 0    WTI9835953296            2015         1  ...     A            NaN
# 1    WTI5946705268            2015         2  ...     A            NaN
# 2    WTI8886837394            2017         1  ...     A            NaN
# 3    WTI5707518714            2016         1  ...     A            NaN
# 4    WTI0290447370            2017         1  ...     A            NaN
#
#     LATITUDE  LONGITUDE COMMUNITY_BOARD COUNCIL_DISTRICT CENSUS_TRACT  \
# ...

# %%
Water.tail()
# Out:
#            BIN    BOROUGH    ZIP HOUSE_NUM       STREET_NAME  BLOCK   LOT  \
# 13479  1080603  MANHATTAN  10001       115      West 31st St    807    50
# 13480  2092723      BRONX  10473       820    Boynton Avenue   3627    40
# 13481  1088764  MANHATTAN  10018       455  WEST   37 STREET    735     6
# 13482  3259642   BROOKLYN  11224      2828      west 28th st   7011    11
# 13483  1038044  MANHATTAN  10017       249      East 48th St   1322  7501
#
#       CONFIRMATION_NUM  REPORTING_YEAR  TANK_NUM  ... ECOLI MEET_STANDARDS  \
# 13479    WTI2985841837            2016         1  ...     A            NaN
# 13480    WTI6412849641            2015         1  ...     A            NaN
# 13481    WTI9580795790            2017         1  ...     A              Y
# 13482    WTI8081627426            2015         1  ...     A            NaN
# 13483    WTI3155103561            2016         1  ...     A            NaN
#
# ...

# %%
Water.describe()
# Out:
#                 BIN           ZIP         BLOCK           LOT  REPORTING_YEAR  \
# count  1.348400e+04  13484.000000  13484.000000  13484.000000    13484.000000
# mean   1.313438e+06  10156.861391   1400.702907   1308.553026     2016.011569
# std    7.700247e+05    360.171788   1419.690313   2817.246492        0.837727
# min    1.000000e+06  10001.000000      0.000000      0.000000     2014.000000
# 25%    1.019876e+06  10016.000000    828.000000     11.000000     2015.000000
# 50%    1.041088e+06  10022.000000   1231.000000     32.000000     2016.000000
# 75%    1.079908e+06  10038.000000   1471.000000     67.000000     2017.000000
# max    5.157402e+06  11694.000000  16177.000000   9078.000000     2018.000000
#
#            TANK_NUM      LATITUDE     LONGITUDE  COMMUNITY_BOARD  \
# count  13484.000000  13425.000000  13425.000000     13425.000000
# mean       1.270320     40.756632    -73.969617         5.805661
# std        0.831573      0.040509      0.036316         2.856156
# ...

# %%
Water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13484 entries, 0 to 13483
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BIN                           13484 non-null  int64
#  1   BOROUGH                       13484 non-null  object
#  2   ZIP                           13484 non-null  int64
#  3   HOUSE_NUM                     13484 non-null  object
#  4   STREET_NAME                   13484 non-null  object
#  5   BLOCK                         13484 non-null  int64
#  6   LOT                           13484 non-null  int64
#  7   CONFIRMATION_NUM              13484 non-null  object
#  8   REPORTING_YEAR                13484 non-null  int64
#  9   TANK_NUM                      13484 non-null  int64
#  10  INSPECTION_BY_FIRM            13482 non-null  object
#  11  INSPECTION_PERFORMED          13484 non-null  object
# ...

# %%
Water.info
# Out:
# <bound method DataFrame.info of            BIN    BOROUGH    ZIP HOUSE_NUM       STREET_NAME  BLOCK   LOT  \
# 0      1034025  MANHATTAN  10024       320    WEST 89 STREET   1250    47
# 1      1087485  MANHATTAN  10038         8        Spruce St.    100  7502
# 2      1082711  MANHATTAN  10011       455    WEST 23 STREET    721     7
# 3      1038647  MANHATTAN  10017         5  Tudor City Place   1333    23
# 4      1088817  MANHATTAN  10022       432          Park Ave   1292  7502
# ...        ...        ...    ...       ...               ...    ...   ...
# 13479  1080603  MANHATTAN  10001       115      West 31st St    807    50
# 13480  2092723      BRONX  10473       820    Boynton Avenue   3627    40
# 13481  1088764  MANHATTAN  10018       455  WEST   37 STREET    735     6
# 13482  3259642   BROOKLYN  11224      2828      west 28th st   7011    11
# 13483  1038044  MANHATTAN  10017       249      East 48th St   1322  7501
#
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("Water.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Water.db")
c = conn.cursor()

# %%
Water.to_sql("Water", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM Water""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   1034025,
#   'MANHATTAN',
#   10024,
#   '320',
#   'WEST 89 STREET',
#   1250,
#   47,
#   'WTI9835953296',
#   2015,
#   1,
#   'ISSEKS BROS INC',
#   'Y',
#   '12/10/2015',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'ENVIRONMENTAL BUILDING SOLUTIONS LLC',
#   'Y',
#   'B',
#   'A',
#   'A',
#   None,
#   40.791082,
#   -73.97710699999999,
#   7.0,
#   6.0,
#   175.0,
#   1012500047.0,
#   'Upper West Side',
#   '05/11/2018 12:15:22 PM'),
#  (1,
#   1087485,
#   'MANHATTAN',
#   10038,
#   '8',
#   'Spruce St.',
#   100,
#   7502,
#   'WTI5946705268',
#   2015,
#   2,
#   'Isseks Bros Inc',
#   'Y',
#   '06/24/2015',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
#   'N',
#   'Y',
# ...

# %%
Water.to_excel("Water.xls")

pd.read_excel("Water.xls")
# Out:
#        Unnamed: 0      BIN    BOROUGH    ZIP HOUSE_NUM       STREET_NAME  \
# 0               0  1034025  MANHATTAN  10024       320    WEST 89 STREET
# 1               1  1087485  MANHATTAN  10038         8        Spruce St.
# 2               2  1082711  MANHATTAN  10011       455    WEST 23 STREET
# 3               3  1038647  MANHATTAN  10017         5  Tudor City Place
# 4               4  1088817  MANHATTAN  10022       432          Park Ave
# ...           ...      ...        ...    ...       ...               ...
# 13479       13479  1080603  MANHATTAN  10001       115      West 31st St
# 13480       13480  2092723      BRONX  10473       820    Boynton Avenue
# 13481       13481  1088764  MANHATTAN  10018       455  WEST   37 STREET
# 13482       13482  3259642   BROOKLYN  11224      2828      west 28th st
# 13483       13483  1038044  MANHATTAN  10017       249      East 48th St
#
#        BLOCK   LOT CONFIRMATION_NUM  REPORTING_YEAR  ...  ECOLI  \
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Rooftop Drinking Water Tank Inspection Results', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X, Y axis Tickmarks (scale of your graph)
plt.yticks([0,1,2,3,4,])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
