# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
Alcoholicdrink =  pd.read_csv("https://query.data.world/s/cbakckyg3svkqklj7ntz6azdje6kws")


Alcoholicdrink
# Out:
#                         id asins                 brand  \
# 0     AV13ClKCGV-KLJ3akN68   NaN                 Gallo
# 1     AV13CsvW-jtxr-f38AQO   NaN       Fresh Craft Co.
# 2     AV13CVI_glJLPUi8O7Po   NaN          1000 Stories
# 3     AV13CVI_glJLPUi8O7Po   NaN          1000 Stories
# 4     AV13CYL4-jtxr-f37_-t   NaN          Wine Cube153
# ...                    ...   ...                   ...
# 2885  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2886  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2887  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2888  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2889  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
#
#                                              categories             dateAdded  \
# 0     Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:11Z
# 1     Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:42Z
# ...

# %%
Alcoholicdrink.head()
# Out:
#                      id asins            brand  \
# 0  AV13ClKCGV-KLJ3akN68   NaN            Gallo
# 1  AV13CsvW-jtxr-f38AQO   NaN  Fresh Craft Co.
# 2  AV13CVI_glJLPUi8O7Po   NaN     1000 Stories
# 3  AV13CVI_glJLPUi8O7Po   NaN     1000 Stories
# 4  AV13CYL4-jtxr-f37_-t   NaN     Wine Cube153
#
#                                           categories             dateAdded  \
# 0  Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:11Z
# 1  Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:42Z
# 2  Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:58:05Z
# 3  Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:58:05Z
# 4  Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:58:18Z
#
#             dateUpdated                                       descriptions  \
# 0  2018-01-10T18:06:28Z                                                NaN
# 1  2018-01-10T05:38:33Z  [{"dateSeen":["2017-12-21T05:43:00.000Z","2017...
# ...

# %%
Alcoholicdrink.tail()
# Out:
#                         id asins                 brand  \
# 2885  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2886  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2887  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2888  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2889  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
#
#                                     categories             dateAdded  \
# 2885  Wine Shop,Kitchen and Food,View All Food  2017-09-25T16:31:30Z
# 2886  Wine Shop,Kitchen and Food,View All Food  2017-09-25T16:31:30Z
# 2887  Wine Shop,Kitchen and Food,View All Food  2017-09-25T16:31:30Z
# 2888  Wine Shop,Kitchen and Food,View All Food  2017-09-25T16:31:30Z
# 2889  Wine Shop,Kitchen and Food,View All Food  2017-09-25T16:31:30Z
#
#                dateUpdated                                       descriptions  \
# 2885  2018-01-03T18:57:51Z  [{"dateSeen":["2017-12-10T09:34:00.000Z","2017...
# ...

# %%
Alcoholicdrink.describe()
# Out:
#          reviews.id  reviews.numHelpful  reviews.rating
# count  1.885000e+03          626.000000     2445.000000
# mean   1.012564e+08            1.282748        4.690798
# std    2.603952e+07            2.906256        0.843344
# min    2.188283e+06            0.000000        1.000000
# 25%    9.674479e+07            0.000000        5.000000
# 50%    1.027956e+08            0.000000        5.000000
# 75%    1.038206e+08            1.000000        5.000000
# max    1.909811e+08           29.000000        5.000000

# %%
Alcoholicdrink.info
# Out:
# <bound method DataFrame.info of                         id asins                 brand  \
# 0     AV13ClKCGV-KLJ3akN68   NaN                 Gallo
# 1     AV13CsvW-jtxr-f38AQO   NaN       Fresh Craft Co.
# 2     AV13CVI_glJLPUi8O7Po   NaN          1000 Stories
# 3     AV13CVI_glJLPUi8O7Po   NaN          1000 Stories
# 4     AV13CYL4-jtxr-f37_-t   NaN          Wine Cube153
# ...                    ...   ...                   ...
# 2885  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2886  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2887  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2888  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2889  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
#
#                                              categories             dateAdded  \
# 0     Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:11Z
# 1     Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:42Z
# ...

# %%
Alcoholicdrink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890 entries, 0 to 2889
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2890 non-null   object
#  1   asins                 870 non-null    object
#  2   brand                 2825 non-null   object
#  3   categories            2890 non-null   object
#  4   dateAdded             2890 non-null   object
#  5   dateUpdated           2890 non-null   object
#  6   descriptions          2738 non-null   object
#  7   dimension             1838 non-null   object
#  8   ean                   2166 non-null   object
#  9   flavors               151 non-null    object
#  10  keys                  2890 non-null   object
#  11  manufacturer          849 non-null    object
#  12  manufacturerNumber    2457 non-null   object
#  13  name                  2890 non-null   object
#  14  reviews.date          2552 non-null   object
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("Alcoholicdrink.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Alcoholicdrink.db")
c = conn.cursor()

# %%
Alcoholicdrink.to_sql("Alcoholicdrink", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM Alcoholicdrink""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   'AV13ClKCGV-KLJ3akN68',
#   None,
#   'Gallo',
#   'Food & Beverage,Beverages,Wine, Beer & Liquor,Wine',
#   '2017-07-24T23:59:11Z',
#   '2018-01-10T18:06:28Z',
#   None,
#   '1.0 in x 1.0 in x 1.0 in',
#   None,
#   None,
#   '492130001994,gallo/13312834',
#   None,
#   '13312834',
#   'Ecco Domani174 Pinot Grigio - 750ml Bottle',
#   '2017-08-01T21:13:49.000Z',
#   '2018-01-09T13:24:04Z',
#   '2017-12-14T19:41:00.000Z,2017-12-19T19:55:00.000Z,2017-12-06T01:40:00.000Z,2017-11-18T20:09:00.000Z,2017-10-26T16:13:00.000Z,2017-08-16T11:20:15.746Z,2017-08-18T18:30:15.452Z,2017-09-01T17:04:29.797Z,2017-08-06T14:00:48.156Z,2017-08-20T18:01:35.030Z,2017-08-08T11:58:19.262Z,2017-08-04T15:49:50.043Z',
#   None,
#   1,
#   None,
#   1.0,
#   5.0,
#   'https://redsky.target.com/groot-domain-api/v1/reviews/13312834?sort=helpfulness_desc&limit=200&offset=0',
#   'This a fantastic white wine for any occasion!',
#   'My Favorite White Wine',
#   None,
#   None,
#   'Bjh',
#   None,
# ...

# %%
Alcoholicdrink.to_excel("Alcoholicdrink.xls")

pd.read_excel("Alcoholicdrink.xls")
# Out:
#       Unnamed: 0                    id asins                 brand  \
# 0              0  AV13ClKCGV-KLJ3akN68   NaN                 Gallo
# 1              1  AV13CsvW-jtxr-f38AQO   NaN       Fresh Craft Co.
# 2              2  AV13CVI_glJLPUi8O7Po   NaN          1000 Stories
# 3              3  AV13CVI_glJLPUi8O7Po   NaN          1000 Stories
# 4              4  AV13CYL4-jtxr-f37_-t   NaN          Wine Cube153
# ...          ...                   ...   ...                   ...
# 2885        2885  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2886        2886  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2887        2887  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2888        2888  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
# 2889        2889  AV654xcDYSSHbkXwoTj_   NaN  Vintage Wine Estates
#
#                                              categories             dateAdded  \
# 0     Food & Beverage,Beverages,Wine, Beer & Liquor,...  2017-07-24T23:59:11Z
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Wine, Beer, and Liquor Reviews', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Wine, Beer, and Liquor Reviews')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
