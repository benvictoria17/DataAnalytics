# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-stock-/blob/master/Windows_Store_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
msft = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-stock-/master/msft.csv")

msft
# Out:
#                                                    Name  ...     Price
# 0                                        Dynamic Reader  ...      Free
# 1     Chemistry, Organic Chemistry and Biochemistry-...  ...      Free
# 2                                            BookViewer  ...      Free
# 3                                    Brick Instructions  ...      Free
# 4     Introduction to Python Programming by GoLearni...  ...      Free
# ...                                                 ...  ...       ...
# 5317                                            JS King  ...  ₹ 269.00
# 5318                                        MQTTSniffer  ...   ₹ 64.00
# 5319                      Dev Utils - JSON, CSV and XML  ...  ₹ 269.00
# 5320                                        Simply Text  ...  ₹ 219.00
# 5321                                                NaN  ...       NaN
#
# [5322 rows x 6 columns]

# %%
msft.head()
# Out:
#                                                 Name  Rating  ...        Date Price
# 0                                     Dynamic Reader     3.5  ...  07-01-2014  Free
# 1  Chemistry, Organic Chemistry and Biochemistry-...     3.0  ...  08-01-2014  Free
# 2                                         BookViewer     3.5  ...  29-02-2016  Free
# 3                                 Brick Instructions     3.5  ...  30-01-2018  Free
# 4  Introduction to Python Programming by GoLearni...     2.0  ...  30-01-2018  Free
#
# [5 rows x 6 columns]

# %%
msft.tail()
# Out:
#                                Name  Rating  ...        Date     Price
# 5317                        JS King     1.0  ...  19-07-2018  ₹ 269.00
# 5318                    MQTTSniffer     2.5  ...  10-04-2017   ₹ 64.00
# 5319  Dev Utils - JSON, CSV and XML     4.0  ...  18-11-2019  ₹ 269.00
# 5320                    Simply Text     4.0  ...  23-01-2014  ₹ 219.00
# 5321                            NaN     NaN  ...         NaN       NaN
#
# [5 rows x 6 columns]

# %%
msft.describe()
# Out:
#             Rating  No of people Rated
# count  5321.000000         5322.000000
# mean      3.792708          551.873168
# std       0.991681          259.820088
# min       1.000000          100.000000
# 25%       3.500000          327.000000
# 50%       4.000000          548.000000
# 75%       4.500000          779.000000
# max       5.000000         1000.000000

# %%
msft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322 entries, 0 to 5321
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                5321 non-null   object
#  1   Rating              5321 non-null   float64
#  2   No of people Rated  5322 non-null   int64
#  3   Category            5321 non-null   object
#  4   Date                5321 non-null   object
#  5   Price               5321 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 249.6+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("msft.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("msft.db")
c = conn.cursor()

# %%
msft.to_sql("msft", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM msft""")
rows = c.fetchall()
rows
# Out:
# [(0, 'Dynamic Reader', 3.5, 268, 'Books', '07-01-2014', 'Free'),
#  (1,
#   'Chemistry, Organic Chemistry and Biochemistry-simpleNeasyApp by WAGmob',
#   3.0,
#   627,
#   'Books',
#   '08-01-2014',
#   'Free'),
#  (2, 'BookViewer', 3.5, 593, 'Books', '29-02-2016', 'Free'),
#  (3, 'Brick Instructions', 3.5, 684, 'Books', '30-01-2018', 'Free'),
#  (4,
#   'Introduction to Python Programming by GoLearningBus',
#   2.0,
#   634,
#   'Books',
#   '30-01-2018',
#   'Free'),
#  (5, 'Gurbani Reader', 4.5, 399, 'Books', '18-01-2017', 'Free'),
#  (6, 'NFO Viewer', 4.5, 566, 'Books', '13-11-2012', 'Free'),
#  (7, 'Text to Speech TTS', 3.0, 175, 'Books', '17-10-2013', 'Free'),
#  (8, 'ACK Comics', 4.0, 460, 'Books', '20-12-2012', 'Free'),
#  (9,
#   'Learn Biology and Human Body Anatomy by GoLearningBus',
#   3.5,
#   363,
#   'Books',
#   '25-11-2013',
#   'Free'),
#  (10, 'Coding Made Easy - SQL', 4.0, 774, 'Books', '30-01-2018', 'Free'),
# ...

# %%
msft.to_excel("msft.xls")

pd.read_excel("msft.xls")
# Out:
#       Unnamed: 0  ...     Price
# 0              0  ...      Free
# 1              1  ...      Free
# 2              2  ...      Free
# 3              3  ...      Free
# 4              4  ...      Free
# ...          ...  ...       ...
# 5317        5317  ...  ₹ 269.00
# 5318        5318  ...   ₹ 64.00
# 5319        5319  ...  ₹ 269.00
# 5320        5320  ...  ₹ 219.00
# 5321        5321  ...       NaN
#
# [5322 rows x 7 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Windows Store.', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Windows Store.')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.
