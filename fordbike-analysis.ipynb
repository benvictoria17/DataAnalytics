# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
bike2019 =pd.read_csv('../input/ford-gobike-2019feb-tripdata/201902-fordgobike-tripdata.csv')

# %%
bike2019.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 1               37.791464              -122.391034            81.0
# 2               37.769305              -122.426826             3.0
# 3               37.774836              -122.446546            70.0
# 4               37.804562              -122.271738           222.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 1                            Berry St at 4th St             37.775880
# 2  Powell St BART Station (Market St at 4th St)             37.786375
# 3                        Central Ave at Fell St             37.773311
# 4                         10th Ave at E 15th St             37.792714
#
#    end_station_longitude  bike_id   user_type  member_birth_year  \
# 0            -122.402923     4902    Customer             1984.0
# 1            -122.393170     2535    Customer                NaN
# 2            -122.404904     5905    Customer             1972.0
# 3            -122.444293     6638  Subscriber             1989.0
# 4            -122.248780     4898  Subscriber             1974.0
#
#   member_gender bike_share_for_all_trip
# 0          Male                      No
# 1           NaN                      No
# 2          Male                      No
# 3         Other                      No
# 4          Male                     Yes

# %%
bike2019.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183412.000000     183215.000000           183412.000000
# mean      726.078435        138.590427               37.771223
# std      1794.389780        111.778864                0.099581
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183412.000000   183215.000000         183412.000000
# mean               -122.352664      136.249123             37.771427
# std                   0.117097      111.515131              0.099490
# min                -122.453704        3.000000             37.317298
# 25%                -122.412408       44.000000             37.770407
# 50%                -122.398285      100.000000             37.781010
# 75%                -122.286533      235.000000             37.797320
# max                -121.874119      398.000000             37.880222
#
#        end_station_longitude        bike_id  member_birth_year
# count          183412.000000  183412.000000      175147.000000
# mean             -122.352250    4472.906375        1984.806437
# std                 0.116673    1664.383394          10.116689
# min              -122.453704      11.000000        1878.000000
# 25%              -122.411726    3777.000000        1980.000000
# 50%              -122.398279    4958.000000        1987.000000
# 75%              -122.288045    5502.000000        1992.000000
# max              -121.874119    6645.000000        2001.000000

# %%
bike2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
#  13  member_birth_year        175147 non-null  float64
#  14  member_gender            175147 non-null  object
#  15  bike_share_for_all_trip  183412 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %%
bike2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
#  13  member_birth_year        175147 non-null  float64
#  14  member_gender            175147 non-null  object
#  15  bike_share_for_all_trip  183412 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %%
bike2019[bike2019.start_station_name.isnull()][["start_station_name","start_station_latitude","start_station_longitude","end_station_name","end_station_latitude","end_station_longitude"]]
# Out:
#        start_station_name  start_station_latitude  start_station_longitude  \
# 475                   NaN                   37.40                  -121.94
# 1733                  NaN                   37.40                  -121.94
# 3625                  NaN                   37.41                  -121.95
# 4070                  NaN                   37.39                  -121.93
# 5654                  NaN                   37.40                  -121.92
# ...                   ...                     ...                      ...
# 176154                NaN                   37.40                  -121.93
# 179730                NaN                   37.40                  -121.94
# 179970                NaN                   37.41                  -121.96
# 180106                NaN                   37.40                  -121.94
# 181201                NaN                   37.40                  -121.93
#
#        end_station_name  end_station_latitude  end_station_longitude
# 475                 NaN                 37.40                -121.93
# 1733                NaN                 37.41                -121.96
# 3625                NaN                 37.41                -121.96
# 4070                NaN                 37.40                -121.92
# 5654                NaN                 37.39                -121.93
# ...                 ...                   ...                    ...
# 176154              NaN                 37.40                -121.93
# 179730              NaN                 37.40                -121.93
# 179970              NaN                 37.41                -121.94
# 180106              NaN                 37.40                -121.94
# 181201              NaN                 37.40                -121.93
#
# [197 rows x 6 columns]

# %%
bike2019[bike2019.start_station_name.isnull()][["start_station_name","start_station_latitude","start_station_longitude","end_station_name","end_station_latitude","end_station_longitude"]]
# Out:
#        start_station_name  start_station_latitude  start_station_longitude  \
# 475                   NaN                   37.40                  -121.94
# 1733                  NaN                   37.40                  -121.94
# 3625                  NaN                   37.41                  -121.95
# 4070                  NaN                   37.39                  -121.93
# 5654                  NaN                   37.40                  -121.92
# ...                   ...                     ...                      ...
# 176154                NaN                   37.40                  -121.93
# 179730                NaN                   37.40                  -121.94
# 179970                NaN                   37.41                  -121.96
# 180106                NaN                   37.40                  -121.94
# 181201                NaN                   37.40                  -121.93
#
#        end_station_name  end_station_latitude  end_station_longitude
# 475                 NaN                 37.40                -121.93
# 1733                NaN                 37.41                -121.96
# 3625                NaN                 37.41                -121.96
# 4070                NaN                 37.40                -121.92
# 5654                NaN                 37.39                -121.93
# ...                 ...                   ...                    ...
# 176154              NaN                 37.40                -121.93
# 179730              NaN                 37.40                -121.93
# 179970              NaN                 37.41                -121.94
# 180106              NaN                 37.40                -121.94
# 181201              NaN                 37.40                -121.93
#
# [197 rows x 6 columns]

# %%
bike2019[bike2019.start_station_name.isnull()].equals(bike2019[bike2019.end_station_name.isnull()])
# Out:
# True

# %%
bike2019["start_time"]= pd.to_datetime(bike2019["start_time"])
bike2019["end_time"]= pd.to_datetime(bike2019["end_time"])
check = bike2019['start_time'] + pd.to_timedelta(bike2019['duration_sec'], unit='s')
check
# Out:
# 0        2019-03-01 08:01:55.145
# 1        2019-03-01 06:42:02.789
# 2        2019-03-01 05:24:07.218
# 3        2019-03-01 04:02:36.010
# 4        2019-03-01 00:20:43.549
#                    ...
# 183407   2019-02-01 00:12:49.724
# 183408   2019-02-01 00:10:47.744
# 183409   2019-02-01 00:08:26.549
# 183410   2019-02-01 00:07:53.360
# 183411   2019-02-01 00:04:51.636
# Length: 183412, dtype: datetime64[ns]

# %%
differnce = pd.concat([bike2019['end_time'],check,bike2019['end_time']-check],axis=1)
differnce.columns = ["End_time","Calculated End_time","Absoulte Difference"]
differnce
# Out:
#                       End_time     Calculated End_time    Absoulte Difference
# 0      2019-03-01 08:01:55.975 2019-03-01 08:01:55.145 0 days 00:00:00.830000
# 1      2019-03-01 06:42:03.056 2019-03-01 06:42:02.789 0 days 00:00:00.267000
# 2      2019-03-01 05:24:08.146 2019-03-01 05:24:07.218 0 days 00:00:00.928000
# 3      2019-03-01 04:02:36.842 2019-03-01 04:02:36.010 0 days 00:00:00.832000
# 4      2019-03-01 00:20:44.074 2019-03-01 00:20:43.549 0 days 00:00:00.525000
# ...                        ...                     ...                    ...
# 183407 2019-02-01 00:12:50.034 2019-02-01 00:12:49.724 0 days 00:00:00.310000
# 183408 2019-02-01 00:10:48.502 2019-02-01 00:10:47.744 0 days 00:00:00.758000
# 183409 2019-02-01 00:08:27.220 2019-02-01 00:08:26.549 0 days 00:00:00.671000
# 183410 2019-02-01 00:07:54.287 2019-02-01 00:07:53.360 0 days 00:00:00.927000
# 183411 2019-02-01 00:04:52.058 2019-02-01 00:04:51.636 0 days 00:00:00.422000
#
# [183412 rows x 3 columns]

# %%
from datetime import datetime, timedelta 
print("Minimum Difference:",differnce["Absoulte Difference"].min())
print("Mean Difference:",differnce["Absoulte Difference"].mean())
print("Max Difference:",differnce["Absoulte Difference"].max())
# Out:
# Minimum Difference: 0 days 00:00:00
# Mean Difference: 0 days 00:00:00.499112729
# Max Difference: 0 days 00:00:00.999000

# %%
print("Average Age:", 2021- bike2019.member_birth_year.mean())
print("Average Male Age:", 2021- bike2019[bike2019["member_gender"]=="Male"].member_birth_year.mean())
print("Average Female Age:", 2021- bike2019[bike2019["member_gender"]=="Female"].member_birth_year.mean())
# Out:
# Average Age: 36.19356312126388
# Average Male Age: 36.451600064293416
# Average Female Age: 35.217461561061555

# %%
bike2019["member_birth_year"] =bike2019["member_birth_year"].fillna(round(bike2019["member_birth_year"].mean())).astype('int32')
bike2019["member_birth_year"].head()
# Out:
# 0    1984
# 1    1985
# 2    1972
# 3    1989
# 4    1974
# Name: member_birth_year, dtype: int32

# %%
bike2019["member_gender"].value_counts(dropna=False)
# Out:
# Male      130651
# Female     40844
# NaN         8265
# Other       3652
# Name: member_gender, dtype: int64

# %%
bike2019["member_gender"]= bike2019["member_gender"].fillna(np.random.choice(["Male","Female"]))
bike2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  datetime64[ns]
#  2   end_time                 183412 non-null  datetime64[ns]
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
#  13  member_birth_year        183412 non-null  int32
#  14  member_gender            183412 non-null  object
#  15  bike_share_for_all_trip  183412 non-null  object
# dtypes: datetime64[ns](2), float64(6), int32(1), int64(2), object(5)
# memory usage: 21.7+ MB

# %%
bike2019.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183215 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183215 non-null  int64
#  1   start_time               183215 non-null  datetime64[ns]
#  2   end_time                 183215 non-null  datetime64[ns]
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183215 non-null  float64
#  6   start_station_longitude  183215 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183215 non-null  float64
#  10  end_station_longitude    183215 non-null  float64
#  11  bike_id                  183215 non-null  int64
#  12  user_type                183215 non-null  object
#  13  member_birth_year        183215 non-null  int32
#  14  member_gender            183215 non-null  object
#  15  bike_share_for_all_trip  183215 non-null  object
# dtypes: datetime64[ns](2), float64(6), int32(1), int64(2), object(5)
# memory usage: 23.1+ MB

# %%
from sklearn import preprocessing
df = bike2019.dropna(axis=0)
df[["member_gender","bike_share_for_all_trip","user_type","start_station_name","end_station_name"]] =df[["member_gender","bike_share_for_all_trip","user_type","start_station_name","end_station_name"]].apply(preprocessing.LabelEncoder().fit_transform)
df
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         duration_sec              start_time                end_time  \
# 0              52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 1              42521 2019-02-28 18:53:21.789 2019-03-01 06:42:03.056
# 2              61854 2019-02-28 12:13:13.218 2019-03-01 05:24:08.146
# 3              36490 2019-02-28 17:54:26.010 2019-03-01 04:02:36.842
# 4               1585 2019-02-28 23:54:18.549 2019-03-01 00:20:44.074
# ...              ...                     ...                     ...
# 183407           480 2019-02-01 00:04:49.724 2019-02-01 00:12:50.034
# 183408           313 2019-02-01 00:05:34.744 2019-02-01 00:10:48.502
# 183409           141 2019-02-01 00:06:05.549 2019-02-01 00:08:27.220
# 183410           139 2019-02-01 00:05:34.360 2019-02-01 00:07:54.287
# 183411           271 2019-02-01 00:00:20.636 2019-02-01 00:04:52.058
#
#         start_station_id  start_station_name  start_station_latitude  \
# 0                   21.0                 220               37.789625
# 1                   23.0                 297               37.791464
# 2                   86.0                 204               37.769305
# 3                  375.0                 159               37.774836
# 4                    7.0                 143               37.804562
# ...                  ...                 ...                     ...
# 183407              27.0                  80               37.788059
# 183408              21.0                 220               37.789625
# 183409             278.0                 294               37.331932
# 183410             220.0                 267               37.811351
# 183411              24.0                 283               37.789677
#
#         start_station_longitude  end_station_id  end_station_name  \
# 0                   -122.400811            13.0               109
# 1                   -122.391034            81.0                82
# 2                   -122.426826             3.0               241
# 3                   -122.446546            70.0                97
# 4                   -122.271738           222.0                 0
# ...                         ...             ...               ...
# 183407              -122.391865           324.0               302
# 183408              -122.400811            66.0                45
# 183409              -121.904888           277.0               221
# 183410              -122.273422           216.0               266
# 183411              -122.390428            37.0                38
#
#         end_station_latitude  end_station_longitude  bike_id  user_type  \
# 0                  37.794231            -122.402923     4902          0
# 1                  37.775880            -122.393170     2535          0
# 2                  37.786375            -122.404904     5905          0
# 3                  37.773311            -122.444293     6638          1
# 4                  37.792714            -122.248780     4898          1
# ...                      ...                    ...      ...        ...
# 183407             37.788300            -122.408531     4832          1
# 183408             37.778742            -122.392741     4960          1
# 183409             37.333658            -121.908586     3824          1
# 183410             37.817827            -122.275698     5095          1
# 183411             37.785000            -122.395936     1057          1
#
#         member_birth_year  member_gender  bike_share_for_all_trip
# 0                    1984              1                        0
# 1                    1985              0                        0
# 2                    1972              1                        0
# 3                    1989              2                        0
# 4                    1974              1                        1
# ...                   ...            ...                      ...
# 183407               1996              1                        0
# 183408               1984              1                        0
# 183409               1990              1                        1
# 183410               1988              1                        0
# 183411               1989              1                        0
#
# [183215 rows x 16 columns]

# %%
import seaborn as sns
# %matplotlib inline


# calculate the correlation matrix
corr = df.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '15pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_ebbe2_ th {
#           font-size: 7pt;
#     }    #T_ebbe2_ td {
#           padding: 0em 0em;
#     }    #T_ebbe2_ th:hover {
#           font-size: 12pt;
#     }    #T_ebbe2_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_ebbe2_row0_col0,#T_ebbe2_row1_col1,#T_ebbe2_row2_col2,#T_ebbe2_row3_col3,#T_ebbe2_row4_col4,#T_ebbe2_row5_col5,#T_ebbe2_row6_col6,#T_ebbe2_row7_col7,#T_ebbe2_row8_col8,#T_ebbe2_row9_col9,#T_ebbe2_row10_col10,#T_ebbe2_row11_col11,#T_ebbe2_row12_col12,#T_ebbe2_row13_col13{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col1,#T_ebbe2_row6_col8,#T_ebbe2_row6_col13,#T_ebbe2_row9_col13,#T_ebbe2_row10_col2{
#             background-color:  #dd637c;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col2{
#             background-color:  #de6c83;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col3,#T_ebbe2_row0_col7,#T_ebbe2_row9_col2,#T_ebbe2_row10_col1{
#             background-color:  #de6b82;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col4,#T_ebbe2_row12_col4,#T_ebbe2_row12_col8{
#             background-color:  #dc5b75;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col5{
#             background-color:  #de687f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col6,#T_ebbe2_row9_col6{
#             background-color:  #de6980;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col8,#T_ebbe2_row1_col2,#T_ebbe2_row6_col10,#T_ebbe2_row10_col3,#T_ebbe2_row10_col7,#T_ebbe2_row12_col9{
#             background-color:  #dc5973;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col9,#T_ebbe2_row0_col11,#T_ebbe2_row0_col13,#T_ebbe2_row6_col4{
#             background-color:  #dd657d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col10,#T_ebbe2_row1_col3,#T_ebbe2_row2_col1,#T_ebbe2_row3_col4,#T_ebbe2_row3_col8,#T_ebbe2_row4_col3,#T_ebbe2_row4_col7,#T_ebbe2_row5_col7,#T_ebbe2_row6_col5,#T_ebbe2_row7_col4,#T_ebbe2_row7_col8,#T_ebbe2_row8_col3,#T_ebbe2_row8_col7,#T_ebbe2_row9_col4,#T_ebbe2_row9_col8,#T_ebbe2_row10_col0,#T_ebbe2_row11_col3,#T_ebbe2_row11_col7,#T_ebbe2_row12_col11,#T_ebbe2_row13_col3,#T_ebbe2_row13_col7{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row0_col12,#T_ebbe2_row2_col9,#T_ebbe2_row2_col12,#T_ebbe2_row2_col13,#T_ebbe2_row6_col11,#T_ebbe2_row6_col12{
#             background-color:  #dc5c76;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col0,#T_ebbe2_row3_col13,#T_ebbe2_row5_col2,#T_ebbe2_row7_col13,#T_ebbe2_row9_col12{
#             background-color:  #e07389;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col4{
#             background-color:  #e2e7ee;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col5{
#             background-color:  #efdde0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col6{
#             background-color:  #df6f85;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col7{
#             background-color:  #d83e5d;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col8{
#             background-color:  #dfe5ed;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col9,#T_ebbe2_row6_col0,#T_ebbe2_row10_col6,#T_ebbe2_row10_col11{
#             background-color:  #dd627b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col10,#T_ebbe2_row9_col3,#T_ebbe2_row9_col7,#T_ebbe2_row9_col10,#T_ebbe2_row11_col5{
#             background-color:  #e0798d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col11,#T_ebbe2_row5_col11{
#             background-color:  #e599a8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col12,#T_ebbe2_row5_col12,#T_ebbe2_row11_col1{
#             background-color:  #e17a8f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row1_col13{
#             background-color:  #eab9c3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row2_col0,#T_ebbe2_row6_col9{
#             background-color:  #dd5f78;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row2_col3{
#             background-color:  #da4d69;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row2_col4,#T_ebbe2_row2_col6,#T_ebbe2_row2_col8,#T_ebbe2_row11_col9,#T_ebbe2_row12_col13{
#             background-color:  #dd6179;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row2_col5,#T_ebbe2_row2_col10{
#             background-color:  #db5570;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row2_col7{
#             background-color:  #d94663;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row2_col11,#T_ebbe2_row5_col6,#T_ebbe2_row9_col5{
#             background-color:  #db5771;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col0,#T_ebbe2_row7_col0{
#             background-color:  #eed2d7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col1,#T_ebbe2_row13_col0{
#             background-color:  #e7a5b2;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col2,#T_ebbe2_row3_col10,#T_ebbe2_row3_col12,#T_ebbe2_row4_col0,#T_ebbe2_row7_col6,#T_ebbe2_row7_col10,#T_ebbe2_row7_col12,#T_ebbe2_row8_col0{
#             background-color:  #ecc6ce;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col5,#T_ebbe2_row7_col1{
#             background-color:  #e7a8b5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col6,#T_ebbe2_row7_col2{
#             background-color:  #ebc2ca;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col7,#T_ebbe2_row4_col8,#T_ebbe2_row7_col3,#T_ebbe2_row8_col4{
#             background-color:  #457abb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col9,#T_ebbe2_row7_col9{
#             background-color:  #efdade;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row3_col11,#T_ebbe2_row7_col11{
#             background-color:  #ebbfc8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row4_col1{
#             background-color:  #b4c7df;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  15pt;
#         }#T_ebbe2_row4_col2,#T_ebbe2_r
