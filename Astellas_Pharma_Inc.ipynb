# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/AnalyzeStocks/blob/master/Astellas_Pharma_Inc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pandas_datareader
import sqlite3
import yfinance

# %%
Astellas = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/ALPMY?period1=1569545811&period2=1601168211&interval=1d&events=history")

Astellas
# Out:
#            Date   Open   High    Low  Close  Adj Close  Volume
# 0    2019-09-27  14.30  14.36  14.10  14.28  14.099504   24700
# 1    2019-09-30  14.21  14.27  14.21  14.25  14.069884   19800
# 2    2019-10-01  14.16  14.17  14.06  14.06  13.882286   25800
# 3    2019-10-02  14.01  14.01  13.78  13.82  13.645319   84100
# 4    2019-10-03  13.75  13.85  13.69  13.79  13.615699   61000
# ..          ...    ...    ...    ...    ...        ...     ...
# 247  2020-09-21  15.23  15.28  15.02  15.24  15.240000   55900
# 248  2020-09-22  15.11  15.35  15.10  15.35  15.350000   94600
# 249  2020-09-23  15.44  15.45  15.28  15.34  15.340000  106600
# 250  2020-09-24  15.37  15.42  15.33  15.37  15.370000   50300
# 251  2020-09-25  15.26  15.35  15.23  15.31  15.310000   52900
#
# [252 rows x 7 columns]

# %%
Astellas.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close  Volume
# 0  2019-09-27  14.30  14.36  14.10  14.28  14.099504   24700
# 1  2019-09-30  14.21  14.27  14.21  14.25  14.069884   19800
# 2  2019-10-01  14.16  14.17  14.06  14.06  13.882286   25800
# 3  2019-10-02  14.01  14.01  13.78  13.82  13.645319   84100
# 4  2019-10-03  13.75  13.85  13.69  13.79  13.615699   61000

# %%
Astellas.tail()
# Out:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2020-09-21  197.190002  202.710007  ...  202.539993  39839700
# 2020-09-22  205.059998  208.100006  ...  207.419998  33517100
# 2020-09-23  207.899994  208.100006  ...  200.589996  30803800
# 2020-09-24  199.850006  205.570007  ...  203.190002  31202500
# 2020-09-25  203.550003  209.039993  ...  207.820007  29416000
#
# [5 rows x 6 columns]

# %%
Astellas.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  8707.000000  8707.000000  ...  8707.000000  8.707000e+03
# mean     31.510702    31.855588  ...    26.616499  6.006099e+07
# std      36.324482    36.704717  ...    36.227401  3.868367e+07
# min       0.088542     0.092014  ...     0.057623  2.304000e+06
# 25%       3.644531     3.707031  ...     2.338699  3.625320e+07
# 50%      26.410000    26.718750  ...    18.549547  5.322840e+07
# 75%      35.187500    35.650002  ...    26.117239  7.375140e+07
# max     229.270004   232.860001  ...   231.649994  1.031789e+09
#
# [8 rows x 6 columns]

# %%
Astellas.info
# Out:
# <bound method DataFrame.info of                   Open        High  ...   Adj Close      Volume
# Date                                ...
# 1986-03-13    0.088542    0.101562  ...    0.062055  1031788800
# 1986-03-14    0.097222    0.102431  ...    0.064271   308160000
# 1986-03-17    0.100694    0.103299  ...    0.065379   133171200
# 1986-03-18    0.102431    0.103299  ...    0.063717    67766400
# 1986-03-19    0.099826    0.100694  ...    0.062609    47894400
# ...                ...         ...  ...         ...         ...
# 2020-09-21  197.190002  202.710007  ...  202.539993    39839700
# 2020-09-22  205.059998  208.100006  ...  207.419998    33517100
# 2020-09-23  207.899994  208.100006  ...  200.589996    30803800
# 2020-09-24  199.850006  205.570007  ...  203.190002    31202500
# 2020-09-25  203.550003  209.039993  ...  207.820007    29416000
#
# [8707 rows x 6 columns]>

# %%
Astellas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8707 entries, 1986-03-13 to 2020-09-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       8707 non-null   float64
#  1   High       8707 non-null   float64
#  2   Low        8707 non-null   float64
#  3   Close      8707 non-null   float64
#  4   Adj Close  8707 non-null   float64
#  5   Volume     8707 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 476.2 KB

# %%
conn = sqlite3.connect("Astellas.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Astellas.db")
c = conn.cursor()

# %%
Astellas.to_sql("Astellas", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM Astellas""")
rows = c.fetchall()
rows
# Out:
# [('1986-03-13 00:00:00',
#   0.0885416641831398,
#   0.1015625,
#   0.0885416641831398,
#   0.0972222238779068,
#   0.06205500289797783,
#   1031788800),
#  ('1986-03-14 00:00:00',
#   0.0972222238779068,
#   0.1024305522441864,
#   0.0972222238779068,
#   0.1006944477558136,
#   0.06427128612995148,
#   308160000),
#  ('1986-03-17 00:00:00',
#   0.1006944477558136,
#   0.1032986119389534,
#   0.1006944477558136,
#   0.1024305522441864,
#   0.06537942588329315,
#   133171200),
#  ('1986-03-18 00:00:00',
#   0.1024305522441864,
#   0.1032986119389534,
#   0.0989583358168602,
#   0.0998263880610466,
#   0.06371721625328064,
#   67766400),
#  ('1986-03-19 00:00:00',
#   0.0998263880610466,
#   0.1006944477558136,
#   0.0972222238779068,
#   0.0980902761220932,
#   0.06260908395051956,
#   47894400),
#  ('1986-03-20 00:00:00',
#   0.0980902761220932,
#   0.0980902761220932,
#   0.0946180522441864,
#   0.0954861119389534,
#   0.06094687432050705,
#   58435200),
#  ('1986-03-21 00:00:00',
# ...

# %%
Astellas.to_excel("Astellas.xls")

pd.read_excel("Astellas.xls")
# Out:
#            Date        Open        High  ...       Close   Adj Close      Volume
# 0    1986-03-13    0.088542    0.101562  ...    0.097222    0.062055  1031788800
# 1    1986-03-14    0.097222    0.102431  ...    0.100694    0.064271   308160000
# 2    1986-03-17    0.100694    0.103299  ...    0.102431    0.065379   133171200
# 3    1986-03-18    0.102431    0.103299  ...    0.099826    0.063717    67766400
# 4    1986-03-19    0.099826    0.100694  ...    0.098090    0.062609    47894400
# ...         ...         ...         ...  ...         ...         ...         ...
# 8702 2020-09-21  197.190002  202.710007  ...  202.539993  202.539993    39839700
# 8703 2020-09-22  205.059998  208.100006  ...  207.419998  207.419998    33517100
# 8704 2020-09-23  207.899994  208.100006  ...  200.589996  200.589996    30803800
# 8705 2020-09-24  199.850006  205.570007  ...  203.190002  203.190002    31202500
# 8706 2020-09-25  203.550003  209.039993  ...  207.820007  207.820007    29416000
#
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Astellas Pharma Inc', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Astellas Pharma Inc')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
