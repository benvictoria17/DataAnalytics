# %%
import numpy as np 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/2022%20Ukraine%20Russia%20War/russia_losses_equipment.csv")

# %%
dd = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/2022%20Ukraine%20Russia%20War/russia_losses_personnel.csv")

# %%
dd
# Out:
#           date  day  personnel personnel*  POW
# 0   2022-02-25    2       2800      about    0
# 1   2022-02-26    3       4300      about    0
# 2   2022-02-27    4       4500      about    0
# 3   2022-02-28    5       5300      about    0
# 4   2022-03-01    6       5710      about  200
# 5   2022-03-02    7       5840      about  200
# 6   2022-03-03    8       9000      about  200
# 7   2022-03-04    9       9166      about  200
# 8   2022-03-05   10      10000      about  216
# 9   2022-03-06   11      11000      about  232
# 10  2022-03-07   12      11000       more  259
# 11  2022-03-08   13      12000      about  284
# 12  2022-03-09   14      12000      about  360
# 13  2022-03-10   15      12000       more  371
# 14  2022-03-11   16      12000       more  389
# 15  2022-03-12   17      12000       more  389
# 16  2022-03-13   18      12000       more  389
# 17  2022-03-14   19      12000       more  389
# 18  2022-03-15   20      13500      about  389
# ...

# %%
df
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
# 0   2022-02-25    2        10           7    80   516               49    4
# 1   2022-02-26    3        27          26   146   706               49    4
# 2   2022-02-27    4        27          26   150   706               50    4
# 3   2022-02-28    5        29          29   150   816               74   21
# 4   2022-03-01    6        29          29   198   846               77   24
# 5   2022-03-02    7        30          31   211   862               85   40
# 6   2022-03-03    8        30          31   217   900               90   42
# 7   2022-03-04    9        33          37   251   939              105   50
# 8   2022-03-05   10        39          40   269   945              105   50
# 9   2022-03-06   11        44          48   285   985              109   50
# 10  2022-03-07   12        46          68   290   999              117   50
# ...

# %%
df.isna().sum()
# Out:
# date                      0
# day                       0
# aircraft                  0
# helicopter                0
# tank                      0
# APC                       0
# field artillery           0
# MRL                       0
# military auto             0
# fuel tank                 0
# drone                     0
# naval ship                0
# anti-aircraft warfare     0
# special equipment        19
# dtype: int64

# %%
df.head(2)
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  MRL  \
# 0  2022-02-25    2        10           7    80  516               49    4
# 1  2022-02-26    3        27          26   146  706               49    4
#
#    military auto  fuel tank  drone  naval ship  anti-aircraft warfare  \
# 0            100         60      0           2                      0
# 1            130         60      2           2                      0
#
#    special equipment
# 0                NaN
# 1                NaN

# %%
df_filtered=df.query("drone==0 & tank<100")[["date"]]
df_filtered
# Out:
#          date
# 0  2022-02-25

# %%
df.describe().T
# Out:
#                        count         mean         std    min     25%     50%  \
# day                     25.0    14.000000    7.359801    2.0    8.00    14.0
# aircraft                25.0    55.520000   26.674145   10.0   30.00    49.0
# helicopter              25.0    69.320000   35.504366    7.0   31.00    81.0
# tank                    25.0   313.920000  117.514864   80.0  217.00   317.0
# APC                     25.0  1092.200000  276.919964  516.0  900.00  1070.0
# field artillery         25.0   130.080000   56.052743   49.0   90.00   120.0
# MRL                     25.0    50.280000   22.552753    4.0   42.00    56.0
# military auto           25.0   530.920000  256.218156  100.0  374.00   482.0
# fuel tank               25.0    60.000000    0.000000   60.0   60.00    60.0
# drone                   25.0     7.520000    5.930992    0.0    3.00     7.0
# naval ship              25.0     2.600000    0.500000    2.0    2.00     3.0
# ...

# %%
sns.scatterplot(x="tank", y="helicopter", data=df)
# Out:
# <AxesSubplot:xlabel='tank', ylabel='helicopter'>

# %%
sns.violinplot(  y="drone",data=df,linewidth=5)
# Out:
# <AxesSubplot:ylabel='drone'>

# %%
sns.scatterplot(x=df["drone"],y=dd["personnel"])
# Out:
# <AxesSubplot:xlabel='drone', ylabel='personnel'>

# %%
df.sa
