# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/panda/blob/master/Chicago_Crime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
ChicagoCrime = pd.read_csv("/content/Crimes_-_2001_to_present.csv")

ChicagoCrime
# Out:
#              ID Case Number  ...  Longitude                       Location
# 0      10000092    HY189866  ... -87.744385  (41.891398861, -87.744384567)
# 1      10000094    HY190059  ... -87.665319  (41.773371528, -87.665319468)
# 2      10000095    HY190052  ... -87.596643   (41.81386068, -87.596642837)
# 3      10000096    HY190054  ... -87.622619  (41.800802415, -87.622619343)
# 4      10000097    HY189976  ... -87.743354  (41.878064761, -87.743354013)
# ...         ...         ...  ...        ...                            ...
# 17580  10033401    HY222931  ... -87.642687  (41.745893488, -87.642687037)
# 17581  10033402    HY222938  ... -87.682060  (41.942121437, -87.682060491)
# 17582  10033405    HY222784  ... -87.633209  (41.878123916, -87.633208786)
# 17583  10033411    HY222825  ... -87.704375  (41.941054854, -87.704374814)
# 17584  10033412    HY222838  ...        NaN                            NaN
#
# [17585 rows x 22 columns]

# %%
ChicagoCrime.head()
# Out:
#          ID Case Number  ...  Longitude                       Location
# 0  10000092    HY189866  ... -87.744385  (41.891398861, -87.744384567)
# 1  10000094    HY190059  ... -87.665319  (41.773371528, -87.665319468)
# 2  10000095    HY190052  ... -87.596643   (41.81386068, -87.596642837)
# 3  10000096    HY190054  ... -87.622619  (41.800802415, -87.622619343)
# 4  10000097    HY189976  ... -87.743354  (41.878064761, -87.743354013)
#
# [5 rows x 22 columns]

# %%
ChicagoCrime.tail()
# Out:
#              ID Case Number  ...  Longitude                       Location
# 17580  10033401    HY222931  ... -87.642687  (41.745893488, -87.642687037)
# 17581  10033402    HY222938  ... -87.682060  (41.942121437, -87.682060491)
# 17582  10033405    HY222784  ... -87.633209  (41.878123916, -87.633208786)
# 17583  10033411    HY222825  ... -87.704375  (41.941054854, -87.704374814)
# 17584  10033412    HY222838  ...        NaN                            NaN
#
# [5 rows x 22 columns]

# %%
ChicagoCrime.describe()
# Out:
#                  ID          Beat  ...      Latitude     Longitude
# count  1.758500e+04  17585.000000  ...  17499.000000  17499.000000
# mean   9.974067e+06   1136.307023  ...     41.839043    -87.672482
# std    5.496617e+05    687.183392  ...      0.085565      0.059844
# min    4.756000e+03    111.000000  ...     41.644610    -87.906702
# 25%    1.000874e+07    612.000000  ...     41.765997    -87.717170
# 50%    1.001736e+07   1021.000000  ...     41.853608    -87.666667
# 75%    1.002537e+07   1633.000000  ...     41.902432    -87.627929
# max    1.115646e+07   2535.000000  ...     42.022535    -87.526517
#
# [8 rows x 10 columns]

# %%
ChicagoCrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17585 entries, 0 to 17584
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    17585 non-null  int64
#  1   Case Number           17585 non-null  object
#  2   Date                  17585 non-null  object
#  3   Block                 17585 non-null  object
#  4   IUCR                  17585 non-null  object
#  5   Primary Type          17585 non-null  object
#  6   Description           17585 non-null  object
#  7   Location Description  17564 non-null  object
#  8   Arrest                17585 non-null  bool
#  9   Domestic              17585 non-null  bool
#  10  Beat                  17585 non-null  int64
#  11  District              17585 non-null  int64
#  12  Ward                  17585 non-null  int64
#  13  Community Area        17585 non-null  int64
#  14  FBI Code              17585 non-null  object
# ...

# %%
ChicagoCrime.info
# Out:
# <bound method DataFrame.info of              ID Case Number  ...  Longitude                       Location
# 0      10000092    HY189866  ... -87.744385  (41.891398861, -87.744384567)
# 1      10000094    HY190059  ... -87.665319  (41.773371528, -87.665319468)
# 2      10000095    HY190052  ... -87.596643   (41.81386068, -87.596642837)
# 3      10000096    HY190054  ... -87.622619  (41.800802415, -87.622619343)
# 4      10000097    HY189976  ... -87.743354  (41.878064761, -87.743354013)
# ...         ...         ...  ...        ...                            ...
# 17580  10033401    HY222931  ... -87.642687  (41.745893488, -87.642687037)
# 17581  10033402    HY222938  ... -87.682060  (41.942121437, -87.682060491)
# 17582  10033405    HY222784  ... -87.633209  (41.878123916, -87.633208786)
# 17583  10033411    HY222825  ... -87.704375  (41.941054854, -87.704374814)
# 17584  10033412    HY222838  ...        NaN                            NaN
#
# [17585 rows x 22 columns]>

# %%
import sqlite3

# %%
conn = sqlite3.connect("ChicagoCrime.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("ChicagoCrime.db")
c = conn.cursor()

# %%
ChicagoCrime.to_sql("ChicagoCrime", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM ChicagoCrime""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   10000092,
#   'HY189866',
#   '03/18/2015 07:44:00 PM',
#   '047XX W OHIO ST',
#   '041A',
#   'BATTERY',
#   'AGGRAVATED: HANDGUN',
#   'STREET',
#   0,
#   0,
#   1111,
#   11,
#   28,
#   25,
#   '04B',
#   1144606.0,
#   1903566.0,
#   2015.0,
#   '02/10/2018 03:50:01 PM',
#   41.891398861,
#   -87.74438456700001,
#   '(41.891398861, -87.744384567)'),
#  (1,
#   10000094,
#   'HY190059',
#   '03/18/2015 11:00:00 PM',
#   '066XX S MARSHFIELD AVE',
#   '4625',
#   'OTHER OFFENSE',
#   'PAROLE VIOLATION',
#   'STREET',
#   1,
#   0,
#   725,
#   7,
#   15,
#   67,
#   '26',
#   1166468.0,
#   1860715.0,
#   2015.0,
#   '02/10/2018 03:50:01 PM',
#   41.773371528,
#   -87.66531946799999,
#   '(41.773371528, -87.665319468)'),
#  (2,
#   10000095,
#   'HY190052',
#   '03/18/2015 10:45:00 PM',
#   '044XX S LAKE PARK AVE',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'APARTMENT',
#   0,
#   1,
#   222,
#   2,
#   4,
#   39,
#   '08B',
#   1185075.0,
# ...

# %%
ChicagoCrime.to_excel("ChicagoCrime.xls")

pd.read_excel("ChicagoCrime.xls")
# Out:
#        Unnamed: 0        ID  ...  Longitude                       Location
# 0               0  10000092  ... -87.744385  (41.891398861, -87.744384567)
# 1               1  10000094  ... -87.665319  (41.773371528, -87.665319468)
# 2               2  10000095  ... -87.596643   (41.81386068, -87.596642837)
# 3               3  10000096  ... -87.622619  (41.800802415, -87.622619343)
# 4               4  10000097  ... -87.743354  (41.878064761, -87.743354013)
# ...           ...       ...  ...        ...                            ...
# 17580       17580  10033401  ... -87.642687  (41.745893488, -87.642687037)
# 17581       17581  10033402  ... -87.682060  (41.942121437, -87.682060491)
# 17582       17582  10033405  ... -87.633209  (41.878123916, -87.633208786)
# 17583       17583  10033411  ... -87.704375  (41.941054854, -87.704374814)
# 17584       17584  10033412  ...        NaN                            NaN
#
# [17585 rows x 23 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Chicago Crime', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Chicago Crime')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
ChicagoCrime.shape
# Out:
# (17585, 22)
