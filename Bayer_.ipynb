# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/AnalyzeStocks/blob/master/Bayer_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  yfinance

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pandas_datareader
import sqlite3
import yfinance

# %%
BAYN = "BAYN"

# %%
BAYN = yfinance.download(BAYN)

BAYN
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2012-06-18  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-19  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-20  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-21  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-22  0.03000  0.03000  0.03000  0.03000    0.03000       0
# ...             ...      ...      ...      ...        ...     ...
# 2020-09-17  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-21  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-22  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-23  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-24  0.00001  0.00001  0.00001  0.00001    0.00001       0
#
# [2081 rows x 6 columns]

# %%
BAYN.head()
# Out:
#             Open  High   Low  Close  Adj Close  Volume
# Date
# 2012-06-18  0.03  0.03  0.03   0.03       0.03       0
# 2012-06-19  0.03  0.03  0.03   0.03       0.03       0
# 2012-06-20  0.03  0.03  0.03   0.03       0.03       0
# 2012-06-21  0.03  0.03  0.03   0.03       0.03       0
# 2012-06-22  0.03  0.03  0.03   0.03       0.03       0

# %%
BAYN.tail()
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2020-09-17  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-21  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-22  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-23  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-24  0.00001  0.00001  0.00001  0.00001    0.00001       0

# %%
BAYN.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  2081.000000  2081.000000  ...  2081.000000   2081.000000
# mean      0.020755     0.020798  ...     0.020656    466.161461
# std       0.013832     0.013893  ...     0.013611   3626.097535
# min       0.000010     0.000010  ...     0.000010      0.000000
# 25%       0.010000     0.010000  ...     0.010000      0.000000
# 50%       0.015000     0.015000  ...     0.015000      0.000000
# 75%       0.030000     0.030000  ...     0.030000      0.000000
# max       0.100000     0.100000  ...     0.100000  72600.000000
#
# [8 rows x 6 columns]

# %%
BAYN.info
# Out:
# <bound method DataFrame.info of                Open     High      Low    Close  Adj Close  Volume
# Date
# 2012-06-18  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-19  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-20  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-21  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2012-06-22  0.03000  0.03000  0.03000  0.03000    0.03000       0
# ...             ...      ...      ...      ...        ...     ...
# 2020-09-17  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-21  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-22  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-23  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2020-09-24  0.00001  0.00001  0.00001  0.00001    0.00001       0
#
# [2081 rows x 6 columns]>

# %%
BAYN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2081 entries, 2012-06-18 to 2020-09-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2081 non-null   float64
#  1   High       2081 non-null   float64
#  2   Low        2081 non-null   float64
#  3   Close      2081 non-null   float64
#  4   Adj Close  2081 non-null   float64
#  5   Volume     2081 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 113.8 KB

# %%
conn = sqlite3.connect("BAYN.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("BAYN.db")
c = conn.cursor()

# %%
BAYN.to_sql("BAYN", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM BAYN""")
rows = c.fetchall()
rows
# Out:
# [('2012-06-18 00:00:00',
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0),
#  ('2012-06-19 00:00:00',
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0),
#  ('2012-06-20 00:00:00',
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0),
#  ('2012-06-21 00:00:00',
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0),
#  ('2012-06-22 00:00:00',
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0),
#  ('2012-06-25 00:00:00',
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0.029999999329447746,
#   0),
# ...

# %%
BAYN.to_excel("BAYN.xls")

pd.read_excel("BAYN.xls")
# Out:
#            Date     Open     High      Low    Close  Adj Close  Volume
# 0    2012-06-18  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 1    2012-06-19  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 2    2012-06-20  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 3    2012-06-21  0.03000  0.03000  0.03000  0.03000    0.03000       0
# 4    2012-06-22  0.03000  0.03000  0.03000  0.03000    0.03000       0
# ...         ...      ...      ...      ...      ...        ...     ...
# 2076 2020-09-17  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2077 2020-09-21  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2078 2020-09-22  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2079 2020-09-23  0.00001  0.00001  0.00001  0.00001    0.00001       0
# 2080 2020-09-24  0.00001  0.00001  0.00001  0.00001    0.00001       0
#
# [2081 rows x 7 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Bayer', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Bayer')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
