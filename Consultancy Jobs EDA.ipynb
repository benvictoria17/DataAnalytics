# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Consultants%20Survey%20Dataset/Consulting_survey_DataSet.csv")
rows, colums = df.shape
print(f"Dataset has {rows} rows and {colums} columns.")
# Out:
# Dataset has 4200 rows and 19 columns.

# %%
df
# Out:
#                 Timestamp Do you CURRENTLY work at a consulting firm?  \
# 0      9/29/2021 10:35:35                                         Yes
# 1      9/29/2021 10:35:44                                         Yes
# 2      9/29/2021 10:36:00                                         Yes
# 3      9/29/2021 10:36:16                                         Yes
# 4      9/29/2021 10:36:19                                         Yes
# ...                   ...                                         ...
# 4195   10/19/2021 8:21:36                                         Yes
# 4196   10/19/2021 8:29:55                                         Yes
# 4197  10/19/2021 10:13:15                                         Yes
# 4198  10/19/2021 10:30:46                                          No
# 4199  10/19/2021 10:58:20                                         Yes
#
#      Which firm do you CURRENTLY work for?  \
# 0                        Other or Boutique
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Do you CURRENTLY work at a consulting firm?',
#        'Which firm do you CURRENTLY work for?',
#        'Are you CURRENTLY in a Commercial or Federal practice? ',
#        'What is your CURRENT title (or equivalent)? ',
#        'What COUNTRY are you CURRENTLY based out of?',
#        'What is your CURRENT annual base compensation in USD (not including bonuses, perks, or other incentives)? Please consult Google for conversion tools for local currency into USD. Enter number values only.',
#        'What is the total amount in USD of BONUSES you estimate you will receive in 2021? Enter number only.',
#        'Expected total compensation (calculated)',
#        'How many hours per week on AVERAGE do you work (including non-billable time)?',
#        'Have you gotten an OFFER from another company this year?',
#        'Was the offer from another CONSULTING FIRM?',
#        'Which firm was the HIGHEST (base compensation) OFFER from?',
# ...

# %%
df['Do you CURRENTLY work at a consulting firm?'].value_counts()
# Out:
# Yes    3923
# No      276
# Name: Do you CURRENTLY work at a consulting firm?, dtype: int64

# %%
df['What COUNTRY are you CURRENTLY based out of?'].value_counts()
# Out:
# United States of America    2025
# India                        336
# United Kingdom               290
# Canada                       234
# Australia                    160
#                             ...
# Ukraine                        1
# Antigua And Barbuda            1
# Ecuador                        1
# Cyprus                         1
# Croatia                        1
# Name: What COUNTRY are you CURRENTLY based out of?, Length: 84, dtype: int64

# %%
df['What COUNTRY are you CURRENTLY based out of?'].value_counts()
# Out:
# United States of America    2025
# India                        336
# United Kingdom               290
# Canada                       234
# Australia                    160
#                             ...
# Ukraine                        1
# Antigua And Barbuda            1
# Ecuador                        1
# Cyprus                         1
# Croatia                        1
# Name: What COUNTRY are you CURRENTLY based out of?, Length: 84, dtype: int64

# %%
plt.figure(figsize=(16,6))

histogram = df['Which firm do you CURRENTLY work for?'].hist()

plt.xticks(rotation=90, horizontalalignment="center")
plt.title("No. of consultants responded from the consulting firms")
plt.xlabel("Consulting Firms")
plt.ylabel("No. of consultants")
plt.show()

# %%
anual_compansation = df['What is your CURRENT annual base compensation in USD (not including bonuses, perks, or other incentives)? Please consult Google for conversion tools for local currency into USD. Enter number values only.']
AC = anual_compansation.values
print(f'Anual Componsation range: {max(AC)} - {min(AC)}')
# Out:
# Anual Componsation range: 1630000.0 - 0.0
