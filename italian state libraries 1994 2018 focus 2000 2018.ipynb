# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
libraryoriginal = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Italian%20State%20Libraries%201994-2018%2C%20focus%202000-2018/BibliotecheStatali_01_Tavola1_published.csv",sep=";")
libraryprovinces = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Italian%20State%20Libraries%201994-2018%2C%20focus%202000-2018/BibliotecheStatali_01_published.csv",sep=";")

# %%
libraryoriginal.head(101)
# Out:
#      Year         Area     Region   Province  Manuscripts  Printed_total  \
# 0    1998         Nord   Piemonte     TORINO       8572.0       846109.0
# 1    1998         Nord  Lombardia    CREMONA       2573.0       441573.0
# 2    1998         Nord  Lombardia     MILANO       2117.0       838475.0
# 3    1998         Nord  Lombardia      PAVIA       1956.0       339398.0
# 4    1998         Nord     Veneto     PADOVA       2843.0       533413.0
# ..    ...          ...        ...        ...          ...            ...
# 96   2001       Centro     Marche   MACERATA         58.0        63273.0
# 97   2001       Centro      Lazio  FROSINONE       2680.0       134808.0
# 98   2001       Centro      Lazio      RIETI        350.0        40473.0
# 99   2001       Centro      Lazio       ROMA      23530.0      6229302.0
# 100  2001  Mezzogiorno   Campania   AVELLINO        579.0       140532.0
#
#      Printed_incunaboli  Printed_cinquecentine  Printed_leaflets  \
# ...

# %%
libraryoriginal.tail()
# Out:
#      Year         Area      Region  Province  Manuscripts  Printed_total  \
# 562  2018  Mezzogiorno      Puglia      BARI        454.0       332520.0
# 563  2018  Mezzogiorno  Basilicata   POTENZA        118.0       138420.0
# 564  2018  Mezzogiorno    Calabria   COSENZA        170.0       142897.0
# 565  2018  Mezzogiorno    Sardegna  CAGLIARI        604.0       550810.0
# 566  2018  Mezzogiorno    Sardegna   SASSARI       2374.0       222110.0
#
#      Printed_incunaboli  Printed_cinquecentine  Printed_leaflets  \
# 562                55.0                 2223.0           65907.0
# 563                 3.0                  113.0           11994.0
# 564                 6.0                  400.0           16810.0
# 565               238.0                 5326.0           30319.0
# 566                74.0                 3502.0           26997.0
#
#      Printed_Periodicals_active  Books_requested Loans  Personnel
# 562                       201.0           4250.0  1900       29.0
# ...

# %%
libraryoriginal.describe()
# Out:
#               Year   Manuscripts  Printed_total  Printed_incunaboli  \
# count   567.000000    554.000000   5.540000e+02          548.000000
# mean   2008.000000   7528.969314   9.106008e+05         1308.808394
# std       6.060648  12772.047047   1.642986e+06         1818.198434
# min    1998.000000      1.000000   3.870800e+04            0.000000
# 25%    2003.000000    453.000000   1.678080e+05           42.000000
# 50%    2008.000000   1949.000000   3.964860e+05          383.500000
# 75%    2013.000000   8955.750000   6.322198e+05         1791.000000
# max    2018.000000  52244.000000   7.330272e+06         6741.000000
#
#        Printed_cinquecentine  Printed_leaflets  Printed_Periodicals_active  \
# count             549.000000      5.520000e+02                  525.000000
# mean            13206.107468      2.848410e+05                 2363.466667
# std             19728.578419      6.441692e+05                 5491.848470
# ...

# %%
libraryoriginal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        567 non-null    int64
#  1   Area                        567 non-null    object
#  2   Region                      567 non-null    object
#  3   Province                    567 non-null    object
#  4   Manuscripts                 554 non-null    float64
#  5   Printed_total               554 non-null    float64
#  6   Printed_incunaboli          548 non-null    float64
#  7   Printed_cinquecentine       549 non-null    float64
#  8   Printed_leaflets            552 non-null    float64
#  9   Printed_Periodicals_active  525 non-null    float64
#  10  Books_requested             552 non-null    float64
#  11  Loans                       531 non-null    object
#  12  Personnel                   554 non-null    float64
# ...

# %%
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker",
            data=tips);
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);
sns.relplot(x="total_bill", y="tip", hue="size", data=tips);
sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=tips);
sns.relplot(x="total_bill", y="tip", size="size", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips);
df = pd.DataFrame(dict(time=np.arange(500),
                       value=np.random.randn(500).cumsum()))
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.figure.autofmt_xdate()
df = pd.DataFrame(np.random.randn(500, 2).cumsum(axis=0), columns=["x", "y"])
sns.relplot(x="x", y="y", sort=False, kind="line", data=df);

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", kind="line", ci="sd", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", estimator=None, kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", estimator=None, kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            dashes=False, markers=True, kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5,
            height=3, aspect=.75, linewidth=2.5,
            kind="line", data=fmri.query("region == 'frontal'"));
