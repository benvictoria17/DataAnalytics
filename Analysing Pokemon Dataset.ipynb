</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pokemon["Type 2"].isnull().sum()
# Out:
# 386

# %%
pokemon["Name"].nunique()
# Out:
# 800

# %%
pokemon["check"] = pokemon[['HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed']].sum(axis = 1)

pokemon[pokemon["check"]!=pokemon["Total"]].any()

# %%
pokemon.drop("check", axis = 1, inplace = True)

# %%
pokemon["Type 2"]
pokemon['Second Type'] =  np.where(pokemon["Type 2"].isnull(), False, True)

# %%
pokemon.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>800.000000</td>
#       <td>800.00000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.000000</td>
#       <td>800.00000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>362.813750</td>
#       <td>435.10250</td>
#       <td>69.258750</td>
#       <td>79.001250</td>
#       <td>73.842500</td>
#       <td>72.820000</td>
#       <td>71.902500</td>
#       <td>68.277500</td>
#       <td>3.32375</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>208.343798</td>
#       <td>119.96304</td>
#       <td>25.534669</td>
#       <td>32.457366</td>
#       <td>31.183501</td>
#       <td>32.722294</td>
#       <td>27.828916</td>
#       <td>29.060474</td>
#       <td>1.66129</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#       <td>180.00000</td>
#       <td>1.000000</td>
#       <td>5.000000</td>
#       <td>5.000000</td>
#       <td>10.000000</td>
#       <td>20.000000</td>
#       <td>5.000000</td>
#       <td>1.00000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>184.750000</td>
#       <td>330.00000</td>
#       <td>50.000000</td>
#       <td>55.000000</td>
#       <td>50.000000</td>
#       <td>49.750000</td>
#       <td>50.000000</td>
#       <td>45.000000</td>
#       <td>2.00000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>364.500000</td>
#       <td>450.00000</td>
#       <td>65.000000</td>
#       <td>75.000000</td>
#       <td>70.000000</td>
#       <td>65.000000</td>
#       <td>70.000000</td>
#       <td>65.000000</td>
#       <td>3.00000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>539.250000</td>
#       <td>515.00000</td>
#       <td>80.000000</td>
#       <td>100.000000</td>
#       <td>90.000000</td>
#       <td>95.000000</td>
#       <td>90.000000</td>
#       <td>90.000000</td>
#       <td>5.00000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>721.000000</td>
#       <td>780.00000</td>
#       <td>255.000000</td>
#       <td>190.000000</td>
#       <td>230.000000</td>
#       <td>194.000000</td>
#       <td>230.000000</td>
#       <td>180.000000</td>
#       <td>6.00000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pokemon[pokemon["HP"]==1]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Second Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>316</th>
#       <td>292</td>
#       <td>Shedinja</td>
#       <td>Bug</td>
#       <td>Ghost</td>
#       <td>236</td>
#       <td>1</td>
#       <td>90</td>
#       <td>45</td>
#       <td>30</td>
#       <td>30</td>
#       <td>40</td>
#       <td>3</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pokemon[pokemon["Attack"]< 6]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Second Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>121</th>
#       <td>113</td>
#       <td>Chansey</td>
#       <td>Normal</td>
#       <td>NaN</td>
#       <td>450</td>
#       <td>250</td>
#       <td>5</td>
#       <td>5</td>
#       <td>35</td>
#       <td>105</td>
#       <td>50</td>
#       <td>1</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>488</th>
#       <td>440</td>
#       <td>Happiny</td>
#       <td>Normal</td>
#       <td>NaN</td>
#       <td>220</td>
#       <td>100</td>
#       <td>5</td>
#       <td>5</td>
#       <td>15</td>
#       <td>65</td>
#       <td>30</td>
#       <td>4</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pokemon[pokemon["Defense"]< 6]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Second Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>121</th>
#       <td>113</td>
#       <td>Chansey</td>
#       <td>Normal</td>
#       <td>NaN</td>
#       <td>450</td>
#       <td>250</td>
#       <td>5</td>
#       <td>5</td>
#       <td>35</td>
#       <td>105</td>
#       <td>50</td>
#       <td>1</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>488</th>
#       <td>440</td>
#       <td>Happiny</td>
#       <td>Normal</td>
#       <td>NaN</td>
#       <td>220</td>
#       <td>100</td>
#       <td>5</td>
#       <td>5</td>
#       <td>15</td>
#       <td>65</td>
#       <td>30</td>
#       <td>4</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pokemon[pokemon["Total"]==180]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Second Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>206</th>
#       <td>191</td>
#       <td>Sunkern</td>
#       <td>Grass</td>
#       <td>NaN</td>
#       <td>180</td>
#       <td>30</td>
#       <td>30</td>
#       <td>30</td>
#       <td>30</td>
#       <td>30</td>
#       <td>30</td>
#       <td>2</td>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
plt.figure(figsize=(12,10))
sns.displot(x = "Attack", data = pokemon, kde = True)
plt.suptitle("Distribution of Attack stats")

# %%
plt.figure(figsize=(12,10))
sns.displot(x = "Defense", data = pokemon, kde = True)
plt.suptitle("Distribution of Defense stats")

# %%
plt.figure(figsize=(12,10))
sns.displot(x = "HP", data = pokemon, kde = True)
plt.suptitle("Distribution of HP stats")

# %%
plt.figure(figsize=(12,10))
sns.displot(x = "Total", data = pokemon, kde = True)
plt.suptitle("Distribution of Total stats")

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Type 1", data=pokemon, order = pokemon['Type 1'].value_counts().index, palette = "Paired")
plt.suptitle("Rank of the type 1 pokemons", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Rank of the type 1 pokemons')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Type 1", hue = "Second Type", data=pokemon, order = pokemon[ "Type 1"].value_counts().index, color = "purple")
plt.suptitle("Rank of the type 1 pokemons ", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Rank of the type 1 pokemons ')

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = "Type 1", y = "Total", data = pokemon)
plt.suptitle("Distribution of Total and Type 1 data ", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Distribution of Total and Type 1 data ')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Type 2", data=pokemon, order = pokemon['Type 2'].value_counts().index, palette = "gist_earth_r")
plt.suptitle("Distribution of the Type 2 pokemons", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Distribution of the Type 2 pokemons')

# %%
plt.figure(figsize=(15,6))

sns.scatterplot(x ="Attack", y = "Defense", data = pokemon, hue = "Second Type",  )
plt.suptitle("Distribution Attack and Defense data seperated by Second Type", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Distribution Attack and Defense data seperated by Second Type')

# %%
Water = pokemon[pokemon["Type 1"] == "Water"].fillna("No type")
plt.figure(figsize=(15,6))
sns.countplot(x = "Type 2", data = Water, palette ="GnBu_r", order = Water['Type 2'].value_counts().index)
plt.suptitle("Type 2 data for Water pokemons in descending order", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Type 2 data for Water pokemons in descending order')

# %%
pokemon[(pokemon["Type 1"] == "Water") & (pokemon["Type 2"] == "Steel") ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>#</th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Generation</th>
#       <th>Legendary</th>
#       <th>Second Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>440</th>
#       <td>395</td>
#       <td>Empoleon</td>
#       <td>Water</td>
#       <td>Steel</td>
#       <td>530</td>
#       <td>84</td>
#       <td>86</td>
#       <td>88</td>
#       <td>111</td>
#       <td>101</td>
#       <td>60</td>
#       <td>4</td>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sns.countplot(x = "Generation" , data = Water, palette ="coolwarm", order = Water['Generation'].value_counts().index)
plt.suptitle("Generation distribution for water type pokemon")
# Out:
# Text(0.5, 0.98, 'Generation distribution for water type pokemon')

# %%
Dragon = pokemon[pokemon["Type 1"] == "Dragon"].fillna("No type")

# %%
sns.countplot(x = "Generation" , data = Dragon, palette ="CMRmap", order = Dragon['Generation'].value_counts().index)
plt.suptitle("Generation data for Dragon pokemons")
# Out:
# Text(0.5, 0.98, 'Generation data for Dragon pokemons')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = "Type 2", data = Dragon, palette ="PuRd_r", order = Dragon['Type 2'].value_counts().index)
plt.suptitle("Type 2 data for Dragon pokemons in descending order")
# Out:
# Text(0.5, 0.98, 'Type 2 data for Dragon pokemons in descending order')

# %%
gen1 = pokemon[pokemon["Generation"] == 1]
plt.figure(figsize=(15,6))
sns.countplot(x="Type 1", data=gen1, order = gen1['Type 1'].value_counts().index, palette = "Paired")
plt.suptitle("Distribution of Type 1 data in Generation 1")
# Out:
# Text(0.5, 0.98, 'Distribution of Type 1 data in Generation 1')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Type 1", data=pokemon,  hue = "Generation", order = pokemon['Type 1'].value_counts().index, palette = "Paired")
plt.suptitle("Distribution of the Type 1 pokemons seperated by Generation")
plt.legend(loc='center right', title ="Generation" )

# %%
sum(pokemon["Legendary"] == True)
# Out:
# 65

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x = "Type 1", y = "Total", data = pokemon, hue = "Legendary")
plt.suptitle("Spread of Type 1 vs Total data separated by Legendary")
# Out:
# Text(0.5, 0.98, 'Spread of Type 1 vs Total data separated by Legendary')
