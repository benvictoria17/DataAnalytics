# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/pandas/blob/master/Italy_COVID_19_provincia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
ItalyCOVID19provincia = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/Coronavirus%20COVID-19%20Italy%20(updated%20regularly)/provincial_data.csv")

ItalyCOVID19provincia
# Out:
#       codice_provincia  codice_regione  ... stato totale_casi
# 0                   69              13  ...   ITA           0
# 1                   66              13  ...   ITA           0
# 2                   68              13  ...   ITA           0
# 3                   67              13  ...   ITA           0
# 4                  979              13  ...   ITA           0
# ...                ...             ...  ...   ...         ...
# 4731                26               5  ...   ITA        1522
# 4732                27               5  ...   ITA        1170
# 4733                23               5  ...   ITA        2112
# 4734                24               5  ...   ITA        1242
# 4735               999               5  ...   ITA         279
#
# [4736 rows x 12 columns]

# %%
ItalyCOVID19provincia.head()
# Out:
#    codice_provincia  codice_regione  ... stato totale_casi
# 0                69              13  ...   ITA           0
# 1                66              13  ...   ITA           0
# 2                68              13  ...   ITA           0
# 3                67              13  ...   ITA           0
# 4               979              13  ...   ITA           0
#
# [5 rows x 12 columns]

# %%
ItalyCOVID19provincia.describe()
# Out:
#        codice_provincia  codice_regione          lat         long  totale_casi
# count       4736.000000     4736.000000  4736.000000  4736.000000  4736.000000
# mean         207.523438       10.140625    35.868843    10.112000   256.146537
# std          347.419709        5.915033    16.073221     5.098131   752.041772
# min            1.000000        1.000000     0.000000     0.000000     0.000000
# 25%           32.750000        5.000000    38.848542     8.583304     0.000000
# 50%           64.500000        9.000000    42.609815    11.188560    22.000000
# 75%           96.250000       15.250000    44.947714    13.593962   180.250000
# max          999.000000       20.000000    46.499335    18.171897  8911.000000

# %%
ItalyCOVID19provincia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4736 entries, 0 to 4735
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   codice_provincia         4736 non-null   int64
#  1   codice_regione           4736 non-null   int64
#  2   data                     4736 non-null   object
#  3   denominazione_provincia  4736 non-null   object
#  4   denominazione_regione    4736 non-null   object
#  5   lat                      4736 non-null   float64
#  6   long                     4736 non-null   float64
#  7   note_en                  4 non-null      object
#  8   note_it                  4 non-null      object
#  9   sigla_provincia          3922 non-null   object
#  10  stato                    4736 non-null   object
#  11  totale_casi              4736 non-null   int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 444.1+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("ItalyCOVID19provincia.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("ItalyCOVID19provincia.db")
c = conn.cursor()

# %%
ItalyCOVID19provincia.to_sql("ItalyCOVID19provincia", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM ItalyCOVID19provincia""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   69,
#   13,
#   '2020-02-24T18:00:00',
#   'Chieti',
#   'Abruzzo',
#   42.35103167,
#   14.16754574,
#   None,
#   None,
#   'CH',
#   'ITA',
#   0),
#  (1,
#   66,
#   13,
#   '2020-02-24T18:00:00',
#   "L'Aquila",
#   'Abruzzo',
#   42.35122196,
#   13.39843823,
#   None,
#   None,
#   'AQ',
#   'ITA',
#   0),
#  (2,
#   68,
#   13,
#   '2020-02-24T18:00:00',
#   'Pescara',
#   'Abruzzo',
#   42.46458398,
#   14.21364822,
#   None,
#   None,
#   'PE',
#   'ITA',
#   0),
#  (3,
#   67,
#   13,
#   '2020-02-24T18:00:00',
#   'Teramo',
#   'Abruzzo',
#   42.6589177,
#   13.70439971,
#   None,
#   None,
#   'TE',
#   'ITA',
#   0),
#  (4,
#   979,
#   13,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Abruzzo',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (5,
#   77,
#   17,
#   '2020-02-24T18:00:00',
#   'Matera',
#   'Basilicata',
#   40.66751177,
#   16.59792442,
#   None,
#   None,
#   'MT',
#   'ITA',
#   0),
#  (6,
#   76,
#   17,
#   '2020-02-24T18:00:00',
#   'Potenza',
#   'Basilicata',
#   40.63947052,
#   15.80514834,
#   None,
#   None,
#   'PZ',
#   'ITA',
#   0),
#  (7,
#   980,
#   17,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Basilicata',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (8,
#   21,
#   4,
#   '2020-02-24T18:00:00',
#   'Bolzano',
#   'P.A. Bolzano',
#   46.49933453,
#   11.35662422,
#   None,
#   None,
#   'BZ',
#   'ITA',
#   0),
#  (9,
#   981,
#   4,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'P.A. Bolzano',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (10,
#   79,
#   18,
#   '2020-02-24T18:00:00',
#   'Catanzaro',
#   'Calabria',
#   38.90597598,
#   16.59440194,
#   None,
#   None,
#   'CZ',
#   'ITA',
#   0),
#  (11,
#   78,
#   18,
#   '2020-02-24T18:00:00',
#   'Cosenza',
#   'Calabria',
#   39.29308681,
#   16.25609692,
#   None,
#   None,
#   'CS',
#   'ITA',
#   0),
#  (12,
#   101,
#   18,
#   '2020-02-24T18:00:00',
#   'Crotone',
#   'Calabria',
#   39.08036878,
#   17.12538864,
#   None,
#   None,
#   'KR',
#   'ITA',
#   0),
#  (13,
#   80,
#   18,
#   '2020-02-24T18:00:00',
#   'Reggio di Calabria',
#   'Calabria',
#   38.10922769,
#   15.643452700000001,
#   None,
#   None,
#   'RC',
#   'ITA',
#   0),
#  (14,
#   102,
#   18,
#   '2020-02-24T18:00:00',
#   'Vibo Valentia',
#   'Calabria',
#   38.67624147,
#   16.10157414,
#   None,
#   None,
#   'VV',
#   'ITA',
#   0),
#  (15,
#   982,
#   18,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Calabria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (16,
#   64,
#   15,
#   '2020-02-24T18:00:00',
#   'Avellino',
#   'Campania',
#   40.91404699,
#   14.79528803,
#   None,
#   None,
#   'AV',
#   'ITA',
#   0),
#  (17,
#   62,
#   15,
#   '2020-02-24T18:00:00',
#   'Benevento',
#   'Campania',
#   41.12969987,
#   14.78151683,
#   None,
#   None,
#   'BN',
#   'ITA',
#   0),
#  (18,
#   61,
#   15,
#   '2020-02-24T18:00:00',
#   'Caserta',
#   'Campania',
#   41.07465878,
#   14.33240464,
#   None,
#   None,
#   'CE',
#   'ITA',
#   0),
#  (19,
#   63,
#   15,
#   '2020-02-24T18:00:00',
#   'Napoli',
#   'Campania',
#   40.83956555,
#   14.25084984,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (20,
#   65,
#   15,
#   '2020-02-24T18:00:00',
#   'Salerno',
#   'Campania',
#   40.67821961,
#   14.759402599999998,
#   None,
#   None,
#   'SA',
#   'ITA',
#   0),
#  (21,
#   983,
#   15,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Campania',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (22,
#   37,
#   8,
#   '2020-02-24T18:00:00',
#   'Bologna',
#   'Emilia-Romagna',
#   44.49436681,
#   11.341720800000001,
#   None,
#   None,
#   'BO',
#   'ITA',
#   0),
#  (23,
#   38,
#   8,
#   '2020-02-24T18:00:00',
#   'Ferrara',
#   'Emilia-Romagna',
#   44.83599085,
#   11.61868934,
#   None,
#   None,
#   'FE',
#   'ITA',
#   0),
#  (24,
#   40,
#   8,
#   '2020-02-24T18:00:00',
#   'Forlì-Cesena',
#   'Emilia-Romagna',
#   44.22268559,
#   12.04068608,
#   None,
#   None,
#   'FC',
#   'ITA',
#   0),
#  (25,
#   36,
#   8,
#   '2020-02-24T18:00:00',
#   'Modena',
#   'Emilia-Romagna',
#   44.64600009,
#   10.92615487,
#   None,
#   None,
#   'MO',
#   'ITA',
#   0),
#  (26,
#   34,
#   8,
#   '2020-02-24T18:00:00',
#   'Parma',
#   'Emilia-Romagna',
#   44.80107394,
#   10.32834985,
#   None,
#   None,
#   'PR',
#   'ITA',
#   0),
#  (27,
#   33,
#   8,
#   '2020-02-24T18:00:00',
#   'Piacenza',
#   'Emilia-Romagna',
#   45.05193462,
#   9.692632596000001,
#   None,
#   None,
#   'PC',
#   'ITA',
#   0),
#  (28,
#   39,
#   8,
#   '2020-02-24T18:00:00',
#   'Ravenna',
#   'Emilia-Romagna',
#   44.41722493,
#   12.19913936,
#   None,
#   None,
#   'RA',
#   'ITA',
#   0),
#  (29,
#   35,
#   8,
#   '2020-02-24T18:00:00',
#   "Reggio nell'Emilia",
#   'Emilia-Romagna',
#   44.69735289,
#   10.63007973,
#   None,
#   None,
#   'RE',
#   'ITA',
#   0),
#  (30,
#   99,
#   8,
#   '2020-02-24T18:00:00',
#   'Rimini',
#   'Emilia-Romagna',
#   44.06090087,
#   12.5656295,
#   None,
#   None,
#   'RN',
#   'ITA',
#   0),
#  (31,
#   984,
#   8,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Emilia-Romagna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (32,
#   31,
#   6,
#   '2020-02-24T18:00:00',
#   'Gorizia',
#   'Friuli Venezia Giulia',
#   45.94149817,
#   13.62212502,
#   None,
#   None,
#   'GO',
#   'ITA',
#   0),
#  (33,
#   93,
#   6,
#   '2020-02-24T18:00:00',
#   'Pordenone',
#   'Friuli Venezia Giulia',
#   45.95443546,
#   12.66002909,
#   None,
#   None,
#   'PN',
#   'ITA',
#   0),
#  (34,
#   32,
#   6,
#   '2020-02-24T18:00:00',
#   'Trieste',
#   'Friuli Venezia Giulia',
#   45.6494354,
#   13.76813649,
#   None,
#   None,
#   'TS',
#   'ITA',
#   0),
#  (35,
#   30,
#   6,
#   '2020-02-24T18:00:00',
#   'Udine',
#   'Friuli Venezia Giulia',
#   46.06255516,
#   13.2348383,
#   None,
#   None,
#   'UD',
#   'ITA',
#   0),
#  (36,
#   985,
#   6,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Friuli Venezia Giulia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (37,
#   60,
#   12,
#   '2020-02-24T18:00:00',
#   'Frosinone',
#   'Lazio',
#   41.63964569,
#   13.35117161,
#   None,
#   None,
#   'FR',
#   'ITA',
#   0),
#  (38,
#   59,
#   12,
#   '2020-02-24T18:00:00',
#   'Latina',
#   'Lazio',
#   41.46759465,
#   12.90368482,
#   None,
#   None,
#   'LT',
#   'ITA',
#   0),
#  (39,
#   57,
#   12,
#   '2020-02-24T18:00:00',
#   'Rieti',
#   'Lazio',
#   42.40488444,
#   12.86205939,
#   None,
#   None,
#   'RI',
#   'ITA',
#   0),
#  (40,
#   58,
#   12,
#   '2020-02-24T18:00:00',
#   'Roma',
#   'Lazio',
#   41.89277044,
#   12.48366722,
#   None,
#   None,
#   'RM',
#   'ITA',
#   0),
#  (41,
#   56,
#   12,
#   '2020-02-24T18:00:00',
#   'Viterbo',
#   'Lazio',
#   42.4173828,
#   12.10473416,
#   None,
#   None,
#   'VT',
#   'ITA',
#   0),
#  (42,
#   986,
#   12,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lazio',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (43,
#   10,
#   7,
#   '2020-02-24T18:00:00',
#   'Genova',
#   'Liguria',
#   44.41149314,
#   8.9326992,
#   None,
#   None,
#   'GE',
#   'ITA',
#   0),
#  (44,
#   8,
#   7,
#   '2020-02-24T18:00:00',
#   'Imperia',
#   'Liguria',
#   43.88570648,
#   8.027850297999999,
#   None,
#   None,
#   'IM',
#   'ITA',
#   0),
#  (45,
#   11,
#   7,
#   '2020-02-24T18:00:00',
#   'La Spezia',
#   'Liguria',
#   44.10704991,
#   9.8281897,
#   None,
#   None,
#   'SP',
#   'ITA',
#   0),
#  (46,
#   9,
#   7,
#   '2020-02-24T18:00:00',
#   'Savona',
#   'Liguria',
#   44.30750461,
#   8.481108654,
#   None,
#   None,
#   'SV',
#   'ITA',
#   0),
#  (47,
#   987,
#   7,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Liguria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (48,
#   16,
#   3,
#   '2020-02-24T18:00:00',
#   'Bergamo',
#   'Lombardia',
#   45.69441368,
#   9.668424528,
#   None,
#   None,
#   'BG',
#   'ITA',
#   0),
#  (49,
#   17,
#   3,
#   '2020-02-24T18:00:00',
#   'Brescia',
#   'Lombardia',
#   45.53993052,
#   10.21910323,
#   None,
#   None,
#   'BS',
#   'ITA',
#   0),
#  (50,
#   13,
#   3,
#   '2020-02-24T18:00:00',
#   'Como',
#   'Lombardia',
#   45.8099912,
#   9.085159546,
#   None,
#   None,
#   'CO',
#   'ITA',
#   0),
#  (51,
#   19,
#   3,
#   '2020-02-24T18:00:00',
#   'Cremona',
#   'Lombardia',
#   45.13336675,
#   10.02420865,
#   None,
#   None,
#   'CR',
#   'ITA',
#   0),
#  (52,
#   97,
#   3,
#   '2020-02-24T18:00:00',
#   'Lecco',
#   'Lombardia',
#   45.85575781,
#   9.393392246,
#   None,
#   None,
#   'LC',
#   'ITA',
#   0),
#  (53,
#   98,
#   3,
#   '2020-02-24T18:00:00',
#   'Lodi',
#   'Lombardia',
#   45.31440693,
#   9.503720769,
#   None,
#   None,
#   'LO',
#   'ITA',
#   0),
#  (54,
#   20,
#   3,
#   '2020-02-24T18:00:00',
#   'Mantova',
#   'Lombardia',
#   45.15726772,
#   10.79277363,
#   None,
#   None,
#   'MN',
#   'ITA',
#   0),
#  (55,
#   15,
#   3,
#   '2020-02-24T18:00:00',
#   'Milano',
#   'Lombardia',
#   45.46679409,
#   9.190347404,
#   None,
#   None,
#   'MI',
#   'ITA',
#   0),
#  (56,
#   108,
#   3,
#   '2020-02-24T18:00:00',
#   'Monza e della Brianza',
#   'Lombardia',
#   45.58439043,
#   9.273582472000001,
#   None,
#   None,
#   'MB',
#   'ITA',
#   0),
#  (57,
#   18,
#   3,
#   '2020-02-24T18:00:00',
#   'Pavia',
#   'Lombardia',
#   45.18509264,
#   9.160157191,
#   None,
#   None,
#   'PV',
#   'ITA',
#   0),
#  (58,
#   14,
#   3,
#   '2020-02-24T18:00:00',
#   'Sondrio',
#   'Lombardia',
#   46.17099261,
#   9.87147489,
#   None,
#   None,
#   'SO',
#   'ITA',
#   0),
#  (59,
#   12,
#   3,
#   '2020-02-24T18:00:00',
#   'Varese',
#   'Lombardia',
#   45.81701677,
#   8.822868344,
#   None,
#   None,
#   'VA',
#   'ITA',
#   0),
#  (60,
#   988,
#   3,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lombardia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (61,
#   42,
#   11,
#   '2020-02-24T18:00:00',
#   'Ancona',
#   'Marche',
#   43.61675973,
#   13.5188753,
#   None,
#   None,
#   'AN',
#   'ITA',
#   0),
#  (62,
#   44,
#   11,
#   '2020-02-24T18:00:00',
#   'Ascoli Piceno',
#   'Marche',
#   42.85322304,
#   13.57691127,
#   None,
#   None,
#   'AP',
#   'ITA',
#   0),
#  (63,
#   109,
#   11,
#   '2020-02-24T18:00:00',
#   'Fermo',
#   'Marche',
#   43.16058534,
#   13.71839535,
#   None,
#   None,
#   'FM',
#   'ITA',
#   0),
#  (64,
#   43,
#   11,
#   '2020-02-24T18:00:00',
#   'Macerata',
#   'Marche',
#   43.30023926,
#   13.45307182,
#   None,
#   None,
#   'MC',
#   'ITA',
#   0),
#  (65,
#   41,
#   11,
#   '2020-02-24T18:00:00',
#   'Pesaro e Urbino',
#   'Marche',
#   43.91014021,
#   12.91345989,
#   None,
#   None,
#   'PU',
#   'ITA',
#   0),
#  (66,
#   989,
#   11,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Marche',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (67,
#   70,
#   14,
#   '2020-02-24T18:00:00',
#   'Campobasso',
#   'Molise',
#   41.55774754,
#   14.65916051,
#   None,
#   None,
#   'CB',
#   'ITA',
#   0),
#  (68,
#   94,
#   14,
#   '2020-02-24T18:00:00',
#   'Isernia',
#   'Molise',
#   41.58800826,
#   14.22575407,
#   None,
#   None,
#   'IS',
#   'ITA',
#   0),
#  (69,
#   990,
#   14,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Molise',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (70,
#   6,
#   1,
#   '2020-02-24T18:00:00',
#   'Alessandria',
#   'Piemonte',
#   44.91297351,
#   8.615401155,
#   None,
#   None,
#   'AL',
#   'ITA',
#   0),
#  (71,
#   5,
#   1,
#   '2020-02-24T18:00:00',
#   'Asti',
#   'Piemonte',
#   44.89912921,
#   8.204142547,
#   None,
#   None,
#   'AT',
#   'ITA',
#   0),
#  (72,
#   96,
#   1,
#   '2020-02-24T18:00:00',
#   'Biella',
#   'Piemonte',
#   45.5665112,
#   8.054082167,
#   None,
#   None,
#   'BI',
#   'ITA',
#   0),
#  (73,
#   4,
#   1,
#   '2020-02-24T18:00:00',
#   'Cuneo',
#   'Piemonte',
#   44.39329625,
#   7.551171632000001,
#   None,
#   None,
#   'CN',
#   'ITA',
#   0),
#  (74,
#   3,
#   1,
#   '2020-02-24T18:00:00',
#   'Novara',
#   'Piemonte',
#   45.44588506,
#   8.621915884,
#   None,
#   None,
#   'NO',
#   'ITA',
#   0),
#  (75,
#   1,
#   1,
#   '2020-02-24T18:00:00',
#   'Torino',
#   'Piemonte',
#   45.0732745,
#   7.680687483,
#   None,
#   None,
#   'TO',
#   'ITA',
#   0),
#  (76,
#   103,
#   1,
#   '2020-02-24T18:00:00',
#   'Verbano-Cusio-Ossola',
#   'Piemonte',
#   45.921445500000004,
#   8.551078752999999,
#   None,
#   None,
#   'VB',
#   'ITA',
#   0),
#  (77,
#   2,
#   1,
#   '2020-02-24T18:00:00',
#   'Vercelli',
#   'Piemonte',
#   45.32398135,
#   8.423234312,
#   None,
#   None,
#   'VC',
#   'ITA',
#   0),
#  (78,
#   991,
#   1,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Piemonte',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (79,
#   72,
#   16,
#   '2020-02-24T18:00:00',
#   'Bari',
#   'Puglia',
#   41.12559576,
#   16.86736689,
#   None,
#   None,
#   'BA',
#   'ITA',
#   0),
#  (80,
#   110,
#   16,
#   '2020-02-24T18:00:00',
#   'Barletta-Andria-Trani',
#   'Puglia',
#   41.22705039,
#   16.29520432,
#   None,
#   None,
#   'BT',
#   'ITA',
#   0),
#  (81,
#   74,
#   16,
#   '2020-02-24T18:00:00',
#   'Brindisi',
#   'Puglia',
#   40.63848545,
#   17.94601575,
#   None,
#   None,
#   'BR',
#   'ITA',
#   0),
#  (82,
#   71,
#   16,
#   '2020-02-24T18:00:00',
#   'Foggia',
#   'Puglia',
#   41.46226865,
#   15.54305094,
#   None,
#   None,
#   'FG',
#   'ITA',
#   0),
#  (83,
#   75,
#   16,
#   '2020-02-24T18:00:00',
#   'Lecce',
#   'Puglia',
#   40.35354285,
#   18.1718973,
#   None,
#   None,
#   'LE',
#   'ITA',
#   0),
#  (84,
#   73,
#   16,
#   '2020-02-24T18:00:00',
#   'Taranto',
#   'Puglia',
#   40.47354739,
#   17.23237181,
#   None,
#   None,
#   'TA',
#   'ITA',
#   0),
#  (85,
#   992,
#   16,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Puglia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (86,
#   92,
#   20,
#   '2020-02-24T18:00:00',
#   'Cagliari',
#   'Sardegna',
#   39.21531192,
#   9.110616306,
#   None,
#   None,
#   'CA',
#   'ITA',
#   0),
#  (87,
#   91,
#   20,
#   '2020-02-24T18:00:00',
#   'Nuoro',
#   'Sardegna',
#   40.32318834,
#   9.330296393,
#   None,
#   None,
#   'NU',
#   'ITA',
#   0),
#  (88,
#   95,
#   20,
#   '2020-02-24T18:00:00',
#   'Oristano',
#   'Sardegna',
#   39.90381075,
#   8.591183151000001,
#   None,
#   None,
#   'OR',
#   'ITA',
#   0),
#  (89,
#   90,
#   20,
#   '2020-02-24T18:00:00',
#   'Sassari',
#   'Sardegna',
#   40.72667657,
#   8.559667131,
#   None,
#   None,
#   'SS',
#   'ITA',
#   0),
#  (90,
#   111,
#   20,
#   '2020-02-24T18:00:00',
#   'Sud Sardegna',
#   'Sardegna',
#   39.16641462,
#   8.526242676,
#   None,
#   None,
#   'SU',
#   'ITA',
#   0),
#  (91,
#   993,
#   20,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Sardegna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (92,
#   84,
#   19,
#   '2020-02-24T18:00:00',
#   'Agrigento',
#   'Sicilia',
#   37.30971088,
#   13.584574900000002,
#   None,
#   None,
#   'AG',
#   'ITA',
#   0),
#  (93,
#   85,
#   19,
#   '2020-02-24T18:00:00',
#   'Caltanissetta',
#   'Sicilia',
#   37.49213171,
#   14.06184973,
#   None,
#   None,
#   'CL',
#   'ITA',
#   0),
#  (94,
#   87,
#   19,
#   '2020-02-24T18:00:00',
#   'Catania',
#   'Sicilia',
#   37.50287803,
#   15.08704691,
#   None,
#   None,
#   'CT',
#   'ITA',
#   0),
#  (95,
#   86,
#   19,
#   '2020-02-24T18:00:00',
#   'Enna',
#   'Sicilia',
#   37.56705701,
#   14.27909375,
#   None,
#   None,
#   'EN',
#   'ITA',
#   0),
#  (96,
#   83,
#   19,
#   '2020-02-24T18:00:00',
#   'Messina',
#   'Sicilia',
#   38.19395845,
#   15.55572302,
#   None,
#   None,
#   'ME',
#   'ITA',
#   0),
#  (97,
#   82,
#   19,
#   '2020-02-24T18:00:00',
#   'Palermo',
#   'Sicilia',
#   38.11569725,
#   13.362356699999998,
#   None,
#   None,
#   'PA',
#   'ITA',
#   0),
#  (98,
#   88,
#   19,
#   '2020-02-24T18:00:00',
#   'Ragusa',
#   'Sicilia',
#   36.92509198,
#   14.73069891,
#   None,
#   None,
#   'RG',
#   'ITA',
#   0),
#  (99,
#   89,
#   19,
#   '2020-02-24T18:00:00',
#   'Siracusa',
#   'Sicilia',
#   37.05991687,
#   15.29333182,
#   None,
#   None,
#   'SR',
#   'ITA',
#   0),
#  (100,
#   81,
#   19,
#   '2020-02-24T18:00:00',
#   'Trapani',
#   'Sicilia',
#   38.01850065,
#   12.51365684,
#   None,
#   None,
#   'TP',
#   'ITA',
#   0),
#  (101,
#   994,
#   19,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Sicilia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (102,
#   51,
#   9,
#   '2020-02-24T18:00:00',
#   'Arezzo',
#   'Toscana',
#   43.46642752,
#   11.88228844,
#   None,
#   None,
#   'AR',
#   'ITA',
#   0),
#  (103,
#   48,
#   9,
#   '2020-02-24T18:00:00',
#   'Firenze',
#   'Toscana',
#   43.76923077,
#   11.25588885,
#   None,
#   None,
#   'FI',
#   'ITA',
#   0),
#  (104,
#   53,
#   9,
#   '2020-02-24T18:00:00',
#   'Grosseto',
#   'Toscana',
#   42.76026758,
#   11.11356398,
#   None,
#   None,
#   'GR',
#   'ITA',
#   0),
#  (105,
#   49,
#   9,
#   '2020-02-24T18:00:00',
#   'Livorno',
#   'Toscana',
#   43.55234873,
#   10.3086781,
#   None,
#   None,
#   'LI',
#   'ITA',
#   0),
#  (106,
#   46,
#   9,
#   '2020-02-24T18:00:00',
#   'Lucca',
#   'Toscana',
#   43.84432283,
#   10.50151366,
#   None,
#   None,
#   'LU',
#   'ITA',
#   0),
#  (107,
#   45,
#   9,
#   '2020-02-24T18:00:00',
#   'Massa Carrara',
#   'Toscana',
#   44.03674425,
#   10.14173829,
#   None,
#   None,
#   'MS',
#   'ITA',
#   0),
#  (108,
#   50,
#   9,
#   '2020-02-24T18:00:00',
#   'Pisa',
#   'Toscana',
#   43.71553206,
#   10.40127259,
#   None,
#   None,
#   'PI',
#   'ITA',
#   0),
#  (109,
#   47,
#   9,
#   '2020-02-24T18:00:00',
#   'Pistoia',
#   'Toscana',
#   43.933465000000005,
#   10.91734146,
#   None,
#   None,
#   'PT',
#   'ITA',
#   0),
#  (110,
#   100,
#   9,
#   '2020-02-24T18:00:00',
#   'Prato',
#   'Toscana',
#   43.88062274,
#   11.09703315,
#   None,
#   None,
#   'PO',
#   'ITA',
#   0),
#  (111,
#   52,
#   9,
#   '2020-02-24T18:00:00',
#   'Siena',
#   'Toscana',
#   43.31816374,
#   11.33190988,
#   None,
#   None,
#   'SI',
#   'ITA',
#   0),
#  (112,
#   995,
#   9,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Toscana',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (113,
#   22,
#   4,
#   '2020-02-24T18:00:00',
#   'Trento',
#   'P.A. Trento',
#   46.06893511,
#   11.12123097,
#   None,
#   None,
#   'TN',
#   'ITA',
#   0),
#  (114,
#   996,
#   4,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'P.A. Trento',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (115,
#   54,
#   10,
#   '2020-02-24T18:00:00',
#   'Perugia',
#   'Umbria',
#   43.10675841,
#   12.38824698,
#   None,
#   None,
#   'PG',
#   'ITA',
#   0),
#  (116,
#   55,
#   10,
#   '2020-02-24T18:00:00',
#   'Terni',
#   'Umbria',
#   42.56071258,
#   12.6466875,
#   None,
#   None,
#   'TR',
#   'ITA',
#   0),
#  (117,
#   997,
#   10,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Umbria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (118,
#   7,
#   2,
#   '2020-02-24T18:00:00',
#   'Aosta',
#   "Valle d'Aosta",
#   45.73750286,
#   7.320149366,
#   None,
#   None,
#   'AO',
#   'ITA',
#   0),
#  (119,
#   998,
#   2,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   "Valle d'Aosta",
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (120,
#   25,
#   5,
#   '2020-02-24T18:00:00',
#   'Belluno',
#   'Veneto',
#   46.13837528,
#   12.21704167,
#   None,
#   None,
#   'BL',
#   'ITA',
#   0),
#  (121,
#   28,
#   5,
#   '2020-02-24T18:00:00',
#   'Padova',
#   'Veneto',
#   45.40692987,
#   11.87608718,
#   None,
#   None,
#   'PD',
#   'ITA',
#   0),
#  (122,
#   29,
#   5,
#   '2020-02-24T18:00:00',
#   'Rovigo',
#   'Veneto',
#   45.07107289,
#   11.79007,
#   None,
#   None,
#   'RO',
#   'ITA',
#   0),
#  (123,
#   26,
#   5,
#   '2020-02-24T18:00:00',
#   'Treviso',
#   'Veneto',
#   45.66754571,
#   12.24507363,
#   None,
#   None,
#   'TV',
#   'ITA',
#   0),
#  (124,
#   27,
#   5,
#   '2020-02-24T18:00:00',
#   'Venezia',
#   'Veneto',
#   45.43490485,
#   12.33845213,
#   None,
#   None,
#   'VE',
#   'ITA',
#   0),
#  (125,
#   23,
#   5,
#   '2020-02-24T18:00:00',
#   'Verona',
#   'Veneto',
#   45.43839046,
#   10.99352685,
#   None,
#   None,
#   'VR',
#   'ITA',
#   0),
#  (126,
#   24,
#   5,
#   '2020-02-24T18:00:00',
#   'Vicenza',
#   'Veneto',
#   45.547497,
#   11.54597109,
#   None,
#   None,
#   'VI',
#   'ITA',
#   0),
#  (127,
#   999,
#   5,
#   '2020-02-24T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Veneto',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (128,
#   69,
#   13,
#   '2020-02-25T18:00:00',
#   'Chieti',
#   'Abruzzo',
#   42.35103167,
#   14.16754574,
#   None,
#   None,
#   'CH',
#   'ITA',
#   0),
#  (129,
#   66,
#   13,
#   '2020-02-25T18:00:00',
#   "L'Aquila",
#   'Abruzzo',
#   42.35122196,
#   13.39843823,
#   None,
#   None,
#   'AQ',
#   'ITA',
#   0),
#  (130,
#   68,
#   13,
#   '2020-02-25T18:00:00',
#   'Pescara',
#   'Abruzzo',
#   42.46458398,
#   14.21364822,
#   None,
#   None,
#   'PE',
#   'ITA',
#   0),
#  (131,
#   67,
#   13,
#   '2020-02-25T18:00:00',
#   'Teramo',
#   'Abruzzo',
#   42.6589177,
#   13.70439971,
#   None,
#   None,
#   'TE',
#   'ITA',
#   0),
#  (132,
#   979,
#   13,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Abruzzo',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (133,
#   77,
#   17,
#   '2020-02-25T18:00:00',
#   'Matera',
#   'Basilicata',
#   40.66751177,
#   16.59792442,
#   None,
#   None,
#   'MT',
#   'ITA',
#   0),
#  (134,
#   76,
#   17,
#   '2020-02-25T18:00:00',
#   'Potenza',
#   'Basilicata',
#   40.63947052,
#   15.80514834,
#   None,
#   None,
#   'PZ',
#   'ITA',
#   0),
#  (135,
#   980,
#   17,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Basilicata',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (136,
#   21,
#   4,
#   '2020-02-25T18:00:00',
#   'Bolzano',
#   'P.A. Bolzano',
#   46.49933453,
#   11.35662422,
#   None,
#   None,
#   'BZ',
#   'ITA',
#   1),
#  (137,
#   981,
#   4,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'P.A. Bolzano',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (138,
#   79,
#   18,
#   '2020-02-25T18:00:00',
#   'Catanzaro',
#   'Calabria',
#   38.90597598,
#   16.59440194,
#   None,
#   None,
#   'CZ',
#   'ITA',
#   0),
#  (139,
#   78,
#   18,
#   '2020-02-25T18:00:00',
#   'Cosenza',
#   'Calabria',
#   39.29308681,
#   16.25609692,
#   None,
#   None,
#   'CS',
#   'ITA',
#   0),
#  (140,
#   101,
#   18,
#   '2020-02-25T18:00:00',
#   'Crotone',
#   'Calabria',
#   39.08036878,
#   17.12538864,
#   None,
#   None,
#   'KR',
#   'ITA',
#   0),
#  (141,
#   80,
#   18,
#   '2020-02-25T18:00:00',
#   'Reggio di Calabria',
#   'Calabria',
#   38.10922769,
#   15.643452700000001,
#   None,
#   None,
#   'RC',
#   'ITA',
#   0),
#  (142,
#   102,
#   18,
#   '2020-02-25T18:00:00',
#   'Vibo Valentia',
#   'Calabria',
#   38.67624147,
#   16.10157414,
#   None,
#   None,
#   'VV',
#   'ITA',
#   0),
#  (143,
#   982,
#   18,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Calabria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (144,
#   64,
#   15,
#   '2020-02-25T18:00:00',
#   'Avellino',
#   'Campania',
#   40.91404699,
#   14.79528803,
#   None,
#   None,
#   'AV',
#   'ITA',
#   0),
#  (145,
#   62,
#   15,
#   '2020-02-25T18:00:00',
#   'Benevento',
#   'Campania',
#   41.12969987,
#   14.78151683,
#   None,
#   None,
#   'BN',
#   'ITA',
#   0),
#  (146,
#   61,
#   15,
#   '2020-02-25T18:00:00',
#   'Caserta',
#   'Campania',
#   41.07465878,
#   14.33240464,
#   None,
#   None,
#   'CE',
#   'ITA',
#   0),
#  (147,
#   63,
#   15,
#   '2020-02-25T18:00:00',
#   'Napoli',
#   'Campania',
#   40.83956555,
#   14.25084984,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (148,
#   65,
#   15,
#   '2020-02-25T18:00:00',
#   'Salerno',
#   'Campania',
#   40.67821961,
#   14.759402599999998,
#   None,
#   None,
#   'SA',
#   'ITA',
#   0),
#  (149,
#   983,
#   15,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Campania',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (150,
#   37,
#   8,
#   '2020-02-25T18:00:00',
#   'Bologna',
#   'Emilia-Romagna',
#   44.49436681,
#   11.341720800000001,
#   None,
#   None,
#   'BO',
#   'ITA',
#   0),
#  (151,
#   38,
#   8,
#   '2020-02-25T18:00:00',
#   'Ferrara',
#   'Emilia-Romagna',
#   44.83599085,
#   11.61868934,
#   None,
#   None,
#   'FE',
#   'ITA',
#   0),
#  (152,
#   40,
#   8,
#   '2020-02-25T18:00:00',
#   'Forlì-Cesena',
#   'Emilia-Romagna',
#   44.22268559,
#   12.04068608,
#   None,
#   None,
#   'FC',
#   'ITA',
#   0),
#  (153,
#   36,
#   8,
#   '2020-02-25T18:00:00',
#   'Modena',
#   'Emilia-Romagna',
#   44.64600009,
#   10.92615487,
#   None,
#   None,
#   'MO',
#   'ITA',
#   3),
#  (154,
#   34,
#   8,
#   '2020-02-25T18:00:00',
#   'Parma',
#   'Emilia-Romagna',
#   44.80107394,
#   10.32834985,
#   None,
#   None,
#   'PR',
#   'ITA',
#   4),
#  (155,
#   33,
#   8,
#   '2020-02-25T18:00:00',
#   'Piacenza',
#   'Emilia-Romagna',
#   45.05193462,
#   9.692632596000001,
#   None,
#   None,
#   'PC',
#   'ITA',
#   18),
#  (156,
#   39,
#   8,
#   '2020-02-25T18:00:00',
#   'Ravenna',
#   'Emilia-Romagna',
#   44.41722493,
#   12.19913936,
#   None,
#   None,
#   'RA',
#   'ITA',
#   0),
#  (157,
#   35,
#   8,
#   '2020-02-25T18:00:00',
#   "Reggio nell'Emilia",
#   'Emilia-Romagna',
#   44.69735289,
#   10.63007973,
#   None,
#   None,
#   'RE',
#   'ITA',
#   0),
#  (158,
#   99,
#   8,
#   '2020-02-25T18:00:00',
#   'Rimini',
#   'Emilia-Romagna',
#   44.06090087,
#   12.5656295,
#   None,
#   None,
#   'RN',
#   'ITA',
#   1),
#  (159,
#   984,
#   8,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Emilia-Romagna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (160,
#   31,
#   6,
#   '2020-02-25T18:00:00',
#   'Gorizia',
#   'Friuli Venezia Giulia',
#   45.94149817,
#   13.62212502,
#   None,
#   None,
#   'GO',
#   'ITA',
#   0),
#  (161,
#   93,
#   6,
#   '2020-02-25T18:00:00',
#   'Pordenone',
#   'Friuli Venezia Giulia',
#   45.95443546,
#   12.66002909,
#   None,
#   None,
#   'PN',
#   'ITA',
#   0),
#  (162,
#   32,
#   6,
#   '2020-02-25T18:00:00',
#   'Trieste',
#   'Friuli Venezia Giulia',
#   45.6494354,
#   13.76813649,
#   None,
#   None,
#   'TS',
#   'ITA',
#   0),
#  (163,
#   30,
#   6,
#   '2020-02-25T18:00:00',
#   'Udine',
#   'Friuli Venezia Giulia',
#   46.06255516,
#   13.2348383,
#   None,
#   None,
#   'UD',
#   'ITA',
#   0),
#  (164,
#   985,
#   6,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Friuli Venezia Giulia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (165,
#   60,
#   12,
#   '2020-02-25T18:00:00',
#   'Frosinone',
#   'Lazio',
#   41.63964569,
#   13.35117161,
#   None,
#   None,
#   'FR',
#   'ITA',
#   0),
#  (166,
#   59,
#   12,
#   '2020-02-25T18:00:00',
#   'Latina',
#   'Lazio',
#   41.46759465,
#   12.90368482,
#   None,
#   None,
#   'LT',
#   'ITA',
#   0),
#  (167,
#   57,
#   12,
#   '2020-02-25T18:00:00',
#   'Rieti',
#   'Lazio',
#   42.40488444,
#   12.86205939,
#   None,
#   None,
#   'RI',
#   'ITA',
#   0),
#  (168,
#   58,
#   12,
#   '2020-02-25T18:00:00',
#   'Roma',
#   'Lazio',
#   41.89277044,
#   12.48366722,
#   None,
#   None,
#   'RM',
#   'ITA',
#   3),
#  (169,
#   56,
#   12,
#   '2020-02-25T18:00:00',
#   'Viterbo',
#   'Lazio',
#   42.4173828,
#   12.10473416,
#   None,
#   None,
#   'VT',
#   'ITA',
#   0),
#  (170,
#   986,
#   12,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lazio',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (171,
#   10,
#   7,
#   '2020-02-25T18:00:00',
#   'Genova',
#   'Liguria',
#   44.41149314,
#   8.9326992,
#   None,
#   None,
#   'GE',
#   'ITA',
#   0),
#  (172,
#   8,
#   7,
#   '2020-02-25T18:00:00',
#   'Imperia',
#   'Liguria',
#   43.88570648,
#   8.027850297999999,
#   None,
#   None,
#   'IM',
#   'ITA',
#   0),
#  (173,
#   11,
#   7,
#   '2020-02-25T18:00:00',
#   'La Spezia',
#   'Liguria',
#   44.10704991,
#   9.8281897,
#   None,
#   None,
#   'SP',
#   'ITA',
#   0),
#  (174,
#   9,
#   7,
#   '2020-02-25T18:00:00',
#   'Savona',
#   'Liguria',
#   44.30750461,
#   8.481108654,
#   None,
#   None,
#   'SV',
#   'ITA',
#   1),
#  (175,
#   987,
#   7,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Liguria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (176,
#   16,
#   3,
#   '2020-02-25T18:00:00',
#   'Bergamo',
#   'Lombardia',
#   45.69441368,
#   9.668424528,
#   None,
#   None,
#   'BG',
#   'ITA',
#   18),
#  (177,
#   17,
#   3,
#   '2020-02-25T18:00:00',
#   'Brescia',
#   'Lombardia',
#   45.53993052,
#   10.21910323,
#   None,
#   None,
#   'BS',
#   'ITA',
#   0),
#  (178,
#   13,
#   3,
#   '2020-02-25T18:00:00',
#   'Como',
#   'Lombardia',
#   45.8099912,
#   9.085159546,
#   None,
#   None,
#   'CO',
#   'ITA',
#   0),
#  (179,
#   19,
#   3,
#   '2020-02-25T18:00:00',
#   'Cremona',
#   'Lombardia',
#   45.13336675,
#   10.02420865,
#   None,
#   None,
#   'CR',
#   'ITA',
#   53),
#  (180,
#   97,
#   3,
#   '2020-02-25T18:00:00',
#   'Lecco',
#   'Lombardia',
#   45.85575781,
#   9.393392246,
#   None,
#   None,
#   'LC',
#   'ITA',
#   0),
#  (181,
#   98,
#   3,
#   '2020-02-25T18:00:00',
#   'Lodi',
#   'Lombardia',
#   45.31440693,
#   9.503720769,
#   None,
#   None,
#   'LO',
#   'ITA',
#   125),
#  (182,
#   20,
#   3,
#   '2020-02-25T18:00:00',
#   'Mantova',
#   'Lombardia',
#   45.15726772,
#   10.79277363,
#   None,
#   None,
#   'MN',
#   'ITA',
#   0),
#  (183,
#   15,
#   3,
#   '2020-02-25T18:00:00',
#   'Milano',
#   'Lombardia',
#   45.46679409,
#   9.190347404,
#   None,
#   None,
#   'MI',
#   'ITA',
#   8),
#  (184,
#   108,
#   3,
#   '2020-02-25T18:00:00',
#   'Monza e della Brianza',
#   'Lombardia',
#   45.58439043,
#   9.273582472000001,
#   None,
#   None,
#   'MB',
#   'ITA',
#   3),
#  (185,
#   18,
#   3,
#   '2020-02-25T18:00:00',
#   'Pavia',
#   'Lombardia',
#   45.18509264,
#   9.160157191,
#   None,
#   None,
#   'PV',
#   'ITA',
#   27),
#  (186,
#   14,
#   3,
#   '2020-02-25T18:00:00',
#   'Sondrio',
#   'Lombardia',
#   46.17099261,
#   9.87147489,
#   None,
#   None,
#   'SO',
#   'ITA',
#   1),
#  (187,
#   12,
#   3,
#   '2020-02-25T18:00:00',
#   'Varese',
#   'Lombardia',
#   45.81701677,
#   8.822868344,
#   None,
#   None,
#   'VA',
#   'ITA',
#   0),
#  (188,
#   988,
#   3,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lombardia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   5),
#  (189,
#   42,
#   11,
#   '2020-02-25T18:00:00',
#   'Ancona',
#   'Marche',
#   43.61675973,
#   13.5188753,
#   None,
#   None,
#   'AN',
#   'ITA',
#   0),
#  (190,
#   44,
#   11,
#   '2020-02-25T18:00:00',
#   'Ascoli Piceno',
#   'Marche',
#   42.85322304,
#   13.57691127,
#   None,
#   None,
#   'AP',
#   'ITA',
#   0),
#  (191,
#   109,
#   11,
#   '2020-02-25T18:00:00',
#   'Fermo',
#   'Marche',
#   43.16058534,
#   13.71839535,
#   None,
#   None,
#   'FM',
#   'ITA',
#   0),
#  (192,
#   43,
#   11,
#   '2020-02-25T18:00:00',
#   'Macerata',
#   'Marche',
#   43.30023926,
#   13.45307182,
#   None,
#   None,
#   'MC',
#   'ITA',
#   0),
#  (193,
#   41,
#   11,
#   '2020-02-25T18:00:00',
#   'Pesaro e Urbino',
#   'Marche',
#   43.91014021,
#   12.91345989,
#   None,
#   None,
#   'PU',
#   'ITA',
#   0),
#  (194,
#   989,
#   11,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Marche',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (195,
#   70,
#   14,
#   '2020-02-25T18:00:00',
#   'Campobasso',
#   'Molise',
#   41.55774754,
#   14.65916051,
#   None,
#   None,
#   'CB',
#   'ITA',
#   0),
#  (196,
#   94,
#   14,
#   '2020-02-25T18:00:00',
#   'Isernia',
#   'Molise',
#   41.58800826,
#   14.22575407,
#   None,
#   None,
#   'IS',
#   'ITA',
#   0),
#  (197,
#   990,
#   14,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Molise',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (198,
#   6,
#   1,
#   '2020-02-25T18:00:00',
#   'Alessandria',
#   'Piemonte',
#   44.91297351,
#   8.615401155,
#   None,
#   None,
#   'AL',
#   'ITA',
#   0),
#  (199,
#   5,
#   1,
#   '2020-02-25T18:00:00',
#   'Asti',
#   'Piemonte',
#   44.89912921,
#   8.204142547,
#   None,
#   None,
#   'AT',
#   'ITA',
#   0),
#  (200,
#   96,
#   1,
#   '2020-02-25T18:00:00',
#   'Biella',
#   'Piemonte',
#   45.5665112,
#   8.054082167,
#   None,
#   None,
#   'BI',
#   'ITA',
#   0),
#  (201,
#   4,
#   1,
#   '2020-02-25T18:00:00',
#   'Cuneo',
#   'Piemonte',
#   44.39329625,
#   7.551171632000001,
#   None,
#   None,
#   'CN',
#   'ITA',
#   0),
#  (202,
#   3,
#   1,
#   '2020-02-25T18:00:00',
#   'Novara',
#   'Piemonte',
#   45.44588506,
#   8.621915884,
#   None,
#   None,
#   'NO',
#   'ITA',
#   0),
#  (203,
#   1,
#   1,
#   '2020-02-25T18:00:00',
#   'Torino',
#   'Piemonte',
#   45.0732745,
#   7.680687483,
#   None,
#   None,
#   'TO',
#   'ITA',
#   3),
#  (204,
#   103,
#   1,
#   '2020-02-25T18:00:00',
#   'Verbano-Cusio-Ossola',
#   'Piemonte',
#   45.921445500000004,
#   8.551078752999999,
#   None,
#   None,
#   'VB',
#   'ITA',
#   0),
#  (205,
#   2,
#   1,
#   '2020-02-25T18:00:00',
#   'Vercelli',
#   'Piemonte',
#   45.32398135,
#   8.423234312,
#   None,
#   None,
#   'VC',
#   'ITA',
#   0),
#  (206,
#   991,
#   1,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Piemonte',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (207,
#   72,
#   16,
#   '2020-02-25T18:00:00',
#   'Bari',
#   'Puglia',
#   41.12559576,
#   16.86736689,
#   None,
#   None,
#   'BA',
#   'ITA',
#   0),
#  (208,
#   110,
#   16,
#   '2020-02-25T18:00:00',
#   'Barletta-Andria-Trani',
#   'Puglia',
#   41.22705039,
#   16.29520432,
#   None,
#   None,
#   'BT',
#   'ITA',
#   0),
#  (209,
#   74,
#   16,
#   '2020-02-25T18:00:00',
#   'Brindisi',
#   'Puglia',
#   40.63848545,
#   17.94601575,
#   None,
#   None,
#   'BR',
#   'ITA',
#   0),
#  (210,
#   71,
#   16,
#   '2020-02-25T18:00:00',
#   'Foggia',
#   'Puglia',
#   41.46226865,
#   15.54305094,
#   None,
#   None,
#   'FG',
#   'ITA',
#   0),
#  (211,
#   75,
#   16,
#   '2020-02-25T18:00:00',
#   'Lecce',
#   'Puglia',
#   40.35354285,
#   18.1718973,
#   None,
#   None,
#   'LE',
#   'ITA',
#   0),
#  (212,
#   73,
#   16,
#   '2020-02-25T18:00:00',
#   'Taranto',
#   'Puglia',
#   40.47354739,
#   17.23237181,
#   None,
#   None,
#   'TA',
#   'ITA',
#   0),
#  (213,
#   992,
#   16,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Puglia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (214,
#   92,
#   20,
#   '2020-02-25T18:00:00',
#   'Cagliari',
#   'Sardegna',
#   39.21531192,
#   9.110616306,
#   None,
#   None,
#   'CA',
#   'ITA',
#   0),
#  (215,
#   91,
#   20,
#   '2020-02-25T18:00:00',
#   'Nuoro',
#   'Sardegna',
#   40.32318834,
#   9.330296393,
#   None,
#   None,
#   'NU',
#   'ITA',
#   0),
#  (216,
#   95,
#   20,
#   '2020-02-25T18:00:00',
#   'Oristano',
#   'Sardegna',
#   39.90381075,
#   8.591183151000001,
#   None,
#   None,
#   'OR',
#   'ITA',
#   0),
#  (217,
#   90,
#   20,
#   '2020-02-25T18:00:00',
#   'Sassari',
#   'Sardegna',
#   40.72667657,
#   8.559667131,
#   None,
#   None,
#   'SS',
#   'ITA',
#   0),
#  (218,
#   111,
#   20,
#   '2020-02-25T18:00:00',
#   'Sud Sardegna',
#   'Sardegna',
#   39.16641462,
#   8.526242676,
#   None,
#   None,
#   'SU',
#   'ITA',
#   0),
#  (219,
#   993,
#   20,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Sardegna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (220,
#   84,
#   19,
#   '2020-02-25T18:00:00',
#   'Agrigento',
#   'Sicilia',
#   37.30971088,
#   13.584574900000002,
#   None,
#   None,
#   'AG',
#   'ITA',
#   0),
#  (221,
#   85,
#   19,
#   '2020-02-25T18:00:00',
#   'Caltanissetta',
#   'Sicilia',
#   37.49213171,
#   14.06184973,
#   None,
#   None,
#   'CL',
#   'ITA',
#   0),
#  (222,
#   87,
#   19,
#   '2020-02-25T18:00:00',
#   'Catania',
#   'Sicilia',
#   37.50287803,
#   15.08704691,
#   None,
#   None,
#   'CT',
#   'ITA',
#   0),
#  (223,
#   86,
#   19,
#   '2020-02-25T18:00:00',
#   'Enna',
#   'Sicilia',
#   37.56705701,
#   14.27909375,
#   None,
#   None,
#   'EN',
#   'ITA',
#   0),
#  (224,
#   83,
#   19,
#   '2020-02-25T18:00:00',
#   'Messina',
#   'Sicilia',
#   38.19395845,
#   15.55572302,
#   None,
#   None,
#   'ME',
#   'ITA',
#   0),
#  (225,
#   82,
#   19,
#   '2020-02-25T18:00:00',
#   'Palermo',
#   'Sicilia',
#   38.11569725,
#   13.362356699999998,
#   None,
#   None,
#   'PA',
#   'ITA',
#   3),
#  (226,
#   88,
#   19,
#   '2020-02-25T18:00:00',
#   'Ragusa',
#   'Sicilia',
#   36.92509198,
#   14.73069891,
#   None,
#   None,
#   'RG',
#   'ITA',
#   0),
#  (227,
#   89,
#   19,
#   '2020-02-25T18:00:00',
#   'Siracusa',
#   'Sicilia',
#   37.05991687,
#   15.29333182,
#   None,
#   None,
#   'SR',
#   'ITA',
#   0),
#  (228,
#   81,
#   19,
#   '2020-02-25T18:00:00',
#   'Trapani',
#   'Sicilia',
#   38.01850065,
#   12.51365684,
#   None,
#   None,
#   'TP',
#   'ITA',
#   0),
#  (229,
#   994,
#   19,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Sicilia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (230,
#   51,
#   9,
#   '2020-02-25T18:00:00',
#   'Arezzo',
#   'Toscana',
#   43.46642752,
#   11.88228844,
#   None,
#   None,
#   'AR',
#   'ITA',
#   0),
#  (231,
#   48,
#   9,
#   '2020-02-25T18:00:00',
#   'Firenze',
#   'Toscana',
#   43.76923077,
#   11.25588885,
#   None,
#   None,
#   'FI',
#   'ITA',
#   1),
#  (232,
#   53,
#   9,
#   '2020-02-25T18:00:00',
#   'Grosseto',
#   'Toscana',
#   42.76026758,
#   11.11356398,
#   None,
#   None,
#   'GR',
#   'ITA',
#   0),
#  (233,
#   49,
#   9,
#   '2020-02-25T18:00:00',
#   'Livorno',
#   'Toscana',
#   43.55234873,
#   10.3086781,
#   None,
#   None,
#   'LI',
#   'ITA',
#   0),
#  (234,
#   46,
#   9,
#   '2020-02-25T18:00:00',
#   'Lucca',
#   'Toscana',
#   43.84432283,
#   10.50151366,
#   None,
#   None,
#   'LU',
#   'ITA',
#   0),
#  (235,
#   45,
#   9,
#   '2020-02-25T18:00:00',
#   'Massa Carrara',
#   'Toscana',
#   44.03674425,
#   10.14173829,
#   None,
#   None,
#   'MS',
#   'ITA',
#   0),
#  (236,
#   50,
#   9,
#   '2020-02-25T18:00:00',
#   'Pisa',
#   'Toscana',
#   43.71553206,
#   10.40127259,
#   None,
#   None,
#   'PI',
#   'ITA',
#   0),
#  (237,
#   47,
#   9,
#   '2020-02-25T18:00:00',
#   'Pistoia',
#   'Toscana',
#   43.933465000000005,
#   10.91734146,
#   None,
#   None,
#   'PT',
#   'ITA',
#   1),
#  (238,
#   100,
#   9,
#   '2020-02-25T18:00:00',
#   'Prato',
#   'Toscana',
#   43.88062274,
#   11.09703315,
#   None,
#   None,
#   'PO',
#   'ITA',
#   0),
#  (239,
#   52,
#   9,
#   '2020-02-25T18:00:00',
#   'Siena',
#   'Toscana',
#   43.31816374,
#   11.33190988,
#   None,
#   None,
#   'SI',
#   'ITA',
#   0),
#  (240,
#   995,
#   9,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Toscana',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (241,
#   22,
#   4,
#   '2020-02-25T18:00:00',
#   'Trento',
#   'P.A. Trento',
#   46.06893511,
#   11.12123097,
#   None,
#   None,
#   'TN',
#   'ITA',
#   0),
#  (242,
#   996,
#   4,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'P.A. Trento',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (243,
#   54,
#   10,
#   '2020-02-25T18:00:00',
#   'Perugia',
#   'Umbria',
#   43.10675841,
#   12.38824698,
#   None,
#   None,
#   'PG',
#   'ITA',
#   0),
#  (244,
#   55,
#   10,
#   '2020-02-25T18:00:00',
#   'Terni',
#   'Umbria',
#   42.56071258,
#   12.6466875,
#   None,
#   None,
#   'TR',
#   'ITA',
#   0),
#  (245,
#   997,
#   10,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Umbria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (246,
#   7,
#   2,
#   '2020-02-25T18:00:00',
#   'Aosta',
#   "Valle d'Aosta",
#   45.73750286,
#   7.320149366,
#   None,
#   None,
#   'AO',
#   'ITA',
#   0),
#  (247,
#   998,
#   2,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   "Valle d'Aosta",
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (248,
#   25,
#   5,
#   '2020-02-25T18:00:00',
#   'Belluno',
#   'Veneto',
#   46.13837528,
#   12.21704167,
#   None,
#   None,
#   'BL',
#   'ITA',
#   0),
#  (249,
#   28,
#   5,
#   '2020-02-25T18:00:00',
#   'Padova',
#   'Veneto',
#   45.40692987,
#   11.87608718,
#   None,
#   None,
#   'PD',
#   'ITA',
#   30),
#  (250,
#   29,
#   5,
#   '2020-02-25T18:00:00',
#   'Rovigo',
#   'Veneto',
#   45.07107289,
#   11.79007,
#   None,
#   None,
#   'RO',
#   'ITA',
#   0),
#  (251,
#   26,
#   5,
#   '2020-02-25T18:00:00',
#   'Treviso',
#   'Veneto',
#   45.66754571,
#   12.24507363,
#   None,
#   None,
#   'TV',
#   'ITA',
#   1),
#  (252,
#   27,
#   5,
#   '2020-02-25T18:00:00',
#   'Venezia',
#   'Veneto',
#   45.43490485,
#   12.33845213,
#   None,
#   None,
#   'VE',
#   'ITA',
#   7),
#  (253,
#   23,
#   5,
#   '2020-02-25T18:00:00',
#   'Verona',
#   'Veneto',
#   45.43839046,
#   10.99352685,
#   None,
#   None,
#   'VR',
#   'ITA',
#   0),
#  (254,
#   24,
#   5,
#   '2020-02-25T18:00:00',
#   'Vicenza',
#   'Veneto',
#   45.547497,
#   11.54597109,
#   None,
#   None,
#   'VI',
#   'ITA',
#   0),
#  (255,
#   999,
#   5,
#   '2020-02-25T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Veneto',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   5),
#  (256,
#   69,
#   13,
#   '2020-02-26T18:00:00',
#   'Chieti',
#   'Abruzzo',
#   42.35103167,
#   14.16754574,
#   None,
#   None,
#   'CH',
#   'ITA',
#   0),
#  (257,
#   66,
#   13,
#   '2020-02-26T18:00:00',
#   "L'Aquila",
#   'Abruzzo',
#   42.35122196,
#   13.39843823,
#   None,
#   None,
#   'AQ',
#   'ITA',
#   0),
#  (258,
#   68,
#   13,
#   '2020-02-26T18:00:00',
#   'Pescara',
#   'Abruzzo',
#   42.46458398,
#   14.21364822,
#   None,
#   None,
#   'PE',
#   'ITA',
#   0),
#  (259,
#   67,
#   13,
#   '2020-02-26T18:00:00',
#   'Teramo',
#   'Abruzzo',
#   42.6589177,
#   13.70439971,
#   None,
#   None,
#   'TE',
#   'ITA',
#   0),
#  (260,
#   979,
#   13,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Abruzzo',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (261,
#   77,
#   17,
#   '2020-02-26T18:00:00',
#   'Matera',
#   'Basilicata',
#   40.66751177,
#   16.59792442,
#   None,
#   None,
#   'MT',
#   'ITA',
#   0),
#  (262,
#   76,
#   17,
#   '2020-02-26T18:00:00',
#   'Potenza',
#   'Basilicata',
#   40.63947052,
#   15.80514834,
#   None,
#   None,
#   'PZ',
#   'ITA',
#   0),
#  (263,
#   980,
#   17,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Basilicata',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (264,
#   21,
#   4,
#   '2020-02-26T18:00:00',
#   'Bolzano',
#   'P.A. Bolzano',
#   46.49933453,
#   11.35662422,
#   None,
#   None,
#   'BZ',
#   'ITA',
#   1),
#  (265,
#   981,
#   4,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'P.A. Bolzano',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (266,
#   79,
#   18,
#   '2020-02-26T18:00:00',
#   'Catanzaro',
#   'Calabria',
#   38.90597598,
#   16.59440194,
#   None,
#   None,
#   'CZ',
#   'ITA',
#   0),
#  (267,
#   78,
#   18,
#   '2020-02-26T18:00:00',
#   'Cosenza',
#   'Calabria',
#   39.29308681,
#   16.25609692,
#   None,
#   None,
#   'CS',
#   'ITA',
#   0),
#  (268,
#   101,
#   18,
#   '2020-02-26T18:00:00',
#   'Crotone',
#   'Calabria',
#   39.08036878,
#   17.12538864,
#   None,
#   None,
#   'KR',
#   'ITA',
#   0),
#  (269,
#   80,
#   18,
#   '2020-02-26T18:00:00',
#   'Reggio di Calabria',
#   'Calabria',
#   38.10922769,
#   15.643452700000001,
#   None,
#   None,
#   'RC',
#   'ITA',
#   0),
#  (270,
#   102,
#   18,
#   '2020-02-26T18:00:00',
#   'Vibo Valentia',
#   'Calabria',
#   38.67624147,
#   16.10157414,
#   None,
#   None,
#   'VV',
#   'ITA',
#   0),
#  (271,
#   982,
#   18,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Calabria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (272,
#   64,
#   15,
#   '2020-02-26T18:00:00',
#   'Avellino',
#   'Campania',
#   40.91404699,
#   14.79528803,
#   None,
#   None,
#   'AV',
#   'ITA',
#   0),
#  (273,
#   62,
#   15,
#   '2020-02-26T18:00:00',
#   'Benevento',
#   'Campania',
#   41.12969987,
#   14.78151683,
#   None,
#   None,
#   'BN',
#   'ITA',
#   0),
#  (274,
#   61,
#   15,
#   '2020-02-26T18:00:00',
#   'Caserta',
#   'Campania',
#   41.07465878,
#   14.33240464,
#   None,
#   None,
#   'CE',
#   'ITA',
#   0),
#  (275,
#   63,
#   15,
#   '2020-02-26T18:00:00',
#   'Napoli',
#   'Campania',
#   40.83956555,
#   14.25084984,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (276,
#   65,
#   15,
#   '2020-02-26T18:00:00',
#   'Salerno',
#   'Campania',
#   40.67821961,
#   14.759402599999998,
#   None,
#   None,
#   'SA',
#   'ITA',
#   0),
#  (277,
#   983,
#   15,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Campania',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (278,
#   37,
#   8,
#   '2020-02-26T18:00:00',
#   'Bologna',
#   'Emilia-Romagna',
#   44.49436681,
#   11.341720800000001,
#   None,
#   None,
#   'BO',
#   'ITA',
#   0),
#  (279,
#   38,
#   8,
#   '2020-02-26T18:00:00',
#   'Ferrara',
#   'Emilia-Romagna',
#   44.83599085,
#   11.61868934,
#   None,
#   None,
#   'FE',
#   'ITA',
#   0),
#  (280,
#   40,
#   8,
#   '2020-02-26T18:00:00',
#   'Forlì-Cesena',
#   'Emilia-Romagna',
#   44.22268559,
#   12.04068608,
#   None,
#   None,
#   'FC',
#   'ITA',
#   0),
#  (281,
#   36,
#   8,
#   '2020-02-26T18:00:00',
#   'Modena',
#   'Emilia-Romagna',
#   44.64600009,
#   10.92615487,
#   None,
#   None,
#   'MO',
#   'ITA',
#   8),
#  (282,
#   34,
#   8,
#   '2020-02-26T18:00:00',
#   'Parma',
#   'Emilia-Romagna',
#   44.80107394,
#   10.32834985,
#   None,
#   None,
#   'PR',
#   'ITA',
#   8),
#  (283,
#   33,
#   8,
#   '2020-02-26T18:00:00',
#   'Piacenza',
#   'Emilia-Romagna',
#   45.05193462,
#   9.692632596000001,
#   None,
#   None,
#   'PC',
#   'ITA',
#   28),
#  (284,
#   39,
#   8,
#   '2020-02-26T18:00:00',
#   'Ravenna',
#   'Emilia-Romagna',
#   44.41722493,
#   12.19913936,
#   None,
#   None,
#   'RA',
#   'ITA',
#   0),
#  (285,
#   35,
#   8,
#   '2020-02-26T18:00:00',
#   "Reggio nell'Emilia",
#   'Emilia-Romagna',
#   44.69735289,
#   10.63007973,
#   None,
#   None,
#   'RE',
#   'ITA',
#   0),
#  (286,
#   99,
#   8,
#   '2020-02-26T18:00:00',
#   'Rimini',
#   'Emilia-Romagna',
#   44.06090087,
#   12.5656295,
#   None,
#   None,
#   'RN',
#   'ITA',
#   3),
#  (287,
#   984,
#   8,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Emilia-Romagna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (288,
#   31,
#   6,
#   '2020-02-26T18:00:00',
#   'Gorizia',
#   'Friuli Venezia Giulia',
#   45.94149817,
#   13.62212502,
#   None,
#   None,
#   'GO',
#   'ITA',
#   0),
#  (289,
#   93,
#   6,
#   '2020-02-26T18:00:00',
#   'Pordenone',
#   'Friuli Venezia Giulia',
#   45.95443546,
#   12.66002909,
#   None,
#   None,
#   'PN',
#   'ITA',
#   0),
#  (290,
#   32,
#   6,
#   '2020-02-26T18:00:00',
#   'Trieste',
#   'Friuli Venezia Giulia',
#   45.6494354,
#   13.76813649,
#   None,
#   None,
#   'TS',
#   'ITA',
#   0),
#  (291,
#   30,
#   6,
#   '2020-02-26T18:00:00',
#   'Udine',
#   'Friuli Venezia Giulia',
#   46.06255516,
#   13.2348383,
#   None,
#   None,
#   'UD',
#   'ITA',
#   0),
#  (292,
#   985,
#   6,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Friuli Venezia Giulia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (293,
#   60,
#   12,
#   '2020-02-26T18:00:00',
#   'Frosinone',
#   'Lazio',
#   41.63964569,
#   13.35117161,
#   None,
#   None,
#   'FR',
#   'ITA',
#   0),
#  (294,
#   59,
#   12,
#   '2020-02-26T18:00:00',
#   'Latina',
#   'Lazio',
#   41.46759465,
#   12.90368482,
#   None,
#   None,
#   'LT',
#   'ITA',
#   0),
#  (295,
#   57,
#   12,
#   '2020-02-26T18:00:00',
#   'Rieti',
#   'Lazio',
#   42.40488444,
#   12.86205939,
#   None,
#   None,
#   'RI',
#   'ITA',
#   0),
#  (296,
#   58,
#   12,
#   '2020-02-26T18:00:00',
#   'Roma',
#   'Lazio',
#   41.89277044,
#   12.48366722,
#   None,
#   None,
#   'RM',
#   'ITA',
#   3),
#  (297,
#   56,
#   12,
#   '2020-02-26T18:00:00',
#   'Viterbo',
#   'Lazio',
#   42.4173828,
#   12.10473416,
#   None,
#   None,
#   'VT',
#   'ITA',
#   0),
#  (298,
#   986,
#   12,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lazio',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (299,
#   10,
#   7,
#   '2020-02-26T18:00:00',
#   'Genova',
#   'Liguria',
#   44.41149314,
#   8.9326992,
#   None,
#   None,
#   'GE',
#   'ITA',
#   0),
#  (300,
#   8,
#   7,
#   '2020-02-26T18:00:00',
#   'Imperia',
#   'Liguria',
#   43.88570648,
#   8.027850297999999,
#   None,
#   None,
#   'IM',
#   'ITA',
#   0),
#  (301,
#   11,
#   7,
#   '2020-02-26T18:00:00',
#   'La Spezia',
#   'Liguria',
#   44.10704991,
#   9.8281897,
#   None,
#   None,
#   'SP',
#   'ITA',
#   1),
#  (302,
#   9,
#   7,
#   '2020-02-26T18:00:00',
#   'Savona',
#   'Liguria',
#   44.30750461,
#   8.481108654,
#   None,
#   None,
#   'SV',
#   'ITA',
#   10),
#  (303,
#   987,
#   7,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Liguria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (304,
#   16,
#   3,
#   '2020-02-26T18:00:00',
#   'Bergamo',
#   'Lombardia',
#   45.69441368,
#   9.668424528,
#   None,
#   None,
#   'BG',
#   'ITA',
#   20),
#  (305,
#   17,
#   3,
#   '2020-02-26T18:00:00',
#   'Brescia',
#   'Lombardia',
#   45.53993052,
#   10.21910323,
#   None,
#   None,
#   'BS',
#   'ITA',
#   2),
#  (306,
#   13,
#   3,
#   '2020-02-26T18:00:00',
#   'Como',
#   'Lombardia',
#   45.8099912,
#   9.085159546,
#   None,
#   None,
#   'CO',
#   'ITA',
#   0),
#  (307,
#   19,
#   3,
#   '2020-02-26T18:00:00',
#   'Cremona',
#   'Lombardia',
#   45.13336675,
#   10.02420865,
#   None,
#   None,
#   'CR',
#   'ITA',
#   57),
#  (308,
#   97,
#   3,
#   '2020-02-26T18:00:00',
#   'Lecco',
#   'Lombardia',
#   45.85575781,
#   9.393392246,
#   None,
#   None,
#   'LC',
#   'ITA',
#   0),
#  (309,
#   98,
#   3,
#   '2020-02-26T18:00:00',
#   'Lodi',
#   'Lombardia',
#   45.31440693,
#   9.503720769,
#   None,
#   None,
#   'LO',
#   'ITA',
#   128),
#  (310,
#   20,
#   3,
#   '2020-02-26T18:00:00',
#   'Mantova',
#   'Lombardia',
#   45.15726772,
#   10.79277363,
#   None,
#   None,
#   'MN',
#   'ITA',
#   0),
#  (311,
#   15,
#   3,
#   '2020-02-26T18:00:00',
#   'Milano',
#   'Lombardia',
#   45.46679409,
#   9.190347404,
#   None,
#   None,
#   'MI',
#   'ITA',
#   8),
#  (312,
#   108,
#   3,
#   '2020-02-26T18:00:00',
#   'Monza e della Brianza',
#   'Lombardia',
#   45.58439043,
#   9.273582472000001,
#   None,
#   None,
#   'MB',
#   'ITA',
#   4),
#  (313,
#   18,
#   3,
#   '2020-02-26T18:00:00',
#   'Pavia',
#   'Lombardia',
#   45.18509264,
#   9.160157191,
#   None,
#   None,
#   'PV',
#   'ITA',
#   27),
#  (314,
#   14,
#   3,
#   '2020-02-26T18:00:00',
#   'Sondrio',
#   'Lombardia',
#   46.17099261,
#   9.87147489,
#   None,
#   None,
#   'SO',
#   'ITA',
#   3),
#  (315,
#   12,
#   3,
#   '2020-02-26T18:00:00',
#   'Varese',
#   'Lombardia',
#   45.81701677,
#   8.822868344,
#   None,
#   None,
#   'VA',
#   'ITA',
#   0),
#  (316,
#   988,
#   3,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lombardia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   9),
#  (317,
#   42,
#   11,
#   '2020-02-26T18:00:00',
#   'Ancona',
#   'Marche',
#   43.61675973,
#   13.5188753,
#   None,
#   None,
#   'AN',
#   'ITA',
#   0),
#  (318,
#   44,
#   11,
#   '2020-02-26T18:00:00',
#   'Ascoli Piceno',
#   'Marche',
#   42.85322304,
#   13.57691127,
#   None,
#   None,
#   'AP',
#   'ITA',
#   0),
#  (319,
#   109,
#   11,
#   '2020-02-26T18:00:00',
#   'Fermo',
#   'Marche',
#   43.16058534,
#   13.71839535,
#   None,
#   None,
#   'FM',
#   'ITA',
#   0),
#  (320,
#   43,
#   11,
#   '2020-02-26T18:00:00',
#   'Macerata',
#   'Marche',
#   43.30023926,
#   13.45307182,
#   None,
#   None,
#   'MC',
#   'ITA',
#   0),
#  (321,
#   41,
#   11,
#   '2020-02-26T18:00:00',
#   'Pesaro e Urbino',
#   'Marche',
#   43.91014021,
#   12.91345989,
#   None,
#   None,
#   'PU',
#   'ITA',
#   1),
#  (322,
#   989,
#   11,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Marche',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (323,
#   70,
#   14,
#   '2020-02-26T18:00:00',
#   'Campobasso',
#   'Molise',
#   41.55774754,
#   14.65916051,
#   None,
#   None,
#   'CB',
#   'ITA',
#   0),
#  (324,
#   94,
#   14,
#   '2020-02-26T18:00:00',
#   'Isernia',
#   'Molise',
#   41.58800826,
#   14.22575407,
#   None,
#   None,
#   'IS',
#   'ITA',
#   0),
#  (325,
#   990,
#   14,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Molise',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (326,
#   6,
#   1,
#   '2020-02-26T18:00:00',
#   'Alessandria',
#   'Piemonte',
#   44.91297351,
#   8.615401155,
#   None,
#   None,
#   'AL',
#   'ITA',
#   0),
#  (327,
#   5,
#   1,
#   '2020-02-26T18:00:00',
#   'Asti',
#   'Piemonte',
#   44.89912921,
#   8.204142547,
#   None,
#   None,
#   'AT',
#   'ITA',
#   0),
#  (328,
#   96,
#   1,
#   '2020-02-26T18:00:00',
#   'Biella',
#   'Piemonte',
#   45.5665112,
#   8.054082167,
#   None,
#   None,
#   'BI',
#   'ITA',
#   0),
#  (329,
#   4,
#   1,
#   '2020-02-26T18:00:00',
#   'Cuneo',
#   'Piemonte',
#   44.39329625,
#   7.551171632000001,
#   None,
#   None,
#   'CN',
#   'ITA',
#   0),
#  (330,
#   3,
#   1,
#   '2020-02-26T18:00:00',
#   'Novara',
#   'Piemonte',
#   45.44588506,
#   8.621915884,
#   None,
#   None,
#   'NO',
#   'ITA',
#   0),
#  (331,
#   1,
#   1,
#   '2020-02-26T18:00:00',
#   'Torino',
#   'Piemonte',
#   45.0732745,
#   7.680687483,
#   None,
#   None,
#   'TO',
#   'ITA',
#   3),
#  (332,
#   103,
#   1,
#   '2020-02-26T18:00:00',
#   'Verbano-Cusio-Ossola',
#   'Piemonte',
#   45.921445500000004,
#   8.551078752999999,
#   None,
#   None,
#   'VB',
#   'ITA',
#   0),
#  (333,
#   2,
#   1,
#   '2020-02-26T18:00:00',
#   'Vercelli',
#   'Piemonte',
#   45.32398135,
#   8.423234312,
#   None,
#   None,
#   'VC',
#   'ITA',
#   0),
#  (334,
#   991,
#   1,
#   '2020-02-26T18:00:00',
#   'In fase di definizione/aggiornamento',
#   'Piemonte',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (335,
#   72,
#   16,
# ...
#   None,
#   'BL',
#   'ITA',
#   0),
#  (889,
#   28,
#   5,
#   '2020-03-01T17:00:00',
#   'Padova',
#   'Veneto',
#   45.40692987,
#   11.87608718,
#   None,
#   None,
#   'PD',
#   'ITA',
#   105),
#  (890,
#   29,
#   5,
#   '2020-03-01T17:00:00',
#   'Rovigo',
#   'Veneto',
#   45.07107289,
#   11.79007,
#   None,
#   None,
#   'RO',
#   'ITA',
#   0),
#  (891,
#   26,
#   5,
#   '2020-03-01T17:00:00',
#   'Treviso',
#   'Veneto',
#   45.66754571,
#   12.24507363,
#   None,
#   None,
#   'TV',
#   'ITA',
#   43),
#  (892,
#   27,
#   5,
#   '2020-03-01T17:00:00',
#   'Venezia',
#   'Veneto',
#   45.43490485,
#   12.33845213,
#   None,
#   None,
#   'VE',
#   'ITA',
#   24),
#  (893,
#   23,
#   5,
#   '2020-03-01T17:00:00',
#   'Verona',
#   'Veneto',
#   45.43839046,
#   10.99352685,
#   None,
#   None,
#   'VR',
#   'ITA',
#   2),
#  (894,
#   24,
#   5,
#   '2020-03-01T17:00:00',
#   'Vicenza',
#   'Veneto',
#   45.547497,
#   11.54597109,
#   None,
#   None,
#   'VI',
#   'ITA',
#   3),
#  (895,
#   999,
#   5,
#   '2020-03-01T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Veneto',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   86),
#  (896,
#   69,
#   13,
#   '2020-03-02T17:00:00',
#   'Chieti',
#   'Abruzzo',
#   42.35103167,
#   14.16754574,
#   None,
#   None,
#   'CH',
#   'ITA',
#   0),
#  (897,
#   66,
#   13,
#   '2020-03-02T17:00:00',
#   "L'Aquila",
#   'Abruzzo',
#   42.35122196,
#   13.39843823,
#   None,
#   None,
#   'AQ',
#   'ITA',
#   0),
#  (898,
#   68,
#   13,
#   '2020-03-02T17:00:00',
#   'Pescara',
#   'Abruzzo',
#   42.46458398,
#   14.21364822,
#   None,
#   None,
#   'PE',
#   'ITA',
#   0),
#  (899,
#   67,
#   13,
#   '2020-03-02T17:00:00',
#   'Teramo',
#   'Abruzzo',
#   42.6589177,
#   13.70439971,
#   None,
#   None,
#   'TE',
#   'ITA',
#   5),
#  (900,
#   979,
#   13,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Abruzzo',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (901,
#   77,
#   17,
#   '2020-03-02T17:00:00',
#   'Matera',
#   'Basilicata',
#   40.66751177,
#   16.59792442,
#   None,
#   None,
#   'MT',
#   'ITA',
#   0),
#  (902,
#   76,
#   17,
#   '2020-03-02T17:00:00',
#   'Potenza',
#   'Basilicata',
#   40.63947052,
#   15.80514834,
#   None,
#   None,
#   'PZ',
#   'ITA',
#   0),
#  (903,
#   980,
#   17,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Basilicata',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (904,
#   21,
#   4,
#   '2020-03-02T17:00:00',
#   'Bolzano',
#   'P.A. Bolzano',
#   46.49933453,
#   11.35662422,
#   None,
#   None,
#   'BZ',
#   'ITA',
#   1),
#  (905,
#   981,
#   4,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'P.A. Bolzano',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (906,
#   79,
#   18,
#   '2020-03-02T17:00:00',
#   'Catanzaro',
#   'Calabria',
#   38.90597598,
#   16.59440194,
#   None,
#   None,
#   'CZ',
#   'ITA',
#   0),
#  (907,
#   78,
#   18,
#   '2020-03-02T17:00:00',
#   'Cosenza',
#   'Calabria',
#   39.29308681,
#   16.25609692,
#   None,
#   None,
#   'CS',
#   'ITA',
#   1),
#  (908,
#   101,
#   18,
#   '2020-03-02T17:00:00',
#   'Crotone',
#   'Calabria',
#   39.08036878,
#   17.12538864,
#   None,
#   None,
#   'KR',
#   'ITA',
#   0),
#  (909,
#   80,
#   18,
#   '2020-03-02T17:00:00',
#   'Reggio di Calabria',
#   'Calabria',
#   38.10922769,
#   15.643452700000001,
#   None,
#   None,
#   'RC',
#   'ITA',
#   0),
#  (910,
#   102,
#   18,
#   '2020-03-02T17:00:00',
#   'Vibo Valentia',
#   'Calabria',
#   38.67624147,
#   16.10157414,
#   None,
#   None,
#   'VV',
#   'ITA',
#   0),
#  (911,
#   982,
#   18,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Calabria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (912,
#   64,
#   15,
#   '2020-03-02T17:00:00',
#   'Avellino',
#   'Campania',
#   40.91404699,
#   14.79528803,
#   None,
#   None,
#   'AV',
#   'ITA',
#   0),
#  (913,
#   62,
#   15,
#   '2020-03-02T17:00:00',
#   'Benevento',
#   'Campania',
#   41.12969987,
#   14.78151683,
#   None,
#   None,
#   'BN',
#   'ITA',
#   0),
#  (914,
#   61,
#   15,
#   '2020-03-02T17:00:00',
#   'Caserta',
#   'Campania',
#   41.07465878,
#   14.33240464,
#   None,
#   None,
#   'CE',
#   'ITA',
#   0),
#  (915,
#   63,
#   15,
#   '2020-03-02T17:00:00',
#   'Napoli',
#   'Campania',
#   40.83956555,
#   14.25084984,
#   None,
#   None,
#   None,
#   'ITA',
#   17),
#  (916,
#   65,
#   15,
#   '2020-03-02T17:00:00',
#   'Salerno',
#   'Campania',
#   40.67821961,
#   14.759402599999998,
#   None,
#   None,
#   'SA',
#   'ITA',
#   0),
#  (917,
#   983,
#   15,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Campania',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (918,
#   37,
#   8,
#   '2020-03-02T17:00:00',
#   'Bologna',
#   'Emilia-Romagna',
#   44.49436681,
#   11.341720800000001,
#   None,
#   None,
#   'BO',
#   'ITA',
#   3),
#  (919,
#   38,
#   8,
#   '2020-03-02T17:00:00',
#   'Ferrara',
#   'Emilia-Romagna',
#   44.83599085,
#   11.61868934,
#   None,
#   None,
#   'FE',
#   'ITA',
#   0),
#  (920,
#   40,
#   8,
#   '2020-03-02T17:00:00',
#   'Forlì-Cesena',
#   'Emilia-Romagna',
#   44.22268559,
#   12.04068608,
#   None,
#   None,
#   'FC',
#   'ITA',
#   1),
#  (921,
#   36,
#   8,
#   '2020-03-02T17:00:00',
#   'Modena',
#   'Emilia-Romagna',
#   44.64600009,
#   10.92615487,
#   None,
#   None,
#   'MO',
#   'ITA',
#   29),
#  (922,
#   34,
#   8,
#   '2020-03-02T17:00:00',
#   'Parma',
#   'Emilia-Romagna',
#   44.80107394,
#   10.32834985,
#   None,
#   None,
#   'PR',
#   'ITA',
#   61),
#  (923,
#   33,
#   8,
#   '2020-03-02T17:00:00',
#   'Piacenza',
#   'Emilia-Romagna',
#   45.05193462,
#   9.692632596000001,
#   None,
#   None,
#   'PC',
#   'ITA',
#   212),
#  (924,
#   39,
#   8,
#   '2020-03-02T17:00:00',
#   'Ravenna',
#   'Emilia-Romagna',
#   44.41722493,
#   12.19913936,
#   None,
#   None,
#   'RA',
#   'ITA',
#   2),
#  (925,
#   35,
#   8,
#   '2020-03-02T17:00:00',
#   "Reggio nell'Emilia",
#   'Emilia-Romagna',
#   44.69735289,
#   10.63007973,
#   None,
#   None,
#   'RE',
#   'ITA',
#   8),
#  (926,
#   99,
#   8,
#   '2020-03-02T17:00:00',
#   'Rimini',
#   'Emilia-Romagna',
#   44.06090087,
#   12.5656295,
#   None,
#   None,
#   'RN',
#   'ITA',
#   19),
#  (927,
#   984,
#   8,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Emilia-Romagna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (928,
#   31,
#   6,
#   '2020-03-02T17:00:00',
#   'Gorizia',
#   'Friuli Venezia Giulia',
#   45.94149817,
#   13.62212502,
#   None,
#   None,
#   'GO',
#   'ITA',
#   0),
#  (929,
#   93,
#   6,
#   '2020-03-02T17:00:00',
#   'Pordenone',
#   'Friuli Venezia Giulia',
#   45.95443546,
#   12.66002909,
#   None,
#   None,
#   'PN',
#   'ITA',
#   0),
#  (930,
#   32,
#   6,
#   '2020-03-02T17:00:00',
#   'Trieste',
#   'Friuli Venezia Giulia',
#   45.6494354,
#   13.76813649,
#   None,
#   None,
#   'TS',
#   'ITA',
#   9),
#  (931,
#   30,
#   6,
#   '2020-03-02T17:00:00',
#   'Udine',
#   'Friuli Venezia Giulia',
#   46.06255516,
#   13.2348383,
#   None,
#   None,
#   'UD',
#   'ITA',
#   0),
#  (932,
#   985,
#   6,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Friuli Venezia Giulia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (933,
#   60,
#   12,
#   '2020-03-02T17:00:00',
#   'Frosinone',
#   'Lazio',
#   41.63964569,
#   13.35117161,
#   None,
#   None,
#   'FR',
#   'ITA',
#   0),
#  (934,
#   59,
#   12,
#   '2020-03-02T17:00:00',
#   'Latina',
#   'Lazio',
#   41.46759465,
#   12.90368482,
#   None,
#   None,
#   'LT',
#   'ITA',
#   0),
#  (935,
#   57,
#   12,
#   '2020-03-02T17:00:00',
#   'Rieti',
#   'Lazio',
#   42.40488444,
#   12.86205939,
#   None,
#   None,
#   'RI',
#   'ITA',
#   0),
#  (936,
#   58,
#   12,
#   '2020-03-02T17:00:00',
#   'Roma',
#   'Lazio',
#   41.89277044,
#   12.48366722,
#   None,
#   None,
#   'RM',
#   'ITA',
#   7),
#  (937,
#   56,
#   12,
#   '2020-03-02T17:00:00',
#   'Viterbo',
#   'Lazio',
#   42.4173828,
#   12.10473416,
#   None,
#   None,
#   'VT',
#   'ITA',
#   0),
#  (938,
#   986,
#   12,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lazio',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (939,
#   10,
#   7,
#   '2020-03-02T17:00:00',
#   'Genova',
#   'Liguria',
#   44.41149314,
#   8.9326992,
#   None,
#   None,
#   'GE',
#   'ITA',
#   1),
#  (940,
#   8,
#   7,
#   '2020-03-02T17:00:00',
#   'Imperia',
#   'Liguria',
#   43.88570648,
#   8.027850297999999,
#   None,
#   None,
#   'IM',
#   'ITA',
#   1),
#  (941,
#   11,
#   7,
#   '2020-03-02T17:00:00',
#   'La Spezia',
#   'Liguria',
#   44.10704991,
#   9.8281897,
#   None,
#   None,
#   'SP',
#   'ITA',
#   1),
#  (942,
#   9,
#   7,
#   '2020-03-02T17:00:00',
#   'Savona',
#   'Liguria',
#   44.30750461,
#   8.481108654,
#   None,
#   None,
#   'SV',
#   'ITA',
#   16),
#  (943,
#   987,
#   7,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Liguria',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   3),
#  (944,
#   16,
#   3,
#   '2020-03-02T17:00:00',
#   'Bergamo',
#   'Lombardia',
#   45.69441368,
#   9.668424528,
#   None,
#   None,
#   'BG',
#   'ITA',
#   243),
#  (945,
#   17,
#   3,
#   '2020-03-02T17:00:00',
#   'Brescia',
#   'Lombardia',
#   45.53993052,
#   10.21910323,
#   'Apd-EN-0001',
#   'Apd-IT-0001',
#   'BS',
#   'ITA',
#   60),
#  (946,
#   13,
#   3,
#   '2020-03-02T17:00:00',
#   'Como',
#   'Lombardia',
#   45.8099912,
#   9.085159546,
#   None,
#   None,
#   'CO',
#   'ITA',
#   2),
#  (947,
#   19,
#   3,
#   '2020-03-02T17:00:00',
#   'Cremona',
#   'Lombardia',
#   45.13336675,
#   10.02420865,
#   None,
#   None,
#   'CR',
#   'ITA',
#   223),
#  (948,
#   97,
#   3,
#   '2020-03-02T17:00:00',
#   'Lecco',
#   'Lombardia',
#   45.85575781,
#   9.393392246,
#   None,
#   None,
#   'LC',
#   'ITA',
#   3),
#  (949,
#   98,
#   3,
#   '2020-03-02T17:00:00',
#   'Lodi',
#   'Lombardia',
#   45.31440693,
#   9.503720769,
#   None,
#   None,
#   'LO',
#   'ITA',
#   384),
#  (950,
#   20,
#   3,
#   '2020-03-02T17:00:00',
#   'Mantova',
#   'Lombardia',
#   45.15726772,
#   10.79277363,
#   None,
#   None,
#   'MN',
#   'ITA',
#   5),
#  (951,
#   15,
#   3,
#   '2020-03-02T17:00:00',
#   'Milano',
#   'Lombardia',
#   45.46679409,
#   9.190347404,
#   None,
#   None,
#   'MI',
#   'ITA',
#   58),
#  (952,
#   108,
#   3,
#   '2020-03-02T17:00:00',
#   'Monza e della Brianza',
#   'Lombardia',
#   45.58439043,
#   9.273582472000001,
#   None,
#   None,
#   'MB',
#   'ITA',
#   8),
#  (953,
#   18,
#   3,
#   '2020-03-02T17:00:00',
#   'Pavia',
#   'Lombardia',
#   45.18509264,
#   9.160157191,
#   None,
#   None,
#   'PV',
#   'ITA',
#   83),
#  (954,
#   14,
#   3,
#   '2020-03-02T17:00:00',
#   'Sondrio',
#   'Lombardia',
#   46.17099261,
#   9.87147489,
#   None,
#   None,
#   'SO',
#   'ITA',
#   3),
#  (955,
#   12,
#   3,
#   '2020-03-02T17:00:00',
#   'Varese',
#   'Lombardia',
#   45.81701677,
#   8.822868344,
#   None,
#   None,
#   'VA',
#   'ITA',
#   4),
#  (956,
#   988,
#   3,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Lombardia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   178),
#  (957,
#   42,
#   11,
#   '2020-03-02T17:00:00',
#   'Ancona',
#   'Marche',
#   43.61675973,
#   13.5188753,
#   None,
#   None,
#   'AN',
#   'ITA',
#   2),
#  (958,
#   44,
#   11,
#   '2020-03-02T17:00:00',
#   'Ascoli Piceno',
#   'Marche',
#   42.85322304,
#   13.57691127,
#   None,
#   None,
#   'AP',
#   'ITA',
#   0),
#  (959,
#   109,
#   11,
#   '2020-03-02T17:00:00',
#   'Fermo',
#   'Marche',
#   43.16058534,
#   13.71839535,
#   None,
#   None,
#   'FM',
#   'ITA',
#   0),
#  (960,
#   43,
#   11,
#   '2020-03-02T17:00:00',
#   'Macerata',
#   'Marche',
#   43.30023926,
#   13.45307182,
#   None,
#   None,
#   'MC',
#   'ITA',
#   0),
#  (961,
#   41,
#   11,
#   '2020-03-02T17:00:00',
#   'Pesaro e Urbino',
#   'Marche',
#   43.91014021,
#   12.91345989,
#   None,
#   None,
#   'PU',
#   'ITA',
#   33),
#  (962,
#   989,
#   11,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Marche',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (963,
#   70,
#   14,
#   '2020-03-02T17:00:00',
#   'Campobasso',
#   'Molise',
#   41.55774754,
#   14.65916051,
#   None,
#   None,
#   'CB',
#   'ITA',
#   0),
#  (964,
#   94,
#   14,
#   '2020-03-02T17:00:00',
#   'Isernia',
#   'Molise',
#   41.58800826,
#   14.22575407,
#   None,
#   None,
#   'IS',
#   'ITA',
#   0),
#  (965,
#   990,
#   14,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Molise',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (966,
#   6,
#   1,
#   '2020-03-02T17:00:00',
#   'Alessandria',
#   'Piemonte',
#   44.91297351,
#   8.615401155,
#   None,
#   None,
#   'AL',
#   'ITA',
#   0),
#  (967,
#   5,
#   1,
#   '2020-03-02T17:00:00',
#   'Asti',
#   'Piemonte',
#   44.89912921,
#   8.204142547,
#   None,
#   None,
#   'AT',
#   'ITA',
#   37),
#  (968,
#   96,
#   1,
#   '2020-03-02T17:00:00',
#   'Biella',
#   'Piemonte',
#   45.5665112,
#   8.054082167,
#   None,
#   None,
#   'BI',
#   'ITA',
#   0),
#  (969,
#   4,
#   1,
#   '2020-03-02T17:00:00',
#   'Cuneo',
#   'Piemonte',
#   44.39329625,
#   7.551171632000001,
#   None,
#   None,
#   'CN',
#   'ITA',
#   0),
#  (970,
#   3,
#   1,
#   '2020-03-02T17:00:00',
#   'Novara',
#   'Piemonte',
#   45.44588506,
#   8.621915884,
#   None,
#   None,
#   'NO',
#   'ITA',
#   3),
#  (971,
#   1,
#   1,
#   '2020-03-02T17:00:00',
#   'Torino',
#   'Piemonte',
#   45.0732745,
#   7.680687483,
#   None,
#   None,
#   'TO',
#   'ITA',
#   6),
#  (972,
#   103,
#   1,
#   '2020-03-02T17:00:00',
#   'Verbano-Cusio-Ossola',
#   'Piemonte',
#   45.921445500000004,
#   8.551078752999999,
#   None,
#   None,
#   'VB',
#   'ITA',
#   4),
#  (973,
#   2,
#   1,
#   '2020-03-02T17:00:00',
#   'Vercelli',
#   'Piemonte',
#   45.32398135,
#   8.423234312,
#   None,
#   None,
#   'VC',
#   'ITA',
#   1),
#  (974,
#   991,
#   1,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Piemonte',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (975,
#   72,
#   16,
#   '2020-03-02T17:00:00',
#   'Bari',
#   'Puglia',
#   41.12559576,
#   16.86736689,
#   None,
#   None,
#   'BA',
#   'ITA',
#   1),
#  (976,
#   110,
#   16,
#   '2020-03-02T17:00:00',
#   'Barletta-Andria-Trani',
#   'Puglia',
#   41.22705039,
#   16.29520432,
#   None,
#   None,
#   'BT',
#   'ITA',
#   0),
#  (977,
#   74,
#   16,
#   '2020-03-02T17:00:00',
#   'Brindisi',
#   'Puglia',
#   40.63848545,
#   17.94601575,
#   None,
#   None,
#   'BR',
#   'ITA',
#   0),
#  (978,
#   71,
#   16,
#   '2020-03-02T17:00:00',
#   'Foggia',
#   'Puglia',
#   41.46226865,
#   15.54305094,
#   None,
#   None,
#   'FG',
#   'ITA',
#   0),
#  (979,
#   75,
#   16,
#   '2020-03-02T17:00:00',
#   'Lecce',
#   'Puglia',
#   40.35354285,
#   18.1718973,
#   None,
#   None,
#   'LE',
#   'ITA',
#   0),
#  (980,
#   73,
#   16,
#   '2020-03-02T17:00:00',
#   'Taranto',
#   'Puglia',
#   40.47354739,
#   17.23237181,
#   None,
#   None,
#   'TA',
#   'ITA',
#   3),
#  (981,
#   992,
#   16,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Puglia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (982,
#   92,
#   20,
#   '2020-03-02T17:00:00',
#   'Cagliari',
#   'Sardegna',
#   39.21531192,
#   9.110616306,
#   None,
#   None,
#   'CA',
#   'ITA',
#   0),
#  (983,
#   91,
#   20,
#   '2020-03-02T17:00:00',
#   'Nuoro',
#   'Sardegna',
#   40.32318834,
#   9.330296393,
#   None,
#   None,
#   'NU',
#   'ITA',
#   0),
#  (984,
#   95,
#   20,
#   '2020-03-02T17:00:00',
#   'Oristano',
#   'Sardegna',
#   39.90381075,
#   8.591183151000001,
#   None,
#   None,
#   'OR',
#   'ITA',
#   0),
#  (985,
#   90,
#   20,
#   '2020-03-02T17:00:00',
#   'Sassari',
#   'Sardegna',
#   40.72667657,
#   8.559667131,
#   None,
#   None,
#   'SS',
#   'ITA',
#   0),
#  (986,
#   111,
#   20,
#   '2020-03-02T17:00:00',
#   'Sud Sardegna',
#   'Sardegna',
#   39.16641462,
#   8.526242676,
#   None,
#   None,
#   'SU',
#   'ITA',
#   0),
#  (987,
#   993,
#   20,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Sardegna',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   0),
#  (988,
#   84,
#   19,
#   '2020-03-02T17:00:00',
#   'Agrigento',
#   'Sicilia',
#   37.30971088,
#   13.584574900000002,
#   None,
#   None,
#   'AG',
#   'ITA',
#   0),
#  (989,
#   85,
#   19,
#   '2020-03-02T17:00:00',
#   'Caltanissetta',
#   'Sicilia',
#   37.49213171,
#   14.06184973,
#   None,
#   None,
#   'CL',
#   'ITA',
#   0),
#  (990,
#   87,
#   19,
#   '2020-03-02T17:00:00',
#   'Catania',
#   'Sicilia',
#   37.50287803,
#   15.08704691,
#   None,
#   None,
#   'CT',
#   'ITA',
#   1),
#  (991,
#   86,
#   19,
#   '2020-03-02T17:00:00',
#   'Enna',
#   'Sicilia',
#   37.56705701,
#   14.27909375,
#   None,
#   None,
#   'EN',
#   'ITA',
#   0),
#  (992,
#   83,
#   19,
#   '2020-03-02T17:00:00',
#   'Messina',
#   'Sicilia',
#   38.19395845,
#   15.55572302,
#   None,
#   None,
#   'ME',
#   'ITA',
#   0),
#  (993,
#   82,
#   19,
#   '2020-03-02T17:00:00',
#   'Palermo',
#   'Sicilia',
#   38.11569725,
#   13.362356699999998,
#   None,
#   None,
#   'PA',
#   'ITA',
#   3),
#  (994,
#   88,
#   19,
#   '2020-03-02T17:00:00',
#   'Ragusa',
#   'Sicilia',
#   36.92509198,
#   14.73069891,
#   None,
#   None,
#   'RG',
#   'ITA',
#   0),
#  (995,
#   89,
#   19,
#   '2020-03-02T17:00:00',
#   'Siracusa',
#   'Sicilia',
#   37.05991687,
#   15.29333182,
#   None,
#   None,
#   'SR',
#   'ITA',
#   0),
#  (996,
#   81,
#   19,
#   '2020-03-02T17:00:00',
#   'Trapani',
#   'Sicilia',
#   38.01850065,
#   12.51365684,
#   None,
#   None,
#   'TP',
#   'ITA',
#   0),
#  (997,
#   994,
#   19,
#   '2020-03-02T17:00:00',
#   'In fase di definizione/aggiornamento',
#   'Sicilia',
#   0.0,
#   0.0,
#   None,
#   None,
#   None,
#   'ITA',
#   3),
#  (998,
#   51,
#   9,
#   '2020-03-02T17:00:00',
#   'Arezzo',
#   'Toscana',
#   43.46642752,
#   11.88228844,
#   None,
#   None,
#   'AR',
#   'ITA',
#   1),
#  (999,
#   48,
#   9,
#   '2020-03-02T17:00:00',
#   'Firenze',
#   'Toscana',
#   43.76923077,
#   11.25588885,
#   None,
#   None,
#   'FI',
#   'ITA',
#   4),
#  ...]

# %%
ItalyCOVID19provincia.to_excel("ItalyCOVID19provincia.xls")

pd.read_excel("ItalyCOVID19provincia.xls")
# Out:
#       Unnamed: 0  codice_provincia  ...  stato totale_casi
# 0              0                69  ...    ITA           0
# 1              1                66  ...    ITA           0
# 2              2                68  ...    ITA           0
# 3              3                67  ...    ITA           0
# 4              4               979  ...    ITA           0
# ...          ...               ...  ...    ...         ...
# 4731        4731                26  ...    ITA        1522
# 4732        4732                27  ...    ITA        1170
# 4733        4733                23  ...    ITA        2112
# 4734        4734                24  ...    ITA        1242
# 4735        4735               999  ...    ITA         279
#
# [4736 rows x 13 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Italy COVID-19 provincia.ipynb', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Italy COVID-19 provincia.ipynb')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")

# Create violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()

# %%
# Import necessarily libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
titanic = sns.load_dataset("titanic")

# Set up a factorplot
g = sns.factorplot("class", "survived", "sex", data=titanic, kind="bar", palette="muted", legend=False)
                   
# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Import Matplotlib
import matplotlib.pyplot as plt

# Check the available styles
plt.style.available

# Use Matplotlib defaults
plt.style.use("classic")

# %%
# Import the necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Define a variable N
N = 500

# Construct the colormap
current_palette = sns.color_palette("muted", n_colors=5)
cmap = ListedColormap(sns.color_palette(current_palette).as_hex())

# Initialize the data
data1 = np.random.randn(N)
data2 = np.random.randn(N)
# Assume that there are 5 possible labels
colors = np.random.randint(0,5,N)

# Create a scatter plot
plt.scatter(data1, data2, c=colors, cmap=cmap)

# Add a color bar
plt.colorbar()

# Show the plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Reset default params
sns.set()

# Set context to `"paper"`
sns.set_context("paper")

# Load iris data
iris = sns.load_dataset("iris")

# Construct iris plot
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set context to `"paper"`
sns.set_context("paper", font_scale=3, rc={"font.size":8,"axes.labelsize":5})

# Load iris data
iris = sns.load_dataset("iris")

# Construct iris plot
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Reset default params
sns.set(rc={"font.size":8,"axes.labelsize":5})

# Load iris data
iris = sns.load_dataset("iris")

# Construct iris plot
sns.swarmplot(x="species", y="petal_length", data=iris)

# Show plot
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")

# Set axes style to white for first subplot
with sns.axes_style("white"):
    plt.subplot(211)
    sns.swarmplot(x="species", y="petal_length", data=iris)

# Initialize second subplot
plt.subplot(212)

# Plot violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot                   
plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Initialize Figure and Axes object
fig, ax = plt.subplots(figsize=(10,4))

# Load in the data
iris = sns.load_dataset("iris")

# Create swarmplot
sns.swarmplot(x="species", y="petal_length", data=iris, ax=ax)

# Show plot
plt.show()

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns 

# Load data
titanic = sns.load_dataset("titanic")

# Set up a factorplot
g = sns.factorplot("class", "survived", "sex", data=titanic, kind="bar", size=6, aspect=2, palette="muted", legend=False)

# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd

# Initialize the data
x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})

# Create an lmplot
grid = sns.lmplot('x', 'y', data, size=7, truncate=True, scatter_kws={"s": 100})

# Rotate the labels on x-axis
grid.set_xticklabels(rotation=30)

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
tips = sns.load_dataset("tips")

# Create the boxplot
ax = sns.boxplot(x="total_bill", data=tips)

# Set the `xlim`
ax.set(xlim=(0, 100))

# Show the plot
plt.show()

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd

# Initialize the data
x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})

# Create lmplot
lm = sns.lmplot('x', 'y', data, size=7, truncate=True, scatter_kws={"s": 100})

# Get hold of the `Axes` objects
axes = lm.ax

# Tweak the `Axes` properties
axes.set_ylim(-1000000000,)

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd

# Initialize the data
x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})

# Create lmplot
lm = sns.lmplot('x', 'y', data, size=7, truncate=True, scatter_kws={"s": 100})

# Access the Figure
fig = lm.fig 

# Add a title to the Figure
fig.suptitle('this is the figure title', fontsize=12)

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd

# Create the data
x = 10 ** np.arange(1, 10)
y = x * 2
data = pd.DataFrame(data={'x': x, 'y': y})

# Initialize figure and ax
fig, ax = plt.subplots()

# Set the scale of the x-and y-axes
ax.set(xscale="log", yscale="log")

# Create a regplot
sns.regplot("x", "y", data, ax=ax, scatter_kws={"s": 100})

# Show plot
plt.show()

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns 

# Load data
titanic = sns.load_dataset("titanic")

# Set up a factorplot
g = sns.factorplot("class", "survived", "sex", data=titanic, kind="bar", size=6, palette="muted", legend=False)

# Set the `yscale`
g.set(yscale="log")

# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns 

tips = sns.load_dataset("tips")

# Create the boxplot
ax = sns.boxplot(x="total_bill", data=tips)

# Set title
ax.set_title("boxplot")

# Show the plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
