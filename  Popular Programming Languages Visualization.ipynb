# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Reading the csv file using pandas
data = pd.read_csv('https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/Most%20Popular%20Programming%20Languages%20from%202004%20to%202020%20V3.csv')

#Convering the date to Datetime data type
data['Date'] = pd.to_datetime(data['Date'])

#Setting date as index
data.set_index('Date', inplace = True)

#Displying first few lines of the dataset
data.head()
# Out:
#             Abap   Ada  C/C++    C#  Cobol  Dart  Delphi   Go  Groovy  \
# Date
# 2004-07-01  0.34  0.36  10.08  4.71   0.43   0.0    2.82  0.0    0.03
# 2004-08-01  0.36  0.36   9.81  4.99   0.46   0.0    2.67  0.0    0.07
# 2004-09-01  0.41  0.41   9.63  5.06   0.51   0.0    2.65  0.0    0.08
# 2004-10-01  0.40  0.38   9.50  5.31   0.53   0.0    2.77  0.0    0.09
# 2004-11-01  0.38  0.38   9.52  5.24   0.55   0.0    2.76  0.0    0.07
#
#             Haskell  ...    PHP  Python     R  Ruby  Rust  Scala  Swift  \
# Date                 ...
# 2004-07-01     0.22  ...  18.75    2.53  0.39  0.33  0.08   0.03    0.0
# 2004-08-01     0.20  ...  19.26    2.64  0.41  0.40  0.09   0.03    0.0
# 2004-09-01     0.21  ...  19.49    2.72  0.40  0.41  0.10   0.03    0.0
# 2004-10-01     0.20  ...  19.34    2.92  0.42  0.46  0.11   0.04    0.0
# 2004-11-01     0.24  ...  19.43    2.84  0.41  0.45  0.13   0.04    0.0
#
#             TypeScript   VBA  Visual Basic
# Date
# 2004-07-01         0.0  1.44          8.56
# 2004-08-01         0.0  1.46          8.57
# 2004-09-01         0.0  1.55          8.41
# 2004-10-01         0.0  1.61          8.49
# 2004-11-01         0.0  1.50          8.24
#
# [5 rows x 28 columns]

# %%
import missingno as miss

miss.matrix(data)

# %%
data.describe()
# Out:
#              Abap         Ada       C/C++          C#       Cobol        Dart  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     0.495455    0.299747    8.375455    7.625657    0.380152    0.108939
# std      0.103023    0.087338    1.811846    1.313997    0.073405    0.129612
# min      0.320000    0.170000    5.620000    4.710000    0.220000    0.000000
# 25%      0.400000    0.230000    7.487500    6.592500    0.320000    0.000000
# 50%      0.500000    0.290000    8.090000    7.340000    0.370000    0.110000
# 75%      0.580000    0.350000    9.057500    8.987500    0.430000    0.130000
# max      0.720000    0.610000   13.000000   10.000000    0.560000    0.580000
#
#            Delphi          Go      Groovy     Haskell  ...         PHP  \
# count  198.000000  198.000000  198.000000  198.000000  ...  198.000000
# mean     1.074949    0.299596    0.333636    0.299848  ...   14.351667
# std      0.756099    0.433096    0.139767    0.038991  ...    4.882732
# min      0.230000    0.000000    0.030000    0.200000  ...    5.690000
# 25%      0.390000    0.000000    0.260000    0.280000  ...   10.422500
# 50%      0.860000    0.075000    0.380000    0.300000  ...   14.855000
# 75%      1.702500    0.432500    0.450000    0.320000  ...   19.322500
# max      2.820000    1.520000    0.520000    0.390000  ...   20.840000
#
#            Python           R        Ruby        Rust       Scala       Swift  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean    11.441818    2.079293    2.139192    0.228283    0.538586    1.093434
# std      8.340192    1.344834    0.695704    0.229842    0.445485    1.402468
# min      2.530000    0.380000    0.330000    0.050000    0.010000    0.000000
# 25%      5.217500    0.850000    1.630000    0.080000    0.135000    0.000000
# 50%      8.255000    1.770000    2.465000    0.115000    0.410000    0.000000
# 75%     14.602500    3.525000    2.650000    0.320000    1.010000    2.485000
# max     31.730000    4.250000    2.940000    1.160000    1.370000    3.580000
#
#        TypeScript         VBA  Visual Basic
# count  198.000000  198.000000    198.000000
# mean     0.428636    1.686313      3.793384
# std      0.653594    0.336129      2.183263
# min      0.000000    1.020000      0.670000
# 25%      0.000000    1.452500      1.615000
# 50%      0.010000    1.615000      3.790000
# 75%      0.792500    1.812500      5.380000
# max      1.860000    2.640000      8.570000
#
# [8 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 198 entries, 2004-07-01 to 2020-12-01
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Abap          198 non-null    float64
#  1   Ada           198 non-null    float64
#  2   C/C++         198 non-null    float64
#  3   C#            198 non-null    float64
#  4   Cobol         198 non-null    float64
#  5   Dart          198 non-null    float64
#  6   Delphi        198 non-null    float64
#  7   Go            198 non-null    float64
#  8   Groovy        198 non-null    float64
#  9   Haskell       198 non-null    float64
#  10  Java          198 non-null    float64
#  11  JavaScript    198 non-null    float64
#  12  Julia         198 non-null    float64
#  13  Kotlin        198 non-null    float64
#  14  Lua           198 non-null    float64
#  15  Matlab        198 non-null    float64
#  16  Objective-C   198 non-null    float64
#  17  Perl          198 non-null    float64
#  18  PHP           198 non-null    float64
#  19  Python        198 non-null    float64
#  20  R             198 non-null    float64
#  21  Ruby          198 non-null    float64
#  22  Rust          198 non-null    float64
#  23  Scala         198 non-null    float64
#  24  Swift         198 non-null    float64
#  25  TypeScript    198 non-null    float64
#  26  VBA           198 non-null    float64
#  27  Visual Basic  198 non-null    float64
# dtypes: float64(28)
# memory usage: 44.9 KB

# %%
mask = data.mean() > 2.5

data = data.loc[:, mask]

clms = data.columns.tolist()
clms
# Out:
# ['C/C++',
#  'C#',
#  'Java',
#  'JavaScript',
#  'Matlab',
#  'Objective-C',
#  'Perl',
#  'PHP',
#  'Python',
#  'Visual Basic']

# %%
plt.figure(figsize = (15, 8))
sns.set(style = 'dark')

for language in clms:
    sns.lineplot(x = data.index, y = data[language], label = language)

plt.ylabel('Popularity', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.title('Popular Prgramming Languages', fontsize = 20)
plt.legend(loc = 2)
plt.yticks(fontsize = 10)
plt.xticks(rotation = 45, fontsize = 10)
plt.tight_layout()
plt.show()
