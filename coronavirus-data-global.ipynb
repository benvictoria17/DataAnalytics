# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
coronavirus = pd.read_csv("https://raw.githubusercontent.com/RamiKrispin/coronavirus/master/csv/coronavirus.csv")

coronavirus
# Out:
#               date  province      country       lat        long       type  \
# 0       2020-01-22       NaN  Afghanistan  33.93911   67.709953  confirmed
# 1       2020-01-23       NaN  Afghanistan  33.93911   67.709953  confirmed
# 2       2020-01-24       NaN  Afghanistan  33.93911   67.709953  confirmed
# 3       2020-01-25       NaN  Afghanistan  33.93911   67.709953  confirmed
# 4       2020-01-26       NaN  Afghanistan  33.93911   67.709953  confirmed
# ...            ...       ...          ...       ...         ...        ...
# 177405  2020-08-30  Zhejiang        China  29.18320  120.093400  recovered
# 177406  2020-08-31  Zhejiang        China  29.18320  120.093400  recovered
# 177407  2020-09-01  Zhejiang        China  29.18320  120.093400  recovered
# 177408  2020-09-02  Zhejiang        China  29.18320  120.093400  recovered
# 177409  2020-09-03  Zhejiang        China  29.18320  120.093400  recovered
#
#         cases
# 0           0
# 1           0
# 2           0
# ...

# %%
coronavirus.head(3)
# Out:
#          date province      country       lat       long       type  cases
# 0  2020-01-22      NaN  Afghanistan  33.93911  67.709953  confirmed      0
# 1  2020-01-23      NaN  Afghanistan  33.93911  67.709953  confirmed      0
# 2  2020-01-24      NaN  Afghanistan  33.93911  67.709953  confirmed      0

# %%
coronavirus.tail()
# Out:
#               date  province country      lat      long       type  cases
# 177405  2020-08-30  Zhejiang   China  29.1832  120.0934  recovered      0
# 177406  2020-08-31  Zhejiang   China  29.1832  120.0934  recovered      0
# 177407  2020-09-01  Zhejiang   China  29.1832  120.0934  recovered      0
# 177408  2020-09-02  Zhejiang   China  29.1832  120.0934  recovered      0
# 177409  2020-09-03  Zhejiang   China  29.1832  120.0934  recovered      0

# %%
coronavirus.describe()
# Out:
#                  lat           long          cases
# count  177410.000000  177410.000000  177410.000000
# mean       20.676502      24.494931     251.880807
# std        24.735876      69.200824    2449.144511
# min       -51.796300    -135.000000  -16298.000000
# 25%         6.611100     -12.885800       0.000000
# 50%        22.166700      21.745300       0.000000
# 75%        40.182400      80.771797       8.000000
# max        71.706900     178.065000  140050.000000

# %%
coronavirus.info
# Out:
# <bound method DataFrame.info of               date  province      country       lat        long       type  \
# 0       2020-01-22       NaN  Afghanistan  33.93911   67.709953  confirmed
# 1       2020-01-23       NaN  Afghanistan  33.93911   67.709953  confirmed
# 2       2020-01-24       NaN  Afghanistan  33.93911   67.709953  confirmed
# 3       2020-01-25       NaN  Afghanistan  33.93911   67.709953  confirmed
# 4       2020-01-26       NaN  Afghanistan  33.93911   67.709953  confirmed
# ...            ...       ...          ...       ...         ...        ...
# 177405  2020-08-30  Zhejiang        China  29.18320  120.093400  recovered
# 177406  2020-08-31  Zhejiang        China  29.18320  120.093400  recovered
# 177407  2020-09-01  Zhejiang        China  29.18320  120.093400  recovered
# 177408  2020-09-02  Zhejiang        China  29.18320  120.093400  recovered
# 177409  2020-09-03  Zhejiang        China  29.18320  120.093400  recovered
#
#         cases
# 0           0
# ...

# %%
coronavirus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177410 entries, 0 to 177409
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      177410 non-null  object
#  1   province  51754 non-null   object
#  2   country   177410 non-null  object
#  3   lat       177410 non-null  float64
#  4   long      177410 non-null  float64
#  5   type      177410 non-null  object
#  6   cases     177410 non-null  int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 9.5+ MB

# %%
import sqlite3

# %%
conn = sqlite3.connect("coronavirus.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("coronavirus.db")
c = conn.cursor()

# %%
coronavirus.to_sql("coronavirus", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM coronavirus""")
rows = c.fetchall()
rows[0:92]
# Out:
# [(0, '2020-01-22', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (1, '2020-01-23', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (2, '2020-01-24', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (3, '2020-01-25', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (4, '2020-01-26', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (5, '2020-01-27', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (6, '2020-01-28', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (7, '2020-01-29', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (8, '2020-01-30', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (9, '2020-01-31', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (10, '2020-02-01', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
#  (11, '2020-02-02', None, 'Afghanistan', 33.93911, 67.709953, 'confirmed', 0),
# ...

# %%
coronavirus.to_excel("coronavirus.xlsx")

pd.read_excel("coronavirus.xlsx")

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('coronavirus data global', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('coronavirus data global')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
