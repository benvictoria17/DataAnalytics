# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-panda/blob/master/COVDI19_Global_cases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# countrywiselatest

# %%
countrywiselatest = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/COVID-19%20Dataset/datasets_494766_1402868_country_wise_latest.csv")

countrywiselatest
# Out:
#          Country/Region  Confirmed  ...  1 week % increase             WHO Region
# 0           Afghanistan      36263  ...               2.07  Eastern Mediterranean
# 1               Albania       4880  ...              17.00                 Europe
# 2               Algeria      27973  ...              18.07                 Africa
# 3               Andorra        907  ...               2.60                 Europe
# 4                Angola        950  ...              26.84                 Africa
# ..                  ...        ...  ...                ...                    ...
# 182  West Bank and Gaza      10621  ...              19.12  Eastern Mediterranean
# 183      Western Sahara         10  ...               0.00                 Africa
# 184               Yemen       1691  ...               4.45  Eastern Mediterranean
# 185              Zambia       4552  ...              36.86                 Africa
# ...

# %%
daywise = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/COVID-19%20Dataset/datasets_494766_1402868_day_wise.csv")

daywise
# Out:
#            Date  Confirmed  ...  Deaths / 100 Recovered  No. of countries
# 0    2020-01-22        555  ...                   60.71                 6
# 1    2020-01-23        654  ...                   60.00                 8
# 2    2020-01-24        941  ...                   72.22                 9
# 3    2020-01-25       1434  ...                  107.69                11
# 4    2020-01-26       2118  ...                  107.69                13
# ..          ...        ...  ...                     ...               ...
# 183  2020-07-23   15510481  ...                    7.27               187
# 184  2020-07-24   15791645  ...                    7.16               187
# 185  2020-07-25   16047190  ...                    7.04               187
# 186  2020-07-26   16251796  ...                    6.98               187
# 187  2020-07-27   16480485  ...                    6.91               187
#
# [188 rows x 12 columns]

# %%
daywise.tail()
# Out:
#            Date  Confirmed  ...  Deaths / 100 Recovered  No. of countries
# 183  2020-07-23   15510481  ...                    7.27               187
# 184  2020-07-24   15791645  ...                    7.16               187
# 185  2020-07-25   16047190  ...                    7.04               187
# 186  2020-07-26   16251796  ...                    6.98               187
# 187  2020-07-27   16480485  ...                    6.91               187
#
# [5 rows x 12 columns]

# %%
daywise.describe()
# Out:
#           Confirmed         Deaths  ...  Deaths / 100 Recovered  No. of countries
# count  1.880000e+02     188.000000  ...              188.000000        188.000000
# mean   4.406960e+06  230770.760638  ...               22.104521        144.351064
# std    4.757988e+06  217929.094183  ...               22.568307         65.175979
# min    5.550000e+02      17.000000  ...                6.260000          6.000000
# 25%    1.121910e+05    3935.000000  ...                9.650000        101.250000
# 50%    2.848733e+06  204190.000000  ...               15.380000        184.000000
# 75%    7.422046e+06  418634.500000  ...               25.342500        187.000000
# max    1.648048e+07  654036.000000  ...              134.430000        187.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# worldometerdata

# %%
worldometerdata = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/COVID-19%20Dataset/datasets_494766_1402868_worldometer_data.csv")

worldometerdata
# Out:
#             Country/Region      Continent  ...  Tests/1M pop      WHO Region
# 0                      USA  North America  ...      190640.0        Americas
# 1                   Brazil  South America  ...       62085.0        Americas
# 2                    India           Asia  ...       16035.0  South-EastAsia
# 3                   Russia         Europe  ...      203623.0          Europe
# 4             South Africa         Africa  ...       53044.0          Africa
# ..                     ...            ...  ...           ...             ...
# 204             Montserrat  North America  ...       12220.0             NaN
# 205  Caribbean Netherlands  North America  ...       16154.0             NaN
# 206       Falkland Islands  South America  ...      520493.0             NaN
# 207           Vatican City         Europe  ...           NaN          Europe
# 208         Western Sahara         Africa  ...           NaN          Africa
#
# [209 rows x 16 columns]

# %%
worldometerdata.head()
# Out:
#   Country/Region      Continent  ...  Tests/1M pop      WHO Region
# 0            USA  North America  ...      190640.0        Americas
# 1         Brazil  South America  ...       62085.0        Americas
# 2          India           Asia  ...       16035.0  South-EastAsia
# 3         Russia         Europe  ...      203623.0          Europe
# 4   South Africa         Africa  ...       53044.0          Africa
#
# [5 rows x 16 columns]

# %%
daywise.describe()
# Out:
#           Confirmed         Deaths  ...  Deaths / 100 Recovered  No. of countries
# count  1.880000e+02     188.000000  ...              188.000000        188.000000
# mean   4.406960e+06  230770.760638  ...               22.104521        144.351064
# std    4.757988e+06  217929.094183  ...               22.568307         65.175979
# min    5.550000e+02      17.000000  ...                6.260000          6.000000
# 25%    1.121910e+05    3935.000000  ...                9.650000        101.250000
# 50%    2.848733e+06  204190.000000  ...               15.380000        184.000000
# 75%    7.422046e+06  418634.500000  ...               25.342500        187.000000
# max    1.648048e+07  654036.000000  ...              134.430000        187.000000
#
# [8 rows x 11 columns]

# %%
import sqlite3

# %%
conn = sqlite3.connect("daywise.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("daywise.db")
c = conn.cursor()

# %%
daywise.to_sql("daywise", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM daywise""")
rows = c.fetchall()
rows
# Out:
# [(0, '2020-01-22', 555, 17, 28, 510, 0, 0, 0, 3.06, 5.05, 60.71, 6),
#  (1, '2020-01-23', 654, 18, 30, 606, 99, 1, 2, 2.75, 4.59, 60.0, 8),
#  (2, '2020-01-24', 941, 26, 36, 879, 287, 8, 6, 2.76, 3.83, 72.22, 9),
#  (3, '2020-01-25', 1434, 42, 39, 1353, 493, 16, 3, 2.93, 2.72, 107.69, 11),
#  (4, '2020-01-26', 2118, 56, 52, 2010, 684, 14, 13, 2.64, 2.46, 107.69, 13),
#  (5, '2020-01-27', 2927, 82, 61, 2784, 809, 26, 9, 2.8, 2.08, 134.43, 16),
#  (6, '2020-01-28', 5578, 131, 107, 5340, 2651, 49, 46, 2.35, 1.92, 122.43, 16),
#  (7, '2020-01-29', 6166, 133, 125, 5908, 588, 2, 18, 2.16, 2.03, 106.4, 18),
#  (8, '2020-01-30', 8234, 171, 141, 7922, 2068, 38, 16, 2.08, 1.71, 121.28, 20),
#  (9, '2020-01-31', 9927, 213, 219, 9495, 1693, 42, 78, 2.15, 2.21, 97.26, 24),
#  (10,
#   '2020-02-01',
#   12038,
#   259,
#   281,
#   11498,
#   2111,
#   46,
#   62,
#   2.15,
#   2.33,
#   92.17,
#   25),
#  (11,
#   '2020-02-02',
#   16787,
#   362,
#   459,
#   15966,
#   4749,
#   103,
#   178,
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('daywise', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('daywise')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('worldometerdata', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('worldometerdata')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('AT&T Inc. (T)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('AT&T Inc. (T)')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
