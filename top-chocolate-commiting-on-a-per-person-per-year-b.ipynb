# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
chocolate = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/Top%20chocolate-Commiting%20on%20a%20Per-Person%2CPer-Year%20basicis.csv")

chocolate
# Out:
#                country   lbs    kg
# 0          Switzerland  22.4  10.1
# 1              Austria  20.1   9.1
# 2              Ireland  19.5   8.8
# 3              Germany  18.0   8.2
# 4               Norway  17.9   8.1
# 5              Denmark  17.7   8.0
# 6  United Kingdom (UK)  17.5   7.9
# 7              Belgium  13.2   6.0
# 8            Australia  13.0   5.9
# 9               Sweden  12.9   5.8

# %%
chocolate.head()
# Out:
#        country   lbs    kg
# 0  Switzerland  22.4  10.1
# 1      Austria  20.1   9.1
# 2      Ireland  19.5   8.8
# 3      Germany  18.0   8.2
# 4       Norway  17.9   8.1

# %%
chocolate.tail()
# Out:
#                country   lbs   kg
# 5              Denmark  17.7  8.0
# 6  United Kingdom (UK)  17.5  7.9
# 7              Belgium  13.2  6.0
# 8            Australia  13.0  5.9
# 9               Sweden  12.9  5.8

# %%
chocolate.describe()
# Out:
#              lbs        kg
# count  10.000000  10.00000
# mean   17.220000   7.79000
# std     3.237557   1.45789
# min    12.900000   5.80000
# 25%    14.275000   6.47500
# 50%    17.800000   8.05000
# 75%    19.125000   8.65000
# max    22.400000  10.10000

# %%
chocolate.info
# Out:
# <bound method DataFrame.info of                country   lbs    kg
# 0          Switzerland  22.4  10.1
# 1              Austria  20.1   9.1
# 2              Ireland  19.5   8.8
# 3              Germany  18.0   8.2
# 4               Norway  17.9   8.1
# 5              Denmark  17.7   8.0
# 6  United Kingdom (UK)  17.5   7.9
# 7              Belgium  13.2   6.0
# 8            Australia  13.0   5.9
# 9               Sweden  12.9   5.8>

# %%
chocolate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  10 non-null     object
#  1   lbs      10 non-null     float64
#  2   kg       10 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 368.0+ bytes

# %%
conn = sqlite3.connect("chocolate.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("chocolate.db")
c = conn.cursor()

# %%
chocolate.to_sql("chocolate", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM chocolate""")
rows = c.fetchall()
rows
# Out:
# [(0, 'Switzerland', 22.4, 10.1),
#  (1, 'Austria', 20.1, 9.1),
#  (2, 'Ireland', 19.5, 8.8),
#  (3, 'Germany', 18.0, 8.2),
#  (4, 'Norway', 17.9, 8.1),
#  (5, 'Denmark', 17.7, 8.0),
#  (6, 'United Kingdom (UK)', 17.5, 7.9),
#  (7, 'Belgium', 13.2, 6.0),
#  (8, 'Australia', 13.0, 5.9),
#  (9, 'Sweden', 12.9, 5.8)]

# %%
chocolate.to_excel("chocolate.xls")

pd.read_excel("chocolate.xls")
# Out:
#    Unnamed: 0              country   lbs    kg
# 0           0          Switzerland  22.4  10.1
# 1           1              Austria  20.1   9.1
# 2           2              Ireland  19.5   8.8
# 3           3              Germany  18.0   8.2
# 4           4               Norway  17.9   8.1
# 5           5              Denmark  17.7   8.0
# 6           6  United Kingdom (UK)  17.5   7.9
# 7           7              Belgium  13.2   6.0
# 8           8            Australia  13.0   5.9
# 9           9               Sweden  12.9   5.8

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Top chocolate-Commiting on a Per-Person,Per-Year b', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Top chocolate-Commiting on a Per-Person,Per-Year b')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
