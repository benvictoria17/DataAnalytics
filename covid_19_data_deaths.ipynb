# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/panda/blob/master/covid_19_data_deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
deaths = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/excess-deaths/deaths.csv")

deaths
# Out:
#             country placename  ... excess_deaths                   baseline
# 0           Austria       NaN  ...        -112.0  2015-2019 historical data
# 1           Austria       NaN  ...         -27.0  2015-2019 historical data
# 2           Austria       NaN  ...         -54.0  2015-2019 historical data
# 3           Austria       NaN  ...         111.0  2015-2019 historical data
# 4           Austria       NaN  ...        -157.0  2015-2019 historical data
# ...             ...       ...  ...           ...                        ...
# 6707  United States       NaN  ...           NaN                        NaN
# 6708  United States       NaN  ...           NaN                        NaN
# 6709  United States       NaN  ...           NaN                        NaN
# 6710  United States       NaN  ...           NaN                        NaN
# 6711  United States       NaN  ...           NaN                        NaN
#
# [6712 rows x 12 columns]

# %%
deaths.head()
# Out:
#    country placename  ... excess_deaths                   baseline
# 0  Austria       NaN  ...        -112.0  2015-2019 historical data
# 1  Austria       NaN  ...         -27.0  2015-2019 historical data
# 2  Austria       NaN  ...         -54.0  2015-2019 historical data
# 3  Austria       NaN  ...         111.0  2015-2019 historical data
# 4  Austria       NaN  ...        -157.0  2015-2019 historical data
#
# [5 rows x 12 columns]

# %%
deaths.tail()
# Out:
#             country placename  ... excess_deaths baseline
# 6707  United States       NaN  ...           NaN      NaN
# 6708  United States       NaN  ...           NaN      NaN
# 6709  United States       NaN  ...           NaN      NaN
# 6710  United States       NaN  ...           NaN      NaN
# 6711  United States       NaN  ...           NaN      NaN
#
# [5 rows x 12 columns]

# %%
deaths.describe()
# Out:
#              month         week        deaths  expected_deaths  excess_deaths
# count  6712.000000  5535.000000   6712.000000       621.000000     621.000000
# mean      6.192938    24.828726   5121.710369      5709.370370     688.597424
# std       3.375412    14.489566   7796.713950     10323.200513    2538.182279
# min       1.000000     2.000000     48.000000        67.000000   -4047.000000
# 25%       3.000000    12.000000    986.000000      1011.000000     -99.000000
# 50%       6.000000    23.000000   1718.500000      1573.000000       8.000000
# 75%       9.000000    37.000000   8225.000000      7085.000000     410.000000
# max      12.000000    52.000000  80623.000000     60617.000000   26351.000000

# %%
deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6712 entries, 0 to 6711
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          6712 non-null   object
#  1   placename        2699 non-null   object
#  2   frequency        6712 non-null   object
#  3   start_date       5385 non-null   object
#  4   end_date         5385 non-null   object
#  5   year             6712 non-null   object
#  6   month            6712 non-null   int64
#  7   week             5535 non-null   float64
#  8   deaths           6712 non-null   int64
#  9   expected_deaths  621 non-null    float64
#  10  excess_deaths    621 non-null    float64
#  11  baseline         649 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 629.4+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("deaths.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("deaths.db")
c = conn.cursor()

# %%
deaths.to_sql("deaths", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM deaths""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   'Austria',
#   None,
#   'weekly',
#   '2020-01-06',
#   '2020-01-12',
#   '2020',
#   1,
#   2.0,
#   1702,
#   1814.0,
#   -112.0,
#   '2015-2019 historical data'),
#  (1,
#   'Austria',
#   None,
#   'weekly',
#   '2020-01-13',
#   '2020-01-19',
#   '2020',
#   1,
#   3.0,
#   1797,
#   1824.0,
#   -27.0,
#   '2015-2019 historical data'),
#  (2,
#   'Austria',
#   None,
#   'weekly',
#   '2020-01-20',
#   '2020-01-26',
#   '2020',
#   1,
#   4.0,
#   1778,
#   1832.0,
#   -54.0,
#   '2015-2019 historical data'),
#  (3,
#   'Austria',
#   None,
#   'weekly',
#   '2020-01-27',
#   '2020-02-02',
#   '2020',
#   2,
#   5.0,
#   1947,
#   1836.0,
#   111.0,
#   '2015-2019 historical data'),
#  (4,
#   'Austria',
#   None,
#   'weekly',
#   '2020-02-03',
#   '2020-02-09',
#   '2020',
#   2,
#   6.0,
#   1678,
#   1835.0,
#   -157.0,
#   '2015-2019 historical data'),
#  (5,
#   'Austria',
#   None,
#   'weekly',
#   '2020-02-10',
#   '2020-02-16',
#   '2020',
#   2,
#   7.0,
# ...

# %%
deaths.to_excel("deaths.xls")

pd.read_excel("deaths.xls")
# Out:
#       Unnamed: 0        country  ... excess_deaths                   baseline
# 0              0        Austria  ...        -112.0  2015-2019 historical data
# 1              1        Austria  ...         -27.0  2015-2019 historical data
# 2              2        Austria  ...         -54.0  2015-2019 historical data
# 3              3        Austria  ...         111.0  2015-2019 historical data
# 4              4        Austria  ...        -157.0  2015-2019 historical data
# ...          ...            ...  ...           ...                        ...
# 6707        6707  United States  ...           NaN                        NaN
# 6708        6708  United States  ...           NaN                        NaN
# 6709        6709  United States  ...           NaN                        NaN
# 6710        6710  United States  ...           NaN                        NaN
# 6711        6711  United States  ...           NaN                        NaN
#
# [6712 rows x 13 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('covid-19-data deaths', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('covid-19-data deaths')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.
