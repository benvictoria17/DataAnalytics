# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# importing data
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/pandas/master/dataset/Who%20eats%20the%20food%20we%20grow%3F/FAO.csv",  encoding = "ISO-8859-1")
pd.options.mode.chained_assignment = None

# %%
df.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# 1      67.71  ...   419.0   445.0   546.0   455.0   490.0   415.0   442.0
# 2      67.71  ...    58.0   236.0   262.0   263.0   230.0   379.0   315.0
# 3      67.71  ...   185.0    43.0    44.0    48.0    62.0    55.0    60.0
# 4      67.71  ...   120.0   208.0   233.0   249.0   247.0   195.0   178.0
#
#     Y2011  Y2012  Y2013
# 0  4711.0   4810   4895
# 1   476.0    425    422
# 2   203.0    367    360
# 3    72.0     78     89
# 4   191.0    200    200
#
# [5 rows x 63 columns]

# %%
area_list = list(df['Area'].unique())
year_list = list(df.iloc[:,10:].columns)

plt.figure(figsize=(24,12))
for ar in area_list:
    yearly_produce = []
    for yr in year_list:
        yearly_produce.append(df[yr][df['Area'] == ar].sum())
    plt.plot(yearly_produce, label=ar)
plt.xticks(np.arange(53), tuple(year_list), rotation=60)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=8, mode="expand", borderaxespad=0.)
plt.savefig('p.png')
plt.show()

# %%
sns.factorplot("Element", data=df, kind="count")
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot("Area", data=df[(df['Area'] == "India") | (df['Area'] == "China, mainland") | (df['Area'] == "United States of America")], kind="count", hue="Element", size=8, aspect=.8)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3675: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
new_df_dict = {}
for ar in area_list:
    yearly_produce = []
    for yr in year_list:
        yearly_produce.append(df[yr][df['Area']==ar].sum())
    new_df_dict[ar] = yearly_produce
new_df = pd.DataFrame(new_df_dict)

new_df.head()
# Out:
#    Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  Argentina  \
# 0       9481.0   1706.0   7488.0  4834.0                 92.0    43402.0
# 1       9414.0   1749.0   7235.0  4775.0                 94.0    40784.0
# 2       9194.0   1767.0   6861.0  5240.0                105.0    40219.0
# 3      10170.0   1889.0   7255.0  5286.0                 95.0    41638.0
# 4      10473.0   1884.0   7509.0  5527.0                 84.0    44936.0
#
#    Armenia  Australia  Austria  Azerbaijan  ...  United Republic of Tanzania  \
# 0      0.0    25795.0  22542.0         0.0  ...                      12367.0
# 1      0.0    27618.0  22627.0         0.0  ...                      12810.0
# 2      0.0    28902.0  23637.0         0.0  ...                      13109.0
# 3      0.0    29107.0  24099.0         0.0  ...                      12965.0
# 4      0.0    28961.0  22664.0         0.0  ...                      13742.0
#
#    United States of America  Uruguay  Uzbekistan  Vanuatu  \
# 0                  559347.0   4631.0         0.0     97.0
# 1                  556319.0   4448.0         0.0    101.0
# 2                  552630.0   4682.0         0.0    103.0
# 3                  555677.0   4723.0         0.0    102.0
# 4                  589288.0   4581.0         0.0    107.0
#
#    Venezuela (Bolivarian Republic of)  Viet Nam   Yemen  Zambia  Zimbabwe
# 0                              9523.0   23856.0  2982.0  2976.0    3260.0
# 1                              9369.0   25220.0  3038.0  3057.0    3503.0
# 2                              9788.0   26053.0  3147.0  3069.0    3479.0
# 3                             10539.0   26377.0  3224.0  3121.0    3738.0
# 4                             10641.0   26961.0  3328.0  3236.0    3940.0
#
# [5 rows x 174 columns]

# %%
new_df = pd.DataFrame.transpose(new_df)
new_df.columns = year_list

new_df.head()
# Out:
#                       Y1961   Y1962   Y1963    Y1964    Y1965    Y1966  \
# Afghanistan          9481.0  9414.0  9194.0  10170.0  10473.0  10169.0
# Albania              1706.0  1749.0  1767.0   1889.0   1884.0   1995.0
# Algeria              7488.0  7235.0  6861.0   7255.0   7509.0   7536.0
# Angola               4834.0  4775.0  5240.0   5286.0   5527.0   5677.0
# Antigua and Barbuda    92.0    94.0   105.0     95.0     84.0     73.0
#
#                        Y1967    Y1968    Y1969    Y1970  ...    Y2004  \
# Afghanistan          11289.0  11508.0  11815.0  10454.0  ...  16542.0
# Albania               2046.0   2169.0   2230.0   2395.0  ...   6637.0
# Algeria               7986.0   8839.0   9003.0   9355.0  ...  48619.0
# Angola                5833.0   5685.0   6219.0   6460.0  ...  25541.0
# Antigua and Barbuda     64.0     59.0     68.0     77.0  ...     92.0
#
#                        Y2005    Y2006    Y2007    Y2008    Y2009    Y2010  \
# Afghanistan          17658.0  18317.0  19248.0  19381.0  20661.0  21030.0
# Albania               6719.0   6911.0   6744.0   7168.0   7316.0   7907.0
# Algeria              49562.0  51067.0  49933.0  50916.0  57505.0  60071.0
# Angola               26696.0  28247.0  29877.0  32053.0  36985.0  38400.0
# Antigua and Barbuda    115.0    110.0    122.0    115.0    114.0    115.0
#
#                        Y2011    Y2012    Y2013
# Afghanistan          21100.0  22706.0  23007.0
# Albania               8114.0   8221.0   8271.0
# Algeria              65852.0  69365.0  72161.0
# Angola               40573.0  38064.0  48639.0
# Antigua and Barbuda    118.0    113.0    119.0
#
# [5 rows x 53 columns]

# %%
mean_produce = []
for i in range(174):
    mean_produce.append(new_df.iloc[i,:].values.mean())
new_df['Mean_Produce'] = mean_produce

new_df['Rank'] = new_df['Mean_Produce'].rank(ascending=False)

new_df.head()
# Out:
#                       Y1961   Y1962   Y1963    Y1964    Y1965    Y1966  \
# Afghanistan          9481.0  9414.0  9194.0  10170.0  10473.0  10169.0
# Albania              1706.0  1749.0  1767.0   1889.0   1884.0   1995.0
# Algeria              7488.0  7235.0  6861.0   7255.0   7509.0   7536.0
# Angola               4834.0  4775.0  5240.0   5286.0   5527.0   5677.0
# Antigua and Barbuda    92.0    94.0   105.0     95.0     84.0     73.0
#
#                        Y1967    Y1968    Y1969    Y1970  ...    Y2006  \
# Afghanistan          11289.0  11508.0  11815.0  10454.0  ...  18317.0
# Albania               2046.0   2169.0   2230.0   2395.0  ...   6911.0
# Algeria               7986.0   8839.0   9003.0   9355.0  ...  51067.0
# Angola                5833.0   5685.0   6219.0   6460.0  ...  28247.0
# Antigua and Barbuda     64.0     59.0     68.0     77.0  ...    110.0
#
#                        Y2007    Y2008    Y2009    Y2010    Y2011    Y2012  \
# Afghanistan          19248.0  19381.0  20661.0  21030.0  21100.0  22706.0
# Albania               6744.0   7168.0   7316.0   7907.0   8114.0   8221.0
# Algeria              49933.0  50916.0  57505.0  60071.0  65852.0  69365.0
# Angola               29877.0  32053.0  36985.0  38400.0  40573.0  38064.0
# Antigua and Barbuda    122.0    115.0    114.0    115.0    118.0    113.0
#
#                        Y2013  Mean_Produce   Rank
# Afghanistan          23007.0  13003.056604   69.0
# Albania               8271.0   4475.509434  104.0
# Algeria              72161.0  28879.490566   38.0
# Angola               48639.0  13321.056604   68.0
# Antigua and Barbuda    119.0     83.886792  172.0
#
# [5 rows x 55 columns]

# %%
item_list = list(df['Item'].unique())

item_df = pd.DataFrame()
item_df['Item_Name'] = item_list

for yr in year_list:
    item_produce = []
    for it in item_list:
        item_produce.append(df[yr][df['Item']==it].sum())
    item_df[yr] = item_produce

# %%
item_df.head()
# Out:
#                   Item_Name     Y1961     Y1962     Y1963     Y1964     Y1965  \
# 0        Wheat and products  138829.0  144643.0  147325.0  156273.0  168822.0
# 1  Rice (Milled Equivalent)  122700.0  131842.0  139507.0  148304.0  150056.0
# 2       Barley and products   46180.0   48915.0   51642.0   54184.0   54945.0
# 3        Maize and products  168039.0  168305.0  172905.0  175468.0  190304.0
# 4       Millet and products   19075.0   19019.0   19740.0   20353.0   18377.0
#
#       Y1966     Y1967     Y1968     Y1969  ...     Y2004     Y2005     Y2006  \
# 0  169832.0  171469.0  179530.0  189658.0  ...  527394.0  532263.0  537279.0
# 1  155583.0  158587.0  164614.0  167922.0  ...  361107.0  366025.0  372629.0
# 2   55463.0   56424.0   60455.0   65501.0  ...  102055.0   97185.0  100981.0
# 3  200860.0  213050.0  215613.0  221953.0  ...  545024.0  549036.0  543280.0
# 4   20860.0   22997.0   21785.0   23966.0  ...   25789.0   25496.0   25997.0
#
#       Y2007     Y2008     Y2009     Y2010     Y2011   Y2012   Y2013
# 0  529271.0  562239.0  557245.0  549926.0  578179.0  576597  587492
# 1  378698.0  389708.0  394221.0  398559.0  404152.0  406787  410880
# 2   93310.0   98209.0   99135.0   92563.0   92570.0   88766   99452
# 3  573892.0  592231.0  557940.0  584337.0  603297.0  608730  671300
# 4   26750.0   26373.0   24575.0   27039.0   25740.0   26105   26346
#
# [5 rows x 54 columns]

# %%
sum_col = []
for i in range(115):
    sum_col.append(item_df.iloc[i,1:].values.sum())
item_df['Sum'] = sum_col
item_df['Production_Rank'] = item_df['Sum'].rank(ascending=False)

item_df.head()
# Out:
#                   Item_Name     Y1961     Y1962     Y1963     Y1964     Y1965  \
# 0        Wheat and products  138829.0  144643.0  147325.0  156273.0  168822.0
# 1  Rice (Milled Equivalent)  122700.0  131842.0  139507.0  148304.0  150056.0
# 2       Barley and products   46180.0   48915.0   51642.0   54184.0   54945.0
# 3        Maize and products  168039.0  168305.0  172905.0  175468.0  190304.0
# 4       Millet and products   19075.0   19019.0   19740.0   20353.0   18377.0
#
#       Y1966     Y1967     Y1968     Y1969  ...     Y2006     Y2007     Y2008  \
# 0  169832.0  171469.0  179530.0  189658.0  ...  537279.0  529271.0  562239.0
# 1  155583.0  158587.0  164614.0  167922.0  ...  372629.0  378698.0  389708.0
# 2   55463.0   56424.0   60455.0   65501.0  ...  100981.0   93310.0   98209.0
# 3  200860.0  213050.0  215613.0  221953.0  ...  543280.0  573892.0  592231.0
# 4   20860.0   22997.0   21785.0   23966.0  ...   25997.0   26750.0   26373.0
#
#       Y2009     Y2010     Y2011   Y2012   Y2013         Sum  Production_Rank
# 0  557245.0  549926.0  578179.0  576597  587492  19194671.0              6.0
# 1  394221.0  398559.0  404152.0  406787  410880  14475448.0              8.0
# 2   99135.0   92563.0   92570.0   88766   99452   4442742.0             20.0
# 3  557940.0  584337.0  603297.0  608730  671300  19960640.0              5.0
# 4   24575.0   27039.0   25740.0   26105   26346   1225400.0             38.0
#
# [5 rows x 56 columns]

# %%
item_df['Item_Name'][item_df['Production_Rank'] < 11.0].sort_values()
# Out:
# 56    Cereals - Excluding Beer
# 65     Fruits - Excluding Wine
# 3           Maize and products
# 53     Milk - Excluding Butter
# 6        Potatoes and products
# 1     Rice (Milled Equivalent)
# 57               Starchy Roots
# 64                  Vegetables
# 27           Vegetables, Other
# 0           Wheat and products
# Name: Item_Name, dtype: object

# %%
sns.factorplot("Item", data=df[(df['Item']=='Wheat and products') | (df['Item']=='Rice (Milled Equivalent)') | (df['Item']=='Maize and products') | (df['Item']=='Potatoes and products') | (df['Item']=='Vegetables, Other') | (df['Item']=='Milk - Excluding Butter') | (df['Item']=='Cereals - Excluding Beer') | (df['Item']=='Starchy Roots') | (df['Item']=='Vegetables') | (df['Item']=='Fruits - Excluding Wine')], kind="count", hue="Element", size=20, aspect=.8)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3675: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
year_df = df.iloc[:,10:]
fig, ax = plt.subplots(figsize=(16,10))
sns.heatmap(year_df.corr(), ax=ax)

# %%
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row', figsize=(10,10))
ax1.set(xlabel='Y1968', ylabel='Y1961')
ax2.set(xlabel='Y1968', ylabel='Y1963')
ax3.set(xlabel='Y1968', ylabel='Y1986')
ax4.set(xlabel='Y1968', ylabel='Y2013')
sns.jointplot(x="Y1968", y="Y1961", data=df, kind="reg", ax=ax1)
sns.jointplot(x="Y1968", y="Y1963", data=df, kind="reg", ax=ax2)
sns.jointplot(x="Y1968", y="Y1986", data=df, kind="reg", ax=ax3)
sns.jointplot(x="Y1968", y="Y2013", data=df, kind="reg", ax=ax4)
plt.close(2)
plt.close(3)
plt.close(4)
plt.close(5)

# %%
new_item_df = item_df.drop(["Item_Name","Sum","Production_Rank"], axis = 1)
fig, ax = plt.subplots(figsize=(12,24))
sns.heatmap(new_item_df,ax=ax)
ax.set_yticklabels(item_df.Item_Name.values[::-1])
plt.show()

# %%
new_df.head()
# Out:
#                       Y1961   Y1962   Y1963    Y1964    Y1965    Y1966  \
# Afghanistan          9481.0  9414.0  9194.0  10170.0  10473.0  10169.0
# Albania              1706.0  1749.0  1767.0   1889.0   1884.0   1995.0
# Algeria              7488.0  7235.0  6861.0   7255.0   7509.0   7536.0
# Angola               4834.0  4775.0  5240.0   5286.0   5527.0   5677.0
# Antigua and Barbuda    92.0    94.0   105.0     95.0     84.0     73.0
#
#                        Y1967    Y1968    Y1969    Y1970  ...    Y2006  \
# Afghanistan          11289.0  11508.0  11815.0  10454.0  ...  18317.0
# Albania               2046.0   2169.0   2230.0   2395.0  ...   6911.0
# Algeria               7986.0   8839.0   9003.0   9355.0  ...  51067.0
# Angola                5833.0   5685.0   6219.0   6460.0  ...  28247.0
# Antigua and Barbuda     64.0     59.0     68.0     77.0  ...    110.0
#
#                        Y2007    Y2008    Y2009    Y2010    Y2011    Y2012  \
# Afghanistan          19248.0  19381.0  20661.0  21030.0  21100.0  22706.0
# Albania               6744.0   7168.0   7316.0   7907.0   8114.0   8221.0
# Algeria              49933.0  50916.0  57505.0  60071.0  65852.0  69365.0
# Angola               29877.0  32053.0  36985.0  38400.0  40573.0  38064.0
# Antigua and Barbuda    122.0    115.0    114.0    115.0    118.0    113.0
#
#                        Y2013  Mean_Produce   Rank
# Afghanistan          23007.0  13003.056604   69.0
# Albania               8271.0   4475.509434  104.0
# Algeria              72161.0  28879.490566   38.0
# Angola               48639.0  13321.056604   68.0
# Antigua and Barbuda    119.0     83.886792  172.0
#
# [5 rows x 55 columns]

# %%
# !pip install DataFrame
# Out:
# Collecting DataFrame
#   Downloading dataframe-0.2.1.3-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from DataFrame) (1.18.5)
# Requirement already satisfied: scipy>=0.18.0 in /opt/conda/lib/python3.7/site-packages (from DataFrame) (1.4.1)
# Requirement already satisfied: nose==1.3.7 in /opt/conda/lib/python3.7/site-packages (from DataFrame) (1.3.7)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.7/site-packages (from DataFrame) (0.8.7)
# Requirement already satisfied: sphinx>=1.4.5 in /opt/conda/lib/python3.7/site-packages (from DataFrame) (3.0.2)
# Requirement already satisfied: pytest>=2.9.2 in /opt/conda/lib/python3.7/site-packages (from DataFrame) (5.4.1)
# Requirement already satisfied: sphinxcontrib-devhelp in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.0.2)
# Requirement already satisfied: requests>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (2.23.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.0.1)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (2.8.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (0.7.12)
# Requirement already satisfied: imagesize in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.2.0)
# Requirement already satisfied: Jinja2>=2.3 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (2.11.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (20.1)
# Requirement already satisfied: docutils>=0.12 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (0.15.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (46.1.3.post20200325)
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (2.6.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /opt/conda/lib/python3.7/site-packages (from sphinx>=1.4.5->DataFrame) (2.0.0)
# Requirement already satisfied: py>=1.5.0 in /opt/conda/lib/python3.7/site-packages (from pytest>=2.9.2->DataFrame) (1.8.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from pytest>=2.9.2->DataFrame) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from pytest>=2.9.2->DataFrame) (8.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest>=2.9.2->DataFrame) (0.13.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from pytest>=2.9.2->DataFrame) (0.1.9)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest>=2.9.2->DataFrame) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.4.5->DataFrame) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.4.5->DataFrame) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.4.5->DataFrame) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.4.5->DataFrame) (2.9)
# Requirement already satisfied: pytz>=2015.7 in /opt/conda/lib/python3.7/site-packages (from babel>=1.3->sphinx>=1.4.5->DataFrame) (2019.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from Jinja2>=2.3->sphinx>=1.4.5->DataFrame) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->sphinx>=1.4.5->DataFrame) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from packaging->sphinx>=1.4.5->DataFrame) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest>=2.9.2->DataFrame) (3.1.0)
# Installing collected packages: DataFrame
# Successfully installed DataFrame-0.2.1.3

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
