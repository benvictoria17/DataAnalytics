# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/Earthquakes%20-%20Indian%20Subcontinent/Earthquake.csv")
df.head()
# Out:
#                        time  latitude  longitude  depth  mag magType    nst  \
# 0  2009-12-31T09:57:29.720Z    27.319     91.510   10.0  5.5      mb  205.0
# 1  2009-12-29T13:33:22.870Z    35.017     73.005   63.8  4.0      mb   40.0
# 2  2009-12-29T09:01:55.310Z    24.357     94.807  124.8  5.6     mwb  206.0
# 3  2009-12-28T02:15:04.870Z    30.686     83.769   10.0  4.4      mb   50.0
# 4  2009-12-26T00:23:38.570Z    14.001     92.862   42.6  5.0      mb  117.0
#
#     gap  dmin   rms  ...                   updated  \
# 0  37.4   NaN  0.89  ...  2017-04-26T18:09:55.932Z
# 1  95.8   NaN  0.94  ...  2014-11-07T01:40:19.294Z
# 2  17.3   NaN  0.77  ...  2016-11-10T02:22:03.905Z
# 3  40.6   NaN  1.08  ...  2014-11-07T01:40:19.031Z
# 4  68.1   NaN  0.82  ...  2014-11-07T01:40:18.641Z
#
#                            place        type horizontalError depthError  \
# 0                         Bhutan  earthquake             NaN        NaN
# 1           northwestern Kashmir  earthquake             NaN        8.6
# 2    Myanmar-India border region  earthquake             NaN        NaN
# 3                 western Xizang  earthquake             NaN        NaN
# 4  Andaman Islands, India region  earthquake             NaN        5.7
#
#    magError  magNst    status  locationSource magSource
# 0       NaN   118.0  reviewed              us        us
# 1       NaN     7.0  reviewed              us        us
# 2       NaN     NaN  reviewed              us        us
# 3       NaN     9.0  reviewed              us        us
# 4       NaN    56.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
len(df.index)
# Out:
# 14698

# %%
df.nunique()
# Out:
# time               14698
# latitude           10713
# longitude          10140
# depth               3554
# mag                   48
# magType               10
# nst                  427
# gap                 2253
# dmin                1954
# rms                  171
# net                    2
# id                 14698
# updated            13594
# place               2419
# type                   1
# horizontalError      145
# depthError           463
# magError             269
# magNst               193
# status                 2
# locationSource         5
# magSource              8
# dtype: int64

# %%
df.drop_duplicates(subset ="time",keep = False, inplace = True)

# %%
len(df.index)
# Out:
# 14698

# %%
df.fillna("")
# Out:
#                            time  latitude  longitude  depth  mag magType  \
# 0      2009-12-31T09:57:29.720Z    27.319     91.510   10.0  5.5      mb
# 1      2009-12-29T13:33:22.870Z    35.017     73.005   63.8  4.0      mb
# 2      2009-12-29T09:01:55.310Z    24.357     94.807  124.8  5.6     mwb
# 3      2009-12-28T02:15:04.870Z    30.686     83.769   10.0  4.4      mb
# 4      2009-12-26T00:23:38.570Z    14.001     92.862   42.6  5.0      mb
# ...                         ...       ...        ...    ...  ...     ...
# 14693  2010-01-11T16:07:13.800Z    36.041     70.893  104.7  4.6      mb
# 14694  2010-01-11T05:15:16.160Z    29.744     80.557   35.0  4.7      mb
# 14695  2010-01-11T03:38:43.300Z    14.243     93.505   66.4  4.0      mb
# 14696  2010-01-05T14:28:18.340Z    32.384     85.273   54.1  4.9      mb
# 14697  2010-01-01T02:22:23.820Z    30.646     83.791   10.0  5.2     mwc
#
#          nst    gap dmin   rms  ...                   updated  \
# 0      205.0   37.4       0.89  ...  2017-04-26T18:09:55.932Z
# 1       40.0   95.8       0.94  ...  2014-11-07T01:40:19.294Z
# 2      206.0   17.3       0.77  ...  2016-11-10T02:22:03.905Z
# 3       50.0   40.6       1.08  ...  2014-11-07T01:40:19.031Z
# 4      117.0   68.1       0.82  ...  2014-11-07T01:40:18.641Z
# ...      ...    ...  ...   ...  ...                       ...
# 14693   41.0   93.7       1.11  ...  2014-11-07T01:40:26.476Z
# 14694   27.0   84.6       1.09  ...  2014-11-07T01:40:26.418Z
# 14695   18.0  181.4       0.85  ...  2014-11-07T01:40:26.412Z
# 14696   58.0  108.2       0.83  ...  2014-11-07T01:40:25.340Z
# 14697   84.0   78.6       1.09  ...  2016-11-10T02:22:11.026Z
#
#                                 place        type horizontalError depthError  \
# 0                              Bhutan  earthquake
# 1                northwestern Kashmir  earthquake                        8.6
# 2         Myanmar-India border region  earthquake
# 3                      western Xizang  earthquake
# 4       Andaman Islands, India region  earthquake                        5.7
# ...                               ...         ...             ...        ...
# 14693  Hindu Kush region, Afghanistan  earthquake
# 14694       Nepal-India border region  earthquake                        0.0
# 14695   Andaman Islands, India region  earthquake                       22.2
# 14696                  western Xizang  earthquake                       11.4
# 14697                  western Xizang  earthquake
#
#       magError magNst    status locationSource magSource
# 0               118.0  reviewed             us        us
# 1                 7.0  reviewed             us        us
# 2                      reviewed             us        us
# 3                 9.0  reviewed             us        us
# 4                56.0  reviewed             us        us
# ...        ...    ...       ...            ...       ...
# 14693             6.0  reviewed             us        us
# 14694             4.0  reviewed             us        us
# 14695             2.0  reviewed             us        us
# 14696            15.0  reviewed             us        us
# 14697                  reviewed             us      gcmt
#
# [14698 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
df['time'] = pd.to_datetime(df['time'])
df.head()
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2009-12-31 09:57:29.720000+00:00    27.319     91.510   10.0  5.5      mb
# 1 2009-12-29 13:33:22.870000+00:00    35.017     73.005   63.8  4.0      mb
# 2 2009-12-29 09:01:55.310000+00:00    24.357     94.807  124.8  5.6     mwb
# 3 2009-12-28 02:15:04.870000+00:00    30.686     83.769   10.0  4.4      mb
# 4 2009-12-26 00:23:38.570000+00:00    14.001     92.862   42.6  5.0      mb
#
#      nst   gap  dmin   rms  ...                   updated  \
# 0  205.0  37.4   NaN  0.89  ...  2017-04-26T18:09:55.932Z
# 1   40.0  95.8   NaN  0.94  ...  2014-11-07T01:40:19.294Z
# 2  206.0  17.3   NaN  0.77  ...  2016-11-10T02:22:03.905Z
# 3   50.0  40.6   NaN  1.08  ...  2014-11-07T01:40:19.031Z
# 4  117.0  68.1   NaN  0.82  ...  2014-11-07T01:40:18.641Z
#
#                            place        type horizontalError depthError  \
# 0                         Bhutan  earthquake             NaN        NaN
# 1           northwestern Kashmir  earthquake             NaN        8.6
# 2    Myanmar-India border region  earthquake             NaN        NaN
# 3                 western Xizang  earthquake             NaN        NaN
# 4  Andaman Islands, India region  earthquake             NaN        5.7
#
#    magError  magNst    status  locationSource magSource
# 0       NaN   118.0  reviewed              us        us
# 1       NaN     7.0  reviewed              us        us
# 2       NaN     NaN  reviewed              us        us
# 3       NaN     9.0  reviewed              us        us
# 4       NaN    56.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
df = df.drop(columns = ['magType', 'nst','gap', 'dmin', 'rms', 'net', 'id', 'updated', 'type',
       'horizontalError', 'depthError', 'magError', 'magNst', 'status',
       'locationSource', 'magSource'])

# %%
sns.pairplot(df)

# %%
sns.violinplot(df['mag'],orient='v')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='mag'>

# %%
df[df['mag']==df['mag'].max()]
# Out:
#                                   time  latitude  longitude  depth  mag  \
# 9586  2001-11-14 09:26:10.010000+00:00   35.9460    90.5410  10.00  7.8
# 12139 2015-04-25 06:11:25.950000+00:00   28.2305    84.7314   8.22  7.8
#
#                          place
# 9586   southern Qinghai, China
# 12139   36km E of Khudi, Nepal

# %%
(df['mag']>=3.5).value_counts()
# Out:
# True     14344
# False      354
# Name: mag, dtype: int64

# %%
new_df=df.loc[df['mag'] >= 3.5].reset_index().drop(columns=['index'])
len(new_df.index)
# Out:
# 14344

# %%
new_df.head()
# Out:
#                               time  latitude  longitude  depth  mag  \
# 0 2009-12-31 09:57:29.720000+00:00    27.319     91.510   10.0  5.5
# 1 2009-12-29 13:33:22.870000+00:00    35.017     73.005   63.8  4.0
# 2 2009-12-29 09:01:55.310000+00:00    24.357     94.807  124.8  5.6
# 3 2009-12-28 02:15:04.870000+00:00    30.686     83.769   10.0  4.4
# 4 2009-12-26 00:23:38.570000+00:00    14.001     92.862   42.6  5.0
#
#                            place
# 0                         Bhutan
# 1           northwestern Kashmir
# 2    Myanmar-India border region
# 3                 western Xizang
# 4  Andaman Islands, India region

# %%
diction={}
new_df.drop(['place'], axis =1 , inplace = True)
sns.pairplot(new_df,vars=new_df.columns[1:])

# %%
sns.violinplot(new_df['mag'],orient='v')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# <AxesSubplot:xlabel='mag'>

# %%
new_df.plot(x='time',y='mag',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='time'>

# %%
for i in range(2000,2020,5):
    mask = (new_df['time'] > str(i+1)+'-1-1') & (new_df['time'] <= str(i+5)+'-12-31')
    diction.update({(str(i+1)+'-'+str(i+5)):new_df.loc[mask].reset_index().drop(columns=['index'])})
diction['2001-2005'].head()
# Out:
#                               time  latitude  longitude  depth  mag
# 0 2005-12-30 23:56:04.650000+00:00     5.508     94.546   49.5  4.6
# 1 2005-12-30 19:47:31.340000+00:00    11.524     93.553   30.0  3.8
# 2 2005-12-30 19:31:59.800000+00:00    36.250     71.262  186.4  3.8
# 3 2005-12-30 15:18:14.030000+00:00    36.660     71.108  224.2  4.5
# 4 2005-12-30 11:13:43.510000+00:00    36.536     71.063  192.6  4.5

# %%
mean_mag=[]
time=[]
interval=[]
sqrt_dE=[] 
b=[]
a=[]
niu=[]
delta_M=[]
max_mag=[]
for key in diction:
    interval+=[key]
    time+=[diction[key].time.max()-diction[key].time.min()]
    mean_mag+=[diction[key].mag.mean()]
    sqrt_dE+=[sum((10**(11.8+1.5*diction[key].mag))**0.5)]
    n=len(diction[key])
    Ni=[]
    for i in range(0,len(diction[key]),1):
        Ni+=[(diction[key].mag[i]<=diction[key].mag).sum()]
    sum_1=0
    for i in range(0,len(diction[key]),1):
        sum_1+=diction[key].mag[i]*np.log10(Ni[i])
    sum_mi=sum(diction[key].mag)
    sum_ni=0
    for i in range(0,len(diction[key]),1):
        sum_ni+=np.log10(Ni[i])
    sum_mi2=sum(diction[key].mag**2)
    b_temp=0
    b_temp=(n*sum_1-sum_mi*sum_ni)/(sum_mi**2-n*sum_mi2)
    b+=[b_temp]
    a_temp=0
    for i in range(0,len(diction[key]),1):
        a_temp+=(np.log(Ni[i])+b_temp*diction[key].mag[i])/n
    a+=[a_temp]
    niu_temp=0
    for i in range(0,len(diction[key]),1):
        niu_temp+=((np.log(Ni[i])-(a_temp-b_temp*diction[key].mag[i]))**2/(n-1))
    niu+=[niu_temp]
    delta_M+=[abs(diction[key].mag.max()-a_temp/b_temp)/10]
    max_mag+=[diction[key].mag.max()]
time=pd.to_timedelta(time, errors='coerce').days
sqrt_dE = [i / j for i, j in zip(sqrt_dE , time)]
df=pd.DataFrame({'period':interval,
                'T':time,
                'mean_mag':mean_mag,
                'Speed':sqrt_dE,
                'b':b,
                'niu':niu,
                'delta_M':delta_M,
                'max_mag': max_mag,
                })
df.head()
# Out:
#       period     T  mean_mag         Speed         b       niu   delta_M  \
# 0  2001-2005  1823  4.446800  9.769447e+09  0.814042  0.358947  0.621844
# 1  2006-2010  1823  4.325855  5.429726e+09  0.807539  0.351617  0.600057
# 2  2011-2015  1822  4.456482  4.528406e+09  1.042164  0.319705  0.344146
# 3  2016-2020   730  4.432896  3.130998e+09  1.102924  0.320471  0.291965
#
#    max_mag
# 0      7.8
# 1      7.5
# 2      7.8
# 3      6.9

# %%
df.plot(x='period',y='mean_mag',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='period'>

# %%
df.to_csv(r'quakes_toTrain.csv', index = None, header=True)
import numpy as np
import pandas as pd
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.metrics import mean_squared_error
get_ipython().run_line_magic('matplotlib', 'inline')
df1 = pd.read_csv('/kaggle/working/quakes_toTrain.csv')
df1.dtypes
# Out:
# period       object
# T             int64
# mean_mag    float64
# Speed       float64
# b           float64
# niu         float64
# delta_M     float64
# max_mag     float64
# dtype: object

# %%
temp=[]
for i in range(len(df1.period)):
    temp += [pd.to_datetime(df1.period[i][:4] , format = '%Y')]
df1['period'] = temp;
data = df1.drop(['period'], axis=1)
data.index = df1.period
data.head()
# Out:
#                T  mean_mag         Speed         b       niu   delta_M  \
# period
# 2001-01-01  1823  4.446800  9.769447e+09  0.814042  0.358947  0.621844
# 2006-01-01  1823  4.325855  5.429726e+09  0.807539  0.351617  0.600057
# 2011-01-01  1822  4.456482  4.528406e+09  1.042164  0.319705  0.344146
# 2016-01-01   730  4.432896  3.130998e+09  1.102924  0.320471  0.291965
#
#             max_mag
# period
# 2001-01-01      7.8
# 2006-01-01      7.5
# 2011-01-01      7.8
# 2016-01-01      6.9

# %%
plt.rcParams["figure.figsize"] = (20,3)
data.mean_mag.plot()
data.max_mag.plot()
pyplot.show()

# %%
df1.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'period'}>,
#         <AxesSubplot:title={'center':'T'}>,
#         <AxesSubplot:title={'center':'mean_mag'}>],
#        [<AxesSubplot:title={'center':'Speed'}>,
#         <AxesSubplot:title={'center':'b'}>,
#         <AxesSubplot:title={'center':'niu'}>],
#        [<AxesSubplot:title={'center':'delta_M'}>,
#         <AxesSubplot:title={'center':'max_mag'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
autocorrelation_plot(data.mean_mag)
autocorrelation_plot(data.max_mag)
pyplot.show()

# %%
data.corr()
# Out:
#                  T  mean_mag     Speed         b       niu   delta_M   max_mag
# T         1.000000 -0.191919  0.601874 -0.702484  0.559397  0.674593  0.942665
# mean_mag -0.191919  1.000000  0.113221  0.537452 -0.434119 -0.489042  0.145944
# Speed     0.601874  0.113221  1.000000 -0.771395  0.838900  0.810124  0.661371
# b        -0.702484  0.537452 -0.771395  1.000000 -0.971015 -0.996891 -0.538043
# niu       0.559397 -0.434119  0.838900 -0.971015  1.000000  0.985815  0.432716
# delta_M   0.674593 -0.489042  0.810124 -0.996891  0.985815  1.000000  0.527636
# max_mag   0.942665  0.145944  0.661371 -0.538043  0.432716  0.527636  1.000000

# %%
data.mean_mag.plot()
data.max_mag.plot()
pyplot.show()

# %%
data
# Out:
#                T  mean_mag         Speed         b       niu   delta_M  \
# period
# 2001-01-01  1823  4.446800  9.769447e+09  0.814042  0.358947  0.621844
# 2006-01-01  1823  4.325855  5.429726e+09  0.807539  0.351617  0.600057
# 2011-01-01  1822  4.456482  4.528406e+09  1.042164  0.319705  0.344146
# 2016-01-01   730  4.432896  3.130998e+09  1.102924  0.320471  0.291965
#
#             max_mag
# period
# 2001-01-01      7.8
# 2006-01-01      7.5
# 2011-01-01      7.8
# 2016-01-01      6.9
