# %%
# !sudo pip install yfinance
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import yfinance
import seaborn as sns
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.8/dist-packages (0.1.74)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.23.3)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.8/dist-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.5.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.26->yfinance) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.26->yfinance) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.26->yfinance) (2019.11.28)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.24.0->yfinance) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.14.0)

# %%
BND = yfinance.download("BND")
BND
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2007-04-10  75.070000  75.260002  75.000000  75.239998  47.045074    35000
# 2007-04-11  75.160004  75.290001  75.029999  75.040001  46.920044    87700
# 2007-04-12  75.059998  75.080002  74.959999  75.029999  46.913795    78100
# 2007-04-13  75.040001  75.070000  74.849998  74.910004  46.838776    18000
# 2007-04-16  74.989998  74.989998  74.940002  74.980003  46.882519    52700
# ...               ...        ...        ...        ...        ...      ...
# 2022-09-19  72.989998  73.180000  72.910004  73.110001  73.110001  6374900
# 2022-09-20  72.709999  72.879997  72.620003  72.750000  72.750000  4750500
# 2022-09-21  72.820000  72.989998  72.440002  72.949997  72.949997  6360300
# 2022-09-22  72.480003  72.489998  72.110001  72.199997  72.199997  5216100
# 2022-09-23  72.250000  72.250000  71.750000  72.000000  72.000000  6885149
#
# [3894 rows x 6 columns]

# %%
BND.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2007-04-10  75.070000  75.260002  75.000000  75.239998  47.045074   35000
# 2007-04-11  75.160004  75.290001  75.029999  75.040001  46.920044   87700
# 2007-04-12  75.059998  75.080002  74.959999  75.029999  46.913795   78100
# 2007-04-13  75.040001  75.070000  74.849998  74.910004  46.838776   18000
# 2007-04-16  74.989998  74.989998  74.940002  74.980003  46.882519   52700

# %%
BND.tail()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-09-19  72.989998  73.180000  72.910004  73.110001  73.110001  6374900
# 2022-09-20  72.709999  72.879997  72.620003  72.750000  72.750000  4750500
# 2022-09-21  72.820000  72.989998  72.440002  72.949997  72.949997  6360300
# 2022-09-22  72.480003  72.489998  72.110001  72.199997  72.199997  5216100
# 2022-09-23  72.250000  72.250000  71.750000  72.000000  72.000000  6885149

# %%
BND.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3894 entries, 2007-04-10 to 2022-09-23
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3894 non-null   float64
#  1   High       3894 non-null   float64
#  2   Low        3894 non-null   float64
#  3   Close      3894 non-null   float64
#  4   Adj Close  3894 non-null   float64
#  5   Volume     3894 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 213.0 KB

# %%
BND.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3894.000000  3894.000000  3894.000000  3894.000000  3894.000000
# mean     81.345408    81.462925    81.209561    81.341199    66.796989
# std       3.344949     3.319520     3.389163     3.344058    10.273648
# min      70.250000    71.589996    67.000000    69.959999    46.131142
# 25%      79.279999    79.360001    79.162502    79.269997    59.358250
# 50%      81.570000    81.674999    81.459999    81.559998    67.378475
# 75%      83.639999    83.757502    83.540001    83.639999    72.324051
# max      89.550003    90.910004    89.440002    89.480003    85.401474
#
#              Volume
# count  3.894000e+03
# mean   2.269748e+06
# std    2.241623e+06
# min    0.000000e+00
# 25%    7.496000e+05
# 50%    1.581950e+06
# 75%    3.037475e+06
# max    2.479270e+07

# %%
data = sns.load_dataset("iris") 
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
data = sns.load_dataset("iris") 
  
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
plt.title('Title using Matplotlib Function')
  
plt.show()

# %%
data = sns.load_dataset("iris") 
  
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
plt.xlim(5)
  
plt.show()

# %%
data = sns.load_dataset("iris")

sns.lineplot(x="sepal_length", y="sepal_width", data=data)

sns.despine()
plt.show()

# %%
data = sns.load_dataset("iris") 
  
plt.figure(figsize = (2, 4))
  
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
sns.despine()
  
plt.show()

# %%
data = sns.load_dataset("iris") 
  
sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
sns.set_context("paper")
  
plt.show()

# %%
data = sns.load_dataset("iris") 
  
  
def plot():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data) 
  
with sns.axes_style('darkgrid'):
      
    plt.subplot(211)
    plot()
      
plt.subplot(212)
plot()

# %%
data = sns.load_dataset("iris") 
  
def plot():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  
# setting the default color palette
sns.set_palette('vlag')
plt.subplot(211)
  

plot()
  
sns.set_palette('Accent')
plt.subplot(212)
plot()
  
plt.show()

# %%
data = sns.load_dataset("iris")
  
def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  
# Creating a new figure with width = 5 inches
fig = plt.figure(figsize =(5, 4)) 
  
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
  
graph()
  
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
  
graph()
  
plt.show()

# %%
data = sns.load_dataset("iris") 
  
def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  
# Adding the subplot at the specified
plt.subplot(121)
graph()
  

plt.subplot(122)
graph()
  
plt.show()

# %%
data = sns.load_dataset("iris")
  
def graph():
    sns.lineplot(x="sepal_length", y="sepal_width", data=data)
  
# adding the subplots
axes1 = plt.subplot2grid (
  (7, 1), (0, 0), rowspan = 2,  colspan = 1) 
graph()
  
axes2 = plt.subplot2grid (
  (7, 1), (2, 0), rowspan = 2, colspan = 1) 
graph()
    
axes3 = plt.subplot2grid (
  (7, 1), (4, 0), rowspan = 2, colspan = 1)
graph()

# %%
data = sns.load_dataset("iris")
  
plot = sns.FacetGrid(data, col="species")
plot.map(plt.plot, "sepal_width")
  
plt.show()

# %%
data = sns.load_dataset("flights")
  
plot = sns.PairGrid(data)
plot.map(plt.plot)
  
plt.show()

# %%
data = sns.load_dataset("iris")
  
sns.lineplot(x='sepal_length', y='species', data=data)
plt.show()

# %%
data = sns.load_dataset("iris")
  
sns.barplot(x='species', y='sepal_length', data=data)
plt.show()

# %%
data = sns.load_dataset("iris")
  
sns.countplot(x='species', data=data)
plt.show()
