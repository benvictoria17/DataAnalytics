# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Data
COVID19Sentiments = pd.read_csv('data/COVID-19_Sentiments.csv')

COVID19Sentiments
# Out:
#                     Text_Id  \
# 0       1241032866567356417
# 1       1241032867699765249
# 2       1241032875102703616
# 3       1241032877099237379
# 4       1241032870405128192
# ...                     ...
# 324474  1266955718772559873
# 324475  1266955725936287746
# 324476  1266955735537266688
# 324477  1266955733297397761
# 324478  1266955733255536640
#
#                                                      Text  \
# 0       RT @theskindoctor13: Shaheen Bagh is still on....
# 1       RT @theskindoctor13: Shaheen Bagh is still on....
# 2       RT @SmokingSkills_: Daughter of an IAS, son of...
# 3       RT @narendramodi: The young actors have someth...
# 4       RT @theskindoctor13: Shaheen Bagh is still on....
# ...                                                   ...
# 324474  For the first time perhaps, someone to took ti...
# 324475  RT @hvgoenka: 70 year Kamalamma offered an NGO...
# 324476  Odisha reports 129 new #COVID19 positive cases...
# ...

# %%
COVID19Sentiments.head()
# Out:
#                Text_Id                                               Text  \
# 0  1241032866567356417  RT @theskindoctor13: Shaheen Bagh is still on....
# 1  1241032867699765249  RT @theskindoctor13: Shaheen Bagh is still on....
# 2  1241032875102703616  RT @SmokingSkills_: Daughter of an IAS, son of...
# 3  1241032877099237379  RT @narendramodi: The young actors have someth...
# 4  1241032870405128192  RT @theskindoctor13: Shaheen Bagh is still on....
#
#                              Date              Location  Sentiments
# 0  Fri Mar 20 16:04:27 +0000 2020  Uttar Pradesh, India       0.000
# 1  Fri Mar 20 16:04:27 +0000 2020                Mumbai       0.000
# 2  Fri Mar 20 16:04:29 +0000 2020        Jodhpur, India       0.350
# 3  Fri Mar 20 16:04:29 +0000 2020      Gurugram, Bharat       0.125
# 4  Fri Mar 20 16:04:28 +0000 2020      New Delhi, India       0.000

# %%
COVID19Sentiments.tail()
# Out:
#                     Text_Id  \
# 324474  1266955718772559873
# 324475  1266955725936287746
# 324476  1266955735537266688
# 324477  1266955733297397761
# 324478  1266955733255536640
#
#                                                      Text  \
# 324474  For the first time perhaps, someone to took ti...
# 324475  RT @hvgoenka: 70 year Kamalamma offered an NGO...
# 324476  Odisha reports 129 new #COVID19 positive cases...
# 324477  @nidhiindiatv Happy rainy day ..\n\nHope rain ...
# 324478  RT @nsui: Kerala Student Union activists did S...
#
#                                   Date              Location  Sentiments
# 324474  Sun May 31 04:52:36 +0000 2020                 India    0.446429
# 324475  Sun May 31 04:52:38 +0000 2020         Nagpur, India   -0.250000
# 324476  Sun May 31 04:52:40 +0000 2020      New Delhi, India    0.057576
# 324477  Sun May 31 04:52:40 +0000 2020  Muzaffarnagar, India    0.200000
# 324478  Sun May 31 04:52:40 +0000 2020      New Delhi, India    0.000000

# %%
COVID19Sentiments.describe()
# Out:
#             Text_Id     Sentiments
# count  3.244790e+05  318989.000000
# mean   1.251673e+18       0.073588
# std    7.250714e+15       0.258904
# min    1.241033e+18      -1.000000
# 25%    1.246004e+18       0.000000
# 50%    1.249943e+18       0.000000
# 75%    1.256807e+18       0.191667
# max    1.266956e+18       1.000000

# %%
COVID19Sentiments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324479 entries, 0 to 324478
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Text_Id     324479 non-null  int64
#  1   Text        324479 non-null  object
#  2   Date        324479 non-null  object
#  3   Location    324479 non-null  object
#  4   Sentiments  318989 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 12.4+ MB

# %%
COVID19Sentiments.info
# Out:
# <bound method DataFrame.info of                     Text_Id  \
# 0       1241032866567356417
# 1       1241032867699765249
# 2       1241032875102703616
# 3       1241032877099237379
# 4       1241032870405128192
# ...                     ...
# 324474  1266955718772559873
# 324475  1266955725936287746
# 324476  1266955735537266688
# 324477  1266955733297397761
# 324478  1266955733255536640
#
#                                                      Text  \
# 0       RT @theskindoctor13: Shaheen Bagh is still on....
# 1       RT @theskindoctor13: Shaheen Bagh is still on....
# 2       RT @SmokingSkills_: Daughter of an IAS, son of...
# 3       RT @narendramodi: The young actors have someth...
# 4       RT @theskindoctor13: Shaheen Bagh is still on....
# ...                                                   ...
# 324474  For the first time perhaps, someone to took ti...
# 324475  RT @hvgoenka: 70 year Kamalamma offered an NGO...
# 324476  Odisha reports 129 new #COVID19 positive cases...
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("COVID19Sentiments.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("COVID19Sentiments.db")
c = conn.cursor()

# %%
COVID19Sentiments.to_sql("COVID19Sentiments", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM COVID19Sentiments""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   1241032866567356417,
#   "RT @theskindoctor13: Shaheen Bagh is still on.\n\nMosques are open.\n\nMuIIahs are saying Corona won't harm if you read qalma.\n\nTiktokiye are m…",
#   'Fri Mar 20 16:04:27 +0000 2020',
#   'Uttar Pradesh, India',
#   0.0),
#  (1,
#   1241032867699765249,
#   "RT @theskindoctor13: Shaheen Bagh is still on.\n\nMosques are open.\n\nMuIIahs are saying Corona won't harm if you read qalma.\n\nTiktokiye are m…",
#   'Fri Mar 20 16:04:27 +0000 2020',
#   'Mumbai',
#   0.0),
#  (2,
#   1241032875102703616,
#   'RT @SmokingSkills_: Daughter of an IAS, son of a Kolkata officer, son of Railway official, and a famous elite singer. All these are very in…',
#   'Fri Mar 20 16:04:29 +0000 2020',
#   'Jodhpur, India',
#   0.35),
#  (3,
#   1241032877099237379,
#   "RT @narendramodi: The young actors have something to say..\n\nIts time to be 'Zyada Savdhan' and do 'Corona ka Punchnama'! #IndiaFightsCorona…",
#   'Fri Mar 20 16:04:29 +0000 2020',
# ...

# %%
COVID19Sentiments.to_excel("COVID19Sentiments.xlsx")

pd.read_excel("COVID19Sentiments.xlsx")
# Out:
#         Unnamed: 0              Text_Id  \
# 0                0  1241032866567355904
# 1                1  1241032867699764992
# 2                2  1241032875102704128
# 3                3  1241032877099237120
# 4                4  1241032870405127936
# ...            ...                  ...
# 324474      324474  1266955718772559872
# 324475      324475  1266955725936288000
# 324476      324476  1266955735537266944
# 324477      324477  1266955733297398016
# 324478      324478  1266955733255536896
#
#                                                      Text  \
# 0       RT @theskindoctor13: Shaheen Bagh is still on....
# 1       RT @theskindoctor13: Shaheen Bagh is still on....
# 2       RT @SmokingSkills_: Daughter of an IAS, son of...
# 3       RT @narendramodi: The young actors have someth...
# 4       RT @theskindoctor13: Shaheen Bagh is still on....
# ...                                                   ...
# 324474  For the first time perhaps, someone to took ti...
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('SBSPS-Challenge-1505-Sentiment-Analysis-of-COVID-19-Tweets-Dashboard-For-Visualization', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('SBSPS-Challenge-1505-Sentiment-Analysis-of-COVID-19-Tweets-Dashboard-For-Visualization')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
