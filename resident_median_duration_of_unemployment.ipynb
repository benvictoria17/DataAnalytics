# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/panda/blob/master/resident_median_duration_of_unemployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
unemployment = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/panda/master/python%20pandas%20data/resident-median-duration-of-unemployment/median-duration-of-unemployment-among-unemployed-residents.csv")

unemployment
# Out:
#     year  median_duration_of_unemployment
# 0   1991                                8
# 1   1992                                6
# 2   1993                                6
# 3   1994                                4
# 4   1996                                4
# 5   1997                                8
# 6   1998                                8
# 7   1999                               12
# 8   2001                                8
# 9   2002                               12
# 10  2003                               12
# 11  2004                               12
# 12  2006                                8
# 13  2007                                8
# 14  2008                                6
# 15  2009                               10
# 16  2010                                8
# 17  2011                                8
# 18  2012                                8
# 19  2013                                8
# 20  2014                                8
# ...

# %%
unemployment.head(20)
# Out:
#     year  median_duration_of_unemployment
# 0   1991                                8
# 1   1992                                6
# 2   1993                                6
# 3   1994                                4
# 4   1996                                4
# 5   1997                                8
# 6   1998                                8
# 7   1999                               12
# 8   2001                                8
# 9   2002                               12
# 10  2003                               12
# 11  2004                               12
# 12  2006                                8
# 13  2007                                8
# 14  2008                                6
# 15  2009                               10
# 16  2010                                8
# 17  2011                                8
# 18  2012                                8
# 19  2013                                8

# %%
unemployment.tail()
# Out:
#     year  median_duration_of_unemployment
# 20  2014                                8
# 21  2015                                8
# 22  2016                                8
# 23  2017                                8
# 24  2018                                8

# %%
unemployment.describe()
# Out:
#               year  median_duration_of_unemployment
# count    25.000000                        25.000000
# mean   2005.040000                         8.160000
# std       8.438404                         2.154066
# min    1991.000000                         4.000000
# 25%    1998.000000                         8.000000
# 50%    2006.000000                         8.000000
# 75%    2012.000000                         8.000000
# max    2018.000000                        12.000000

# %%
import sqlite3

# %%
conn = sqlite3.connect("unemployment.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("unemployment.db")
c = conn.cursor()

# %%
unemployment.to_sql("unemployment", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM unemployment""")
rows = c.fetchall()
rows
# Out:
# [(0, 1991, 8),
#  (1, 1992, 6),
#  (2, 1993, 6),
#  (3, 1994, 4),
#  (4, 1996, 4),
#  (5, 1997, 8),
#  (6, 1998, 8),
#  (7, 1999, 12),
#  (8, 2001, 8),
#  (9, 2002, 12),
#  (10, 2003, 12),
#  (11, 2004, 12),
#  (12, 2006, 8),
#  (13, 2007, 8),
#  (14, 2008, 6),
#  (15, 2009, 10),
#  (16, 2010, 8),
#  (17, 2011, 8),
#  (18, 2012, 8),
#  (19, 2013, 8),
#  (20, 2014, 8),
#  (21, 2015, 8),
#  (22, 2016, 8),
#  (23, 2017, 8),
#  (24, 2018, 8)]

# %%
unemployment.to_excel("unemployment.xls")

pd.read_excel("unemployment.xls")
# Out:
#     Unnamed: 0  year  median_duration_of_unemployment
# 0            0  1991                                8
# 1            1  1992                                6
# 2            2  1993                                6
# 3            3  1994                                4
# 4            4  1996                                4
# 5            5  1997                                8
# 6            6  1998                                8
# 7            7  1999                               12
# 8            8  2001                                8
# 9            9  2002                               12
# 10          10  2003                               12
# 11          11  2004                               12
# 12          12  2006                                8
# 13          13  2007                                8
# 14          14  2008                                6
# 15          15  2009                               10
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('resident-median-duration-of-unemployment', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('resident-median-duration-of-unemployment')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.
